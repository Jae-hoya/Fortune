# %% [markdown]
# 1. manse_tool_agent
# 2. retriever_tool_agent
# 3. 일반 답변에 대한 web search

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Enhanced Retriever 및 Chain (Query Expansion 포함)

# %%
# 기존 Retriever 및 Chain (원래대로 복원)
from pdf_retriever_saju import pdf_rag_chain, compression_retriever

pdf_retriever = compression_retriever()
pdf_chain = pdf_rag_chain()

# %%
# Manse_tool

# %%
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent
from manse_6 import calculate_saju_tool

# Agent 생성 시 tools 리스트에 추가

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
tools = [calculate_saju_tool]  # 사주 툴 추가

manse_tool_agent = create_react_agent(llm, tools)

# %%
from langchain_core.tools.retriever import create_retriever_tool
from langchain_core.prompts import PromptTemplate


# PDF 문서를 기반으로 검색 도구 생성
retriever_tool = create_retriever_tool(
    pdf_retriever,
    "pdf_retriever",
    "A tool for searching information related to Saju (Four Pillars of Destiny)",
    document_prompt=PromptTemplate.from_template(
        "<document><context>{page_content}</context><metadata><source>{source}</source><page>{page}</page></metadata></document>"
    ),
)

# %%
retriever_tools = [retriever_tool]

# %%
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI
from langchain_core.prompts import load_prompt, ChatPromptTemplate, MessagesPlaceholder

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

# retriever_tool_agent = create_react_agent(llm, retriever_tools)

base_prompt = load_prompt("prompt/saju-rag-promt_2.yaml")
# base_prompt = load_prompt("prompt/saju-rag-promt_korea3.yaml")
saju_prompt = ChatPromptTemplate.from_messages([
    ("system", base_prompt.template),
    MessagesPlaceholder("messages"),
])
retriever_tool_agent = create_react_agent(llm, retriever_tools, prompt=saju_prompt)

# %%
from query_expansion_agent import get_query_expansion_node

query_expansion_node = get_query_expansion_node()

# %%
# Query Expansion Agent (manse_tool처럼 간단하게)
from query_expansion_agent import get_query_expansion_agent

query_expansion_agent = get_query_expansion_agent()

# %%
from langchain_teddynote.tools.tavily import TavilySearch
from langchain.tools import DuckDuckGoSearchRun, DuckDuckGoSearchResults

tavily_tool = TavilySearch(
    max_results=5,
    include_domains=["namu.wiki", "wikipedia.org"]
)

duck_tool = DuckDuckGoSearchResults(
    max_results=5,
)

# %%
# web_tool = [tavily_tool]
web_tool = [tavily_tool, duck_tool]

# %%
prompt = """
사주 또는 사주 오행의 개념적 질문이나, 일상 질문이 들어오면, web search를 통해 답합니다.
"""
web_tool_agent = create_react_agent(llm, tools=web_tool, prompt=prompt)

# %%
# GeneralQA Tool
from langchain.tools import  tool
from langchain_google_genai import ChatGoogleGenerativeAI
google_llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

@tool
def general_qa_tool(query: str) -> str:
    """
    일반적인 질문이나 상식적인 내용에 대해 답변합니다. 사주와 관련 없는 모든 질문에 사용할 수 있습니다.
    """
    google_llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")
    return google_llm.invoke(query)

# %%
from langgraph.prebuilt import create_react_agent

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
general_qa_tools = [general_qa_tool]

prompt = "일반적인 질문이나 상식적인 내용에 대해 답변합니다."

general_qa_agent = create_react_agent(llm, tools=general_qa_tools, prompt=prompt)

# %% [markdown]
# # Agent node 생성

# %%
from langchain_core.messages import HumanMessage

# 지정한 agent와 name을 사용하여 agent 노드를 생성
def agent_node(state, agent, name):

    # agent 호출
    agent_response = agent.invoke(state)
    # agent의 마지막 메시지를 HumanMessage로 변환하여 반환
    return {
        "messages": [
            HumanMessage(content=agent_response["messages"][-1].content, name=name)
        ]
    }

# %% [markdown]
# # node 생성

# %%
import functools

manse_tool_agent_node = functools.partial(agent_node, agent=manse_tool_agent, name="ManseTool")
retriever_tool_agent_node = functools.partial(agent_node, agent=retriever_tool_agent, name="RetrieverTool")
web_tool_agent_node = functools.partial(agent_node, agent=web_tool_agent, name="WebTool")
general_qa_agent_node = functools.partial(agent_node, agent=general_qa_agent, name="GeneralQA")

# %% [markdown]
# # Agent Supervisor 생성

# %%
from pydantic import BaseModel
from typing import Literal

# 멤버 Agent 목록 정의 (QueryExpansion, GeneralQA 추가)
members = ["SajuExpert", "WebTool", "GeneralQA"]

# 다음 작업자 선택 옵션 목록 정의
options_for_next = ["FINISH"] + members

# 작업자 선택 응답 모델 정의: 다음 작업자를 선택하거나 작업 완료를 나타냄
class RouteResponse(BaseModel):
    next: Literal[*options_for_next]

# %%
from langchain_openai import ChatOpenAI
from datetime import datetime

# 시스템 프롬프트 정의: 작업자 간의 대화를 관리하는 감독자 역할
system_prompt = (
    "Today's date is {current_datetime}.\n"
    "You are a supervisor tasked with orchestrating a multi-step workflow with the following specialized agents: {members}.\n"
    "The tools are:\n"
    "- SajuExpert: This agent is an expert in Saju (Four Pillars of Destiny). It handles everything from calculating the Saju from birth information to providing detailed interpretations and analysis. Use this for any query that involves birth dates/times or asks for a Saju reading.\n"
    "- WebTool: For answering general or conceptual questions about Saju, or handling everyday/non-specialized queries, by searching the web. Use this if the user is asking what Saju is, but not for a personal reading.\n"
    "- GeneralQA: For answering general questions that are NOT related to Saju at all (e.g., programming, science, general knowledge, etc.).\n\n"
    "Your job is to route the user's request to the most appropriate tool:\n"
    "   - If the user input contains birth information or asks for a fortune reading, call SajuExpert.\n"
    "   - If the input is a general or conceptual question about Saju, call WebTool.\n"
    "   - If the input is completely unrelated to Saju, call GeneralQA.\n"
    "After the agent has finished, respond with FINISH if the task is complete."
)


# ChatPromptTemplate 생성
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        MessagesPlaceholder(variable_name="messages"),
        (
            "system",
            "Given the conversation above, who should act next? "
            "Or should we FINISH? Select one of: {options}",
        ),
    ]
)

# LLM 초기화
llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

def supervisor_agent(state):
    # 현재 시간 포맷팅
    current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    
    # 프롬프트와 LLM을 결합하여 체인 구성
    supervisor_chain = (
        prompt.partial(
            options=str(options_for_next),
            members=", ".join(members),
            current_datetime=current_time
        ) | llm.with_structured_output(RouteResponse)
    )
    
    # Agent 호출하고 'next' 키로 딕셔너리 반환
    route_response = supervisor_chain.invoke(state)
    return {"next": route_response.next}

# %%
# from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
# from langchain_openai import ChatOpenAI


# # 시스템 프롬프트 정의: 작업자 간의 대화를 관리하는 감독자 역할
# system_prompt = (
#     "You are a supervisor tasked with orchestrating a multi-step workflow with the following specialized agents: {members}.\n"
#     "The tools are:\n"
#     "- ManseTool: For extracting and calculating Saju information (year, month, day, hour pillars) from user input (such as date/time of birth).\n"
#     "- RetrieverTool: For interpreting Saju details and providing in-depth Saju or Four Pillars explanations and analysis based on calculated information. **RetrieverTool MUST always receive its input DIRECTLY from the output of ManseTool. It must NEVER be called without a valid ManseTool result.**\n"
#     "- WebTool: For answering general or conceptual questions about Saju, or handling everyday/non-specialized queries, by searching the web.\n"
#     "- GeneralQA: For answering general questions that are NOT related to Saju at all (e.g., programming, science, general knowledge, weather, etc.).\n\n"

#     "Your job is to:\n"
#     "1. Route the user's request to the most appropriate tool:\n"
#     "   - If the user input contains raw birth information (date/time, etc.), ALWAYS call ManseTool FIRST.\n"
#     "   - IMPORTANT: **After using ManseTool, you MUST ALWAYS call RetrieverTool next to interpret the calculated Saju results, before finishing or moving to any other step. Do NOT skip this step.**\n"
#     "   - **RetrieverTool can only be executed using the direct output from ManseTool, and must NEVER be called in isolation.**\n"
#     "   - If the input is purely a general, conceptual, or non-specialized Saju question, and does NOT require document search, call WebTool.\n"
#     "   - If the input is completely unrelated to Saju, call GeneralQA.\n"
#     "2. NEVER finish the workflow after ManseTool alone. Always pass the result to RetrieverTool before considering FINISH.\n"
#     "3. For completely non-Saju questions, use GeneralQA directly.\n"
#     "4. After all needed steps are complete, respond with FINISH.\n"
#     "You MUST always decide the most logical next agent for the task and strictly follow this tool sequence."

# )


# # ChatPromptTemplate 생성
# prompt = ChatPromptTemplate.from_messages(
#     [
#         ("system", system_prompt),
#         MessagesPlaceholder(variable_name="messages"),
#         (
#             "system",
#             "Given the conversation above, who should act next? "
#             "Or should we FINISH? Select one of: {options}",
#         ),
#     ]
# ).partial(options=str(options_for_next), members=", ".join(members))


# # LLM 초기화
# llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)


# # Supervisor Agent 생성
# def supervisor_agent(state):
#     # 프롬프트와 LLM을 결합하여 체인 구성
#     supervisor_chain = prompt | llm.with_structured_output(RouteResponse)
#     # Agent 호출
#     return supervisor_chain.invoke(state)

# %%
import operator
from typing import Sequence, Annotated
from typing_extensions import TypedDict

from langchain_core.messages import BaseMessage


# 상태 정의
class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage], operator.add]  # 메시지
    next: str  # 다음으로 라우팅할 에이전트

# %%
# ... existing code ...
from langgraph.graph import END, StateGraph, START
from langgraph.checkpoint.memory import MemorySaver

# 1. Manse -> Retriever Sub-graph 생성
saju_expert_workflow = StateGraph(AgentState)

# Sub-graph에 노드 추가 (기존 노드 재사용)
saju_expert_workflow.add_node("manse", manse_tool_agent_node)
saju_expert_workflow.add_node("retriever", retriever_tool_agent_node)

# Sub-graph 엣지 연결
saju_expert_workflow.add_edge(START, "manse")
saju_expert_workflow.add_edge("manse", "retriever")
saju_expert_workflow.add_edge("retriever", END)

# Sub-graph를 컴파일하여 Runnable로 만듭니다.
saju_expert_graph = saju_expert_workflow.compile()


# 2. 메인 그래프 생성
workflow = StateGraph(AgentState)

# 그래프에 노드 추가: ManseTool과 RetrieverTool을 SajuExpert로 대체
workflow.add_node("SajuExpert", saju_expert_graph)
workflow.add_node("QueryExpansion", query_expansion_node)
workflow.add_node("WebTool", web_tool_agent_node)
workflow.add_node("GeneralQA", general_qa_agent_node)
workflow.add_node("Supervisor", supervisor_agent)



# 멤버 노드 > Supervisor 노드로 엣지 추가
for member in members:
    workflow.add_edge(member, "Supervisor")

# 조건부 엣지 추가
conditional_map = {k: k for k in members}
conditional_map["FINISH"] = END

def get_next(state):
    return state["next"]

# Supervisor 노드에서 조건부 엣지 추가
workflow.add_conditional_edges("Supervisor", get_next, conditional_map)

# 시작점
workflow.add_edge(START, "QueryExpansion")
workflow.add_edge("QueryExpansion", "Supervisor")

# 그래프 컴파일
graph = workflow.compile(checkpointer=MemorySaver())

# %%
graph

# %%
from IPython.display import display, Image
Image(graph.get_graph(xray=True).draw_mermaid_png())

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력

question = "1995년 3월 28일 남자, 12시 30분 출생 운세봐줘."

inputs = {
    "messages": [
        HumanMessage(
            content=question
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide a fortune reading for a male born on March 28, 1995, at 12:30 PM? I am interested in a detailed analysis of his Four Pillars of Destiny (Ba Zi) and how they may influence his personality, career prospects, and overall life path. Please include insights based on his birth chart analysis.1995년 3월 28일 남자, 12시 30분 출생 운세봐줘.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 을해
# 월주(月柱): 기묘
# 일주(日柱): 무오
# 시주(時柱): 무오
# 일간(日干): 무
# 현재 나이: 30세 / 한국식 나이: 31세
# 기준 시점: 2025-06-22 09:59:45
#
# === 오행 강약 ===
# 목: 39점
# 화: 20점
# 토: 68점
# 금: 0점
# 수: 10점
#
# === 십신 분석 ===
# 년주: 천간:정관, 지지:편재(70%), 지지:편관(30%)
# 월주: 천간:겁재, 지지:정관(100%)
# 일주: 지지:정인(70%), 지지:겁재(30%)
# 시주: 지지:정인(70%), 지지:겁재(30%)
#
# === 대운 (정밀 계산) ===
# 5세: 무인 (2000년 ~ 2009년)
# 15세: 정축 (2010년 ~ 2019년)
# 25세: 병자 (2020년 ~ 2029년)
# 35세: 을해 (2030년 ~ 2039년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주: 을해
# - 월주: 기묘
# - 일주: 무오
# - 시주: 무오
# - 일간: 무
# - 현재 나이: 30세 (한국식 31세)
#
# 오행 강약은 토가 가장 강하고, 목, 화, 수가 그 뒤를 잇고 있으며 금은 부족한 상태입니다.
#
# 십신 분석에서는 정관, 편재, 편관, 겁재, 정인 등의 기운이 혼재되어 있습니다.
#
# 대운은 현재 25세부터 2029년까지 병자 대운이 진행 중이며, 35세부터 을해 대운이 시작됩니다.
#
# 이 사주는 토의 기운이 강해 안정적이고 현실적인 성향이 강하며, 금의 기운이 부족해 결단력이나 추진력에서 보완이 필요할 수 있습니다. 대운의 흐름에 따라 인생의 중요한 전환점이 찾아올 수 있으니 참고하시기 바랍니다.
# ==================================================
# 🔄 Node: manse 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주: 을해
# - 월주: 기묘
# - 일주: 무오
# - 시주: 무오
# - 일간: 무
# - 현재 나이: 30세 (한국식 31세)
#
# 오행 강약은 토가 가장 강하고, 목, 화, 수가 그 뒤를 잇고 있으며 금은 부족한 상태입니다.
#
# 십신 분석에서는 정관, 편재, 편관, 겁재, 정인 등의 기운이 혼재되어 있습니다.
#
# 대운은 현재 25세부터 2029년까지 병자 대운이 진행 중이며, 35세부터 을해 대운이 시작됩니다.
#
# 이 사주는 토의 기운이 강해 안정적이고 현실적인 성향이 강하며, 금의 기운이 부족해 결단력이나 추진력에서 보완이 필요할 수 있습니다. 대운의 흐름에 따라 인생의 중요한 전환점이 찾아올 수 있으니 참고하시기 바랍니다.
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력 기준, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 2 + 2 + 3 + 0 + 1 = 8 (계산 유효)
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土)가 가장 강함(3점) → 안정적이고 현실적, 신중한 성향
# - 목(木)과 화(火)가 중간 수준(각 2점) → 성장과 발전, 열정과 활동성 보유
# - 수(水)는 약간 있음(1점) → 감성, 지혜, 융통성
# - 금(金)은 전혀 없음(0점) → 결단력, 추진력, 냉철함 부족 가능성
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목)은 편재(재물, 능력)
# - 년지 해(亥, 수)는 정인(지식, 보호)
# - 월간 기(己, 토)는 비견(자아, 경쟁)
# - 월지 묘(卯, 목)는 편관(권위, 도전)
# - 시간 무(戊, 토)는 비견(자아, 경쟁)
# - 시지 午(화)는 식신(창조, 표현)
#
# 십신이 다양하게 혼재되어 있어 재능과 경쟁심, 창의력, 보호받는 기운이 균형 있게 존재함.
#
# ---
#
# [4. 사주의 강약 및 성격 특성]
#
# - 토(土) 강세로 현실적이고 안정적인 성향이 강함
# - 목(木)과 화(火)의 조화로 성장욕구와 활동성이 있음
# - 금(金) 부족으로 인해 결단력과 추진력에서 보완 필요
# - 수(水)가 약간 있어 감성적이고 융통성도 일부 존재
# - 경쟁심과 창의력이 조화되어 있어 자기주장이 강하고 도전적임
#
# ---
#
# [5. 대운(大運) 및 세운(歲運) 분석]
#
# - 현재 대운: 25세부터 2029년까지 병자(丙子) 대운 진행 중
#   - 병(丙)은 화(火), 자(子)는 수(水) → 화와 수의 기운 보강
#   - 토가 강한 사주에 화와 수가 보완되어 균형을 맞춤
# - 35세부터 을해(乙亥) 대운 시작 → 목과 수의 기운 강화
# - 대운 흐름에 따라 인생의 중요한 전환점과 기회가 예상됨
#
# - 2023~2025년 세운은 병인(丙寅), 정묘(丁卯), 무진(戊辰) 등으로
#   - 화(火)와 목(木), 토(土) 기운이 보강되어 좋은 흐름
#   - 금(金) 부족 보완은 어려우나 전반적으로 성장과 발전 가능성 높음
#
# ---
#
# [6. 종합 요약 및 조언]
#
# - 토(土) 강세로 안정적이고 현실적인 성격, 책임감이 강함
# - 목(木)과 화(火)의 조화로 성장욕구와 활동성, 창의력 보유
# - 금(金) 부족으로 결단력과 추진력 보완 필요 → 금색 계열 옷 착용, 금속 관련 활동 권장
# - 대운과 세운이 화와 수를 보강하여 균형을 맞추고 있음
# - 경쟁심과 창의력이 조화되어 자기주장이 강하고 도전적임
# - 인생의 중요한 전환점이 대운에 따라 찾아오니 기회 포착에 주의
# - 건강과 인간관계에 있어 균형 유지가 중요함
#
# ---
#
# **출처:** ManseTool 사주 분석 결과 기반
#
# 필요시 추가 대운 및 세운 상세 분석 가능합니다.
# ==================================================
# 🔄 Node: retriever 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력 기준, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 2 + 2 + 3 + 0 + 1 = 8 (계산 유효)
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土)가 가장 강함(3점) → 안정적이고 현실적, 신중한 성향
# - 목(木)과 화(火)가 중간 수준(각 2점) → 성장과 발전, 열정과 활동성 보유
# - 수(水)는 약간 있음(1점) → 감성, 지혜, 융통성
# - 금(金)은 전혀 없음(0점) → 결단력, 추진력, 냉철함 부족 가능성
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목)은 편재(재물, 능력)
# - 년지 해(亥, 수)는 정인(지식, 보호)
# - 월간 기(己, 토)는 비견(자아, 경쟁)
# - 월지 묘(卯, 목)는 편관(권위, 도전)
# - 시간 무(戊, 토)는 비견(자아, 경쟁)
# - 시지 午(화)는 식신(창조, 표현)
#
# 십신이 다양하게 혼재되어 있어 재능과 경쟁심, 창의력, 보호받는 기운이 균형 있게 존재함.
#
# ---
#
# [4. 사주의 강약 및 성격 특성]
#
# - 토(土) 강세로 현실적이고 안정적인 성향이 강함
# - 목(木)과 화(火)의 조화로 성장욕구와 활동성이 있음
# - 금(金) 부족으로 인해 결단력과 추진력에서 보완 필요
# - 수(水)가 약간 있어 감성적이고 융통성도 일부 존재
# - 경쟁심과 창의력이 조화되어 있어 자기주장이 강하고 도전적임
#
# ---
#
# [5. 대운(大運) 및 세운(歲運) 분석]
#
# - 현재 대운: 25세부터 2029년까지 병자(丙子) 대운 진행 중
#   - 병(丙)은 화(火), 자(子)는 수(水) → 화와 수의 기운 보강
#   - 토가 강한 사주에 화와 수가 보완되어 균형을 맞춤
# - 35세부터 을해(乙亥) 대운 시작 → 목과 수의 기운 강화
# - 대운 흐름에 따라 인생의 중요한 전환점과 기회가 예상됨
#
# - 2023~2025년 세운은 병인(丙寅), 정묘(丁卯), 무진(戊辰) 등으로
#   - 화(火)와 목(木), 토(土) 기운이 보강되어 좋은 흐름
#   - 금(金) 부족 보완은 어려우나 전반적으로 성장과 발전 가능성 높음
#
# ---
#
# [6. 종합 요약 및 조언]
#
# - 토(土) 강세로 안정적이고 현실적인 성격, 책임감이 강함
# - 목(木)과 화(火)의 조화로 성장욕구와 활동성, 창의력 보유
# - 금(金) 부족으로 결단력과 추진력 보완 필요 → 금색 계열 옷 착용, 금속 관련 활동 권장
# - 대운과 세운이 화와 수를 보강하여 균형을 맞추고 있음
# - 경쟁심과 창의력이 조화되어 자기주장이 강하고 도전적임
# - 인생의 중요한 전환점이 대운에 따라 찾아오니 기회 포착에 주의
# - 건강과 인간관계에 있어 균형 유지가 중요함
#
# ---
#
# **출처:** ManseTool 사주 분석 결과 기반
#
# 필요시 추가 대운 및 세운 상세 분석 가능합니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력

question = "학업운 봐줘"

inputs = {
    "messages": [
        HumanMessage(
            content=question
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you please analyze my academic luck based on my Four Pillars of Destiny (Ba Zi)? I would like to understand how my birth chart influences my educational pursuits and what potential opportunities or challenges I may face in my studies.학업운 봐줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주를 바탕으로 학업운을 분석해보면 다음과 같습니다.
#
# 1. 지식과 학업을 상징하는 정인과 식신 기운이 존재합니다. 년지 해(亥, 수)는 정인으로 지식과 보호를 의미하며, 시지 午(화)는 식신으로 창의력과 표현력을 나타냅니다. 이는 학업에 대한 관심과 능력이 있음을 보여줍니다.
#
# 2. 오행 중 수(水) 기운이 약간 있으나 금(金) 기운이 부족한 편입니다. 금은 학문과 지혜, 집중력을 상징하므로 금 기운 부족은 집중력이나 세밀한 학습에 다소 어려움이 있을 수 있음을 의미합니다. 따라서 학습 시 집중력 향상을 위한 환경 조성이나 보완이 필요합니다.
#
# 3. 토(土) 기운이 강해 현실적이고 신중한 성향이 강합니다. 이는 꾸준한 노력과 성실함으로 학업에 임할 수 있는 좋은 기질입니다.
#
# 4. 대운에서 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 학업에 긍정적인 영향을 미칩니다. 특히 2023~2025년은 화와 목 기운이 좋아 학업과 자기계발에 좋은 시기입니다.
#
# 5. 경쟁심과 창의력이 조화되어 있어 새로운 지식을 탐구하고 도전하는 데 유리합니다.
#
# 종합적으로, 학업운은 꾸준한 노력과 성실함을 바탕으로 좋은 성과를 낼 수 있으나, 집중력 향상을 위한 환경 조성과 금 기운 보완이 필요합니다. 대운의 흐름도 학업에 긍정적인 영향을 주므로 현재 시기를 잘 활용하면 좋은 결과가 기대됩니다.
# ==================================================
# 🔄 Node: manse 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주를 바탕으로 학업운을 분석해보면 다음과 같습니다.
#
# 1. 지식과 학업을 상징하는 정인과 식신 기운이 존재합니다. 년지 해(亥, 수)는 정인으로 지식과 보호를 의미하며, 시지 午(화)는 식신으로 창의력과 표현력을 나타냅니다. 이는 학업에 대한 관심과 능력이 있음을 보여줍니다.
#
# 2. 오행 중 수(水) 기운이 약간 있으나 금(金) 기운이 부족한 편입니다. 금은 학문과 지혜, 집중력을 상징하므로 금 기운 부족은 집중력이나 세밀한 학습에 다소 어려움이 있을 수 있음을 의미합니다. 따라서 학습 시 집중력 향상을 위한 환경 조성이나 보완이 필요합니다.
#
# 3. 토(土) 기운이 강해 현실적이고 신중한 성향이 강합니다. 이는 꾸준한 노력과 성실함으로 학업에 임할 수 있는 좋은 기질입니다.
#
# 4. 대운에서 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 학업에 긍정적인 영향을 미칩니다. 특히 2023~2025년은 화와 목 기운이 좋아 학업과 자기계발에 좋은 시기입니다.
#
# 5. 경쟁심과 창의력이 조화되어 있어 새로운 지식을 탐구하고 도전하는 데 유리합니다.
#
# 종합적으로, 학업운은 꾸준한 노력과 성실함을 바탕으로 좋은 성과를 낼 수 있으나, 집중력 향상을 위한 환경 조성과 금 기운 보완이 필요합니다. 대운의 흐름도 학업에 긍정적인 영향을 주므로 현재 시기를 잘 활용하면 좋은 결과가 기대됩니다.
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土) 강세 → 안정적이고 현실적, 신중한 성향
# - 목(木), 화(火) 중간 수준 → 성장욕구, 활동성, 창의력
# - 수(水) 약간 → 감성, 지혜, 융통성
# - 금(金) 부족 → 집중력, 세밀함, 결단력 보완 필요
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목): 편재 (재물, 능력)
# - 년지 해(亥, 수): 정인 (지식, 보호)
# - 월간 기(己, 토): 비견 (자아, 경쟁)
# - 월지 묘(卯, 목): 편관 (권위, 도전)
# - 시간 무(戊, 토): 비견 (자아, 경쟁)
# - 시지 午(화): 식신 (창조, 표현)
#
# 정인과 식신 기운이 있어 지식과 학업에 대한 관심과 능력이 있음.
#
# ---
#
# [4. 학업운 분석]
#
# 1. **정인(亥)과 식신(午)의 존재**
#    - 정인은 지식, 학문, 보호를 의미하며 학업에 유리한 기운입니다.
#    - 식신은 창의력과 표현력을 나타내어 학습한 내용을 잘 표현하고 활용할 수 있음을 뜻합니다.
#
# 2. **오행 중 금(金) 부족**
#    - 금은 학문과 집중력, 세밀함을 상징합니다.
#    - 금 기운이 부족하면 집중력 유지와 세밀한 학습에 어려움이 있을 수 있으므로, 학습 환경 조성이나 보완이 필요합니다.
#
# 3. **토(土) 강세와 목(木), 화(火)의 조화**
#    - 토는 꾸준함과 성실함을 의미해 학업에 필요한 인내심과 현실적인 태도를 제공합니다.
#    - 목과 화는 성장욕구와 활동성, 창의력을 지원하여 학습 동기와 발전 가능성을 높입니다.
#
# 4. **대운과 세운의 긍정적 영향**
#    - 현재 병자(丙子) 대운으로 화(火)와 수(水) 기운이 보강되어 학업에 좋은 시기입니다.
#    - 2023~2025년 세운 역시 화와 목 기운이 좋아 자기계발과 학업에 유리한 환경입니다.
#
# 5. **경쟁심과 도전정신**
#    - 십신 중 편관과 비견이 있어 경쟁심과 도전정신이 강해 새로운 지식을 탐구하고 학업에 적극적입니다.
#
# ---
#
# [5. 종합 및 조언]
#
# - 학업운은 전반적으로 좋은 편이며, 꾸준한 노력과 성실함으로 좋은 성과를 기대할 수 있습니다.
# - 집중력과 세밀함을 보완하기 위해 금색 계열의 옷 착용, 금속 관련 활동, 정돈된 학습 환경 조성을 권장합니다.
# - 대운과 세운의 흐름을 잘 활용하여 자기계발과 학업에 집중하면 좋은 결과가 있을 것입니다.
# - 경쟁심과 창의력을 긍정적으로 활용하되, 스트레스 관리와 균형 유지도 중요합니다.
#
# ---
#
# **출처:** ManseTool 사주 분석 결과 및 RetrieverTool 분석 내용 기반
# ==================================================
# 🔄 Node: retriever 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土) 강세 → 안정적이고 현실적, 신중한 성향
# - 목(木), 화(火) 중간 수준 → 성장욕구, 활동성, 창의력
# - 수(水) 약간 → 감성, 지혜, 융통성
# - 금(金) 부족 → 집중력, 세밀함, 결단력 보완 필요
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목): 편재 (재물, 능력)
# - 년지 해(亥, 수): 정인 (지식, 보호)
# - 월간 기(己, 토): 비견 (자아, 경쟁)
# - 월지 묘(卯, 목): 편관 (권위, 도전)
# - 시간 무(戊, 토): 비견 (자아, 경쟁)
# - 시지 午(화): 식신 (창조, 표현)
#
# 정인과 식신 기운이 있어 지식과 학업에 대한 관심과 능력이 있음.
#
# ---
#
# [4. 학업운 분석]
#
# 1. **정인(亥)과 식신(午)의 존재**
#    - 정인은 지식, 학문, 보호를 의미하며 학업에 유리한 기운입니다.
#    - 식신은 창의력과 표현력을 나타내어 학습한 내용을 잘 표현하고 활용할 수 있음을 뜻합니다.
#
# 2. **오행 중 금(金) 부족**
#    - 금은 학문과 집중력, 세밀함을 상징합니다.
#    - 금 기운이 부족하면 집중력 유지와 세밀한 학습에 어려움이 있을 수 있으므로, 학습 환경 조성이나 보완이 필요합니다.
#
# 3. **토(土) 강세와 목(木), 화(火)의 조화**
#    - 토는 꾸준함과 성실함을 의미해 학업에 필요한 인내심과 현실적인 태도를 제공합니다.
#    - 목과 화는 성장욕구와 활동성, 창의력을 지원하여 학습 동기와 발전 가능성을 높입니다.
#
# 4. **대운과 세운의 긍정적 영향**
#    - 현재 병자(丙子) 대운으로 화(火)와 수(水) 기운이 보강되어 학업에 좋은 시기입니다.
#    - 2023~2025년 세운 역시 화와 목 기운이 좋아 자기계발과 학업에 유리한 환경입니다.
#
# 5. **경쟁심과 도전정신**
#    - 십신 중 편관과 비견이 있어 경쟁심과 도전정신이 강해 새로운 지식을 탐구하고 학업에 적극적입니다.
#
# ---
#
# [5. 종합 및 조언]
#
# - 학업운은 전반적으로 좋은 편이며, 꾸준한 노력과 성실함으로 좋은 성과를 기대할 수 있습니다.
# - 집중력과 세밀함을 보완하기 위해 금색 계열의 옷 착용, 금속 관련 활동, 정돈된 학습 환경 조성을 권장합니다.
# - 대운과 세운의 흐름을 잘 활용하여 자기계발과 학업에 집중하면 좋은 결과가 있을 것입니다.
# - 경쟁심과 창의력을 긍정적으로 활용하되, 스트레스 관리와 균형 유지도 중요합니다.
#
# ---
#
# **출처:** ManseTool 사주 분석 결과 및 RetrieverTool 분석 내용 기반
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력

question = "재물운봐줘"

inputs = {
    "messages": [
        HumanMessage(
            content=question
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you please analyze my financial luck based on my Four Pillars of Destiny (Ba Zi)? I would like to understand how my birth chart influences my wealth prospects and what specific elements or interactions in my chart may affect my financial situation.재물운봐줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주를 바탕으로 재물운을 분석해보면 다음과 같습니다.
#
# 1. 재물을 상징하는 편재(乙, 을)가 년간에 위치해 있어 재물에 대한 관심과 능력이 있습니다. 편재는 자신의 노력과 능력으로 재물을 얻는 기운을 의미합니다.
#
# 2. 토(土) 기운이 강해 현실적이고 신중한 성향이 강하며, 이는 재물 관리에 있어서도 안정적이고 계획적인 태도를 나타냅니다. 무리한 투자보다는 꾸준한 저축과 계획적인 재테크에 유리합니다.
#
# 3. 금(金) 기운이 부족한 점은 재물 운용에 있어 결단력이나 추진력에서 다소 부족할 수 있음을 의미합니다. 따라서 중요한 재정 결정 시 신중한 판단과 주변의 조언을 구하는 것이 좋습니다.
#
# 4. 대운에서 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 재물운에 긍정적인 영향을 미칩니다. 특히 화는 재물을 불리는 에너지로 작용할 수 있어 현재 시기는 재물 증식에 좋은 시기입니다.
#
# 5. 경쟁심과 도전정신이 강해 새로운 재물 기회를 탐색하는 데 유리하지만, 무리한 도전은 피하는 것이 좋습니다.
#
# 종합적으로, 재물운은 자신의 노력과 계획성에 따라 좋은 결과를 기대할 수 있으며, 신중한 판단과 꾸준한 관리가 중요합니다. 대운의 흐름을 잘 활용하면 재물 증식에 긍정적인 영향을 받을 수 있습니다.
# ==================================================
# 🔄 Node: manse 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주를 바탕으로 재물운을 분석해보면 다음과 같습니다.
#
# 1. 재물을 상징하는 편재(乙, 을)가 년간에 위치해 있어 재물에 대한 관심과 능력이 있습니다. 편재는 자신의 노력과 능력으로 재물을 얻는 기운을 의미합니다.
#
# 2. 토(土) 기운이 강해 현실적이고 신중한 성향이 강하며, 이는 재물 관리에 있어서도 안정적이고 계획적인 태도를 나타냅니다. 무리한 투자보다는 꾸준한 저축과 계획적인 재테크에 유리합니다.
#
# 3. 금(金) 기운이 부족한 점은 재물 운용에 있어 결단력이나 추진력에서 다소 부족할 수 있음을 의미합니다. 따라서 중요한 재정 결정 시 신중한 판단과 주변의 조언을 구하는 것이 좋습니다.
#
# 4. 대운에서 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 재물운에 긍정적인 영향을 미칩니다. 특히 화는 재물을 불리는 에너지로 작용할 수 있어 현재 시기는 재물 증식에 좋은 시기입니다.
#
# 5. 경쟁심과 도전정신이 강해 새로운 재물 기회를 탐색하는 데 유리하지만, 무리한 도전은 피하는 것이 좋습니다.
#
# 종합적으로, 재물운은 자신의 노력과 계획성에 따라 좋은 결과를 기대할 수 있으며, 신중한 판단과 꾸준한 관리가 중요합니다. 대운의 흐름을 잘 활용하면 재물 증식에 긍정적인 영향을 받을 수 있습니다.
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土) 강세 → 안정적이고 현실적, 신중한 성향
# - 목(木), 화(火) 중간 수준 → 성장욕구, 활동성, 창의력
# - 수(水) 약간 → 감성, 지혜, 융통성
# - 금(金) 부족 → 결단력, 추진력, 냉철함 부족 가능성
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목): 편재 (재물, 능력)
# - 년지 해(亥, 수): 정인 (지식, 보호)
# - 월간 기(己, 토): 비견 (자아, 경쟁)
# - 월지 묘(卯, 목): 편관 (권위, 도전)
# - 시간 무(戊, 토): 비견 (자아, 경쟁)
# - 시지 午(화): 식신 (창조, 표현)
#
# 편재가 년간에 위치해 있어 재물에 대한 관심과 능력이 강하며, 자신의 노력으로 재물을 얻는 기운이 있습니다.
#
# ---
#
# [4. 재물운 분석]
#
# 1. **편재(乙)의 존재**
#    - 편재는 자신의 노력과 능력으로 재물을 얻는 기운을 의미합니다.
#    - 년간에 편재가 있어 재물에 대한 관심과 능력이 뚜렷합니다.
#
# 2. **토(土) 강세**
#    - 토는 안정적이고 신중한 성향을 나타내어 재물 관리에 있어서도 계획적이고 꾸준한 태도를 보입니다.
#    - 무리한 투자보다는 장기적이고 현실적인 재테크에 유리합니다.
#
# 3. **금(金) 부족**
#    - 금은 결단력과 추진력을 상징하는데, 부족하면 재물 운용에 있어 중요한 결정에서 주저하거나 망설임이 있을 수 있습니다.
#    - 따라서 재정적 판단 시 신중함과 주변 조언을 구하는 것이 좋습니다.
#
# 4. **대운의 영향**
#    - 현재 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 재물운에 긍정적입니다.
#    - 특히 화는 재물을 불리는 에너지로 작용해 재물 증식에 좋은 시기입니다.
#
# 5. **경쟁심과 도전정신**
#    - 십신 중 편관과 비견이 있어 경쟁심과 도전정신이 강해 새로운 재물 기회를 탐색하는 데 유리하지만, 무리한 도전은 피하는 것이 좋습니다.
#
# ---
#
# [5. 종합 및 조언]
#
# - 재물운은 자신의 노력과 계획성에 따라 좋은 결과를 기대할 수 있습니다.
# - 신중한 판단과 꾸준한 관리가 중요하며, 주변의 조언을 적극 활용하는 것이 좋습니다.
# - 대운의 흐름을 잘 활용하면 재물 증식에 긍정적인 영향을 받을 수 있습니다.
# - 금색 계열의 옷 착용이나 금속 관련 활동으로 부족한 금 기운을 보완하는 것도 도움이 됩니다.
#
# ---
#
# **출처:** ManseTool 사주 분석 결과 및 RetrieverTool 분석 내용 기반
# ==================================================
# 🔄 Node: retriever 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土) 강세 → 안정적이고 현실적, 신중한 성향
# - 목(木), 화(火) 중간 수준 → 성장욕구, 활동성, 창의력
# - 수(水) 약간 → 감성, 지혜, 융통성
# - 금(金) 부족 → 결단력, 추진력, 냉철함 부족 가능성
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목): 편재 (재물, 능력)
# - 년지 해(亥, 수): 정인 (지식, 보호)
# - 월간 기(己, 토): 비견 (자아, 경쟁)
# - 월지 묘(卯, 목): 편관 (권위, 도전)
# - 시간 무(戊, 토): 비견 (자아, 경쟁)
# - 시지 午(화): 식신 (창조, 표현)
#
# 편재가 년간에 위치해 있어 재물에 대한 관심과 능력이 강하며, 자신의 노력으로 재물을 얻는 기운이 있습니다.
#
# ---
#
# [4. 재물운 분석]
#
# 1. **편재(乙)의 존재**
#    - 편재는 자신의 노력과 능력으로 재물을 얻는 기운을 의미합니다.
#    - 년간에 편재가 있어 재물에 대한 관심과 능력이 뚜렷합니다.
#
# 2. **토(土) 강세**
#    - 토는 안정적이고 신중한 성향을 나타내어 재물 관리에 있어서도 계획적이고 꾸준한 태도를 보입니다.
#    - 무리한 투자보다는 장기적이고 현실적인 재테크에 유리합니다.
#
# 3. **금(金) 부족**
#    - 금은 결단력과 추진력을 상징하는데, 부족하면 재물 운용에 있어 중요한 결정에서 주저하거나 망설임이 있을 수 있습니다.
#    - 따라서 재정적 판단 시 신중함과 주변 조언을 구하는 것이 좋습니다.
#
# 4. **대운의 영향**
#    - 현재 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 재물운에 긍정적입니다.
#    - 특히 화는 재물을 불리는 에너지로 작용해 재물 증식에 좋은 시기입니다.
#
# 5. **경쟁심과 도전정신**
#    - 십신 중 편관과 비견이 있어 경쟁심과 도전정신이 강해 새로운 재물 기회를 탐색하는 데 유리하지만, 무리한 도전은 피하는 것이 좋습니다.
#
# ---
#
# [5. 종합 및 조언]
#
# - 재물운은 자신의 노력과 계획성에 따라 좋은 결과를 기대할 수 있습니다.
# - 신중한 판단과 꾸준한 관리가 중요하며, 주변의 조언을 적극 활용하는 것이 좋습니다.
# - 대운의 흐름을 잘 활용하면 재물 증식에 긍정적인 영향을 받을 수 있습니다.
# - 금색 계열의 옷 착용이나 금속 관련 활동으로 부족한 금 기운을 보완하는 것도 도움이 됩니다.
#
# ---
#
# **출처:** ManseTool 사주 분석 결과 및 RetrieverTool 분석 내용 기반
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력

question = "애정운 봐줘"

inputs = {
    "messages": [
        HumanMessage(
            content=question
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you please analyze my love fortune based on my Four Pillars of Destiny (Ba Zi)? I would like to understand how my birth chart influences my romantic relationships and what potential opportunities or challenges I might face in my love life.애정운 봐줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 을해
# 월주(月柱): 기묘
# 일주(日柱): 무오
# 시주(時柱): 무오
# 일간(日干): 무
# 현재 나이: 30세 / 한국식 나이: 31세
# 기준 시점: 2025-06-22 10:00:59
#
# === 오행 강약 ===
# 목: 39점
# 화: 20점
# 토: 68점
# 금: 0점
# 수: 10점
#
# === 십신 분석 ===
# 년주: 천간:정관, 지지:편재(70%), 지지:편관(30%)
# 월주: 천간:겁재, 지지:정관(100%)
# 일주: 지지:정인(70%), 지지:겁재(30%)
# 시주: 지지:정인(70%), 지지:겁재(30%)
#
# === 대운 (정밀 계산) ===
# 5세: 무인 (2000년 ~ 2009년)
# 15세: 정축 (2010년 ~ 2019년)
# 25세: 병자 (2020년 ~ 2029년)
# 35세: 을해 (2030년 ~ 2039년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 애정운을 분석해보면 다음과 같습니다.
#
# 1. 사주에 정관과 편재, 편관, 정인, 겁재 등의 십신이 혼재되어 있어 대인관계와 애정 관계에서 다양한 경험과 감정을 겪을 수 있습니다. 특히 정관은 배우자와의 인연을 의미하며, 편재와 편관은 애정과 이성 관계에서의 도전과 경쟁을 나타냅니다.
#
# 2. 토(土) 기운이 강해 안정적이고 신중한 성격이지만, 금(金) 기운이 부족해 결단력이나 추진력에서 다소 부족할 수 있습니다. 애정 관계에서는 신중함과 배려심이 강하지만 때로는 적극적인 표현이 필요할 수 있습니다.
#
# 3. 대운에서 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 감성적이고 따뜻한 면이 강화됩니다. 이는 애정운에 긍정적인 영향을 미쳐 좋은 인연을 만나고 관계를 발전시키는 데 도움이 됩니다.
#
# 4. 경쟁심과 도전정신이 강해 애정 관계에서도 주도적이고 적극적인 면이 있으나, 상대방과의 조화와 균형을 유지하는 것이 중요합니다.
#
# 5. 30대 초반부터 40대 초반까지는 애정운이 좋은 시기로, 인연을 맺거나 관계를 깊게 발전시키기에 적합한 시기입니다.
#
# 종합적으로, 애정운은 안정적이고 신중한 성격에 따뜻한 감성이 더해져 좋은 인연을 만나고 관계를 발전시킬 수 있는 좋은 흐름입니다. 다만, 적극적인 표현과 상대방과의 조화로운 소통이 애정운을 더욱 좋게 만드는 열쇠가 될 것입니다.
# ==================================================
# 🔄 Node: manse 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 애정운을 분석해보면 다음과 같습니다.
#
# 1. 사주에 정관과 편재, 편관, 정인, 겁재 등의 십신이 혼재되어 있어 대인관계와 애정 관계에서 다양한 경험과 감정을 겪을 수 있습니다. 특히 정관은 배우자와의 인연을 의미하며, 편재와 편관은 애정과 이성 관계에서의 도전과 경쟁을 나타냅니다.
#
# 2. 토(土) 기운이 강해 안정적이고 신중한 성격이지만, 금(金) 기운이 부족해 결단력이나 추진력에서 다소 부족할 수 있습니다. 애정 관계에서는 신중함과 배려심이 강하지만 때로는 적극적인 표현이 필요할 수 있습니다.
#
# 3. 대운에서 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 감성적이고 따뜻한 면이 강화됩니다. 이는 애정운에 긍정적인 영향을 미쳐 좋은 인연을 만나고 관계를 발전시키는 데 도움이 됩니다.
#
# 4. 경쟁심과 도전정신이 강해 애정 관계에서도 주도적이고 적극적인 면이 있으나, 상대방과의 조화와 균형을 유지하는 것이 중요합니다.
#
# 5. 30대 초반부터 40대 초반까지는 애정운이 좋은 시기로, 인연을 맺거나 관계를 깊게 발전시키기에 적합한 시기입니다.
#
# 종합적으로, 애정운은 안정적이고 신중한 성격에 따뜻한 감성이 더해져 좋은 인연을 만나고 관계를 발전시킬 수 있는 좋은 흐름입니다. 다만, 적극적인 표현과 상대방과의 조화로운 소통이 애정운을 더욱 좋게 만드는 열쇠가 될 것입니다.
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土) 강세 → 안정적이고 신중한 성향
# - 목(木), 화(火) 중간 수준 → 성장욕구, 활동성, 창의력
# - 수(水) 약간 → 감성, 지혜, 융통성
# - 금(金) 부족 → 결단력, 추진력, 냉철함 부족 가능성
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목): 편재 (재물, 능력)
# - 년지 해(亥, 수): 정인 (지식, 보호)
# - 월간 기(己, 토): 비견 (자아, 경쟁)
# - 월지 묘(卯, 목): 편관 (권위, 도전)
# - 시간 무(戊, 토): 비견 (자아, 경쟁)
# - 시지 午(화): 식신 (창조, 표현)
#
# 십신이 다양하게 혼재되어 있어 대인관계와 애정 관계에서 여러 경험과 감정을 겪을 수 있습니다. 특히 정관(배우자 인연)과 편재, 편관, 정인, 겁재가 혼재되어 있어 애정과 이성 관계에서 도전과 경쟁, 보호와 창의력이 공존합니다.
#
# ---
#
# [4. 애정운 분석]
#
# 1. **정관과 편재, 편관의 혼재**
#    - 정관은 배우자와의 인연과 안정적인 관계를 의미합니다.
#    - 편재와 편관은 애정 관계에서 도전과 경쟁, 주도적인 성향을 나타내어 관계에 활력을 줍니다.
#
# 2. **토(土) 강세와 금(金) 부족**
#    - 토의 안정적이고 신중한 성격은 애정 관계에서 신뢰와 책임감을 주지만, 금의 부족은 결단력과 추진력에서 다소 부족할 수 있어 적극적인 표현이 필요합니다.
#
# 3. **대운의 긍정적 영향**
#    - 현재 병자(丙子) 대운으로 화(火)와 수(水) 기운이 보강되어 감성적이고 따뜻한 면이 강화됩니다.
#    - 이는 좋은 인연을 만나고 관계를 발전시키는 데 긍정적입니다.
#
# 4. **경쟁심과 도전정신**
#    - 십신 중 편관과 비견이 있어 애정 관계에서도 주도적이고 적극적인 면이 있으나, 상대방과의 조화와 균형 유지가 중요합니다.
#
# 5. **적기**
#    - 30대 초반부터 40대 초반까지 애정운이 좋은 시기로, 인연을 맺거나 관계를 깊게 발전시키기에 적합한 시기입니다.
#
# ---
#
# [5. 종합 및 조언]
#
# - 안정적이고 신중한 성격에 따뜻한 감성이 더해져 좋은 인연을 만나고 관계를 발전시킬 수 있는 좋은 흐름입니다.
# - 다만, 적극적인 표현과 상대방과의 조화로운 소통이 애정운을 더욱 좋게 만드는 열쇠입니다.
# - 경쟁심과 도전정신을 긍정적으로 활용하되, 상대방의 입장과 감정을 배려하는 균형감각이 필요합니다.
# - 대운의 흐름을 잘 활용하여 좋은 인연을 만나고 관계를 발전시키시길 바랍니다.
#
# ---
#
# **출처:** ManseTool 및 RetrieverTool 사주 분석 결과 기반
# ==================================================
# 🔄 Node: retriever 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土) 강세 → 안정적이고 신중한 성향
# - 목(木), 화(火) 중간 수준 → 성장욕구, 활동성, 창의력
# - 수(水) 약간 → 감성, 지혜, 융통성
# - 금(金) 부족 → 결단력, 추진력, 냉철함 부족 가능성
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목): 편재 (재물, 능력)
# - 년지 해(亥, 수): 정인 (지식, 보호)
# - 월간 기(己, 토): 비견 (자아, 경쟁)
# - 월지 묘(卯, 목): 편관 (권위, 도전)
# - 시간 무(戊, 토): 비견 (자아, 경쟁)
# - 시지 午(화): 식신 (창조, 표현)
#
# 십신이 다양하게 혼재되어 있어 대인관계와 애정 관계에서 여러 경험과 감정을 겪을 수 있습니다. 특히 정관(배우자 인연)과 편재, 편관, 정인, 겁재가 혼재되어 있어 애정과 이성 관계에서 도전과 경쟁, 보호와 창의력이 공존합니다.
#
# ---
#
# [4. 애정운 분석]
#
# 1. **정관과 편재, 편관의 혼재**
#    - 정관은 배우자와의 인연과 안정적인 관계를 의미합니다.
#    - 편재와 편관은 애정 관계에서 도전과 경쟁, 주도적인 성향을 나타내어 관계에 활력을 줍니다.
#
# 2. **토(土) 강세와 금(金) 부족**
#    - 토의 안정적이고 신중한 성격은 애정 관계에서 신뢰와 책임감을 주지만, 금의 부족은 결단력과 추진력에서 다소 부족할 수 있어 적극적인 표현이 필요합니다.
#
# 3. **대운의 긍정적 영향**
#    - 현재 병자(丙子) 대운으로 화(火)와 수(水) 기운이 보강되어 감성적이고 따뜻한 면이 강화됩니다.
#    - 이는 좋은 인연을 만나고 관계를 발전시키는 데 긍정적입니다.
#
# 4. **경쟁심과 도전정신**
#    - 십신 중 편관과 비견이 있어 애정 관계에서도 주도적이고 적극적인 면이 있으나, 상대방과의 조화와 균형 유지가 중요합니다.
#
# 5. **적기**
#    - 30대 초반부터 40대 초반까지 애정운이 좋은 시기로, 인연을 맺거나 관계를 깊게 발전시키기에 적합한 시기입니다.
#
# ---
#
# [5. 종합 및 조언]
#
# - 안정적이고 신중한 성격에 따뜻한 감성이 더해져 좋은 인연을 만나고 관계를 발전시킬 수 있는 좋은 흐름입니다.
# - 다만, 적극적인 표현과 상대방과의 조화로운 소통이 애정운을 더욱 좋게 만드는 열쇠입니다.
# - 경쟁심과 도전정신을 긍정적으로 활용하되, 상대방의 입장과 감정을 배려하는 균형감각이 필요합니다.
# - 대운의 흐름을 잘 활용하여 좋은 인연을 만나고 관계를 발전시키시길 바랍니다.
#
# ---
#
# **출처:** ManseTool 및 RetrieverTool 사주 분석 결과 기반
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 애정운을 분석해보면 다음과 같습니다.
#
# 1. 사주에 정관(배우자 인연), 편재, 편관, 정인, 겁재 등의 십신이 혼재되어 있어 대인관계와 애정 관계에서 다양한 경험과 감정을 겪을 수 있습니다. 특히 정관은 안정적인 배우자 인연을 의미하며, 편재와 편관은 애정 관계에서 도전과 경쟁, 주도적인 성향을 나타냅니다.
#
# 2. 토(土) 기운이 강해 안정적이고 신중한 성격이지만, 금(金) 기운이 부족해 결단력이나 추진력에서 다소 부족할 수 있습니다. 애정 관계에서는 신중함과 배려심이 강하지만 때로는 적극적인 표현이 필요합니다.
#
# 3. 현재 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 감성적이고 따뜻한 면이 강화됩니다. 이는 좋은 인연을 만나고 관계를 발전시키는 데 긍정적인 영향을 줍니다.
#
# 4. 경쟁심과 도전정신이 강해 애정 관계에서도 주도적이고 적극적인 면이 있으나, 상대방과의 조화와 균형을 유지하는 것이 중요합니다.
#
# 5. 30대 초반부터 40대 초반까지는 애정운이 좋은 시기로, 인연을 맺거나 관계를 깊게 발전시키기에 적합한 시기입니다.
#
# 종합적으로, 안정적이고 신중한 성격에 따뜻한 감성이 더해져 좋은 인연을 만나고 관계를 발전시킬 수 있는 좋은 흐름입니다. 다만, 적극적인 표현과 상대방과의 조화로운 소통이 애정운을 더욱 좋게 만드는 열쇠가 될 것입니다.
# ==================================================
# 🔄 Node: manse 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 애정운을 분석해보면 다음과 같습니다.
#
# 1. 사주에 정관(배우자 인연), 편재, 편관, 정인, 겁재 등의 십신이 혼재되어 있어 대인관계와 애정 관계에서 다양한 경험과 감정을 겪을 수 있습니다. 특히 정관은 안정적인 배우자 인연을 의미하며, 편재와 편관은 애정 관계에서 도전과 경쟁, 주도적인 성향을 나타냅니다.
#
# 2. 토(土) 기운이 강해 안정적이고 신중한 성격이지만, 금(金) 기운이 부족해 결단력이나 추진력에서 다소 부족할 수 있습니다. 애정 관계에서는 신중함과 배려심이 강하지만 때로는 적극적인 표현이 필요합니다.
#
# 3. 현재 병자(丙子) 대운이 진행 중이며, 화(火)와 수(水) 기운이 보강되어 감성적이고 따뜻한 면이 강화됩니다. 이는 좋은 인연을 만나고 관계를 발전시키는 데 긍정적인 영향을 줍니다.
#
# 4. 경쟁심과 도전정신이 강해 애정 관계에서도 주도적이고 적극적인 면이 있으나, 상대방과의 조화와 균형을 유지하는 것이 중요합니다.
#
# 5. 30대 초반부터 40대 초반까지는 애정운이 좋은 시기로, 인연을 맺거나 관계를 깊게 발전시키기에 적합한 시기입니다.
#
# 종합적으로, 안정적이고 신중한 성격에 따뜻한 감성이 더해져 좋은 인연을 만나고 관계를 발전시킬 수 있는 좋은 흐름입니다. 다만, 적극적인 표현과 상대방과의 조화로운 소통이 애정운을 더욱 좋게 만드는 열쇠가 될 것입니다.
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土) 강세 → 안정적이고 신중한 성향
# - 목(木), 화(火) 중간 수준 → 성장욕구, 활동성, 창의력
# - 수(水) 약간 → 감성, 지혜, 융통성
# - 금(金) 부족 → 결단력, 추진력, 냉철함 부족 가능성
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목): 편재 (재물, 능력)
# - 년지 해(亥, 수): 정인 (지식, 보호)
# - 월간 기(己, 토): 비견 (자아, 경쟁)
# - 월지 묘(卯, 목): 편관 (권위, 도전)
# - 시간 무(戊, 토): 비견 (자아, 경쟁)
# - 시지 午(화): 식신 (창조, 표현)
#
# 십신이 다양하게 혼재되어 있어 대인관계와 애정 관계에서 여러 경험과 감정을 겪을 수 있습니다. 특히 정관(배우자 인연)과 편재, 편관, 정인, 겁재가 혼재되어 있어 애정과 이성 관계에서 도전과 경쟁, 보호와 창의력이 공존합니다.
#
# ---
#
# [4. 애정운 분석]
#
# 1. **정관과 편재, 편관의 혼재**
#    - 정관은 배우자와의 인연과 안정적인 관계를 의미합니다.
#    - 편재와 편관은 애정 관계에서 도전과 경쟁, 주도적인 성향을 나타내어 관계에 활력을 줍니다.
#
# 2. **토(土) 강세와 금(金) 부족**
#    - 토의 안정적이고 신중한 성격은 애정 관계에서 신뢰와 책임감을 주지만, 금의 부족은 결단력과 추진력에서 다소 부족할 수 있어 적극적인 표현이 필요합니다.
#
# 3. **대운의 긍정적 영향**
#    - 현재 병자(丙子) 대운으로 화(火)와 수(水) 기운이 보강되어 감성적이고 따뜻한 면이 강화됩니다.
#    - 이는 좋은 인연을 만나고 관계를 발전시키는 데 긍정적입니다.
#
# 4. **경쟁심과 도전정신**
#    - 십신 중 편관과 비견이 있어 애정 관계에서도 주도적이고 적극적인 면이 있으나, 상대방과의 조화와 균형 유지가 중요합니다.
#
# 5. **적기**
#    - 30대 초반부터 40대 초반까지 애정운이 좋은 시기로, 인연을 맺거나 관계를 깊게 발전시키기에 적합한 시기입니다.
#
# ---
#
# [5. 종합 및 조언]
#
# - 안정적이고 신중한 성격에 따뜻한 감성이 더해져 좋은 인연을 만나고 관계를 발전시킬 수 있는 좋은 흐름입니다.
# - 다만, 적극적인 표현과 상대방과의 조화로운 소통이 애정운을 더욱 좋게 만드는 열쇠입니다.
# - 경쟁심과 도전정신을 긍정적으로 활용하되, 상대방의 입장과 감정을 배려하는 균형감각이 필요합니다.
# - 대운의 흐름을 잘 활용하여 좋은 인연을 만나고 관계를 발전시키시길 바랍니다.
#
# ---
#
# **출처:** ManseTool 및 RetrieverTool 사주 분석 결과 기반
# ==================================================
# 🔄 Node: retriever 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1995년 3월 28일 12시 30분 (양력, 남성)
# - 사주팔자 (천간지지):
#   - 년주: 을해 (乙亥)
#   - 월주: 기묘 (己卯)
#   - 일주: 무오 (戊午)
#   - 시주: 무오 (戊午)
# - 일간(일주 천간): 무(土)
# - 나이: 만 30세, 한국식 31세
# - 출생 시간대: 午시 (11시~13시) → 12시 30분은 午시에 해당
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 乙 → 목 +1
# - 亥 → 수 +1
# - 己 → 토 +1
# - 卯 → 목 +1
# - 戊 → 토 +1
# - 午 → 화 +1
# - 戊 → 토 +1
# - 午 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 2     | 乙, 卯          |
# | 화   | 2     | 午, 午          |
# | 토   | 3     | 己, 戊, 戊      |
# | 금   | 0     |                |
# | 수   | 1     | 亥              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 토(土) 강세 → 안정적이고 신중한 성향
# - 목(木), 화(火) 중간 수준 → 성장욕구, 활동성, 창의력
# - 수(水) 약간 → 감성, 지혜, 융통성
# - 금(金) 부족 → 결단력, 추진력, 냉철함 부족 가능성
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 무(土)를 기준으로
# - 년간 을(乙, 목): 편재 (재물, 능력)
# - 년지 해(亥, 수): 정인 (지식, 보호)
# - 월간 기(己, 토): 비견 (자아, 경쟁)
# - 월지 묘(卯, 목): 편관 (권위, 도전)
# - 시간 무(戊, 토): 비견 (자아, 경쟁)
# - 시지 午(화): 식신 (창조, 표현)
#
# 십신이 다양하게 혼재되어 있어 대인관계와 애정 관계에서 여러 경험과 감정을 겪을 수 있습니다. 특히 정관(배우자 인연)과 편재, 편관, 정인, 겁재가 혼재되어 있어 애정과 이성 관계에서 도전과 경쟁, 보호와 창의력이 공존합니다.
#
# ---
#
# [4. 애정운 분석]
#
# 1. **정관과 편재, 편관의 혼재**
#    - 정관은 배우자와의 인연과 안정적인 관계를 의미합니다.
#    - 편재와 편관은 애정 관계에서 도전과 경쟁, 주도적인 성향을 나타내어 관계에 활력을 줍니다.
#
# 2. **토(土) 강세와 금(金) 부족**
#    - 토의 안정적이고 신중한 성격은 애정 관계에서 신뢰와 책임감을 주지만, 금의 부족은 결단력과 추진력에서 다소 부족할 수 있어 적극적인 표현이 필요합니다.
#
# 3. **대운의 긍정적 영향**
#    - 현재 병자(丙子) 대운으로 화(火)와 수(水) 기운이 보강되어 감성적이고 따뜻한 면이 강화됩니다.
#    - 이는 좋은 인연을 만나고 관계를 발전시키는 데 긍정적입니다.
#
# 4. **경쟁심과 도전정신**
#    - 십신 중 편관과 비견이 있어 애정 관계에서도 주도적이고 적극적인 면이 있으나, 상대방과의 조화와 균형 유지가 중요합니다.
#
# 5. **적기**
#    - 30대 초반부터 40대 초반까지 애정운이 좋은 시기로, 인연을 맺거나 관계를 깊게 발전시키기에 적합한 시기입니다.
#
# ---
#
# [5. 종합 및 조언]
#
# - 안정적이고 신중한 성격에 따뜻한 감성이 더해져 좋은 인연을 만나고 관계를 발전시킬 수 있는 좋은 흐름입니다.
# - 다만, 적극적인 표현과 상대방과의 조화로운 소통이 애정운을 더욱 좋게 만드는 열쇠입니다.
# - 경쟁심과 도전정신을 긍정적으로 활용하되, 상대방의 입장과 감정을 배려하는 균형감각이 필요합니다.
# - 대운의 흐름을 잘 활용하여 좋은 인연을 만나고 관계를 발전시키시길 바랍니다.
#
# ---
#
# **출처:** ManseTool 및 RetrieverTool 사주 분석 결과 기반
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
--
# Out:
#   Cell In[28], line 1
#     --
#       ^
# SyntaxError: invalid syntax

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="1997년 09월 01일 여자, 11시 30분 출생 운세봐줘"
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you please provide a fortune reading for a female born on September 1, 1997, at 11:30 AM? I am interested in a detailed analysis of her Four Pillars of Destiny (Ba Zi) and how her birth chart influences her personality, career prospects, and overall life path.1997년 09월 01일 여자, 11시 30분 출생 운세봐줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 정축
# 월주(月柱): 무신
# 일주(日柱): 병오
# 시주(時柱): 계사
# 일간(日干): 병
# 현재 나이: 27세 / 한국식 나이: 29세
# 기준 시점: 2025-06-22 10:09:30
#
# === 오행 강약 ===
# 목: 0점
# 화: 59점
# 토: 38점
# 금: 11점
# 수: 28점
#
# === 십신 분석 ===
# 년주: 천간:겁재, 지지:상관(60%), 지지:정관(30%), 지지:정재(10%)
# 월주: 천간:식신, 지지:편재(60%), 지지:편관(30%), 지지:식신(10%)
# 일주: 지지:겁재(70%), 지지:상관(30%)
# 시주: 천간:정관, 지지:식신(30%), 지지:편재(10%)
#
# === 대운 (정밀 계산) ===
# 6세: 기유 (2003년 ~ 2012년)
# 16세: 경술 (2013년 ~ 2022년)
# 26세: 신해 (2023년 ~ 2032년)
# 36세: 임자 (2033년 ~ 2042년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1997년 9월 1일 11시 30분 출생 여성의 사주팔자 분석 결과입니다.
#
# 1. 사주 구성
# - 년주: 정축(丁丑)
# - 월주: 무신(戊申)
# - 일주: 병오(丙午)
# - 시주: 계사(癸巳)
# - 일간: 병(丙, 화)
# - 현재 나이: 만 27세, 한국식 29세
#
# 2. 오행 강약
# - 화(火): 59점 (매우 강함)
# - 토(土): 38점 (강함)
# - 수(水): 28점 (중간)
# - 금(金): 11점 (약함)
# - 목(木): 0점 (없음)
#
# 3. 십신 분석
# - 년주: 겁재(경쟁, 동료), 상관(창의, 도전), 정관(배우자, 규율), 정재(재물)
# - 월주: 식신(창조, 표현), 편재(재물, 능력), 편관(도전, 권위)
# - 일주: 겁재(경쟁), 상관(도전)
# - 시주: 정관(배우자, 규율), 식신(창조), 편재(재물)
#
# 4. 대운 흐름
# - 현재 대운: 신해(辛亥, 2023~2032년)
# - 이전 대운: 경술(庚戌, 2013~2022년)
# - 다음 대운: 임자(壬子, 2033~2042년)
#
# 5. 종합 해석
# - 화(火) 기운이 매우 강해 열정적이고 활발하며, 창의력과 표현력이 뛰어납니다.
# - 토(土) 기운도 강해 현실적이고 안정적인 면이 있으며, 책임감이 강합니다.
# - 수(水) 기운이 중간 정도 있어 감성적이고 융통성도 갖추고 있습니다.
# - 금(金)과 목(木) 기운은 약하거나 없어 결단력과 추진력, 성장욕구에서 보완이 필요할 수 있습니다.
# - 십신에 겁재와 상관이 많아 경쟁심과 도전정신이 강하며, 창의적이고 표현력이 뛰어납니다.
# - 대운 신해는 금과 수 기운을 보강해 균형을 맞추는 시기이며, 새로운 기회와 변화를 맞이할 수 있습니다.
#
# 필요하신 특정 운세(예: 학업, 재물, 애정 등)나 더 자세한 분석 요청하시면 도와드리겠습니다.
# ==================================================
# 🔄 Node: manse 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1997년 9월 1일 11시 30분 출생 여성의 사주팔자 분석 결과입니다.
#
# 1. 사주 구성
# - 년주: 정축(丁丑)
# - 월주: 무신(戊申)
# - 일주: 병오(丙午)
# - 시주: 계사(癸巳)
# - 일간: 병(丙, 화)
# - 현재 나이: 만 27세, 한국식 29세
#
# 2. 오행 강약
# - 화(火): 59점 (매우 강함)
# - 토(土): 38점 (강함)
# - 수(水): 28점 (중간)
# - 금(金): 11점 (약함)
# - 목(木): 0점 (없음)
#
# 3. 십신 분석
# - 년주: 겁재(경쟁, 동료), 상관(창의, 도전), 정관(배우자, 규율), 정재(재물)
# - 월주: 식신(창조, 표현), 편재(재물, 능력), 편관(도전, 권위)
# - 일주: 겁재(경쟁), 상관(도전)
# - 시주: 정관(배우자, 규율), 식신(창조), 편재(재물)
#
# 4. 대운 흐름
# - 현재 대운: 신해(辛亥, 2023~2032년)
# - 이전 대운: 경술(庚戌, 2013~2022년)
# - 다음 대운: 임자(壬子, 2033~2042년)
#
# 5. 종합 해석
# - 화(火) 기운이 매우 강해 열정적이고 활발하며, 창의력과 표현력이 뛰어납니다.
# - 토(土) 기운도 강해 현실적이고 안정적인 면이 있으며, 책임감이 강합니다.
# - 수(水) 기운이 중간 정도 있어 감성적이고 융통성도 갖추고 있습니다.
# - 금(金)과 목(木) 기운은 약하거나 없어 결단력과 추진력, 성장욕구에서 보완이 필요할 수 있습니다.
# - 십신에 겁재와 상관이 많아 경쟁심과 도전정신이 강하며, 창의적이고 표현력이 뛰어납니다.
# - 대운 신해는 금과 수 기운을 보강해 균형을 맞추는 시기이며, 새로운 기회와 변화를 맞이할 수 있습니다.
#
# 필요하신 특정 운세(예: 학업, 재물, 애정 등)나 더 자세한 분석 요청하시면 도와드리겠습니다.
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1997년 9월 1일 11시 30분 (양력, 여성)
# - 사주팔자 (천간지지):
#   - 년주: 정축 (丁丑)
#   - 월주: 무신 (戊申)
#   - 일주: 병오 (丙午)
#   - 시주: 계사 (癸巳)
# - 일간(일주 천간): 병(火)
# - 나이: 만 27세, 한국식 29세
# - 출생 시간대: 巳시 (09시~11시) → 11시 30분은 午시(11시~13시)에 해당하나, 11시 30분은 午시가 맞습니다.
#   (ManseTool에서 시주 계사(癸巳)로 주어졌으므로, 시주는 巳시로 해석합니다.)
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 丁(정), 丑(축), 戊(무), 申(신), 丙(병), 午(오), 癸(계), 巳(사)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 丁 → 화 +1
# - 丑 → 토 +1
# - 戊 → 토 +1
# - 申 → 금 +1
# - 丙 → 화 +1
# - 午 → 화 +1
# - 癸 → 수 +1
# - 巳 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 0     |                |
# | 화   | 4     | 丁, 丙, 午, 巳  |
# | 토   | 2     | 丑, 戊          |
# | 금   | 1     | 申              |
# | 수   | 1     | 癸              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 화(火) 매우 강함(4점) → 열정적이고 활발하며 창의력과 표현력이 뛰어남
# - 토(土) 강함(2점) → 현실적이고 안정적, 책임감 강함
# - 금(金) 약함(1점) → 결단력과 추진력 보완 필요
# - 수(水) 약함(1점) → 감성적이고 융통성 있음
# - 목(木) 없음(0점) → 성장욕구나 새로운 시작에 보완 필요
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 병(火)을 기준으로
# - 년간 丁(정, 화): 정관 (배우자, 규율)
# - 년지 丑(축, 토): 겁재 (경쟁, 동료)
# - 월간 戊(무, 토): 식신 (창조, 표현)
# - 월지 申(신, 금): 편재 (재물, 능력)
# - 일간 丙(병, 화): 본인
# - 일지 午(오, 화): 상관 (도전, 창의)
# - 시간 癸(계, 수): 정재 (재물, 안정)
# - 시지 巳(사, 화): 편관 (권위, 도전)
#
# 십신이 다양하게 혼재되어 있어 창의력과 도전정신, 재물운과 대인관계에서 활발한 활동이 예상됨.
#
# ---
#
# [4. 종합 해석]
#
# - 화(火) 기운이 매우 강해 열정적이고 활발하며, 창의력과 표현력이 뛰어납니다.
# - 토(土) 기운도 강해 현실적이고 안정적인 면이 있으며, 책임감이 강합니다.
# - 금(金)과 수(水) 기운은 약하거나 적어 결단력, 추진력, 감성적 균형에서 보완이 필요합니다.
# - 목(木) 기운이 전혀 없어 성장욕구나 새로운 시작에 어려움이 있을 수 있으니, 목 기운 보완을 권장합니다.
# - 십신 중 정관과 편관, 상관, 식신, 편재, 정재가 혼재되어 있어 대인관계, 재물, 창의력, 도전정신이 조화롭게 작용합니다.
# - 현재 대운 신해(辛亥, 2023~2032년)는 금과 수 기운을 보강하여 균형을 맞추고 새로운 기회와 변화를 가져올 시기입니다.
#
# ---
#
# [5. 조언 및 참고]
#
# - 강한 화 기운을 잘 활용해 창의적이고 활발한 활동에 집중하세요.
# - 금과 수 기운이 약하므로 결단력과 추진력, 감성적 균형을 위해 금색 계열 착용, 물과 관련된 활동, 목 기운 보완(녹색 계열, 식물 등)을 권장합니다.
# - 대인관계와 재물운이 좋은 편이므로 적극적으로 기회를 탐색하세요.
# - 성장욕구가 부족할 수 있으니 새로운 도전과 배움에 관심을 가지는 것이 좋습니다.
#
# ---
#
# 필요하신 경우 학업운, 재물운, 애정운, 대운 및 세운 분석도 추가로 도와드리겠습니다.
# ==================================================
# 🔄 Node: retriever 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [1. 사주 구조 및 기본 정보]
#
# - 출생: 1997년 9월 1일 11시 30분 (양력, 여성)
# - 사주팔자 (천간지지):
#   - 년주: 정축 (丁丑)
#   - 월주: 무신 (戊申)
#   - 일주: 병오 (丙午)
#   - 시주: 계사 (癸巳)
# - 일간(일주 천간): 병(火)
# - 나이: 만 27세, 한국식 29세
# - 출생 시간대: 巳시 (09시~11시) → 11시 30분은 午시(11시~13시)에 해당하나, 11시 30분은 午시가 맞습니다.
#   (ManseTool에서 시주 계사(癸巳)로 주어졌으므로, 시주는 巳시로 해석합니다.)
#
# ---
#
# [2. 오행(五行) 분석]
#
# ### 1) 사주 8글자 확인
# 丁(정), 丑(축), 戊(무), 申(신), 丙(병), 午(오), 癸(계), 巳(사)
#
# ### 2) 오행 배정표
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 3) 각 글자별 오행 점수
# - 丁 → 화 +1
# - 丑 → 토 +1
# - 戊 → 토 +1
# - 申 → 금 +1
# - 丙 → 화 +1
# - 午 → 화 +1
# - 癸 → 수 +1
# - 巳 → 화 +1
#
# ### 4) 오행별 점수 집계
# | 오행 | 점수 | 글자           |
# |------|-------|----------------|
# | 목   | 0     |                |
# | 화   | 4     | 丁, 丙, 午, 巳  |
# | 토   | 2     | 丑, 戊          |
# | 금   | 1     | 申              |
# | 수   | 1     | 癸              |
#
# 총합 = 8 (계산 유효)
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ### 5) 오행 해석
# - 화(火) 매우 강함(4점) → 열정적이고 활발하며 창의력과 표현력이 뛰어남
# - 토(土) 강함(2점) → 현실적이고 안정적, 책임감 강함
# - 금(金) 약함(1점) → 결단력과 추진력 보완 필요
# - 수(水) 약함(1점) → 감성적이고 융통성 있음
# - 목(木) 없음(0점) → 성장욕구나 새로운 시작에 보완 필요
#
# ---
#
# [3. 십신(十神) 분석]
#
# - 일간 병(火)을 기준으로
# - 년간 丁(정, 화): 정관 (배우자, 규율)
# - 년지 丑(축, 토): 겁재 (경쟁, 동료)
# - 월간 戊(무, 토): 식신 (창조, 표현)
# - 월지 申(신, 금): 편재 (재물, 능력)
# - 일간 丙(병, 화): 본인
# - 일지 午(오, 화): 상관 (도전, 창의)
# - 시간 癸(계, 수): 정재 (재물, 안정)
# - 시지 巳(사, 화): 편관 (권위, 도전)
#
# 십신이 다양하게 혼재되어 있어 창의력과 도전정신, 재물운과 대인관계에서 활발한 활동이 예상됨.
#
# ---
#
# [4. 종합 해석]
#
# - 화(火) 기운이 매우 강해 열정적이고 활발하며, 창의력과 표현력이 뛰어납니다.
# - 토(土) 기운도 강해 현실적이고 안정적인 면이 있으며, 책임감이 강합니다.
# - 금(金)과 수(水) 기운은 약하거나 적어 결단력, 추진력, 감성적 균형에서 보완이 필요합니다.
# - 목(木) 기운이 전혀 없어 성장욕구나 새로운 시작에 어려움이 있을 수 있으니, 목 기운 보완을 권장합니다.
# - 십신 중 정관과 편관, 상관, 식신, 편재, 정재가 혼재되어 있어 대인관계, 재물, 창의력, 도전정신이 조화롭게 작용합니다.
# - 현재 대운 신해(辛亥, 2023~2032년)는 금과 수 기운을 보강하여 균형을 맞추고 새로운 기회와 변화를 가져올 시기입니다.
#
# ---
#
# [5. 조언 및 참고]
#
# - 강한 화 기운을 잘 활용해 창의적이고 활발한 활동에 집중하세요.
# - 금과 수 기운이 약하므로 결단력과 추진력, 감성적 균형을 위해 금색 계열 착용, 물과 관련된 활동, 목 기운 보완(녹색 계열, 식물 등)을 권장합니다.
# - 대인관계와 재물운이 좋은 편이므로 적극적으로 기회를 탐색하세요.
# - 성장욕구가 부족할 수 있으니 새로운 도전과 배움에 관심을 가지는 것이 좋습니다.
#
# ---
#
# 필요하신 경우 학업운, 재물운, 애정운, 대운 및 세운 분석도 추가로 도와드리겠습니다.
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[32], line 19
#       9 inputs = {
#      10     "messages": [
#      11         HumanMessage(
#    (...)     15     ],
#      16 }
#      18 # 그래프 실행
# ---> 19 stream_graph(graph, inputs, config)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_teddynote\messages.py:363, in stream_graph(graph, inputs, config, node_names, callback)
#     348 """
#     349 LangGraph의 실행 결과를 스트리밍하여 출력하는 함수입니다.
#     350
#    (...)    360     None: 함수는 스트리밍 결과를 출력만 하고 반환값은 없습니다.
#     361 """
#     362 prev_node = ""
# --> 363 for chunk_msg, metadata in graph.stream(inputs, config, stream_mode="messages"):
#     364     curr_node = metadata["langgraph_node"]
#     366     # node_names가 비어있거나 현재 노드가 node_names에 있는 경우에만 처리
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\__init__.py:2436, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2434         for task in loop.match_cached_writes():
#    2435             loop.output_writes(task.id, task.writes, cached=True)
# -> 2436         for _ in runner.tick(
#    2437             [t for t in loop.tasks.values() if not t.writes],
#    2438             timeout=self.step_timeout,
#    2439             get_waiter=get_waiter,
#    2440             schedule_task=loop.accept_push,
#    2441         ):
#    2442             # emit output
#    2443             yield from output()
#    2444 # emit output
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\runner.py:252, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     250 # panic on failure or timeout
#     251 try:
# --> 252     _panic_or_proceed(
#     253         futures.done.union(f for f, t in futures.items() if t is not None),
#     254         panic=reraise,
#     255     )
#     256 except Exception as exc:
#     257     if tb := exc.__traceback__:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\runner.py:509, in _panic_or_proceed(futs, timeout_exc_cls, panic)
#     507                 interrupts.append(exc)
#     508             elif fut not in SKIP_RERAISE_SET:
# --> 509                 raise exc
#     510 # raise combined interrupts
#     511 if interrupts:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\executor.py:80, in BackgroundExecutor.done(self, task)
#      78 """Remove the task from the tasks dict when it's done."""
#      79 try:
# ---> 80     task.result()
#      81 except GraphBubbleUp:
#      82     # This exception is an interruption signal, not an error
#      83     # so we don't want to re-raise it on exit
#      84     self.tasks.pop(task)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\utils\runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[19], line 50, in supervisor_agent(state)
#      41 supervisor_chain = (
#      42     prompt.partial(
#      43         options=str(options_for_next),
#    (...)     46     ) | llm.with_structured_output(RouteResponse)
#      47 )
#      49 # Agent 호출하고 'next' 키로 딕셔너리 반환
# ---> 50 route_response = supervisor_chain.invoke(state)
#      51 return {"next": route_response.next}
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)   5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)    954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1011, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1005 if self._should_stream(
#    1006     async_api=False,
#    1007     run_manager=run_manager,
#    1008     **kwargs,
#    1009 ):
#    1010     chunks: list[ChatGenerationChunk] = []
# -> 1011     for chunk in self._stream(messages, stop=stop, **kwargs):
#    1012         chunk.message.response_metadata = _gen_info_and_msg_metadata(chunk)
#    1013         if run_manager:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:668, in BaseChatOpenAI._stream(self, messages, stop, run_manager, **kwargs)
#     666     base_generation_info = {"headers": dict(raw_response.headers)}
#     667 else:
# --> 668     response = self.client.create(**payload)
#     669 with response:
#     670     is_first_chunk = True
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:925, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     882 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     883 def create(
#     884     self,
#    (...)    922     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     923 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     924     validate_response_format(response_format)
# --> 925     return self._post(
#     926         "/chat/completions",
#     927         body=maybe_transform(
#     928             {
#     929                 "messages": messages,
#     930                 "model": model,
#     931                 "audio": audio,
#     932                 "frequency_penalty": frequency_penalty,
#     933                 "function_call": function_call,
#     934                 "functions": functions,
#     935                 "logit_bias": logit_bias,
#     936                 "logprobs": logprobs,
#     937                 "max_completion_tokens": max_completion_tokens,
#     938                 "max_tokens": max_tokens,
#     939                 "metadata": metadata,
#     940                 "modalities": modalities,
#     941                 "n": n,
#     942                 "parallel_tool_calls": parallel_tool_calls,
#     943                 "prediction": prediction,
#     944                 "presence_penalty": presence_penalty,
#     945                 "reasoning_effort": reasoning_effort,
#     946                 "response_format": response_format,
#     947                 "seed": seed,
#     948                 "service_tier": service_tier,
#     949                 "stop": stop,
#     950                 "store": store,
#     951                 "stream": stream,
#     952                 "stream_options": stream_options,
#     953                 "temperature": temperature,
#     954                 "tool_choice": tool_choice,
#     955                 "tools": tools,
#     956                 "top_logprobs": top_logprobs,
#     957                 "top_p": top_p,
#     958                 "user": user,
#     959                 "web_search_options": web_search_options,
#     960             },
#     961             completion_create_params.CompletionCreateParamsStreaming
#     962             if stream
#     963             else completion_create_params.CompletionCreateParamsNonStreaming,
#     964         ),
#     965         options=make_request_options(
#     966             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     967         ),
#     968         cast_to=ChatCompletion,
#     969         stream=stream or False,
#     970         stream_cls=Stream[ChatCompletionChunk],
#     971     )
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1034             err.response.read()
#    1036         log.debug("Re-raising status error")
# -> 1037         raise self._make_status_error_from_response(err.response) from None
#    1039     break
#    1041 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "This model's maximum context length is 1047576 tokens. However, your messages resulted in 1180002 tokens (1179956 in the messages, 46 in the functions). Please reduce the length of the messages or functions.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# During task with name 'Supervisor' and id '741de1b9-e7fe-7f24-3ab2-419736bfabfe'

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

question = "1995년 3월 28일 남자, 1997년 09월 01일 여자의 궁합운 운세봐줘"
# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content=question
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you please analyze the compatibility between a male born on March 28, 1995, and a female born on September 1, 1997, using their Four Pillars of Destiny (Ba Zi)? I am interested in understanding their birth chart analysis and how their elements interact, as well as any insights into their potential relationship dynamics and compatibility.1995년 3월 28일 남자, 1997년 09월 01일 여자의 궁합운 운세봐줘
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[36], line 20
#      10 inputs = {
#      11     "messages": [
#      12         HumanMessage(
#    (...)     16     ],
#      17 }
#      19 # 그래프 실행
# ---> 20 stream_graph(graph, inputs, config)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_teddynote\messages.py:363, in stream_graph(graph, inputs, config, node_names, callback)
#     348 """
#     349 LangGraph의 실행 결과를 스트리밍하여 출력하는 함수입니다.
#     350
#    (...)    360     None: 함수는 스트리밍 결과를 출력만 하고 반환값은 없습니다.
#     361 """
#     362 prev_node = ""
# --> 363 for chunk_msg, metadata in graph.stream(inputs, config, stream_mode="messages"):
#     364     curr_node = metadata["langgraph_node"]
#     366     # node_names가 비어있거나 현재 노드가 node_names에 있는 경우에만 처리
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\__init__.py:2436, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2434         for task in loop.match_cached_writes():
#    2435             loop.output_writes(task.id, task.writes, cached=True)
# -> 2436         for _ in runner.tick(
#    2437             [t for t in loop.tasks.values() if not t.writes],
#    2438             timeout=self.step_timeout,
#    2439             get_waiter=get_waiter,
#    2440             schedule_task=loop.accept_push,
#    2441         ):
#    2442             # emit output
#    2443             yield from output()
#    2444 # emit output
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\runner.py:252, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     250 # panic on failure or timeout
#     251 try:
# --> 252     _panic_or_proceed(
#     253         futures.done.union(f for f, t in futures.items() if t is not None),
#     254         panic=reraise,
#     255     )
#     256 except Exception as exc:
#     257     if tb := exc.__traceback__:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\runner.py:509, in _panic_or_proceed(futs, timeout_exc_cls, panic)
#     507                 interrupts.append(exc)
#     508             elif fut not in SKIP_RERAISE_SET:
# --> 509                 raise exc
#     510 # raise combined interrupts
#     511 if interrupts:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\executor.py:80, in BackgroundExecutor.done(self, task)
#      78 """Remove the task from the tasks dict when it's done."""
#      79 try:
# ---> 80     task.result()
#      81 except GraphBubbleUp:
#      82     # This exception is an interruption signal, not an error
#      83     # so we don't want to re-raise it on exit
#      84     self.tasks.pop(task)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\utils\runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[19], line 50, in supervisor_agent(state)
#      41 supervisor_chain = (
#      42     prompt.partial(
#      43         options=str(options_for_next),
#    (...)     46     ) | llm.with_structured_output(RouteResponse)
#      47 )
#      49 # Agent 호출하고 'next' 키로 딕셔너리 반환
# ---> 50 route_response = supervisor_chain.invoke(state)
#      51 return {"next": route_response.next}
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)   5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)    954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1011, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1005 if self._should_stream(
#    1006     async_api=False,
#    1007     run_manager=run_manager,
#    1008     **kwargs,
#    1009 ):
#    1010     chunks: list[ChatGenerationChunk] = []
# -> 1011     for chunk in self._stream(messages, stop=stop, **kwargs):
#    1012         chunk.message.response_metadata = _gen_info_and_msg_metadata(chunk)
#    1013         if run_manager:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:668, in BaseChatOpenAI._stream(self, messages, stop, run_manager, **kwargs)
#     666     base_generation_info = {"headers": dict(raw_response.headers)}
#     667 else:
# --> 668     response = self.client.create(**payload)
#     669 with response:
#     670     is_first_chunk = True
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:925, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     882 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     883 def create(
#     884     self,
#    (...)    922     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     923 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     924     validate_response_format(response_format)
# --> 925     return self._post(
#     926         "/chat/completions",
#     927         body=maybe_transform(
#     928             {
#     929                 "messages": messages,
#     930                 "model": model,
#     931                 "audio": audio,
#     932                 "frequency_penalty": frequency_penalty,
#     933                 "function_call": function_call,
#     934                 "functions": functions,
#     935                 "logit_bias": logit_bias,
#     936                 "logprobs": logprobs,
#     937                 "max_completion_tokens": max_completion_tokens,
#     938                 "max_tokens": max_tokens,
#     939                 "metadata": metadata,
#     940                 "modalities": modalities,
#     941                 "n": n,
#     942                 "parallel_tool_calls": parallel_tool_calls,
#     943                 "prediction": prediction,
#     944                 "presence_penalty": presence_penalty,
#     945                 "reasoning_effort": reasoning_effort,
#     946                 "response_format": response_format,
#     947                 "seed": seed,
#     948                 "service_tier": service_tier,
#     949                 "stop": stop,
#     950                 "store": store,
#     951                 "stream": stream,
#     952                 "stream_options": stream_options,
#     953                 "temperature": temperature,
#     954                 "tool_choice": tool_choice,
#     955                 "tools": tools,
#     956                 "top_logprobs": top_logprobs,
#     957                 "top_p": top_p,
#     958                 "user": user,
#     959                 "web_search_options": web_search_options,
#     960             },
#     961             completion_create_params.CompletionCreateParamsStreaming
#     962             if stream
#     963             else completion_create_params.CompletionCreateParamsNonStreaming,
#     964         ),
#     965         options=make_request_options(
#     966             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     967         ),
#     968         cast_to=ChatCompletion,
#     969         stream=stream or False,
#     970         stream_cls=Stream[ChatCompletionChunk],
#     971     )
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1034             err.response.read()
#    1036         log.debug("Re-raising status error")
# -> 1037         raise self._make_status_error_from_response(err.response) from None
#    1039     break
#    1041 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Request too large for gpt-4.1-mini-long-context in organization org-n8h6eTrPolQT4RTdz1CaZ4kB on tokens per min (TPM): Limit 1000000, Requested 7339794. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# During task with name 'Supervisor' and id '5acf3bad-1834-7d6f-9784-87f3682941ca'

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="대운과 세운, 조심해야 할것들 알려줘"
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide insights on the major luck cycles (Da Yun) and annual luck cycles (Se Yun) in my Four Pillars of Destiny (Ba Zi) chart? Additionally, I would like to know what specific areas I should be cautious about during these cycles, based on my birth chart analysis.대운과 세운, 조심해야 할것들 알려줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 대운과 세운, 그리고 주의사항에 대해 상세히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 대운 시작 나이 및 방향
#
# - 출생 월(음력 7월, 무신월) 기준으로 여성은 대운을 역행(뒤로) 시작합니다.
# - 대운 시작 나이는 보통 8세 전후이며, 정확한 시작 시점은 음력 생월과 생일에 따라 다르지만 대략 7~8세부터 시작한다고 봅니다.
#
# ### 대운 목록 및 해석
#
# | 나이 구간 | 대운  | 천간지지 | 오행 구성 | 해석 및 특징                          |
# |-----------|--------|----------|-----------|-------------------------------------|
# | 0~8       | -      | -        | -         | 출생부터 대운 시작 전, 성장기        |
# | 8~18      | 기유(己酉) | 己(土), 酉(金) | 토, 금    | 토와 금의 기운 강화, 안정과 규율 중시  |
# | 18~28     | 경술(庚戌) | 庚(金), 戌(土) | 금, 토    | 금과 토의 기운 지속 강화, 직장운과 권위 상승 |
# | 28~38     | 신해(辛亥) | 辛(金), 亥(水) | 금, 수    | 금과 수의 기운 강화, 지혜와 융통성 증가, 목 부족 보완 |
# | 38~48     | 임자(壬子) | 壬(水), 子(水) | 수        | 수의 기운 강해짐, 감성 및 정신적 안정, 목 기운 보완 지속 |
#
# - 현재 2024년 기준으로 27세이므로 **신해 대운(28~38세)**에 해당합니다.
# - 신해 대운은 금과 수의 기운이 강해 목 부족을 보완하고, 지혜와 융통성을 키우는 좋은 시기입니다.
# - 이 시기에 새로운 기회와 변화를 맞이할 수 있으며, 특히 학문, 직업, 인간관계에서 긍정적인 발전이 기대됩니다.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2023~2025년)
#
# | 연도 | 세운  | 천간지지 | 오행 구성 | 해석 및 주의사항                      |
# |-------|--------|----------|-----------|-------------------------------------|
# | 2023  | 계묘(癸卯) | 癸(水), 卯(木) | 수, 목    | 부족한 목 기운 보완, 성장과 발전 기회, 건강 주의 (간, 신장) |
# | 2024  | 갑진(甲辰) | 甲(木), 辰(土) | 목, 토    | 목과 토의 조화, 새로운 시작과 안정, 과로 주의 |
# | 2025  | 을사(乙巳) | 乙(木), 巳(火) | 목, 화    | 목과 화의 상승, 열정과 추진력 증가, 감정 조절 필요 |
#
# - 2023년부터 2025년까지는 부족한 목 기운이 보완되는 시기로, 성장과 발전에 유리합니다.
# - 특히 2024년 갑진년은 목과 토가 조화를 이루어 새로운 시작과 안정에 좋은 해입니다.
# - 2025년 을사년은 화의 기운이 강해져 열정이 넘치지만, 감정 조절과 건강 관리에 주의가 필요합니다.
#
# ---
#
# ## 3. 주의해야 할 점 및 조언
#
# ### 1) 건강 관련 주의
#
# - 화가 강하고 목이 부족한 사주이므로, 간과 신장 건강에 신경 써야 합니다.
# - 스트레스가 쌓이면 화가 과도해져 소화기 계통이나 심장에 무리가 올 수 있으니 규칙적인 운동과 휴식이 필요합니다.
#
# ### 2) 성격 및 대인관계
#
# - 화가 강해 성격이 급하고 열정적이지만, 목이 부족해 융통성과 부드러움이 부족할 수 있습니다.
# - 대인관계에서 다소 직설적이거나 고집이 셀 수 있으니 상대방의 입장을 배려하는 노력이 필요합니다.
#
# ### 3) 운세 흐름에 따른 조심사항
#
# - 대운과 세운에서 금과 수가 강화되는 시기에는 감정 기복이나 건강 문제에 주의하세요.
# - 특히 2025년 을사년은 화의 기운이 강해져 감정 조절이 어려울 수 있으니 명상, 요가 등 마음을 다스리는 활동을 권장합니다.
#
# ### 4) 오행 보완 방법
#
# - 목 기운 보완을 위해 녹색 계열의 옷차림, 자연과의 접촉, 채소와 해조류 섭취를 권장합니다.
# - 수 기운을 돕는 검은색, 파란색 계열도 좋으며, 물과 관련된 활동(수영, 산책 등)을 늘리면 좋습니다.
#
# ---
#
# ## 4. 종합 요약
#
# - 현재 신해 대운으로 금과 수의 기운이 강화되어 목 부족을 보완하는 좋은 시기입니다.
# - 2023~2025년 세운 역시 목 기운이 보완되어 성장과 발전에 유리합니다.
# - 건강과 감정 조절에 주의하며, 특히 간과 신장 건강을 챙기세요.
# - 대인관계에서 부드러움과 융통성을 키우는 노력이 필요합니다.
# - 오행 보완을 위한 생활습관 개선과 자연 친화적 활동을 권장합니다.
#
# ---
#
# 필요하시면 더 상세한 대운별 운세 변화나 특정 시기별 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행 분석 기준에 따름.
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 대운과 세운, 그리고 주의사항에 대해 상세히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 대운 시작 나이 및 방향
#
# - 출생 월(음력 7월, 무신월) 기준으로 여성은 대운을 역행(뒤로) 시작합니다.
# - 대운 시작 나이는 보통 8세 전후이며, 정확한 시작 시점은 음력 생월과 생일에 따라 다르지만 대략 7~8세부터 시작한다고 봅니다.
#
# ### 대운 목록 및 해석
#
# | 나이 구간 | 대운  | 천간지지 | 오행 구성 | 해석 및 특징                          |
# |-----------|--------|----------|-----------|-------------------------------------|
# | 0~8       | -      | -        | -         | 출생부터 대운 시작 전, 성장기        |
# | 8~18      | 기유(己酉) | 己(土), 酉(金) | 토, 금    | 토와 금의 기운 강화, 안정과 규율 중시  |
# | 18~28     | 경술(庚戌) | 庚(金), 戌(土) | 금, 토    | 금과 토의 기운 지속 강화, 직장운과 권위 상승 |
# | 28~38     | 신해(辛亥) | 辛(金), 亥(水) | 금, 수    | 금과 수의 기운 강화, 지혜와 융통성 증가, 목 부족 보완 |
# | 38~48     | 임자(壬子) | 壬(水), 子(水) | 수        | 수의 기운 강해짐, 감성 및 정신적 안정, 목 기운 보완 지속 |
#
# - 현재 2024년 기준으로 27세이므로 **신해 대운(28~38세)**에 해당합니다.
# - 신해 대운은 금과 수의 기운이 강해 목 부족을 보완하고, 지혜와 융통성을 키우는 좋은 시기입니다.
# - 이 시기에 새로운 기회와 변화를 맞이할 수 있으며, 특히 학문, 직업, 인간관계에서 긍정적인 발전이 기대됩니다.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2023~2025년)
#
# | 연도 | 세운  | 천간지지 | 오행 구성 | 해석 및 주의사항                      |
# |-------|--------|----------|-----------|-------------------------------------|
# | 2023  | 계묘(癸卯) | 癸(水), 卯(木) | 수, 목    | 부족한 목 기운 보완, 성장과 발전 기회, 건강 주의 (간, 신장) |
# | 2024  | 갑진(甲辰) | 甲(木), 辰(土) | 목, 토    | 목과 토의 조화, 새로운 시작과 안정, 과로 주의 |
# | 2025  | 을사(乙巳) | 乙(木), 巳(火) | 목, 화    | 목과 화의 상승, 열정과 추진력 증가, 감정 조절 필요 |
#
# - 2023년부터 2025년까지는 부족한 목 기운이 보완되는 시기로, 성장과 발전에 유리합니다.
# - 특히 2024년 갑진년은 목과 토가 조화를 이루어 새로운 시작과 안정에 좋은 해입니다.
# - 2025년 을사년은 화의 기운이 강해져 열정이 넘치지만, 감정 조절과 건강 관리에 주의가 필요합니다.
#
# ---
#
# ## 3. 주의해야 할 점 및 조언
#
# ### 1) 건강 관련 주의
#
# - 화가 강하고 목이 부족한 사주이므로, 간과 신장 건강에 신경 써야 합니다.
# - 스트레스가 쌓이면 화가 과도해져 소화기 계통이나 심장에 무리가 올 수 있으니 규칙적인 운동과 휴식이 필요합니다.
#
# ### 2) 성격 및 대인관계
#
# - 화가 강해 성격이 급하고 열정적이지만, 목이 부족해 융통성과 부드러움이 부족할 수 있습니다.
# - 대인관계에서 다소 직설적이거나 고집이 셀 수 있으니 상대방의 입장을 배려하는 노력이 필요합니다.
#
# ### 3) 운세 흐름에 따른 조심사항
#
# - 대운과 세운에서 금과 수가 강화되는 시기에는 감정 기복이나 건강 문제에 주의하세요.
# - 특히 2025년 을사년은 화의 기운이 강해져 감정 조절이 어려울 수 있으니 명상, 요가 등 마음을 다스리는 활동을 권장합니다.
#
# ### 4) 오행 보완 방법
#
# - 목 기운 보완을 위해 녹색 계열의 옷차림, 자연과의 접촉, 채소와 해조류 섭취를 권장합니다.
# - 수 기운을 돕는 검은색, 파란색 계열도 좋으며, 물과 관련된 활동(수영, 산책 등)을 늘리면 좋습니다.
#
# ---
#
# ## 4. 종합 요약
#
# - 현재 신해 대운으로 금과 수의 기운이 강화되어 목 부족을 보완하는 좋은 시기입니다.
# - 2023~2025년 세운 역시 목 기운이 보완되어 성장과 발전에 유리합니다.
# - 건강과 감정 조절에 주의하며, 특히 간과 신장 건강을 챙기세요.
# - 대인관계에서 부드러움과 융통성을 키우는 노력이 필요합니다.
# - 오행 보완을 위한 생활습관 개선과 자연 친화적 활동을 권장합니다.
#
# ---
#
# 필요하시면 더 상세한 대운별 운세 변화나 특정 시기별 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행 분석 기준에 따름.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="금전운알려줘"
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide an analysis of my financial luck based on my Four Pillars of Destiny (Ba Zi)? I am particularly interested in understanding how my birth chart influences my financial opportunities and challenges.금전운알려줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 금전운에 대해 사주 원리와 오행, 십신 분석을 바탕으로 상세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구성 및 오행 요약
#
# | 구분 | 천간 | 지지 | 오행 |
# |-------|-------|-------|-------|
# | 연주  | 丁     | 丑     | 화, 토 |
# | 월주  | 戊     | 申     | 토, 금 |
# | 일주  | 丙     | 午     | 화, 화 |
# | 시주  | 癸     | 巳     | 수, 화 |
#
# - 화(火) 4점, 토(土) 2점, 금(金) 1점, 수(水) 1점, 목(木) 0점
# - 화가 매우 강하고, 토가 그 다음이며 금과 수는 약간, 목은 부족한 상태입니다.
#
# ---
#
# ## 2. 금전운과 관련된 십신 및 오행 해석
#
# ### 1) 금전운을 나타내는 십신
#
# - 금전운은 일간(일주 천간 丙火) 기준으로 재성(財星)과 편재(偏財), 정재(正財)로 판단합니다.
# - 火(일간 丙) 기준으로:
#   - 재성(正財): 토(土) → 戊, 己, 丑, 辰, 戌, 未
#   - 편재(偏財): 토(土) → 같은 토지만 재성과 구분됨
# - 본 사주에서 토(土)는 연지 丑, 월간 戊가 있어 재성(재물) 기운이 존재합니다.
# - 또한 월지 申(金)은 금(金)으로, 금은 화(火)를 극하는 오행으로 재물과 관련된 권위, 직업운과도 연결됩니다.
#
# ### 2) 재물운 강약
#
# - 토(土)가 2점으로 재성 기운이 적당히 있으나, 화(火)가 너무 강해 재성을 많이 극할 수 있습니다.
# - 금(金)은 1점으로 재물과 직업운에 도움을 주는 요소이나, 전체적으로 금이 약한 편입니다.
# - 수(水) 1점은 재물운에 간접적으로 도움을 줄 수 있으나, 목(木)이 전혀 없어 재물의 성장과 확장에 다소 제약이 있을 수 있습니다.
#
# ---
#
# ## 3. 대운과 금전운의 관계
#
# - 현재 대운은 신해(辛亥) 대운(28~38세)으로 금(金)과 수(水)의 기운이 강화되는 시기입니다.
# - 금과 수가 강화되면 재물운이 보완되고, 목 부족을 어느 정도 보완하여 재물의 확장과 관리에 유리합니다.
# - 특히 금의 기운이 강해지면 직업적 안정과 권위가 상승하여 금전적 기회가 늘어납니다.
#
# ---
#
# ## 4. 세운과 금전운
#
# - 2023년 계묘(癸卯), 2024년 갑진(甲辰), 2025년 을사(乙巳) 세운 모두 목(木)과 수(水), 화(火)의 기운이 보완되어 재물운에 긍정적입니다.
# - 특히 2024년 갑진년은 목과 토의 조화로 새로운 재물 기회와 안정이 기대됩니다.
# - 2025년 을사년은 화의 기운이 강해져 추진력과 열정이 증가하지만, 감정 조절이 필요하므로 재물 관리에 신중함이 요구됩니다.
#
# ---
#
# ## 5. 금전운 종합 해석 및 조언
#
# - 재성(土) 기운이 있으나 화(火)가 강해 재물을 다소 극하는 경향이 있으므로 재물 관리에 신중함이 필요합니다.
# - 현재 대운과 세운에서 금과 수가 강화되어 금전운이 점차 좋아지는 시기입니다.
# - 목(木) 부족으로 인해 재물의 성장과 확장에 한계가 있을 수 있으니, 목 기운을 보완하는 생활습관(녹색 계열 옷, 자연과의 접촉 등)을 권장합니다.
# - 재물운을 높이기 위해서는 계획적이고 체계적인 재물 관리가 중요하며, 감정에 치우치지 않는 냉철한 판단력이 필요합니다.
# - 투자나 재테크 시에는 신중한 분석과 전문가 조언을 참고하는 것이 좋습니다.
#
# ---
#
# 필요하시면 구체적인 시기별 금전운 변화나 투자 적기 등도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행, 십신 분석 기준에 따름.
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 금전운에 대해 사주 원리와 오행, 십신 분석을 바탕으로 상세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구성 및 오행 요약
#
# | 구분 | 천간 | 지지 | 오행 |
# |-------|-------|-------|-------|
# | 연주  | 丁     | 丑     | 화, 토 |
# | 월주  | 戊     | 申     | 토, 금 |
# | 일주  | 丙     | 午     | 화, 화 |
# | 시주  | 癸     | 巳     | 수, 화 |
#
# - 화(火) 4점, 토(土) 2점, 금(金) 1점, 수(水) 1점, 목(木) 0점
# - 화가 매우 강하고, 토가 그 다음이며 금과 수는 약간, 목은 부족한 상태입니다.
#
# ---
#
# ## 2. 금전운과 관련된 십신 및 오행 해석
#
# ### 1) 금전운을 나타내는 십신
#
# - 금전운은 일간(일주 천간 丙火) 기준으로 재성(財星)과 편재(偏財), 정재(正財)로 판단합니다.
# - 火(일간 丙) 기준으로:
#   - 재성(正財): 토(土) → 戊, 己, 丑, 辰, 戌, 未
#   - 편재(偏財): 토(土) → 같은 토지만 재성과 구분됨
# - 본 사주에서 토(土)는 연지 丑, 월간 戊가 있어 재성(재물) 기운이 존재합니다.
# - 또한 월지 申(金)은 금(金)으로, 금은 화(火)를 극하는 오행으로 재물과 관련된 권위, 직업운과도 연결됩니다.
#
# ### 2) 재물운 강약
#
# - 토(土)가 2점으로 재성 기운이 적당히 있으나, 화(火)가 너무 강해 재성을 많이 극할 수 있습니다.
# - 금(金)은 1점으로 재물과 직업운에 도움을 주는 요소이나, 전체적으로 금이 약한 편입니다.
# - 수(水) 1점은 재물운에 간접적으로 도움을 줄 수 있으나, 목(木)이 전혀 없어 재물의 성장과 확장에 다소 제약이 있을 수 있습니다.
#
# ---
#
# ## 3. 대운과 금전운의 관계
#
# - 현재 대운은 신해(辛亥) 대운(28~38세)으로 금(金)과 수(水)의 기운이 강화되는 시기입니다.
# - 금과 수가 강화되면 재물운이 보완되고, 목 부족을 어느 정도 보완하여 재물의 확장과 관리에 유리합니다.
# - 특히 금의 기운이 강해지면 직업적 안정과 권위가 상승하여 금전적 기회가 늘어납니다.
#
# ---
#
# ## 4. 세운과 금전운
#
# - 2023년 계묘(癸卯), 2024년 갑진(甲辰), 2025년 을사(乙巳) 세운 모두 목(木)과 수(水), 화(火)의 기운이 보완되어 재물운에 긍정적입니다.
# - 특히 2024년 갑진년은 목과 토의 조화로 새로운 재물 기회와 안정이 기대됩니다.
# - 2025년 을사년은 화의 기운이 강해져 추진력과 열정이 증가하지만, 감정 조절이 필요하므로 재물 관리에 신중함이 요구됩니다.
#
# ---
#
# ## 5. 금전운 종합 해석 및 조언
#
# - 재성(土) 기운이 있으나 화(火)가 강해 재물을 다소 극하는 경향이 있으므로 재물 관리에 신중함이 필요합니다.
# - 현재 대운과 세운에서 금과 수가 강화되어 금전운이 점차 좋아지는 시기입니다.
# - 목(木) 부족으로 인해 재물의 성장과 확장에 한계가 있을 수 있으니, 목 기운을 보완하는 생활습관(녹색 계열 옷, 자연과의 접촉 등)을 권장합니다.
# - 재물운을 높이기 위해서는 계획적이고 체계적인 재물 관리가 중요하며, 감정에 치우치지 않는 냉철한 판단력이 필요합니다.
# - 투자나 재테크 시에는 신중한 분석과 전문가 조언을 참고하는 것이 좋습니다.
#
# ---
#
# 필요하시면 구체적인 시기별 금전운 변화나 투자 적기 등도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행, 십신 분석 기준에 따름.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 1})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="1995년 3월 28일 남자, 12시 30분 출생 운세봐줘"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide a fortune reading for a male born on March 28, 1995, at 12:30 PM? I am interested in a detailed analysis of his Four Pillars of Destiny (Ba Zi) and how they may influence his personality, career prospects, and overall life path. Please include insights based on his birth chart analysis and any significant elements or interactions present in his chart.1995년 3월 28일 남자, 12시 30분 출생 운세봐줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 을해
# 월주(月柱): 기묘
# 일주(日柱): 무오
# 시주(時柱): 무오
# 일간(日干): 무
#
# === 오행 강약 ===
# 목: 39점
# 화: 20점
# 토: 68점
# 금: 0점
# 수: 10점
#
# === 십신 분석 ===
# 년주: 천간:정관, 지지:편재(70%), 지지:편관(30%)
# 월주: 천간:겁재, 지지:정관(100%)
# 일주: 지지:정인(70%), 지지:겁재(30%)
# 시주: 지지:정인(70%), 지지:겁재(30%)
#
# === 대운 (정밀 계산) ===
# 5세: 무인 (2000년 ~ 2009년)
# 15세: 정축 (2010년 ~ 2019년)
# 25세: 병자 (2020년 ~ 2029년)
# 35세: 을해 (2030년 ~ 2039년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주: 을해
# - 월주: 기묘
# - 일주: 무오
# - 시주: 무오
# - 일간: 무
#
# 오행 강약은 토가 가장 강하고, 목과 화가 그 다음이며 금은 부족한 편입니다.
#
# 십신 분석에서는 정관, 편재, 편관, 겁재, 정인이 혼재되어 있어 다양한 성격과 운의 흐름을 나타냅니다.
#
# 대운은 현재 25세부터 2029년까지 병자 대운이 진행 중이며, 이후 35세부터 을해 대운이 시작됩니다.
#
# 이 사주는 토의 기운이 강해 안정적이고 현실적인 성향이 강하며, 목과 화의 기운이 있어 창의력과 활동성도 겸비되어 있습니다. 금의 기운이 부족하므로 금과 관련된 분야나 성격은 보완이 필요할 수 있습니다.
#
# 대운의 흐름에 따라 20대 후반부터 30대 초반까지는 중요한 변화와 성장이 예상되니 이 시기를 잘 활용하는 것이 좋겠습니다.
# ==================================================
# 🔄 Node: ManseTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주: 을해
# - 월주: 기묘
# - 일주: 무오
# - 시주: 무오
# - 일간: 무
#
# 오행 강약은 토가 가장 강하고, 목과 화가 그 다음이며 금은 부족한 편입니다.
#
# 십신 분석에서는 정관, 편재, 편관, 겁재, 정인이 혼재되어 있어 다양한 성격과 운의 흐름을 나타냅니다.
#
# 대운은 현재 25세부터 2029년까지 병자 대운이 진행 중이며, 이후 35세부터 을해 대운이 시작됩니다.
#
# 이 사주는 토의 기운이 강해 안정적이고 현실적인 성향이 강하며, 목과 화의 기운이 있어 창의력과 활동성도 겸비되어 있습니다. 금의 기운이 부족하므로 금과 관련된 분야나 성격은 보완이 필요할 수 있습니다.
#
# 대운의 흐름에 따라 20대 후반부터 30대 초반까지는 중요한 변화와 성장이 예상되니 이 시기를 잘 활용하는 것이 좋겠습니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 (천간지지 변환 및 시주 계산)
#
# - 출생일: 1995년 3월 28일 12시 30분 (양력)
# - 성별: 남성
# - 출생시간: 12시 30분은 지지로 "오시(午時)"에 해당 (11:30~13:30)
#
# ### 사주팔자 (천간지지)
#
# - 연주(년간/년지): 을해(乙亥)
# - 월주(월간/월지): 기묘(己卯)
# - 일주(일간/일지): 무오(戊午)
# - 시주(시간/시지): 무오(戊午)
#
# 총 8글자: 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 1) 천간지지 → 오행 매핑 (기준)
#
# | 오행 | 해당 글자(천간/지지)          |
# |-------|-----------------------------|
# | 목(木) | 甲, 乙, 寅, 卯              |
# | 화(火) | 丙, 丁, 巳, 午              |
# | 토(土) | 戊, 己, 辰, 戌, 丑, 未      |
# | 금(金) | 庚, 辛, 申, 酉              |
# | 수(水) | 壬, 癸, 子, 亥              |
#
# ### 2) 8글자 오행 분류 및 점수
#
# | 글자 | 오행 | 점수 |
# |-------|-------|-------|
# | 乙(을) | 목(木) | 1 |
# | 亥(해) | 수(水) | 1 |
# | 己(기) | 토(土) | 1 |
# | 卯(묘) | 목(木) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
#
# ### 3) 오행별 점수 합산 및 글자
#
# | 오행 | 점수 | 글자             |
# |-------|-------|------------------|
# | 목(木) | 2     | 乙, 卯            |
# | 화(火) | 2     | 午, 午            |
# | 토(土) | 3     | 己, 戊, 戊        |
# | 금(金) | 0     |                  |
# | 수(水) | 1     | 亥                |
#
# **총합: 2+2+3+0+1 = 8 (계산 유효)**
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 강약 및 균형 분석
#
# - **토(土)**가 가장 강함 (3점) → 안정적이고 현실적, 책임감 강함
# - **목(木)**과 **화(火)**가 중간 수준 (각 2점) → 창의력, 성장, 활동성, 열정 있음
# - **수(水)**는 약간 있음 (1점) → 지혜, 유연성, 감성
# - **금(金)**은 전혀 없음 (0점) → 금의 기운 부족, 결단력, 냉철함, 조직력 보완 필요
#
# ### 상생상극 관계
#
# - 목(木)은 화(火)를 생하고, 화(火)는 토(土)를 생함 → 목과 화가 토를 도와주는 좋은 구조
# - 토(土)는 수(水)를 극하고, 수(水)는 화(火)를 극함 → 수가 약해 화를 제어하지 못함
# - 금(金)이 없어 토(土)를 극하거나 목(木)을 제어하는 힘이 부족함
#
# **요약:** 토(土) 중심의 강한 기운에 목(木)과 화(火)가 조화를 이루고 있으나, 금(金) 부족으로 균형이 다소 깨진 상태입니다.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 무(土) 기준)
#
# - 일간(日干): 무(土)
# - 나머지 7글자와의 관계를 십신으로 해석
#
# | 글자 | 십신 관계 (무(土) 기준) | 의미 요약 |
# |-------|-------------------------|-----------|
# | 乙(을) | 편재 (목은 토의 재성) | 재물, 재능, 경쟁 |
# | 亥(해) | 편인 (수는 토의 인성) | 지혜, 보호, 학문 |
# | 己(기) | 비견 (토는 토의 비견) | 동료, 경쟁, 협력 |
# | 卯(묘) | 편재 (목) | 재물, 경쟁 |
# | 戊(무) | 비견 (토) | 동료, 경쟁 |
# | 午(오) | 식신 (화는 토의 식신) | 창의, 표현, 활동 |
# | 戊(무) | 비견 (토) | 동료, 경쟁 |
# | 午(오) | 식신 (화) | 창의, 활동 |
#
# - 비견(己, 戊)과 편재(乙, 卯)가 많아 경쟁심과 자기주장이 강함
# - 식신(午)이 있어 창의력과 표현력이 뛰어남
# - 편인(亥)은 지혜와 보호를 의미해 균형을 맞춤
#
# ---
#
# ## 5. 대운(大運) 분석
#
# - 출생 연도와 월을 기준으로 대운 시작 시기 산출
# - 남성은 출생 월의 절기 기준으로 앞으로 대운이 진행됨
#
# ### 대운 흐름 (예상)
#
# | 나이 | 대운  | 오행 및 특징          |
# |-------|--------|---------------------|
# | 0~5   | 기미(己未) | 토, 안정, 성장기       |
# | 6~15  | 경신(庚申) | 금, 부족한 금 보완 가능 |
# | 16~25 | 신유(辛酉) | 금, 금 기운 강화       |
# | 26~35 | 임술(壬戌) | 수, 감성 및 지혜 보완  |
# | 36~45 | 계해(癸亥) | 수, 지혜와 보호 강화   |
#
# - 25세부터 35세까지는 수(水) 기운이 보완되어 감성과 지혜가 강화되는 시기
# - 금(金) 기운이 부족하므로 6~25세 대운에서 금 기운이 들어와 보완됨
#
# ---
#
# ## 6. 종합 해석 및 조언
#
# ### 성격 및 기질
#
# - 현실적이고 책임감 강한 토(土) 기운이 주도
# - 목(木)과 화(火)의 조화로 창의적이고 활동적이며 성장욕구가 강함
# - 경쟁심과 자기주장이 강하며, 표현력과 활동성이 뛰어남
# - 금(金) 부족으로 인해 때로는 결단력이나 냉철함이 부족할 수 있음
#
# ### 건강 및 생활 조언
#
# - 금(金) 기운 보완을 위해 흰색, 금속성 물건, 규칙적인 운동 권장
# - 수(水) 기운이 약간 있으나 대운에서 보완되므로 감성적 안정에 도움
# - 토(土) 기운이 강해 소화기 계통 건강에 유의 필요
#
# ### 운세 및 대운 활용
#
# - 20대 후반부터 30대 초반까지 수(水) 대운이 들어와 지혜와 감성이 보완되는 시기
# - 금(金) 대운 시기에는 부족한 금 기운을 보완하여 결단력과 조직력이 강화됨
# - 창의력과 활동성을 살려 자신의 분야에서 성장을 도모하면 좋은 결과 기대
#
# ---
#
# ## 7. 요약
#
# | 구분 | 내용 |
# |-------|-------|
# | 사주팔자 | 을해(乙亥), 기묘(己卯), 무오(戊午), 무오(戊午) |
# | 오행분포 | 토 3, 목 2, 화 2, 수 1, 금 0 |
# | 십신특징 | 경쟁심 강한 비견과 편재, 창의적 식신, 지혜의 편인 |
# | 대운흐름 | 금과 수 기운 보완 대운 진행 중 |
# | 성격특징 | 현실적, 책임감, 창의적, 경쟁심 강함, 결단력 보완 필요 |
# | 건강조언 | 소화기 건강 주의, 금 기운 보완 권장 |
# | 운세조언 | 20대 후반~30대 초반 대운 활용 중요 |
#
# ---
#
# 필요하시면 대운과 세운(연운) 분석도 추가로 상세히 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 (천간지지 변환 및 시주 계산)
#
# - 출생일: 1995년 3월 28일 12시 30분 (양력)
# - 성별: 남성
# - 출생시간: 12시 30분은 지지로 "오시(午時)"에 해당 (11:30~13:30)
#
# ### 사주팔자 (천간지지)
#
# - 연주(년간/년지): 을해(乙亥)
# - 월주(월간/월지): 기묘(己卯)
# - 일주(일간/일지): 무오(戊午)
# - 시주(시간/시지): 무오(戊午)
#
# 총 8글자: 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 1) 천간지지 → 오행 매핑 (기준)
#
# | 오행 | 해당 글자(천간/지지)          |
# |-------|-----------------------------|
# | 목(木) | 甲, 乙, 寅, 卯              |
# | 화(火) | 丙, 丁, 巳, 午              |
# | 토(土) | 戊, 己, 辰, 戌, 丑, 未      |
# | 금(金) | 庚, 辛, 申, 酉              |
# | 수(水) | 壬, 癸, 子, 亥              |
#
# ### 2) 8글자 오행 분류 및 점수
#
# | 글자 | 오행 | 점수 |
# |-------|-------|-------|
# | 乙(을) | 목(木) | 1 |
# | 亥(해) | 수(水) | 1 |
# | 己(기) | 토(土) | 1 |
# | 卯(묘) | 목(木) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
#
# ### 3) 오행별 점수 합산 및 글자
#
# | 오행 | 점수 | 글자             |
# |-------|-------|------------------|
# | 목(木) | 2     | 乙, 卯            |
# | 화(火) | 2     | 午, 午            |
# | 토(土) | 3     | 己, 戊, 戊        |
# | 금(金) | 0     |                  |
# | 수(水) | 1     | 亥                |
#
# **총합: 2+2+3+0+1 = 8 (계산 유효)**
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 강약 및 균형 분석
#
# - **토(土)**가 가장 강함 (3점) → 안정적이고 현실적, 책임감 강함
# - **목(木)**과 **화(火)**가 중간 수준 (각 2점) → 창의력, 성장, 활동성, 열정 있음
# - **수(水)**는 약간 있음 (1점) → 지혜, 유연성, 감성
# - **금(金)**은 전혀 없음 (0점) → 금의 기운 부족, 결단력, 냉철함, 조직력 보완 필요
#
# ### 상생상극 관계
#
# - 목(木)은 화(火)를 생하고, 화(火)는 토(土)를 생함 → 목과 화가 토를 도와주는 좋은 구조
# - 토(土)는 수(水)를 극하고, 수(水)는 화(火)를 극함 → 수가 약해 화를 제어하지 못함
# - 금(金)이 없어 토(土)를 극하거나 목(木)을 제어하는 힘이 부족함
#
# **요약:** 토(土) 중심의 강한 기운에 목(木)과 화(火)가 조화를 이루고 있으나, 금(金) 부족으로 균형이 다소 깨진 상태입니다.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 무(土) 기준)
#
# - 일간(日干): 무(土)
# - 나머지 7글자와의 관계를 십신으로 해석
#
# | 글자 | 십신 관계 (무(土) 기준) | 의미 요약 |
# |-------|-------------------------|-----------|
# | 乙(을) | 편재 (목은 토의 재성) | 재물, 재능, 경쟁 |
# | 亥(해) | 편인 (수는 토의 인성) | 지혜, 보호, 학문 |
# | 己(기) | 비견 (토는 토의 비견) | 동료, 경쟁, 협력 |
# | 卯(묘) | 편재 (목) | 재물, 경쟁 |
# | 戊(무) | 비견 (토) | 동료, 경쟁 |
# | 午(오) | 식신 (화는 토의 식신) | 창의, 표현, 활동 |
# | 戊(무) | 비견 (토) | 동료, 경쟁 |
# | 午(오) | 식신 (화) | 창의, 활동 |
#
# - 비견(己, 戊)과 편재(乙, 卯)가 많아 경쟁심과 자기주장이 강함
# - 식신(午)이 있어 창의력과 표현력이 뛰어남
# - 편인(亥)은 지혜와 보호를 의미해 균형을 맞춤
#
# ---
#
# ## 5. 대운(大運) 분석
#
# - 출생 연도와 월을 기준으로 대운 시작 시기 산출
# - 남성은 출생 월의 절기 기준으로 앞으로 대운이 진행됨
#
# ### 대운 흐름 (예상)
#
# | 나이 | 대운  | 오행 및 특징          |
# |-------|--------|---------------------|
# | 0~5   | 기미(己未) | 토, 안정, 성장기       |
# | 6~15  | 경신(庚申) | 금, 부족한 금 보완 가능 |
# | 16~25 | 신유(辛酉) | 금, 금 기운 강화       |
# | 26~35 | 임술(壬戌) | 수, 감성 및 지혜 보완  |
# | 36~45 | 계해(癸亥) | 수, 지혜와 보호 강화   |
#
# - 25세부터 35세까지는 수(水) 기운이 보완되어 감성과 지혜가 강화되는 시기
# - 금(金) 기운이 부족하므로 6~25세 대운에서 금 기운이 들어와 보완됨
#
# ---
#
# ## 6. 종합 해석 및 조언
#
# ### 성격 및 기질
#
# - 현실적이고 책임감 강한 토(土) 기운이 주도
# - 목(木)과 화(火)의 조화로 창의적이고 활동적이며 성장욕구가 강함
# - 경쟁심과 자기주장이 강하며, 표현력과 활동성이 뛰어남
# - 금(金) 부족으로 인해 때로는 결단력이나 냉철함이 부족할 수 있음
#
# ### 건강 및 생활 조언
#
# - 금(金) 기운 보완을 위해 흰색, 금속성 물건, 규칙적인 운동 권장
# - 수(水) 기운이 약간 있으나 대운에서 보완되므로 감성적 안정에 도움
# - 토(土) 기운이 강해 소화기 계통 건강에 유의 필요
#
# ### 운세 및 대운 활용
#
# - 20대 후반부터 30대 초반까지 수(水) 대운이 들어와 지혜와 감성이 보완되는 시기
# - 금(金) 대운 시기에는 부족한 금 기운을 보완하여 결단력과 조직력이 강화됨
# - 창의력과 활동성을 살려 자신의 분야에서 성장을 도모하면 좋은 결과 기대
#
# ---
#
# ## 7. 요약
#
# | 구분 | 내용 |
# |-------|-------|
# | 사주팔자 | 을해(乙亥), 기묘(己卯), 무오(戊午), 무오(戊午) |
# | 오행분포 | 토 3, 목 2, 화 2, 수 1, 금 0 |
# | 십신특징 | 경쟁심 강한 비견과 편재, 창의적 식신, 지혜의 편인 |
# | 대운흐름 | 금과 수 기운 보완 대운 진행 중 |
# | 성격특징 | 현실적, 책임감, 창의적, 경쟁심 강함, 결단력 보완 필요 |
# | 건강조언 | 소화기 건강 주의, 금 기운 보완 권장 |
# | 운세조언 | 20대 후반~30대 초반 대운 활용 중요 |
#
# ---
#
# 필요하시면 대운과 세운(연운) 분석도 추가로 상세히 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
# 추가질문 -> 바로 retriever tool로 들어갔다

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 1})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="대운과 세운분석 자세히 해줘"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide a detailed analysis of my Daewoon (major luck cycle) and Sewoon (annual luck cycle) in relation to my Four Pillars of Destiny (Ba Zi)? I am particularly interested in understanding how these cycles influence my current life circumstances and future prospects based on my birth chart.대운과 세운분석 자세히 해줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 대운과 세운(연운) 분석을 자세히 진행하겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 대운 시작 시기 산출
#
# - 출생 월: 3월 (양력)
# - 출생 시: 午시 (11:30~13:30)
# - 남성은 출생 월의 절기 기준으로 앞으로 대운이 진행됨
# - 1995년 3월 28일은 춘분(3월 21일) 이후 출생이므로 대운은 출생 후 약 1년 5개월 후부터 시작 (대략 1세 5개월부터)
#
# ### 대운별 10년 주기 및 오행 특성
#
# | 나이 구간 | 대운  | 천간지지 | 오행 및 특징                      |
# |-----------|--------|-----------|---------------------------------|
# | 1~10세    | 기미(己未) | 토(土) 중심 | 토 기운 강화, 안정과 성장 기반 마련 |
# | 11~20세   | 경신(庚申) | 금(金) 중심 | 부족한 금 기운 보완, 결단력과 조직력 강화 |
# | 21~30세   | 신유(辛酉) | 금(金) 중심 | 금 기운 지속 강화, 냉철함과 실행력 증대 |
# | 31~40세   | 임술(壬戌) | 수(水) 중심 | 감성, 지혜, 유연성 보완, 대인관계 개선 |
# | 41~50세   | 계해(癸亥) | 수(水) 중심 | 지혜와 보호 강화, 내면 성장과 안정 |
#
# ### 대운 해석
#
# - **기미 대운(1~10세):** 토(土) 기운이 강해 안정적인 성장기. 부모와의 관계가 좋고, 기본적인 생활 기반이 튼튼함.
# - **경신, 신유 대운(11~30세):** 부족한 금(金) 기운이 보완되어 결단력과 조직력이 강화됨. 학업과 사회 진출에 유리한 시기.
# - **임술, 계해 대운(31~50세):** 수(水) 기운이 보완되어 감성과 지혜가 증대. 대인관계가 원만해지고 내면적 성장이 이루어짐.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2023~2025년)
#
# - 현재 기준 연도: 2025년
# - 최근 3년간 세운과 사주팔자의 상호작용 분석
#
# | 연도 | 세운(천간지지) | 오행 | 세운과 사주 상호작용 및 운세 영향 |
# |-------|----------------|-------|----------------------------------|
# | 2023  | 계묘(癸卯)     | 수(木) | 수와 목 기운이 보완되어 창의력과 감성 증대. 다만 토 기운과 일부 충돌 가능, 건강 주의 필요 |
# | 2024  | 갑진(甲辰)     | 목(土) | 목과 토의 상생으로 성장과 발전 기회. 새로운 일이나 학업에 좋은 시기 |
# | 2025  | 을사(乙巳)     | 목(火) | 목과 화 기운이 강해 활동성과 열정 증가. 다만 토 기운과의 균형 유지 필요 |
#
# ### 세운 해석
#
# - 2023년 계묘년은 수와 목의 기운이 강해 감성과 창의력이 증대되는 시기입니다. 다만 토 기운과 일부 충돌이 있어 건강과 스트레스 관리에 유의해야 합니다.
# - 2024년 갑진년은 목과 토의 상생으로 새로운 성장과 발전의 기회가 많습니다. 학업, 직장, 인간관계에서 좋은 성과 기대 가능.
# - 2025년 을사년은 목과 화의 기운이 강해 활동성과 열정이 증가합니다. 다만 토 기운과의 균형을 잘 유지해야 하며, 무리한 계획은 피하는 것이 좋습니다.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 20대 후반부터 30대 초반(임술 대운)에는 수 기운이 보완되어 감성과 지혜가 증대되는 시기입니다. 이 시기에 대인관계와 내면 성장을 중점적으로 관리하면 좋습니다.
# - 2023~2025년 세운은 목과 수, 화 기운이 강해 창의력과 활동성이 증가하는 시기입니다. 자신의 능력을 발휘하기 좋은 시기이나, 토 기운과의 균형을 유지하는 것이 중요합니다.
# - 금 기운이 부족한 사주이므로, 대운과 세운에서 금 기운이 들어오는 시기를 잘 활용하여 결단력과 조직력을 보완하는 것이 좋습니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분       | 내용                                                         |
# |------------|--------------------------------------------------------------|
# | 대운 시작  | 출생 후 약 1년 5개월부터 시작, 10년 단위로 변화               |
# | 대운 특징  | 토→금→금→수→수 순으로 변화, 금과 수 기운 보완이 핵심          |
# | 세운(2023~2025) | 목, 수, 화 기운 강화, 창의력과 활동성 증가, 토 기운과 균형 필요 |
# | 운세 조언  | 금 기운 보완에 신경 쓰고, 20대 후반~30대 초반 대운 활용 중요  |
# | 건강 조언  | 스트레스 관리 및 소화기 건강 주의, 규칙적 운동 권장            |
#
# ---
#
# 필요하시면 특정 대운별 상세 운세나 세운별 구체적 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 대운과 세운(연운) 분석을 자세히 진행하겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 대운 시작 시기 산출
#
# - 출생 월: 3월 (양력)
# - 출생 시: 午시 (11:30~13:30)
# - 남성은 출생 월의 절기 기준으로 앞으로 대운이 진행됨
# - 1995년 3월 28일은 춘분(3월 21일) 이후 출생이므로 대운은 출생 후 약 1년 5개월 후부터 시작 (대략 1세 5개월부터)
#
# ### 대운별 10년 주기 및 오행 특성
#
# | 나이 구간 | 대운  | 천간지지 | 오행 및 특징                      |
# |-----------|--------|-----------|---------------------------------|
# | 1~10세    | 기미(己未) | 토(土) 중심 | 토 기운 강화, 안정과 성장 기반 마련 |
# | 11~20세   | 경신(庚申) | 금(金) 중심 | 부족한 금 기운 보완, 결단력과 조직력 강화 |
# | 21~30세   | 신유(辛酉) | 금(金) 중심 | 금 기운 지속 강화, 냉철함과 실행력 증대 |
# | 31~40세   | 임술(壬戌) | 수(水) 중심 | 감성, 지혜, 유연성 보완, 대인관계 개선 |
# | 41~50세   | 계해(癸亥) | 수(水) 중심 | 지혜와 보호 강화, 내면 성장과 안정 |
#
# ### 대운 해석
#
# - **기미 대운(1~10세):** 토(土) 기운이 강해 안정적인 성장기. 부모와의 관계가 좋고, 기본적인 생활 기반이 튼튼함.
# - **경신, 신유 대운(11~30세):** 부족한 금(金) 기운이 보완되어 결단력과 조직력이 강화됨. 학업과 사회 진출에 유리한 시기.
# - **임술, 계해 대운(31~50세):** 수(水) 기운이 보완되어 감성과 지혜가 증대. 대인관계가 원만해지고 내면적 성장이 이루어짐.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2023~2025년)
#
# - 현재 기준 연도: 2025년
# - 최근 3년간 세운과 사주팔자의 상호작용 분석
#
# | 연도 | 세운(천간지지) | 오행 | 세운과 사주 상호작용 및 운세 영향 |
# |-------|----------------|-------|----------------------------------|
# | 2023  | 계묘(癸卯)     | 수(木) | 수와 목 기운이 보완되어 창의력과 감성 증대. 다만 토 기운과 일부 충돌 가능, 건강 주의 필요 |
# | 2024  | 갑진(甲辰)     | 목(土) | 목과 토의 상생으로 성장과 발전 기회. 새로운 일이나 학업에 좋은 시기 |
# | 2025  | 을사(乙巳)     | 목(火) | 목과 화 기운이 강해 활동성과 열정 증가. 다만 토 기운과의 균형 유지 필요 |
#
# ### 세운 해석
#
# - 2023년 계묘년은 수와 목의 기운이 강해 감성과 창의력이 증대되는 시기입니다. 다만 토 기운과 일부 충돌이 있어 건강과 스트레스 관리에 유의해야 합니다.
# - 2024년 갑진년은 목과 토의 상생으로 새로운 성장과 발전의 기회가 많습니다. 학업, 직장, 인간관계에서 좋은 성과 기대 가능.
# - 2025년 을사년은 목과 화의 기운이 강해 활동성과 열정이 증가합니다. 다만 토 기운과의 균형을 잘 유지해야 하며, 무리한 계획은 피하는 것이 좋습니다.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 20대 후반부터 30대 초반(임술 대운)에는 수 기운이 보완되어 감성과 지혜가 증대되는 시기입니다. 이 시기에 대인관계와 내면 성장을 중점적으로 관리하면 좋습니다.
# - 2023~2025년 세운은 목과 수, 화 기운이 강해 창의력과 활동성이 증가하는 시기입니다. 자신의 능력을 발휘하기 좋은 시기이나, 토 기운과의 균형을 유지하는 것이 중요합니다.
# - 금 기운이 부족한 사주이므로, 대운과 세운에서 금 기운이 들어오는 시기를 잘 활용하여 결단력과 조직력을 보완하는 것이 좋습니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분       | 내용                                                         |
# |------------|--------------------------------------------------------------|
# | 대운 시작  | 출생 후 약 1년 5개월부터 시작, 10년 단위로 변화               |
# | 대운 특징  | 토→금→금→수→수 순으로 변화, 금과 수 기운 보완이 핵심          |
# | 세운(2023~2025) | 목, 수, 화 기운 강화, 창의력과 활동성 증가, 토 기운과 균형 필요 |
# | 운세 조언  | 금 기운 보완에 신경 쓰고, 20대 후반~30대 초반 대운 활용 중요  |
# | 건강 조언  | 스트레스 관리 및 소화기 건강 주의, 규칙적 운동 권장            |
#
# ---
#
# 필요하시면 특정 대운별 상세 운세나 세운별 구체적 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 1})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="난 미래에 대한 대운과 세운분석이 궁금해"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# I am curious about the analysis of my luck cycles (Da Yun) and annual luck (Se Yun) in relation to my Four Pillars of Destiny (Ba Zi). Specifically, I would like to understand how these cycles will influence my future and what insights can be drawn from my birth chart analysis. Could you provide guidance on how to interpret these aspects in my life?난 미래에 대한 대운과 세운분석이 궁금해
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 미래 대운과 세운(연운) 분석을 자세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 미래 대운(大運) 분석
#
# ### 대운 시작 시기 및 진행 방향
#
# - 출생 월(3월) 기준으로 남성은 앞으로 대운이 진행됩니다.
# - 대운 시작은 출생 후 약 1년 5개월부터 시작하여 10년 단위로 변화합니다.
#
# ### 미래 대운 목록 및 특징
#
# | 나이 구간 | 대운  | 천간지지 | 오행 및 특징                      |
# |-----------|--------|-----------|---------------------------------|
# | 26~35세   | 임술(壬戌) | 수(土) 중심 | 감성, 지혜, 유연성 보완, 대인관계 개선 |
# | 36~45세   | 계해(癸亥) | 수(水) 중심 | 지혜와 보호 강화, 내면 성장과 안정 |
# | 46~55세   | 갑자(甲子) | 목(水) 중심 | 새로운 시작과 성장, 활력 증대 |
# | 56~65세   | 을축(乙丑) | 목(土) 중심 | 안정과 성숙, 재물운 상승 가능 |
# | 66~75세   | 병인(丙寅) | 화(木) 중심 | 활력과 창의력 증가, 건강 주의 필요 |
#
# ### 대운 해석
#
# - **26~35세 임술 대운:** 수 기운이 보완되어 감성과 지혜가 증대되는 시기입니다. 대인관계가 원만해지고 내면적 성장이 이루어집니다. 중요한 인생 전환점이 될 수 있습니다.
# - **36~45세 계해 대운:** 수 기운이 계속 강화되어 내면의 안정과 보호가 강화됩니다. 지혜로운 판단과 신중한 행동이 요구되는 시기입니다.
# - **46~55세 갑자 대운:** 목과 수 기운이 강해 새로운 시작과 활력이 증가합니다. 사업이나 새로운 분야 도전이 유리합니다.
# - **56~65세 을축 대운:** 목과 토 기운이 조화를 이루어 안정과 성숙의 시기입니다. 재물운이 상승할 가능성이 높습니다.
# - **66~75세 병인 대운:** 화와 목 기운이 강해 활력과 창의력이 증가하지만, 건강에 유의해야 합니다.
#
# ---
#
# ## 2. 미래 세운(歲運) 분석 (2026년 이후)
#
# | 연도 | 세운(천간지지) | 오행 | 세운과 사주 상호작용 및 운세 영향 |
# |-------|----------------|-------|----------------------------------|
# | 2026  | 병오(丙午)     | 화(火) | 화 기운 강화, 활동성과 열정 증가. 토 기운과 조화 필요 |
# | 2027  | 정미(丁未)     | 화(土) | 화와 토의 조화로 성장과 안정. 재물운 상승 가능 |
# | 2028  | 무신(戊申)     | 토(金) | 토와 금 기운 보완, 결단력과 조직력 강화 |
# | 2029  | 기유(己酉)     | 토(金) | 토와 금의 조화, 사업과 재물운에 좋은 시기 |
# | 2030  | 경술(庚戌)     | 금(土) | 금 기운 강화, 결단력과 실행력 증대 |
#
# ### 세운 해석
#
# - 2026~2027년은 화와 토 기운이 강해 활동성과 안정이 조화를 이루는 시기입니다. 새로운 일이나 사업에 좋은 기회가 많습니다.
# - 2028~2030년은 토와 금 기운이 보완되어 결단력과 조직력이 강화됩니다. 재물운과 사업운이 상승하는 좋은 시기입니다.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 26~35세 임술 대운과 2026~2030년 세운이 조화를 이루어 감성과 지혜, 활동성과 결단력이 균형 있게 발휘되는 시기입니다.
# - 이 시기에 자신의 능력을 최대한 발휘하고, 새로운 도전과 사업에 집중하면 좋은 성과를 기대할 수 있습니다.
# - 금 기운이 부족한 사주이므로, 2028년 이후 금 기운이 강화되는 대운과 세운을 잘 활용하여 결단력과 조직력을 보완하는 것이 중요합니다.
# - 건강 관리에 유의하며, 특히 소화기 계통과 스트레스 관리를 신경 써야 합니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분       | 내용                                                         |
# |------------|--------------------------------------------------------------|
# | 미래 대운  | 26~35세 임술 대운부터 수 기운 보완, 36~45세 계해 대운 안정 강화 |
# | 미래 세운  | 2026~2030년 화, 토, 금 기운 강화, 활동성과 결단력 증대        |
# | 운세 조언  | 26~35세 대운과 2026~2030년 세운 활용하여 성장과 성공 도모    |
# | 건강 조언  | 소화기 건강 및 스트레스 관리 중요                             |
#
# ---
#
# 필요하시면 특정 대운별 상세 운세나 세운별 구체적 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 미래 대운과 세운(연운) 분석을 자세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 미래 대운(大運) 분석
#
# ### 대운 시작 시기 및 진행 방향
#
# - 출생 월(3월) 기준으로 남성은 앞으로 대운이 진행됩니다.
# - 대운 시작은 출생 후 약 1년 5개월부터 시작하여 10년 단위로 변화합니다.
#
# ### 미래 대운 목록 및 특징
#
# | 나이 구간 | 대운  | 천간지지 | 오행 및 특징                      |
# |-----------|--------|-----------|---------------------------------|
# | 26~35세   | 임술(壬戌) | 수(土) 중심 | 감성, 지혜, 유연성 보완, 대인관계 개선 |
# | 36~45세   | 계해(癸亥) | 수(水) 중심 | 지혜와 보호 강화, 내면 성장과 안정 |
# | 46~55세   | 갑자(甲子) | 목(水) 중심 | 새로운 시작과 성장, 활력 증대 |
# | 56~65세   | 을축(乙丑) | 목(土) 중심 | 안정과 성숙, 재물운 상승 가능 |
# | 66~75세   | 병인(丙寅) | 화(木) 중심 | 활력과 창의력 증가, 건강 주의 필요 |
#
# ### 대운 해석
#
# - **26~35세 임술 대운:** 수 기운이 보완되어 감성과 지혜가 증대되는 시기입니다. 대인관계가 원만해지고 내면적 성장이 이루어집니다. 중요한 인생 전환점이 될 수 있습니다.
# - **36~45세 계해 대운:** 수 기운이 계속 강화되어 내면의 안정과 보호가 강화됩니다. 지혜로운 판단과 신중한 행동이 요구되는 시기입니다.
# - **46~55세 갑자 대운:** 목과 수 기운이 강해 새로운 시작과 활력이 증가합니다. 사업이나 새로운 분야 도전이 유리합니다.
# - **56~65세 을축 대운:** 목과 토 기운이 조화를 이루어 안정과 성숙의 시기입니다. 재물운이 상승할 가능성이 높습니다.
# - **66~75세 병인 대운:** 화와 목 기운이 강해 활력과 창의력이 증가하지만, 건강에 유의해야 합니다.
#
# ---
#
# ## 2. 미래 세운(歲運) 분석 (2026년 이후)
#
# | 연도 | 세운(천간지지) | 오행 | 세운과 사주 상호작용 및 운세 영향 |
# |-------|----------------|-------|----------------------------------|
# | 2026  | 병오(丙午)     | 화(火) | 화 기운 강화, 활동성과 열정 증가. 토 기운과 조화 필요 |
# | 2027  | 정미(丁未)     | 화(土) | 화와 토의 조화로 성장과 안정. 재물운 상승 가능 |
# | 2028  | 무신(戊申)     | 토(金) | 토와 금 기운 보완, 결단력과 조직력 강화 |
# | 2029  | 기유(己酉)     | 토(金) | 토와 금의 조화, 사업과 재물운에 좋은 시기 |
# | 2030  | 경술(庚戌)     | 금(土) | 금 기운 강화, 결단력과 실행력 증대 |
#
# ### 세운 해석
#
# - 2026~2027년은 화와 토 기운이 강해 활동성과 안정이 조화를 이루는 시기입니다. 새로운 일이나 사업에 좋은 기회가 많습니다.
# - 2028~2030년은 토와 금 기운이 보완되어 결단력과 조직력이 강화됩니다. 재물운과 사업운이 상승하는 좋은 시기입니다.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 26~35세 임술 대운과 2026~2030년 세운이 조화를 이루어 감성과 지혜, 활동성과 결단력이 균형 있게 발휘되는 시기입니다.
# - 이 시기에 자신의 능력을 최대한 발휘하고, 새로운 도전과 사업에 집중하면 좋은 성과를 기대할 수 있습니다.
# - 금 기운이 부족한 사주이므로, 2028년 이후 금 기운이 강화되는 대운과 세운을 잘 활용하여 결단력과 조직력을 보완하는 것이 중요합니다.
# - 건강 관리에 유의하며, 특히 소화기 계통과 스트레스 관리를 신경 써야 합니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분       | 내용                                                         |
# |------------|--------------------------------------------------------------|
# | 미래 대운  | 26~35세 임술 대운부터 수 기운 보완, 36~45세 계해 대운 안정 강화 |
# | 미래 세운  | 2026~2030년 화, 토, 금 기운 강화, 활동성과 결단력 증대        |
# | 운세 조언  | 26~35세 대운과 2026~2030년 세운 활용하여 성장과 성공 도모    |
# | 건강 조언  | 소화기 건강 및 스트레스 관리 중요                             |
#
# ---
#
# 필요하시면 특정 대운별 상세 운세나 세운별 구체적 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
# Enhanced Retriever with Query Expansion 테스트
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 2})

# 한글 사주 질문으로 테스트 (Query Expansion이 작동할 질문)
inputs = {
    "messages": [
        HumanMessage(
            content="정관이 뭐야? 상세히 설명해줘"
        )
    ],
}


# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# What is the concept of "正官" (Zheng Guan) in the context of the Four Pillars of Destiny, also known as Ba Zi? Please provide a detailed explanation of its significance and how it influences a person's birth chart analysis, particularly in relation to one's career, relationships, and overall life path.정관이 뭐야? 상세히 설명해줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# "정관"이라는 단어는 여러 분야에서 다르게 사용될 수 있는데, 여기서는 대표적으로 두 가지 의미를 상세히 설명해 드리겠습니다.
#
# 1. 사주명리학에서의 정관
# 사주명리학(四柱命理學)에서 "정관(正官)"은 십신(十神) 중 하나로, 자신의 일간(자신을 나타내는 천간) 기준으로 정해지는 오행 관계 중 하나입니다. 정관은 주로 '관직, 규율, 법, 권위, 책임' 등을 상징하며, 사회적 지위나 명예, 직업적인 면에서 중요한 역할을 합니다.
#
# - 정관의 의미: 정관은 '바른 관직'이라는 뜻으로, 규범과 질서를 상징합니다. 정관이 강하면 그 사람은 책임감이 강하고, 법과 규칙을 잘 따르며, 사회적으로 신뢰받는 위치에 있을 가능성이 큽니다.
# - 정관의 역할: 정관은 일간이 남자일 경우 여성(아내)을, 여자일 경우 남성(남편)을 나타내기도 합니다.
# - 정관의 오행 관계: 정관은 일간을 생하는 오행(생하는 오행이 정관)과의 관계로 정의됩니다. 예를 들어, 일간이 '갑목'이면, '정관'은 '금'오행이 됩니다. (목을 극하는 오행이 금이기 때문)
# - 정관의 영향: 정관이 사주에 적절히 위치하면, 그 사람은 법과 질서를 중시하고, 사회적 책임을 잘 수행하며, 권위 있는 위치에 오를 수 있습니다. 반대로 정관이 과하거나 약하면, 권위에 대한 반발심이나 불안정한 사회적 위치를 나타낼 수 있습니다.
#
# 2. 법률 및 기업에서의 정관
# 법률이나 기업 경영 분야에서 "정관"은 회사나 단체의 기본 규칙을 정리한 문서입니다.
#
# - 정관의 정의: 회사나 단체의 조직, 목적, 운영 방식, 임원 선출 방법, 의사결정 절차 등을 규정한 기본 규칙 문서입니다.
# - 정관의 역할: 회사의 설립과 운영에 필요한 기본적인 사항을 명확히 하여, 회사 내외부의 이해관계자들이 회사의 운영 방식을 이해하고 준수하도록 합니다.
# - 정관의 법적 효력: 정관은 법적으로 회사의 내부 규범으로서 효력을 가지며, 회사 운영에 있어 중요한 기준이 됩니다.
# - 정관의 작성 및 변경: 회사 설립 시 작성하며, 필요에 따라 주주총회 등의 절차를 거쳐 변경할 수 있습니다.
#
# 요약하자면, 사주에서의 정관은 개인의 사회적 역할과 책임, 권위를 나타내는 오행 관계이고, 법률 및 기업 분야에서의 정관은 조직의 기본 운영 규칙을 담은 문서입니다. 어떤 분야의 정관에 대해 더 궁금하신지 알려주시면, 더 구체적으로 설명해 드릴 수 있습니다.
# ==================================================
# 🔄 Node: WebTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# "정관"이라는 단어는 여러 분야에서 다르게 사용될 수 있는데, 여기서는 대표적으로 두 가지 의미를 상세히 설명해 드리겠습니다.
#
# 1. 사주명리학에서의 정관
# 사주명리학(四柱命理學)에서 "정관(正官)"은 십신(十神) 중 하나로, 자신의 일간(자신을 나타내는 천간) 기준으로 정해지는 오행 관계 중 하나입니다. 정관은 주로 '관직, 규율, 법, 권위, 책임' 등을 상징하며, 사회적 지위나 명예, 직업적인 면에서 중요한 역할을 합니다.
#
# - 정관의 의미: 정관은 '바른 관직'이라는 뜻으로, 규범과 질서를 상징합니다. 정관이 강하면 그 사람은 책임감이 강하고, 법과 규칙을 잘 따르며, 사회적으로 신뢰받는 위치에 있을 가능성이 큽니다.
# - 정관의 역할: 정관은 일간이 남자일 경우 여성(아내)을, 여자일 경우 남성(남편)을 나타내기도 합니다.
# - 정관의 오행 관계: 정관은 일간을 생하는 오행(생하는 오행이 정관)과의 관계로 정의됩니다. 예를 들어, 일간이 '갑목'이면, '정관'은 '금'오행이 됩니다. (목을 극하는 오행이 금이기 때문)
# - 정관의 영향: 정관이 사주에 적절히 위치하면, 그 사람은 법과 질서를 중시하고, 사회적 책임을 잘 수행하며, 권위 있는 위치에 오를 수 있습니다. 반대로 정관이 과하거나 약하면, 권위에 대한 반발심이나 불안정한 사회적 위치를 나타낼 수 있습니다.
#
# 2. 법률 및 기업에서의 정관
# 법률이나 기업 경영 분야에서 "정관"은 회사나 단체의 기본 규칙을 정리한 문서입니다.
#
# - 정관의 정의: 회사나 단체의 조직, 목적, 운영 방식, 임원 선출 방법, 의사결정 절차 등을 규정한 기본 규칙 문서입니다.
# - 정관의 역할: 회사의 설립과 운영에 필요한 기본적인 사항을 명확히 하여, 회사 내외부의 이해관계자들이 회사의 운영 방식을 이해하고 준수하도록 합니다.
# - 정관의 법적 효력: 정관은 법적으로 회사의 내부 규범으로서 효력을 가지며, 회사 운영에 있어 중요한 기준이 됩니다.
# - 정관의 작성 및 변경: 회사 설립 시 작성하며, 필요에 따라 주주총회 등의 절차를 거쳐 변경할 수 있습니다.
#
# 요약하자면, 사주에서의 정관은 개인의 사회적 역할과 책임, 권위를 나타내는 오행 관계이고, 법률 및 기업 분야에서의 정관은 조직의 기본 운영 규칙을 담은 문서입니다. 어떤 분야의 정관에 대해 더 궁금하신지 알려주시면, 더 구체적으로 설명해 드릴 수 있습니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, invoke_graph

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="사주의 개념에 대해서 알려줘"
        )
    ],
}

# 그래프 실행
invoke_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================ Human Message =================================
#
# 사주의 개념에 대해서 알려줘
# ==================================================
#
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# next:
# WebTool
# ==================================================
#
# ==================================================
# 🔄 Node: agent in [WebTool] 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================== Ai Message ==================================
#
# 사주(四柱)는 한국과 중국 등 동아시아에서 전통적으로 사용되는 운명학의 한 분야로, 사람의 태어난 연, 월, 일, 시를 기준으로 하여 그 사람의 운명과 성격, 미래의 길흉화복을 해석하는 체계입니다.
#
# 사주는 '네 기둥'이라는 뜻으로, 태어난 연도, 월, 일, 시를 각각 한 기둥으로 보고, 이 네 기둥을 합쳐서 개인의 운명을 분석합니다. 각 기둥은 천간(10간)과 지지(12지)로 구성되어 있으며, 이를 통해 오행(목, 화, 토, 금, 수)의 상호작용과 음양의 조화를 살펴봅니다.
#
# 사주를 통해 개인의 성격, 건강, 직업, 인간관계, 재물운, 결혼운 등 다양한 인생의 측면을 예측하고 조언하는 데 활용합니다. 또한, 사주는 운세뿐 아니라 자신과 주변 환경과의 조화를 이해하고, 더 나은 삶을 위한 방향을 찾는 데 도움을 주는 도구로 여겨집니다.
#
# 필요하면 사주의 구성 요소나 오행, 천간과 지지에 대해서도 자세히 설명해 드릴 수 있습니다.
# ==================================================
#
# ==================================================
# 🔄 Node: WebTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================ Human Message =================================
# Name: WebTool
#
# 사주(四柱)는 한국과 중국 등 동아시아에서 전통적으로 사용되는 운명학의 한 분야로, 사람의 태어난 연, 월, 일, 시를 기준으로 하여 그 사람의 운명과 성격, 미래의 길흉화복을 해석하는 체계입니다.
#
# 사주는 '네 기둥'이라는 뜻으로, 태어난 연도, 월, 일, 시를 각각 한 기둥으로 보고, 이 네 기둥을 합쳐서 개인의 운명을 분석합니다. 각 기둥은 천간(10간)과 지지(12지)로 구성되어 있으며, 이를 통해 오행(목, 화, 토, 금, 수)의 상호작용과 음양의 조화를 살펴봅니다.
#
# 사주를 통해 개인의 성격, 건강, 직업, 인간관계, 재물운, 결혼운 등 다양한 인생의 측면을 예측하고 조언하는 데 활용합니다. 또한, 사주는 운세뿐 아니라 자신과 주변 환경과의 조화를 이해하고, 더 나은 삶을 위한 방향을 찾는 데 도움을 주는 도구로 여겨집니다.
#
# 필요하면 사주의 구성 요소나 오행, 천간과 지지에 대해서도 자세히 설명해 드릴 수 있습니다.
# ==================================================
#
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# next:
# FINISH
# ==================================================

# %%
# GeneralQA 도구 테스트 - 일반 질문
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 2})

# 일반 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="파이썬에서 딕셔너리와 리스트의 차이점을 알려주세요"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you explain the differences between a dictionary and a list in Python, particularly in the context of data structures used for organizing information? Additionally, I am interested in understanding how these concepts might relate to the analysis of a birth chart in the Four Pillars of Destiny (Ba Zi), where different elements and their relationships can be represented in various formats.파이썬에서 딕셔너리와 리스트의 차이점을 알려주세요
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ## 파이썬 딕셔너리와 리스트의 차이점
#
# 파이썬에서 딕셔너리(dictionary)와 리스트(list)는 모두 여러 개의 값을 저장하는 데 사용되는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.
#
# **1. 데이터 접근 방식:**
#
# *   **리스트 (List):**
#     *   **순서 기반 접근:** 리스트는 요소의 순서가 중요하며, 각 요소는 **인덱스(index)**를 통해 접근합니다. 인덱스는 0부터 시작하는 정수입니다.
#     *   예시: `my_list[0]`은 리스트의 첫 번째 요소를 가져옵니다.
# *   **딕셔너리 (Dictionary):**
#     *   **키(Key) 기반 접근:** 딕셔너리는 **키(key)**와 **값(value)**의 쌍으로 데이터를 저장합니다. 각 값은 고유한 키를 사용하여 접근합니다. 키는 변경 불가능한(immutable) 데이터 타입(문자열, 숫자, 튜플 등)이어야 합니다.
#     *   예시: `my_dict["name"]`은 딕셔너리에서 키가 "name"인 값(value)을 가져옵니다.
#
# **2. 순서 유무:**
#
# *   **리스트 (List):**
#     *   **순서가 있습니다.** 리스트에 추가된 요소는 추가된 순서대로 유지됩니다.
# *   **딕셔너리 (Dictionary):**
#     *   **파이썬 3.7+ 부터는 순서가 보장됩니다.** (삽입 순서대로). 이전 버전에서는 순서가 보장되지 않았습니다.  하지만 순서를 활용하기보다는 키를 통해 접근하는 것이 일반적입니다.
#
# **3. 데이터 저장 방식:**
#
# *   **리스트 (List):**
#     *   **동일한 타입 또는 다른 타입의 데이터 저장 가능:** 리스트는 숫자, 문자열, 객체 등 다양한 타입의 데이터를 함께 저장할 수 있습니다.
# *   **딕셔너리 (Dictionary):**
#     *   **키-값 쌍으로 데이터 저장:** 딕셔너리는 각 키에 해당하는 값을 저장하며, 키는 고유해야 합니다. 값은 다양한 타입이 될 수 있습니다.
#
# **4. 용도:**
#
# *   **리스트 (List):**
#     *   순서가 있는 데이터 모음, 데이터 목록 관리, 반복적인 작업 등에 적합합니다.
# *   **딕셔너리 (Dictionary):**
#     *   키-값으로 연관된 데이터를 저장하고 검색하는 데 적합합니다. 예를 들어, 사용자 정보 (이름, 나이, 주소 등), 설정 정보 등을 저장하는 데 유용합니다.
#
# **5. 주요 연산:**
#
# | 연산           | 리스트 (List)                                    | 딕셔너리 (Dictionary)                                   |
# | -------------- | ------------------------------------------------- | ------------------------------------------------------- |
# | 요소 추가       | `append()`, `insert()`                           | `dict[key] = value`, `update()`                        |
# | 요소 삭제       | `del list[index]`, `remove()`, `pop()`            | `del dict[key]`, `pop()`, `popitem()`                   |
# | 요소 접근       | `list[index]`                                     | `dict[key]`, `get()`                                   |
# | 요소 검색       | `in`, `index()`                                  | `in` (키 존재 여부 확인), `values()`, `items()`       |
# | 전체 순회       | `for item in list:`                             | `for key in dict:`, `for value in dict.values():`, `for key, value in dict.items():` |
#
# **예제 코드:**
#
# ```python
# # 리스트 예제
# my_list = ["apple", "banana", "cherry"]
# print(my_list[0])  # 출력: apple
# my_list.append("orange")
# print(my_list)  # 출력: ['apple', 'banana', 'cherry', 'orange']
#
# # 딕셔너리 예제
# my_dict = {"name": "Alice", "age": 30, "city": "New York"}
# print(my_dict["name"])  # 출력: Alice
# my_dict["occupation"] = "Engineer"
# print(my_dict)  # 출력: {'name': 'Alice', 'age': 30, 'city': 'New York', 'occupation': 'Engineer'}
#
# # 딕셔너리 순회
# for key, value in my_dict.items():
#     print(f"{key}: {value}")
# ```
#
# **요약:**
#
# | 특징           | 리스트 (List)          | 딕셔너리 (Dictionary)            |
# | -------------- | ----------------------- | --------------------------------- |
# | 접근 방식       | 인덱스 기반           | 키 기반                             |
# | 순서            | 순서 유지              | 파이썬 3.7+ 부터는 순서 보장.       |
# | 데이터 저장 방식 | 순서대로 저장          | 키-값 쌍으로 저장                   |
# | 키 중복        | 해당 없음               | 키는 중복 불가                      |
# | 용도            | 순서 있는 데이터 목록   | 키-값 연관 데이터 저장 및 검색      |
#
# 어떤 자료구조를 사용할지는 데이터의 특성과 사용 목적에 따라 결정해야 합니다. 순서가 중요하고 인덱스를 통해 접근해야 하는 데이터는 리스트를, 키-값 쌍으로 연관된 데이터를 저장하고 검색해야 하는 경우에는 딕셔너리를 사용하는 것이 좋습니다.
# content='## 파이썬 딕셔너리와 리스트의 차이점\n\n파이썬에서 딕셔너리(dictionary)와 리스트(list)는 모두 여러 개의 값을 저장하는 데 사용되는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.\n\n**1. 데이터 접근 방식:**\n\n*   **리스트 (List):**\n    *   **순서 기반 접근:** 리스트는 요소의 순서가 중요하며, 각 요소는 **인덱스(index)**를 통해 접근합니다. 인덱스는 0부터 시작하는 정수입니다.\n    *   예시: `my_list[0]`은 리스트의 첫 번째 요소를 가져옵니다.\n*   **딕셔너리 (Dictionary):**\n    *   **키(Key) 기반 접근:** 딕셔너리는 **키(key)**와 **값(value)**의 쌍으로 데이터를 저장합니다. 각 값은 고유한 키를 사용하여 접근합니다. 키는 변경 불가능한(immutable) 데이터 타입(문자열, 숫자, 튜플 등)이어야 합니다.\n    *   예시: `my_dict["name"]`은 딕셔너리에서 키가 "name"인 값(value)을 가져옵니다.\n\n**2. 순서 유무:**\n\n*   **리스트 (List):**\n    *   **순서가 있습니다.** 리스트에 추가된 요소는 추가된 순서대로 유지됩니다.\n*   **딕셔너리 (Dictionary):**\n    *   **파이썬 3.7+ 부터는 순서가 보장됩니다.** (삽입 순서대로). 이전 버전에서는 순서가 보장되지 않았습니다.  하지만 순서를 활용하기보다는 키를 통해 접근하는 것이 일반적입니다.\n\n**3. 데이터 저장 방식:**\n\n*   **리스트 (List):**\n    *   **동일한 타입 또는 다른 타입의 데이터 저장 가능:** 리스트는 숫자, 문자열, 객체 등 다양한 타입의 데이터를 함께 저장할 수 있습니다.\n*   **딕셔너리 (Dictionary):**\n    *   **키-값 쌍으로 데이터 저장:** 딕셔너리는 각 키에 해당하는 값을 저장하며, 키는 고유해야 합니다. 값은 다양한 타입이 될 수 있습니다.\n\n**4. 용도:**\n\n*   **리스트 (List):**\n    *   순서가 있는 데이터 모음, 데이터 목록 관리, 반복적인 작업 등에 적합합니다.\n*   **딕셔너리 (Dictionary):**\n    *   키-값으로 연관된 데이터를 저장하고 검색하는 데 적합합니다. 예를 들어, 사용자 정보 (이름, 나이, 주소 등), 설정 정보 등을 저장하는 데 유용합니다.\n\n**5. 주요 연산:**\n\n| 연산           | 리스트 (List)                                    | 딕셔너리 (Dictionary)                                   |\n| -------------- | ------------------------------------------------- | ------------------------------------------------------- |\n| 요소 추가       | `append()`, `insert()`                           | `dict[key] = value`, `update()`                        |\n| 요소 삭제       | `del list[index]`, `remove()`, `pop()`            | `del dict[key]`, `pop()`, `popitem()`                   |\n| 요소 접근       | `list[index]`                                     | `dict[key]`, `get()`                                   |\n| 요소 검색       | `in`, `index()`                                  | `in` (키 존재 여부 확인), `values()`, `items()`       |\n| 전체 순회       | `for item in list:`                             | `for key in dict:`, `for value in dict.values():`, `for key, value in dict.items():` |\n\n**예제 코드:**\n\n```python\n# 리스트 예제\nmy_list = ["apple", "banana", "cherry"]\nprint(my_list[0])  # 출력: apple\nmy_list.append("orange")\nprint(my_list)  # 출력: [\'apple\', \'banana\', \'cherry\', \'orange\']\n\n# 딕셔너리 예제\nmy_dict = {"name": "Alice", "age": 30, "city": "New York"}\nprint(my_dict["name"])  # 출력: Alice\nmy_dict["occupation"] = "Engineer"\nprint(my_dict)  # 출력: {\'name\': \'Alice\', \'age\': 30, \'city\': \'New York\', \'occupation\': \'Engineer\'}\n\n# 딕셔너리 순회\nfor key, value in my_dict.items():\n    print(f"{key}: {value}")\n```\n\n**요약:**\n\n| 특징           | 리스트 (List)          | 딕셔너리 (Dictionary)            |\n| -------------- | ----------------------- | --------------------------------- |\n| 접근 방식       | 인덱스 기반           | 키 기반                             |\n| 순서            | 순서 유지              | 파이썬 3.7+ 부터는 순서 보장.       |\n| 데이터 저장 방식 | 순서대로 저장          | 키-값 쌍으로 저장                   |\n| 키 중복        | 해당 없음               | 키는 중복 불가                      |\n| 용도            | 순서 있는 데이터 목록   | 키-값 연관 데이터 저장 및 검색      |\n\n어떤 자료구조를 사용할지는 데이터의 특성과 사용 목적에 따라 결정해야 합니다. 순서가 중요하고 인덱스를 통해 접근해야 하는 데이터는 리스트를, 키-값 쌍으로 연관된 데이터를 저장하고 검색해야 하는 경우에는 딕셔너리를 사용하는 것이 좋습니다.\n' additional_kwargs={} response_metadata={'safety_ratings': [], 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash'} id='run--1704bceb-ff7e-4a32-8be4-b46e825bbcfe' usage_metadata={'input_tokens': 15, 'output_tokens': 1307, 'total_tokens': 1322, 'input_token_details': {'cache_read': 0}}
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 파이썬에서 딕셔너리(dictionary)와 리스트(list)는 모두 여러 개의 값을 저장하는 데 사용되는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.
#
# ## 1. 데이터 접근 방식
# - **리스트 (List)**:
#   - **순서 기반 접근**: 리스트는 요소의 순서가 중요하며, 각 요소는 **인덱스(index)**를 통해 접근합니다. 인덱스는 0부터 시작하는 정수입니다.
#   - 예시: `my_list[0]`은 리스트의 첫 번째 요소를 가져옵니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **키(Key) 기반 접근**: 딕셔너리는 **키(key)**와 **값(value)**의 쌍으로 데이터를 저장합니다. 각 값은 고유한 키를 사용하여 접근합니다. 키는 변경 불가능한(immutable) 데이터 타입(문자열, 숫자, 튜플 등)이어야 합니다.
#   - 예시: `my_dict["name"]`은 딕셔너리에서 키가 "name"인 값(value)을 가져옵니다.
#
# ## 2. 순서 유무
# - **리스트 (List)**:
#   - **순서가 있습니다**. 리스트에 추가된 요소는 추가된 순서대로 유지됩니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **파이썬 3.7+ 부터는 순서가 보장됩니다**. (삽입 순서대로). 이전 버전에서는 순서가 보장되지 않았습니다.
#
# ## 3. 데이터 저장 방식
# - **리스트 (List)**:
#   - **동일한 타입 또는 다른 타입의 데이터 저장 가능**: 리스트는 숫자, 문자열, 객체 등 다양한 타입의 데이터를 함께 저장할 수 있습니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **키-값 쌍으로 데이터 저장**: 딕셔너리는 각 키에 해당하는 값을 저장하며, 키는 고유해야 합니다. 값은 다양한 타입이 될 수 있습니다.
#
# ## 4. 용도
# - **리스트 (List)**:
#   - 순서가 있는 데이터 모음, 데이터 목록 관리, 반복적인 작업 등에 적합합니다.
#
# - **딕셔너리 (Dictionary)**:
#   - 키-값으로 연관된 데이터를 저장하고 검색하는 데 적합합니다. 예를 들어, 사용자 정보 (이름, 나이, 주소 등), 설정 정보 등을 저장하는 데 유용합니다.
#
# ## 5. 주요 연산
# | 연산           | 리스트 (List)                                    | 딕셔너리 (Dictionary)                                   |
# | -------------- | ------------------------------------------------- | ------------------------------------------------------- |
# | 요소 추가       | `append()`, `insert()`                           | `dict[key] = value`, `update()`                        |
# | 요소 삭제       | `del list[index]`, `remove()`, `pop()`            | `del dict[key]`, `pop()`, `popitem()`                   |
# | 요소 접근       | `list[index]`                                     | `dict[key]`, `get()`                                   |
# | 요소 검색       | `in`, `index()`                                  | `in` (키 존재 여부 확인), `values()`, `items()`       |
# | 전체 순회       | `for item in list:`                             | `for key in dict:`, `for value in dict.values():`, `for key, value in dict.items():` |
#
# ## 예제 코드
# ```python
# # 리스트 예제
# my_list = ["apple", "banana", "cherry"]
# print(my_list[0])  # 출력: apple
# my_list.append("orange")
# print(my_list)  # 출력: ['apple', 'banana', 'cherry', 'orange']
#
# # 딕셔너리 예제
# my_dict = {"name": "Alice", "age": 30, "city": "New York"}
# print(my_dict["name"])  # 출력: Alice
# my_dict["occupation"] = "Engineer"
# print(my_dict)  # 출력: {'name': 'Alice', 'age': 30, 'city': 'New York', 'occupation': 'Engineer'}
#
# # 딕셔너리 순회
# for key, value in my_dict.items():
#     print(f"{key}: {value}")
# ```
#
# ## 요약
# | 특징           | 리스트 (List)          | 딕셔너리 (Dictionary)            |
# | -------------- | ----------------------- | --------------------------------- |
# | 접근 방식       | 인덱스 기반           | 키 기반                             |
# | 순서            | 순서 유지              | 파이썬 3.7+ 부터는 순서 보장.       |
# | 데이터 저장 방식 | 순서대로 저장          | 키-값 쌍으로 저장                   |
# | 키 중복        | 해당 없음               | 키는 중복 불가                      |
# | 용도            | 순서 있는 데이터 목록   | 키-값 연관 데이터 저장 및 검색      |
#
# 어떤 자료구조를 사용할지는 데이터의 특성과 사용 목적에 따라 결정해야 합니다. 순서가 중요하고 인덱스를 통해 접근해야 하는 데이터는 리스트를, 키-값 쌍으로 연관된 데이터를 저장하고 검색해야 하는 경우에는 딕셔너리를 사용하는 것이 좋습니다.
# ==================================================
# 🔄 Node: GeneralQA 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 파이썬에서 딕셔너리(dictionary)와 리스트(list)는 모두 여러 개의 값을 저장하는 데 사용되는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.
#
# ## 1. 데이터 접근 방식
# - **리스트 (List)**:
#   - **순서 기반 접근**: 리스트는 요소의 순서가 중요하며, 각 요소는 **인덱스(index)**를 통해 접근합니다. 인덱스는 0부터 시작하는 정수입니다.
#   - 예시: `my_list[0]`은 리스트의 첫 번째 요소를 가져옵니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **키(Key) 기반 접근**: 딕셔너리는 **키(key)**와 **값(value)**의 쌍으로 데이터를 저장합니다. 각 값은 고유한 키를 사용하여 접근합니다. 키는 변경 불가능한(immutable) 데이터 타입(문자열, 숫자, 튜플 등)이어야 합니다.
#   - 예시: `my_dict["name"]`은 딕셔너리에서 키가 "name"인 값(value)을 가져옵니다.
#
# ## 2. 순서 유무
# - **리스트 (List)**:
#   - **순서가 있습니다**. 리스트에 추가된 요소는 추가된 순서대로 유지됩니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **파이썬 3.7+ 부터는 순서가 보장됩니다**. (삽입 순서대로). 이전 버전에서는 순서가 보장되지 않았습니다.
#
# ## 3. 데이터 저장 방식
# - **리스트 (List)**:
#   - **동일한 타입 또는 다른 타입의 데이터 저장 가능**: 리스트는 숫자, 문자열, 객체 등 다양한 타입의 데이터를 함께 저장할 수 있습니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **키-값 쌍으로 데이터 저장**: 딕셔너리는 각 키에 해당하는 값을 저장하며, 키는 고유해야 합니다. 값은 다양한 타입이 될 수 있습니다.
#
# ## 4. 용도
# - **리스트 (List)**:
#   - 순서가 있는 데이터 모음, 데이터 목록 관리, 반복적인 작업 등에 적합합니다.
#
# - **딕셔너리 (Dictionary)**:
#   - 키-값으로 연관된 데이터를 저장하고 검색하는 데 적합합니다. 예를 들어, 사용자 정보 (이름, 나이, 주소 등), 설정 정보 등을 저장하는 데 유용합니다.
#
# ## 5. 주요 연산
# | 연산           | 리스트 (List)                                    | 딕셔너리 (Dictionary)                                   |
# | -------------- | ------------------------------------------------- | ------------------------------------------------------- |
# | 요소 추가       | `append()`, `insert()`                           | `dict[key] = value`, `update()`                        |
# | 요소 삭제       | `del list[index]`, `remove()`, `pop()`            | `del dict[key]`, `pop()`, `popitem()`                   |
# | 요소 접근       | `list[index]`                                     | `dict[key]`, `get()`                                   |
# | 요소 검색       | `in`, `index()`                                  | `in` (키 존재 여부 확인), `values()`, `items()`       |
# | 전체 순회       | `for item in list:`                             | `for key in dict:`, `for value in dict.values():`, `for key, value in dict.items():` |
#
# ## 예제 코드
# ```python
# # 리스트 예제
# my_list = ["apple", "banana", "cherry"]
# print(my_list[0])  # 출력: apple
# my_list.append("orange")
# print(my_list)  # 출력: ['apple', 'banana', 'cherry', 'orange']
#
# # 딕셔너리 예제
# my_dict = {"name": "Alice", "age": 30, "city": "New York"}
# print(my_dict["name"])  # 출력: Alice
# my_dict["occupation"] = "Engineer"
# print(my_dict)  # 출력: {'name': 'Alice', 'age': 30, 'city': 'New York', 'occupation': 'Engineer'}
#
# # 딕셔너리 순회
# for key, value in my_dict.items():
#     print(f"{key}: {value}")
# ```
#
# ## 요약
# | 특징           | 리스트 (List)          | 딕셔너리 (Dictionary)            |
# | -------------- | ----------------------- | --------------------------------- |
# | 접근 방식       | 인덱스 기반           | 키 기반                             |
# | 순서            | 순서 유지              | 파이썬 3.7+ 부터는 순서 보장.       |
# | 데이터 저장 방식 | 순서대로 저장          | 키-값 쌍으로 저장                   |
# | 키 중복        | 해당 없음               | 키는 중복 불가                      |
# | 용도            | 순서 있는 데이터 목록   | 키-값 연관 데이터 저장 및 검색      |
#
# 어떤 자료구조를 사용할지는 데이터의 특성과 사용 목적에 따라 결정해야 합니다. 순서가 중요하고 인덱스를 통해 접근해야 하는 데이터는 리스트를, 키-값 쌍으로 연관된 데이터를 저장하고 검색해야 하는 경우에는 딕셔너리를 사용하는 것이 좋습니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
