# %%
from datetime import datetime

now = datetime.now()
today = now.strftime("%Y-%m-%d")
today
# Out:
# '2025-06-17'

# %% [markdown]
# 1. manse_tool_agent
# 2. retriever_tool_agent
# 3. 일반 답변에 대한 web search

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Enhanced Retriever 및 Chain (Query Expansion 포함)

# %%
# 기존 Retriever 및 Chain (원래대로 복원)
from pdf_retriever_saju import pdf_rag_chain, compression_retriever

pdf_retriever = compression_retriever()
pdf_chain = pdf_rag_chain()

# %%
# Manse_tool

# %%
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent
from manse_tool import calculate_saju_tool

# Agent 생성 시 tools 리스트에 추가

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
tools = [calculate_saju_tool]  # 사주 툴 추가

manse_tool_agent = create_react_agent(llm, tools)

# %%
response = manse_tool_agent.invoke({"messages": [("user", "1995년 3월 28일 남자, 12시 30분 출생")]})

# %%
print(response["messages"][-1].content)
# Out:
# 1995년 3월 28일 12시 30분 출생 남성의 사주팔자를 분석한 결과는 다음과 같습니다.
#
# 년주: 을해
# 월주: 기묘
# 일주: 계신
# 시주: 무오
# 일간: 계
#
# 오행 강약 점수는 목 39점, 화 10점, 토 45점, 금 9점, 수 34점으로 토와 목이 강한 편입니다.
#
# 십신 분석에 따르면,
# - 년주는 식신과 겁재, 상관이 혼재되어 있습니다.
# - 월주는 편관과 식신이 강합니다.
# - 일주는 정인, 겁재, 정관이 섞여 있습니다.
# - 시주는 정관과 편재, 편관이 포함되어 있습니다.
#
# 대운은 5세부터 시작하여 10년 단위로 무인, 정축, 병자, 을해 순으로 변화합니다.
#
# 이 사주는 토와 목의 기운이 강하고, 다양한 십신이 조화를 이루고 있어 균형 잡힌 성격과 운세를 가질 가능성이 큽니다. 더 구체적인 운세나 성격 분석이 필요하시면 말씀해 주세요.

# %%
response = manse_tool_agent.invoke({"messages": [("user", "1995년 9월 22일 남자, 15시 29분")]})

# %%
print(response["messages"][-1].content)
# Out:
# 1995년 9월 22일 15시 29분에 태어난 남성의 사주팔자를 분석한 결과는 다음과 같습니다.
#
# - 년주(年柱): 을해
# - 월주(月柱): 을유
# - 일주(日柱): 신오
# - 시주(時柱): 을미
# - 일간(日干): 신
#
# 오행의 강약은 목이 가장 강하고, 그 다음으로 금, 화, 토, 수 순입니다.
#
# 십신 분석에서는 편재, 상관, 정재, 편관, 편인 등의 기운이 혼재되어 있습니다.
#
# 대운은 5세부터 시작하여 10년 단위로 변화하며, 현재 25세부터 2029년까지 임오 대운에 해당합니다.
#
# 이 사주는 목의 기운이 강하고, 금의 기운도 상당히 있어 균형을 이루는 편입니다. 편재와 상관이 많아 재능과 창의력이 뛰어나고, 새로운 일에 도전하는 성향이 강할 수 있습니다. 다만, 편관과 편인이 있어 스트레스 관리와 건강에 신경 쓰는 것이 좋습니다.
#
# 더 구체적인 운세나 조언이 필요하시면 말씀해 주세요.

# %%
question = "Could you provide a birth chart analysis for a male born on March 28, 1995, focusing on the Four Pillars of Destiny (Ba Zi)? I am interested in understanding the implications of his birth date on his personality, career prospects, and overall life path. Please analyze the birth chart and Great Luck Period (Da Yun) based on Four Pillars of Destiny"
response = manse_tool_agent.invoke({"messages": [("user", question)]})

# %%
print(response["messages"][-1].content)
# Out:
# 이 남성분의 사주팔자 분석 결과를 바탕으로 성격, 진로, 인생 전반에 대해 설명드리겠습니다.
#
# 1. 사주 구성
# - 년주(을해), 월주(기묘), 일주(계신), 시주(무오)로 구성되어 있습니다.
# - 오행의 강약은 목 39점, 화 10점, 토 45점, 금 9점, 수 34점으로 토와 목이 강한 편입니다.
# - 십신 분석에 따르면 식신, 편관, 정인, 정관, 편재 등 다양한 십신이 조화를 이루고 있습니다.
#
# 2. 성격적 특성
# - 목과 토가 강한 사주로, 목의 성장과 발전, 토의 안정과 현실감각이 조화를 이루어 실용적이고 책임감이 강한 성격입니다.
# - 식신과 편관이 있어 창의적이고 도전적인 면도 있으며, 정인과 정관이 있어 지혜롭고 신중한 면도 있습니다.
# - 겁재와 상관이 있어 경쟁심과 독립심이 강하며, 자신의 길을 개척하려는 의지가 강합니다.
#
# 3. 진로 및 직업
# - 목과 토가 강한 점으로 교육, 상담, 의료, 부동산, 건설, 농업 등 안정적이고 성장 가능한 분야에 적합합니다.
# - 식신과 편관이 있어 예술, 기획, 창업, 경영 등 창의력과 리더십이 필요한 분야에서도 성공할 수 있습니다.
# - 정관과 편재가 있어 조직 내에서 관리직이나 재무, 회계 등 실무 능력을 발휘할 수 있습니다.
#
# 4. 인생 전반과 대운
# - 대운은 5세부터 무인, 15세부터 정축, 25세부터 병자, 35세부터 을해로 진행됩니다.
# - 25세부터 시작된 병자 대운은 목과 수의 조화로 학업과 직업에서 성장이 기대되며, 새로운 기회가 많아지는 시기입니다.
# - 35세부터의 을해 대운은 다시 목과 수의 조화가 강해져 인생의 전환점이나 중요한 성취가 예상됩니다.
#
# 요약하면, 이 분은 실용적이고 책임감이 강하며 창의력과 리더십도 갖춘 인물로, 안정적이면서도 도전적인 분야에서 성공할 가능성이 큽니다. 25세 이후부터 좋은 기운이 들어와 인생의 중요한 성취를 이룰 수 있는 시기입니다.

# %%
question = "Could you provide a birth chart analysis for a male born on september 22, 1995, at 15:29? focusing on the Four Pillars of Destiny (Ba Zi)?"
response = manse_tool_agent.invoke({"messages": [("user", question)]})

# %%
print(response["messages"][-1].content)
# Out:
# The Four Pillars of Destiny (Ba Zi) analysis for a male born on September 22, 1995, at 15:29 is as follows:
#
# - Year Pillar: 을해 (Eul-Hae)
# - Month Pillar: 을유 (Eul-Yu)
# - Day Pillar: 신오 (Shin-O)
# - Hour Pillar: 을미 (Eul-Mi)
# - Day Master (Day Stem): 신 (Shin)
#
# Five Elements Strength:
# - Wood: 65 points
# - Fire: 14 points
# - Earth: 13 points
# - Metal: 35 points
# - Water: 10 points
#
# Ten Gods Analysis:
# - Year Pillar: Heavenly Stem -偏財 (Pian Cai, Indirect Wealth), Earthly Branch -傷官 (Shang Guan, Hurting Officer) 70%, 正財 (Zheng Cai, Direct Wealth) 30%
# - Month Pillar: Heavenly Stem -偏財 (Pian Cai, Indirect Wealth)
# - Day Pillar: Earthly Branch -偏官 (Pian Guan, Seven Killings) 70%, 偏印 (Pian Yin, Indirect Resource) 30%
# - Hour Pillar: Heavenly Stem -偏財 (Pian Cai, Indirect Wealth), Earthly Branch -偏印 (Pian Yin, Indirect Resource) 60%, 偏官 (Pian Guan, Seven Killings) 30%, 偏財 (Pian Cai, Indirect Wealth) 10%
#
# Luck Cycles (Da Yun):
# - Age 5: 갑신 (Gap Sin) 2000-2009
# - Age 15: 계미 (Gye Mi) 2010-2019
# - Age 25: 임오 (Im O) 2020-2029
# - Age 35: 신사 (Sin Sa) 2030-2039
#
# This chart shows a strong Wood element, moderate Metal, and relatively weaker Fire, Earth, and Water elements. The presence of Indirect Wealth and Hurting Officer stars suggests creativity and potential for wealth through unconventional means. The Seven Killings and Indirect Resource stars indicate challenges and support in career and personal growth. The luck cycles provide a timeline for favorable and challenging periods in life.

# %%
from langchain_core.tools.retriever import create_retriever_tool
from langchain_core.prompts import PromptTemplate


# PDF 문서를 기반으로 검색 도구 생성
retriever_tool = create_retriever_tool(
    pdf_retriever,
    "pdf_retriever",
    "A tool for searching information related to Saju (Four Pillars of Destiny)",
    document_prompt=PromptTemplate.from_template(
        "<document><context>{page_content}</context><metadata><source>{source}</source><page>{page}</page></metadata></document>"
    ),
)

# %%
retriever_tools = [retriever_tool]

# %%
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI
from langchain_core.prompts import load_prompt, ChatPromptTemplate, MessagesPlaceholder

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

retriever_tool_agent = create_react_agent(llm, retriever_tools)

base_prompt = load_prompt("prompt/saju-rag-promt_2.yaml")
saju_prompt = ChatPromptTemplate.from_messages([
    ("system", base_prompt.template),
    MessagesPlaceholder("messages"),
])
retriever_tool_agent = create_react_agent(llm, retriever_tools, prompt=saju_prompt)

# %%
response = retriever_tool_agent.invoke({"messages": [("user", "1995년 3월 28일 남자의 사주 알려줘")]})

# %%
print(response["messages"][-1].content)
# Out:
# 안녕하세요. 1995년 3월 28일 남자분의 사주를 분석해 드리겠습니다.
#
# 우선, 입력하신 생년월일을 기준으로 정확한 사주(천간지지) 구성을 확인하겠습니다.
#
# ---
#
# ### 1. 사주 구조 (천간지지 변환)
#
# - 출생일: 1995년 3월 28일 (양력 기준으로 가정)
# - 성별: 남자
# - 시간: 입력되지 않아 기본적으로 시주는 미포함 상태입니다. (시간을 알려주시면 시주까지 정확히 분석 가능합니다.)
#
# #### 1) 연주 (년주)
# - 1995년은 을해년(乙亥年)입니다.
#   - 연간: 乙 (을, 목)
#   - 연지: 亥 (해, 수)
#
# #### 2) 월주 (음력 2월 또는 3월인지 확인 필요)
# - 3월 28일은 양력 기준으로 음력 2월 또는 3월에 해당할 수 있습니다.
# - 1995년 음력 2월 28일은 양력 3월 28일과 거의 일치하므로 음력 2월로 가정합니다.
# - 1995년 음력 2월은 병진월(丙辰月)입니다.
#   - 월간: 丙 (병, 화)
#   - 월지: 辰 (진, 토)
#
# #### 3) 일주 (일간과 일지)
# - 1995년 3월 28일의 일간과 일지는 정확한 계산이 필요합니다.
# - 1995년 3월 28일의 일간은 을축일(乙丑日)로 확인됩니다.
#   - 일간: 乙 (을, 목)
#   - 일지: 丑 (축, 토)
#
# #### 4) 시주 (출생 시간 필요)
# - 출생 시간이 없으므로 시주는 분석에서 제외합니다.
# - 시주가 있으면 12지지(자, 축, 인, 묘, 진, 사, 오, 미, 신, 유, 술, 해) 중 하나로 변환하여 분석합니다.
#
# ---
#
# ### 2. 오행 분포 분석 (Wu Xing)
#
# #### 1) 사주 4주 천간지지 8글자
# - 연간: 乙 (목)
# - 연지: 亥 (수)
# - 월간: 丙 (화)
# - 월지: 辰 (토)
# - 일간: 乙 (목)
# - 일지: 丑 (토)
#
# 총 6글자 (시주 미포함)
#
# #### 2) 오행 분포 (각 글자별 오행)
#
# | 글자 | 오행 |
# |-------|-------|
# | 乙    | 목    |
# | 亥    | 수    |
# | 丙    | 화    |
# | 辰    | 토    |
# | 乙    | 목    |
# | 丑    | 토    |
#
# #### 3) 점수 부여 (각 글자 1점)
#
# | 오행 | 점수 | 글자          |
# |-------|-------|---------------|
# | 목    | 2     | 乙, 乙        |
# | 화    | 1     | 丙            |
# | 토    | 2     | 辰, 丑        |
# | 금    | 0     |               |
# | 수    | 1     | 亥            |
#
# 총 점수: 2+1+2+0+1 = 6 (시주 미포함 6글자)
#
# ---
#
# ### 3. 오행 균형 및 해석
#
# - 목(木): 2점 (을간 2개) - 목의 기운이 강한 편입니다.
# - 화(火): 1점 (병간 1개) - 화의 기운이 적당히 있습니다.
# - 토(土): 2점 (진, 축) - 토의 기운도 강한 편입니다.
# - 금(金): 0점 - 금의 기운이 부족합니다.
# - 수(水): 1점 (해) - 수의 기운이 약간 있습니다.
#
# #### 해석
#
# - 목과 토가 강하고, 화와 수는 적당하며 금이 부족한 상태입니다.
# - 목은 성장, 발전, 창조를 의미하며, 토는 안정과 현실적인 면을 나타냅니다.
# - 금이 부족하면 결단력이나 냉철함이 약할 수 있으니 보완이 필요합니다.
#
# ---
#
# ### 4. 십신(십신) 분석 (일간 乙 기준)
#
# - 일간 乙목(을목)을 기준으로 다른 천간지지와의 관계를 분석합니다.
# - 연간 乙(비견): 자신과 같은 기운, 경쟁심과 동료애를 의미
# - 연지 亥(정인): 지혜와 학문, 보호자 역할
# - 월간 丙(편인): 창의력과 지식, 스승과 같은 존재
# - 월지 辰(식신): 재능과 표현력, 창조적 활동
# - 일지 丑(재성): 재물과 부, 현실적인 성취
#
# #### 해석
#
# - 비견과 편인, 정인이 있어 지적이고 창의적인 성향이 강합니다.
# - 식신과 재성이 있어 재능과 물질적 성취도 기대할 수 있습니다.
# - 다만 경쟁심이 강할 수 있으니 조화가 필요합니다.
#
# ---
#
# ### 5. 성격 및 기질
#
# - 목의 기운이 강해 부드럽고 융통성 있으며 성장욕구가 큽니다.
# - 토의 기운이 강해 현실적이고 신중하며 책임감이 강합니다.
# - 화와 수가 적당해 열정과 감성, 지혜가 균형을 이룹니다.
# - 금이 부족해 결단력과 냉철함이 약할 수 있으니 보완이 필요합니다.
#
# ---
#
# ### 6. 종합 요약
#
# - 1995년 3월 28일 출생 남성은 목과 토의 기운이 강한 사주로, 성장과 안정, 현실적 성취를 중시합니다.
# - 지적이고 창의적인 성향이 강하며, 재능과 물질적 성취도 기대됩니다.
# - 금의 기운이 부족해 결단력과 냉철함을 보완하면 더욱 좋은 운세가 될 것입니다.
# - 시주(출생 시간)를 알려주시면 더욱 정확한 분석이 가능합니다.
#
# ---
#
# 필요하시면 출생 시간을 알려주세요. 시주까지 포함한 전체 사주 분석을 도와드리겠습니다.
#
# 감사합니다.

# %%
# Query Expansion Agent (manse_tool처럼 간단하게)
from query_expansion_agent import get_query_expansion_agent

query_expansion_agent = get_query_expansion_agent()

# %%
# Query Expansion Agent 올바른 사용법 테스트
response = query_expansion_agent.invoke({"messages": [("user", "1995년 3월 28일 남자 사주")]})
print(response["messages"][-1].content)
# Out:
# 확장된 영어 질문은 다음과 같습니다:
#
# "Could you provide a birth chart analysis for a male born on March 28, 1995, focusing on the Four Pillars of Destiny (Ba Zi)? I am particularly interested in understanding the implications of his elemental composition, interactions between the Heavenly Stems and Earthly Branches, and any significant life patterns or trends that may emerge from his Ba Zi chart. Please analyze the birth chart and Great Luck Period (Da Yun) based on Four Pillars of Destiny."
#
# 이 질문을 사용하여 문서 검색을 진행해 보세요. 추가적인 도움이 필요하시면 말씀해 주세요!

# %%
from langchain_community.utilities.duckduckgo_search import DuckDuckGoSearchAPIWrapper

# %%
from query_expansion_agent import get_query_expansion_node

query_expansion_node = get_query_expansion_node()

# 노드 테스트
test_state = {"messages": [("user", "정관이 뭐야?")]}
result = query_expansion_node(test_state)

# %%
print(result)
# Out:
# {'messages': [('user', '정관이 뭐야?')], 'expanded_query': 'What is the concept of "Jeonggwan" (正官) in the context of the Four Pillars of Destiny (Ba Zi)? I would like to understand its significance and how it influences one\'s birth chart analysis, particularly in relation to career and authority.', 'original_query': "('user', '정관이 뭐야?')", 'expansion_result': '\n[Query Expansion 결과]\n원본 질문: (\'user\', \'정관이 뭐야?\')\n확장된 영어 질문: What is the concept of "Jeonggwan" (正官) in the context of the Four Pillars of Destiny (Ba Zi)? I would like to understand its significance and how it influences one\'s birth chart analysis, particularly in relation to career and authority.\n\n검색을 위해 확장된 쿼리를 사용합니다.\n'}

# %%
from query_expansion_agent import get_query_expansion_node

query_expansion_node = get_query_expansion_node()

# 노드 테스트
test_state = {"messages": [("user", "1995년 3월 28일 남자 사주")]}
result = query_expansion_node(test_state)

print("노드 테스트 결과:")
print(f"원본 질문: {result.get('original_query')}")
print(f"확장된 질문: {result.get('expanded_query')}")
print(f"확장 결과: {result.get('expansion_result')}")
# Out:
# 노드 테스트 결과:
# 원본 질문: ('user', '1995년 3월 28일 남자 사주')
# 확장된 질문: Could you provide a detailed birth chart analysis for a male born on March 28, 1995, focusing on the Four Pillars of Destiny (Ba Zi)? I am particularly interested in understanding how the elements and heavenly stems interact in his chart, as well as any insights regarding his personality, career prospects, and potential life challenges based on his astrological profile. Please analyze the birth chart and Great Luck Period (Da Yun) based on Four Pillars of Destiny.
# 확장 결과:
# [Query Expansion 결과]
# 원본 질문: ('user', '1995년 3월 28일 남자 사주')
# 확장된 영어 질문: Could you provide a detailed birth chart analysis for a male born on March 28, 1995, focusing on the Four Pillars of Destiny (Ba Zi)? I am particularly interested in understanding how the elements and heavenly stems interact in his chart, as well as any insights regarding his personality, career prospects, and potential life challenges based on his astrological profile. Please analyze the birth chart and Great Luck Period (Da Yun) based on Four Pillars of Destiny.
#
# 검색을 위해 확장된 쿼리를 사용합니다.

# %%
from langchain_teddynote.tools.tavily import TavilySearch
from langchain.tools import DuckDuckGoSearchRun, DuckDuckGoSearchResults

tavily_tool = TavilySearch(
    max_results=5,
    include_domains=["namu.wiki", "wikipedia.org"]
)

duck_tool = DuckDuckGoSearchResults(
    max_results=5,
)

# %%
from langchain_teddynote.tools.tavily import TavilySearch
from langchain.tools import DuckDuckGoSearchRun, DuckDuckGoSearchResults
from langchain_core.documents import Document

tavily_tool = TavilySearch(
    max_results=5,
    include_domains=["namu.wiki", "wikipedia.org"]
    
)

duck_tool = DuckDuckGoSearchResults(
    max_results=5,
)

# %%
# web_tool = [tavily_tool]
web_tool = [tavily_tool, duck_tool]

# %%
prompt = """
사주 또는 사주 오행의 개념적 질문이나, 일상 질문이 들어오면, web search를 통해 답합니다.
"""
web_tool_agent = create_react_agent(llm, tools=web_tool, prompt=prompt)

# %%
response = web_tool_agent.invoke({"messages": [("user", "사주오행에 대해서 설명해줘")]})

# %%
response
# Out:
# {'messages': [HumanMessage(content='사주오행에 대해서 설명해줘', additional_kwargs={}, response_metadata={}, id='00d87508-64fe-4afe-bfdc-46ee02426dd3'),
#   AIMessage(content="사주오행은 동양 철학과 점성학에서 중요한 개념으로, 사람의 운명과 성격, 인생의 흐름을 해석하는 데 사용됩니다. '사주'는 태어난 연도, 월, 일, 시의 네 기둥(四柱)을 의미하며, 각각의 기둥은 천간(10간)과 지지(12지)로 구성되어 있습니다. 이 네 기둥을 통해 개인의 운명을 분석합니다.\n\n'오행'은 우주 만물을 구성하는 다섯 가지 기본 요소인 목(木), 화(火), 토(土), 금(金), 수(水)를 말합니다. 이 다섯 가지 요소는 서로 상생(서로 돕는 관계)과 상극(서로 제약하는 관계)을 통해 자연과 인간의 변화를 설명합니다.\n\n사주오행에서는 태어난 시점의 천간과 지지에 포함된 오행의 조합을 분석하여, 그 사람의 성격, 건강, 직업, 인간관계, 운세 등을 예측합니다. 예를 들어, 목이 강한 사람은 성장과 발전을 상징하며, 화가 강하면 열정과 에너지가 넘치는 성격으로 해석할 수 있습니다.\n\n요약하자면,\n- 사주: 태어난 연월일시의 네 기둥\n- 오행: 목, 화, 토, 금, 수의 다섯 가지 요소\n- 사주오행: 사주의 네 기둥에 포함된 오행을 분석하여 개인의 운명과 성격을 해석하는 방법\n\n더 궁금한 점이나 구체적인 사주풀이에 대해 알고 싶으면 말씀해 주세요!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 366, 'prompt_tokens': 181, 'total_tokens': 547, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_6f2eabb9a5', 'finish_reason': 'stop', 'logprobs': None}, id='run--5fa684bb-bebe-443b-b786-860066a95b55-0', usage_metadata={'input_tokens': 181, 'output_tokens': 366, 'total_tokens': 547, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
print(response["messages"][-1].content)
# Out:
# 사주오행은 동양 철학과 점성학에서 중요한 개념으로, 사람의 운명과 성격, 인생의 흐름을 해석하는 데 사용됩니다. '사주'는 태어난 연도, 월, 일, 시의 네 기둥(四柱)을 의미하며, 각각의 기둥은 천간(10간)과 지지(12지)로 구성되어 있습니다. 이 네 기둥을 통해 개인의 운명을 분석합니다.
#
# '오행'은 우주 만물을 구성하는 다섯 가지 기본 요소인 목(木), 화(火), 토(土), 금(金), 수(水)를 말합니다. 이 다섯 가지 요소는 서로 상생(서로 돕는 관계)과 상극(서로 제약하는 관계)을 통해 자연과 인간의 변화를 설명합니다.
#
# 사주오행에서는 태어난 시점의 천간과 지지에 포함된 오행의 조합을 분석하여, 그 사람의 성격, 건강, 직업, 인간관계, 운세 등을 예측합니다. 예를 들어, 목이 강한 사람은 성장과 발전을 상징하며, 화가 강하면 열정과 에너지가 넘치는 성격으로 해석할 수 있습니다.
#
# 요약하자면,
# - 사주: 태어난 연월일시의 네 기둥
# - 오행: 목, 화, 토, 금, 수의 다섯 가지 요소
# - 사주오행: 사주의 네 기둥에 포함된 오행을 분석하여 개인의 운명과 성격을 해석하는 방법
#
# 더 궁금한 점이나 구체적인 사주풀이에 대해 알고 싶으면 말씀해 주세요!

# %%
# GeneralQA Tool
from langchain.tools import  tool
from langchain_google_genai import ChatGoogleGenerativeAI
google_llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

@tool
def general_qa_tool(query: str) -> str:
    """
    일반적인 질문이나 상식적인 내용에 대해 답변합니다. 사주와 관련 없는 모든 질문에 사용할 수 있습니다.
    """
    google_llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")
    return google_llm.invoke(query)

# %%
from langgraph.prebuilt import create_react_agent

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
general_qa_tools = [general_qa_tool]

prompt = "일반적인 질문이나 상식적인 내용에 대해 답변합니다."

general_qa_agent = create_react_agent(llm, tools=general_qa_tools, prompt=prompt)

# %% [markdown]
# # Agent node 생성

# %%
from langchain_core.messages import HumanMessage

# 지정한 agent와 name을 사용하여 agent 노드를 생성
def agent_node(state, agent, name):
    # agent 호출
    agent_response = agent.invoke(state)
    # agent의 마지막 메시지를 HumanMessage로 변환하여 반환
    return {
        "messages": [
            HumanMessage(content=agent_response["messages"][-1].content, name=name)
        ]
    }

# %% [markdown]
# # node 생성

# %%
import functools

manse_tool_agent_node = functools.partial(agent_node, agent=manse_tool_agent, name="ManseTool")
retriever_tool_agent_node = functools.partial(agent_node, agent=retriever_tool_agent, name="RetrieverTool")
web_tool_agent_node = functools.partial(agent_node, agent=web_tool_agent, name="WebTool")
general_qa_agent_node = functools.partial(agent_node, agent=general_qa_agent, name="GeneralQA")

# %% [markdown]
# # 노드 실험

# %%
manse_message = manse_tool_agent_node(
    {
        "messages": [
            HumanMessage(content="1995년 3월 28일 남자")
        ]
    }
)
print(manse_message)
# Out:
# {'messages': [HumanMessage(content='1995년 3월 28일 남자분의 사주팔자를 분석해보면 다음과 같습니다.\n\n- 년주(年柱): 을해\n- 월주(月柱): 기묘\n- 일주(日柱): 계신\n- 시주(時柱): 무오\n- 일간(日干): 계\n\n오행의 강약은 목 39점, 화 10점, 토 45점, 금 9점, 수 34점으로 토와 목이 강한 편입니다.\n\n십신 분석에서는 년주에 식신과 겁재, 상관이 있고, 월주에 편관과 식신, 일주에 정인, 겁재, 정관, 시주에 정관, 편재, 편관이 분포되어 있습니다.\n\n대운은 5세부터 무인, 15세부터 정축, 25세부터 병자, 35세부터 을해 대운이 돌아옵니다.\n\n이 사주는 토와 목의 기운이 강하고, 다양한 십신이 조화를 이루고 있어 균형 잡힌 성격과 운세를 가질 가능성이 큽니다. 대운의 흐름에 따라 인생의 중요한 전환점이 있을 것으로 보입니다. 더 구체적인 운세나 성격 분석이 필요하시면 알려주세요.', additional_kwargs={}, response_metadata={}, name='ManseTool')]}

# %%
retriever_message =  retriever_tool_agent_node(
    {
        "messages": [
            HumanMessage(content="1995년 3월 28일 남자 12시 30분")
        ]
    }
)
print(retriever_message)
# Out:
# {'messages': [HumanMessage(content='안녕하세요. 1995년 3월 28일 남자 12시 30분 출생 사주 분석을 진행하겠습니다.\n\n---\n\n## 1. 사주 구조 (천간지지 변환)\n\n- 출생일: 1995년 3월 28일 (양력 기준, 시간대: 12시 30분)\n- 성별: 남자\n- 출생시간: 12시 30분 → 지지로는 午시 (11시~13시)\n\n### 1) 연주 (Year Pillar)\n- 1995년은 을해년(乙亥年)입니다.\n  - 연간: 乙 (을, 목)\n  - 연지: 亥 (해, 수)\n\n### 2) 월주 (Month Pillar)\n- 3월은 음력 2월 또는 3월에 따라 다르나, 양력 3월 28일은 음력 2월 중순 경입니다.\n- 1995년 음력 2월은 을묘월(乙卯月)입니다.\n  - 월간: 乙 (을, 목)\n  - 월지: 卯 (묘, 목)\n\n### 3) 일주 (Day Pillar)\n- 1995년 3월 28일의 일간과 일지는 계산기로 확인하면 병진일(丙辰日)입니다.\n  - 일간: 丙 (병, 화)\n  - 일지: 辰 (진, 토)\n\n### 4) 시주 (Hour Pillar)\n- 12시 30분은 午시(11시~13시)입니다.\n- 병오시(丙午時)입니다.\n  - 시간간: 丙 (병, 화)\n  - 시간지: 午 (오, 화)\n\n---\n\n### 최종 사주 8자 (천간지지)\n\n| 구분 | 천간 | 지지 |\n|------|------|------|\n| 연주 | 乙   | 亥   |\n| 월주 | 乙   | 卯   |\n| 일주 | 丙   | 辰   |\n| 시주 | 丙   | 午   |\n\n---\n\n## 2. 오행(五行) 분석\n\n### 1) 천간지지 → 오행 매핑\n\n| 오행 | 해당 천간/지지 |\n|-------|----------------|\n| 목(木) | 甲, 乙, 寅, 卯 |\n| 화(火) | 丙, 丁, 巳, 午 |\n| 토(土) | 戊, 己, 辰, 戌, 丑, 未 |\n| 금(金) | 庚, 辛, 申, 酉 |\n| 수(水) | 壬, 癸, 子, 亥 |\n\n### 2) 8자 오행 분포\n\n- 乙 (연간) → 목 +1\n- 亥 (연지) → 수 +1\n- 乙 (월간) → 목 +1\n- 卯 (월지) → 목 +1\n- 丙 (일간) → 화 +1\n- 辰 (일지) → 토 +1\n- 丙 (시간간) → 화 +1\n- 午 (시지) → 화 +1\n\n### 3) 오행 점수 집계\n\n| 오행 | 점수 | 해당 문자       |\n|-------|-------|----------------|\n| 목(木) | 3     | 乙, 乙, 卯     |\n| 화(火) | 3     | 丙, 丙, 午     |\n| 토(土) | 1     | 辰             |\n| 금(金) | 0     |                |\n| 수(水) | 1     | 亥             |\n\n- 총합: 3 + 3 + 1 + 0 + 1 = 8 (계산 유효)\n\n---\n\n### 4) 오행 분포 표\n\n| 오행 | 점수 | 문자           |\n|-------|-------|----------------|\n| 목(木) | 3     | 乙, 乙, 卯     |\n| 화(火) | 3     | 丙, 丙, 午     |\n| 토(土) | 1     | 辰             |\n| 금(金) | 0     |                |\n| 수(水) | 1     | 亥             |\n\n**Wu Xing total score = 8 (Calculation is valid.)**\n\n---\n\n### 5) 오행 해석\n\n- **목(木)과 화(火)가 강함**: 목과 화가 각각 3개로 강한 편이며, 토와 수는 약간 있고 금은 전혀 없음.\n- **목(木)**: 성장, 발전, 창의력, 부드러움과 융통성을 상징합니다.\n- **화(火)**: 열정, 에너지, 활동성, 리더십을 나타냅니다.\n- **토(土)**: 안정, 신뢰, 현실감, 책임감을 의미합니다.\n- **수(水)**: 지혜, 유연성, 감성, 지식을 뜻합니다.\n- **금(金)**: 결단력, 엄격함, 규율, 조직력을 나타내는데 부족함.\n\n- **상생관계**: 목생화(木生火)로 목과 화가 서로 도와주는 좋은 관계입니다.\n- **상극관계**: 화는 금을 극하지만 금이 없으므로 갈등은 적음.\n- **부족한 금(金)**: 금이 부족하여 결단력이나 규율, 체계적인 면에서 보완이 필요할 수 있음.\n\n- **보완 제안**: 금의 기운을 보충하기 위해 흰색 계열 옷, 금속 악세서리, 규칙적인 생활 습관, 체계적인 사고 훈련 등이 도움이 될 수 있습니다.\n\n---\n\n## 3. 십신(十神) 분석\n\n- 일간(일주 천간): 丙 (병화)\n- 나머지 7자와의 관계:\n\n| 대상 | 천간/지지 | 십신 관계 (병화 기준) |\n|-------|------------|-----------------------|\n| 연간 | 乙 (목)    | 편재 (목은 병화의 재성) |\n| 연지 | 亥 (수)    | 정관 (수는 병화의 관성) |\n| 월간 | 乙 (목)    | 편재                  |\n| 월지 | 卯 (목)    | 편재                  |\n| 일지 | 辰 (토)    | 편인 (토는 병화의 인성) |\n| 시간간 | 丙 (화)   | 비견 (동일한 화)       |\n| 시지 | 午 (화)    | 비견                  |\n\n- **편재(재물, 재능)**가 강하게 3개(乙, 乙, 卯)로 재능과 재물운이 좋음.\n- **정관(관직, 규율)** 1개(亥)로 사회적 지위와 규율을 어느 정도 갖춤.\n- **편인(보호, 학문)** 1개(辰)로 지혜와 보호를 받음.\n- **비견(동료, 경쟁)** 2개(丙, 午)로 동료나 경쟁자가 많고 자기주장이 강함.\n\n---\n\n## 4. 성격 및 기질\n\n- **열정적이고 활동적**이며 리더십이 강함 (화가 강함).\n- **창의적이고 성장욕구가 강함** (목이 강함).\n- **재능과 재물운이 좋아 사업이나 재물 관리에 능함** (편재 다수).\n- **사회적 규율과 책임감도 어느 정도 갖추었으나, 금이 부족해 체계적이고 엄격한 면은 약할 수 있음**.\n- **동료나 경쟁자가 많아 협력과 경쟁을 잘 조화시켜야 함**.\n\n---\n\n## 5. 대운(大運) 및 세운(歲運) 분석 (간략)\n\n- 1995년생 남성은 양력 3월 출생으로 춘분 이후 출생, 대운은 **앞으로 진행**.\n- 대운은 10년 단위로 변하며, 6세부터 시작하는 경우가 많음.\n- 대운과 세운은 사주의 부족한 금 기운을 보완하는 방향으로 금 또는 수 기운이 들어오는 시기가 좋음.\n- 2023~2025년 세운은 갑진(甲辰), 을사(乙巳), 병오(丙午) 등으로 화와 토가 강해 재능과 활동성이 계속 강화되는 시기임.\n\n---\n\n## 6. 종합 요약 및 주의사항\n\n- **강점**: 목과 화가 강해 창의력, 열정, 리더십, 재능과 재물운이 좋음.\n- **약점**: 금 기운 부족으로 체계적이고 엄격한 면이 약할 수 있음.\n- **성격**: 활동적이고 적극적이며 경쟁심이 강함. 협력과 경쟁의 균형이 중요.\n- **조언**: 금 기운 보충을 위해 흰색 계열 착용, 금속 악세서리, 규칙적인 생활 습관 권장.\n- **대운과 세운**: 앞으로 10년 단위 대운에서 금과 수 기운이 들어오는 시기를 잘 활용하면 운이 상승함.\n\n---\n\n필요하시면 대운과 세운을 더 상세히 분석해 드릴 수 있습니다.\n\n---\n\n**출처**: 한국 명리학 전통 이론 및 오행 분류 기준 (내부 자료 기준)', additional_kwargs={}, response_metadata={}, name='RetrieverTool')]}

# %%
web_message = web_tool_agent_node(
    {
        "messages": [
            HumanMessage(content="사주오행에서의 불")
        ]
    }
)
print(web_message)
# Out:
# {'messages': [HumanMessage(content="사주오행에서 '불(火)'은 다섯 가지 기본 요소 중 하나로, 자연과 인간의 다양한 현상을 상징합니다. 불은 다음과 같은 의미와 특성을 가집니다.\n\n1. 기본 의미:\n   - 불은 열정, 에너지, 활력, 빛, 따뜻함을 상징합니다.\n   - 변화와 성장, 발전을 나타내며, 강한 의지와 추진력을 의미하기도 합니다.\n\n2. 성격적 특성:\n   - 불의 기운이 강한 사람은 활발하고 적극적이며, 리더십이 뛰어나고 열정적입니다.\n   - 때로는 성급하거나 다혈질적인 면도 있을 수 있습니다.\n\n3. 계절과 방향:\n   - 불은 여름과 남쪽을 상징합니다.\n   - 여름의 뜨거운 태양과 같은 기운을 지니고 있습니다.\n\n4. 색상과 상징물:\n   - 붉은색, 주황색 등이 불의 색으로 여겨집니다.\n   - 불꽃, 태양, 전등 등이 불의 상징물입니다.\n\n5. 상호작용:\n   - 불은 나무(木)를 태워 성장시키고, 불은 흙(土)을 변화시키며, 금(金)을 녹이고, 물(水)에 의해 꺼질 수 있습니다.\n   - 이러한 상생(相生)과 상극(相剋)의 관계를 통해 사주에서의 균형과 조화를 판단합니다.\n\n사주에서 불의 위치와 세기, 다른 오행과의 관계에 따라 개인의 성격, 운명, 건강, 직업 등 다양한 해석이 이루어집니다. 더 구체적인 사주 분석이 필요하면 태어난 연월일시를 알려주시면 도움을 드릴 수 있습니다.", additional_kwargs={}, response_metadata={}, name='WebTool')]}

# %%
# GeneralQA 테스트
general_qa_message = general_qa_agent_node(
    {
        "messages": [
            HumanMessage(content="파이썬에서 리스트와 튜플의 차이점?")
        ]
    }
)
print(general_qa_message)
# Out:
# {'messages': [HumanMessage(content='파이썬에서 리스트와 튜플은 모두 여러 개의 아이템을 담을 수 있는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.\n\n### 1. 가변성 (Mutability)\n- **리스트 (List)**: 가변(Mutable)합니다. 즉, 리스트를 생성한 후에 요소를 추가, 삭제, 변경할 수 있습니다.\n- **튜플 (Tuple)**: 불변(Immutable)합니다. 튜플을 생성한 후에는 요소를 변경할 수 없습니다. 요소를 추가, 삭제, 수정하는 동작은 허용되지 않습니다.\n\n### 2. 문법\n- **리스트**: 대괄호 `[]`를 사용하여 정의합니다. 예: `my_list = [1, 2, 3]`\n- **튜플**: 소괄호 `()`를 사용하여 정의합니다. 예: `my_tuple = (1, 2, 3)` (괄호는 필수는 아니지만, 명확성을 위해 사용하는 것이 좋습니다. 특히 요소가 하나인 튜플을 만들 때는 쉼표를 꼭 붙여야 합니다: `my_tuple = (1,)`)\n\n### 3. 성능\n- **튜플**: 일반적으로 리스트보다 더 빠릅니다. 튜플은 불변하기 때문에 파이썬 인터프리터가 튜플을 최적화할 수 있습니다. 튜플은 해싱이 가능하므로 딕셔너리의 키로 사용할 수 있습니다.\n- **리스트**: 가변성이 있기 때문에 튜플보다 약간 느릴 수 있습니다.\n\n### 4. 사용 사례\n- **리스트**: 데이터가 변경될 가능성이 있는 경우, 즉 요소를 추가, 삭제, 수정해야 하는 경우에 사용합니다. 예: 사용자 목록, 장바구니 항목 등\n- **튜플**: 데이터가 변경되지 않아야 하는 경우, 즉 읽기 전용 데이터에 사용합니다. 예: 좌표 (x, y), RGB 색상 (red, green, blue), 함수의 반환 값 (여러 값을 반환할 때 튜플을 사용)\n\n### 5. 메서드\n- **리스트**: 요소를 추가, 삭제, 정렬하는 등 다양한 메서드를 제공합니다 (예: `append()`, `insert()`, `remove()`, `sort()`).\n- **튜플**: 리스트에 비해 메서드가 적습니다. 주로 `count()` (특정 요소의 개수 세기)와 `index()` (특정 요소의 인덱스 찾기) 정도만 제공합니다.\n\n### 요약\n\n| 특징        | 리스트 (List) | 튜플 (Tuple) |\n| ----------- | ------------- | ------------- |\n| 가변성      | 가변          | 불변          |\n| 문법        | `[]`          | `()`          |\n| 성능        | 약간 느림     | 빠름          |\n| 사용 사례    | 변경 가능한 데이터 | 읽기 전용 데이터 |\n| 메서드 수   | 많음          | 적음          |\n\n### 예제 코드\n\n```python\n# 리스트\nmy_list = [1, 2, 3]\nmy_list.append(4)  # 요소 추가\nmy_list[0] = 10    # 요소 변경\nprint(my_list)      # 출력: [10, 2, 3, 4]\n\n# 튜플\nmy_tuple = (1, 2, 3)\n# my_tuple.append(4)  # 에러 발생! 튜플은 변경 불가능\n# my_tuple[0] = 10    # 에러 발생! 튜플은 변경 불가능\nprint(my_tuple)      # 출력: (1, 2, 3)\n\n# 튜플은 언패킹에 유용합니다.\nx, y = (10, 20)\nprint(x, y) # 출력: 10 20\n```\n\n리스트와 튜플은 각각의 장단점이 있으므로, 상황에 맞게 적절한 자료구조를 선택하는 것이 중요합니다. 데이터의 변경 가능성, 성능 요구 사항, 코드의 가독성 등을 고려하여 결정해야 합니다.', additional_kwargs={}, response_metadata={}, name='GeneralQA')]}

# %% [markdown]
# # Agent Supervisor 생성

# %%
from pydantic import BaseModel
from typing import Literal

# 멤버 Agent 목록 정의 (QueryExpansion, GeneralQA 추가)
members = ["ManseTool", "RetrieverTool", "WebTool", "GeneralQA"]

# 다음 작업자 선택 옵션 목록 정의
options_for_next = ["Barricade"] + members

# 작업자 선택 응답 모델 정의: 다음 작업자를 선택하거나 작업 완료를 나타냄
class RouteResponse(BaseModel):
    next: Literal[*options_for_next]

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI

# 시스템 프롬프트 정의: 작업자 간의 대화를 관리하는 감독자 역할
system_prompt = (
    "You are a supervisor tasked with orchestrating a multi-step workflow with the following specialized agents: {members}.\n"
    "The tools are:\n"
    "- ManseTool: For extracting and calculating Saju information (year, month, day, hour pillars) from user input (such as date/time of birth).\n"
    "- RetrieverTool: For interpreting Saju details and providing in-depth Saju or Four Pillars explanations and analysis based on calculated information.\n"
    "- WebTool: For answering general or conceptual questions about Saju, or handling everyday/non-specialized queries, by searching the web.\n"
    "- GeneralQA: For answering general questions that are NOT related to Saju at all (e.g., programming, science, general knowledge, etc.).\n\n"

    "Your job is to:\n"
    "1. Route the user's request to the most appropriate tool:\n"
    "   - If the user input contains raw birth information (date/time, etc.), ALWAYS call ManseTool FIRST.\n"
    "   - IMPORTANT: **After using ManseTool, you MUST ALWAYS call RetrieverTool next to interpret the calculated Saju results, before finishing or moving to any other step. Do NOT skip this step.**\n"
    "   - If the input is purely a general, conceptual, or non-specialized Saju question, and does NOT require document search, call WebTool.\n"
    "   - If the input is completely unrelated to Saju, call GeneralQA.\n"
    "2. NEVER finish the workflow after ManseTool alone. Always pass the result to RetrieverTool before considering Barricade.\n"
    "3. For completely non-Saju questions, use GeneralQA directly.\n"
    "3. After all needed steps are complete, respond with Barricade.\n"
    "You MUST always decide the most logical next agent for the task and strictly follow this tool sequence."
)

# ChatPromptTemplate 생성
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        MessagesPlaceholder(variable_name="messages"),
        (
            "system",
            "Given the conversation above, who should act next? "
            "Or should we Barricade? Select one of: {options}",
            # "Or should we FINISH? Select one of: {options}",
        ),
    ]
).partial(options=str(options_for_next), members=", ".join(members))


# LLM 초기화
llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)


# Supervisor Agent 생성
def supervisor_agent(state):
    # 프롬프트와 LLM을 결합하여 체인 구성
    supervisor_chain = prompt | llm.with_structured_output(RouteResponse)
    # Agent 호출
    return supervisor_chain.invoke(state)

# %%
# 답번 적절성 평가 노드: 바리게이트
from langchain_openai import ChatOpenAI

def barricade_node(state):
    # 마지막 메시지(답변)와 원본 질문 추출
    messages = state["messages"]
    user_message = None
    answer_message = None
    if messages:
        user_message = messages[0].content
        answer_message = messages[-1].content

    # LLM 프롬프트
    prompt = f"""아래는 사용자의 질문과 그에 대한 답변입니다.
        질문: {user_message}
        답변: {answer_message}

        이 답변이 질문에 적절하게 답하고 있으면 'FINISH', 적절하지 않으면 'QueryExpansion'만 출력하세요."""

    llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
    result = llm.invoke(prompt)
    
    if "FINISH" in result.content:
        return {"next": "FINISH", "messages": messages}
    else:
        return {"next": "QueryExpansion", "messages": messages}

# %%
import operator
from typing import Sequence, Annotated
from typing_extensions import TypedDict

from langchain_core.messages import BaseMessage


# 상태 정의
class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage], operator.add]  # 메시지
    next: str  # 다음으로 라우팅할 에이전트

# %%
from langgraph.graph import END, StateGraph, START
from langgraph.checkpoint.memory import MemorySaver

# Query Expansion 노드가 포함된 그래프 생성
workflow2 = StateGraph(AgentState)

# 그래프에 노드 추가: members = ["ManseTool", "QueryExpansion", "RetrieverTool", "WebTool", "GeneralQA"]
workflow2.add_node("ManseTool", manse_tool_agent_node)
workflow2.add_node("QueryExpansion", query_expansion_node)  # Query Expansion 노드 추가
workflow2.add_node("RetrieverTool", retriever_tool_agent_node)  # 기존 Retriever 사용
workflow2.add_node("WebTool", web_tool_agent_node)
workflow2.add_node("GeneralQA", general_qa_agent_node)  # GeneralQA 노드 추가
workflow2.add_node("Supervisor", supervisor_agent)
workflow2.add_node("Barricade", barricade_node)


# 멤버 노드 > Supervisor 노드로 엣지 추가
for member in members:
    workflow2.add_edge(member, "Barricade")

# 조건부 엣지 추가
conditional_map = {k: k for k in members}
conditional_map["Barricade"] = "Barricade"
conditional_map["FINISH"] = END

def get_next(state):
    return state["next"]

# Supervisor 노드에서 조건부 엣지 추가
workflow2.add_conditional_edges("Supervisor", get_next, conditional_map)

# 시작점
# workflow2.add_edge(START, "QueryExpansion")
# workflow2.add_edge("QueryExpansion", "Supervisor")
workflow2.add_edge(START, "Supervisor")

# Barricade → Supervisor(적절) / QueryExpansion(부적절) 조건부 엣지
def barricade_next(state):
    return state["next"]

workflow2.add_conditional_edges("Barricade", barricade_next, {
    "QueryExpansion": "QueryExpansion",
    "FINISH": END,
})
workflow2.add_edge("QueryExpansion", "Supervisor")
# 그래프 컴파일
graph2 = workflow2.compile(checkpointer=MemorySaver())

# %%
graph2

# %%
from langgraph.graph import END, StateGraph, START
from langgraph.checkpoint.memory import MemorySaver

# Query Expansion 노드가 포함된 그래프 생성
workflow = StateGraph(AgentState)

# 멤버(agent) 노드
workflow.add_node("ManseTool", manse_tool_agent_node)
workflow.add_node("RetrieverTool", retriever_tool_agent_node)
workflow.add_node("WebTool", web_tool_agent_node)
workflow.add_node("GeneralQA", general_qa_agent_node)
workflow.add_node("QueryExpansion", query_expansion_node)

# Supervisor 노드
workflow.add_node("Supervisor", supervisor_agent)

# Barricade(적절성 평가) 노드
workflow.add_node("Barricade", barricade_node)

members = ["ManseTool", "RetrieverTool", "WebTool", "GeneralQA"]

# 시작점
# workflow.add_edge(START, "QueryExpansion")

workflow.add_edge(START, "Supervisor")


# Supervisor → (각 툴 or FINISH)
conditional_map = {k: k for k in members}  # 각 툴 이름
conditional_map["Barricade"] = "Barricade"    # FINISH일 때만 Barricade로

def get_next(state):
    return state["next"]

workflow.add_conditional_edges("Supervisor", get_next, conditional_map)

# 각 툴 → Supervisor
for member in members:
    workflow.add_edge(member, "Supervisor")

# Barricade → END(적절) / QueryExpansion(부적절)
def barricade_next(state):
    return state["next"]

workflow.add_conditional_edges("Barricade", barricade_next, {
    "FINISH": END,
    "QueryExpansion": "Supervisor"
})
# workflow.add_edge("QueryExpansion", "Supervisor")

graph = workflow.compile(checkpointer=MemorySaver())

# %%
graph

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=30, configurable={"thread_id": 1})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="1995년 3월 28일 남자, 12시 30분 출생 운세봐줘"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 을해
# 월주(月柱): 기묘
# 일주(日柱): 계신
# 시주(時柱): 무오
# 일간(日干): 계
#
# === 오행 강약 ===
# 목: 39점
# 화: 10점
# 토: 45점
# 금: 9점
# 수: 34점
#
# === 십신 분석 ===
# 년주: 천간:식신, 지지:겁재(70%), 지지:상관(30%)
# 월주: 천간:편관, 지지:식신(100%)
# 일주: 지지:정인(60%), 지지:겁재(30%), 지지:정관(10%)
# 시주: 천간:정관, 지지:편재(70%), 지지:편관(30%)
#
# === 대운 (정밀 계산) ===
# 5세: 무인 (2000년 ~ 2009년)
# 15세: 정축 (2010년 ~ 2019년)
# 25세: 병자 (2020년 ~ 2029년)
# 35세: 을해 (2030년 ~ 2039년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주(年柱): 을해
# - 월주(月柱): 기묘
# - 일주(日柱): 계신
# - 시주(時柱): 무오
# - 일간(日干): 계
#
# 오행의 강약은 목 39점, 화 10점, 토 45점, 금 9점, 수 34점으로 토와 목이 강한 편입니다.
#
# 십신 분석에서는 식신, 편관, 정인, 정관, 편재 등의 기운이 조화를 이루고 있습니다.
#
# 대운은 다음과 같이 흐릅니다.
# - 5세부터 14세: 무인 대운 (2000년 ~ 2009년)
# - 15세부터 24세: 정축 대운 (2010년 ~ 2019년)
# - 25세부터 34세: 병자 대운 (2020년 ~ 2029년)
# - 35세부터 44세: 을해 대운 (2030년 ~ 2039년)
#
# 현재 2024년 기준으로 병자 대운에 있으며, 이 시기는 자신의 능력을 발휘하고 성취를 이루기에 좋은 시기입니다. 앞으로 을해 대운이 시작되면 새로운 기회와 변화를 맞이할 수 있습니다.
#
# 전체적으로 토와 목의 기운이 강해 안정적이고 현실적인 성향이 강하며, 지혜와 유연성을 발휘하면 좋은 결과를 얻을 수 있는 운세입니다.
# ==================================================
# 🔄 Node: ManseTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주(年柱): 을해
# - 월주(月柱): 기묘
# - 일주(日柱): 계신
# - 시주(時柱): 무오
# - 일간(日干): 계
#
# 오행의 강약은 목 39점, 화 10점, 토 45점, 금 9점, 수 34점으로 토와 목이 강한 편입니다.
#
# 십신 분석에서는 식신, 편관, 정인, 정관, 편재 등의 기운이 조화를 이루고 있습니다.
#
# 대운은 다음과 같이 흐릅니다.
# - 5세부터 14세: 무인 대운 (2000년 ~ 2009년)
# - 15세부터 24세: 정축 대운 (2010년 ~ 2019년)
# - 25세부터 34세: 병자 대운 (2020년 ~ 2029년)
# - 35세부터 44세: 을해 대운 (2030년 ~ 2039년)
#
# 현재 2024년 기준으로 병자 대운에 있으며, 이 시기는 자신의 능력을 발휘하고 성취를 이루기에 좋은 시기입니다. 앞으로 을해 대운이 시작되면 새로운 기회와 변화를 맞이할 수 있습니다.
#
# 전체적으로 토와 목의 기운이 강해 안정적이고 현실적인 성향이 강하며, 지혜와 유연성을 발휘하면 좋은 결과를 얻을 수 있는 운세입니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 사주팔자(사주명리) 분석을 아래와 같이 정밀하게 진행하겠습니다.
#
# ---
#
# ## 1. 사주 구조 (천간지지 변환 및 시주 계산)
#
# - 출생일: 1995년 3월 28일 12시 30분 (양력 기준, 남성)
# - 시각: 12시 30분 → 지지 시각은 午시(11시~13시)로 분류됩니다.
#
# ### 사주팔자 (천간지지 8자)
#
# - 년주(年柱): 을해(乙亥)
# - 월주(月柱): 기묘(己卯)
# - 일주(日柱): 계신(癸申)
# - 시주(時柱): 무오(戊午)
#
# → 8자: 乙(을), 亥(해), 己(기), 卯(묘), 癸(계), 申(신), 戊(무), 午(오)
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 2-1) 천간지지 → 오행 매핑 (기준)
#
# | 오행 | 해당 천간/지지 문자 |
# |-------|--------------------|
# | 목(木) | 甲, 乙, 寅, 卯 |
# | 화(火) | 丙, 丁, 巳, 午 |
# | 토(土) | 戊, 己, 辰, 戌, 丑, 未 |
# | 금(金) | 庚, 辛, 申, 酉 |
# | 수(水) | 壬, 癸, 子, 亥 |
#
# ### 2-2) 8자별 오행 배정 및 점수
#
# | 문자 | 오행 | 점수 |
# |-------|-------|-------|
# | 乙(을) | 목(木) | 1 |
# | 亥(해) | 수(水) | 1 |
# | 己(기) | 토(土) | 1 |
# | 卯(묘) | 목(木) | 1 |
# | 癸(계) | 수(水) | 1 |
# | 申(신) | 금(金) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
#
# ### 2-3) 오행별 합산
#
# | 오행 | 점수 | 문자 |
# |-------|-------|-------|
# | 목(木) | 2 | 乙, 卯 |
# | 화(火) | 1 | 午 |
# | 토(土) | 2 | 己, 戊 |
# | 금(金) | 1 | 申 |
# | 수(水) | 2 | 亥, 癸 |
#
# **총합: 2+1+2+1+2 = 8 (계산 유효)**
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 강약 및 해석
#
# - **목(木): 2점** — 성장, 발전, 유연성, 창의력 상징. 목이 적당히 강해 새로운 것을 배우고 성장하는 성향이 강함.
# - **화(火): 1점** — 열정, 활력, 추진력. 다소 약한 편이나 존재하여 활발한 성격의 기초가 됨.
# - **토(土): 2점** — 안정, 현실감, 신뢰성. 토가 강해 현실적이고 신중한 면이 강함.
# - **금(金): 1점** — 결단력, 엄격함, 규율. 금이 약간 있어 결단력과 규칙성을 보완.
# - **수(水): 2점** — 지혜, 유연성, 감성. 수가 강해 지혜롭고 감성적인 면이 있음.
#
# ### 해석
#
# - 목과 토가 강한 편으로, 성장과 안정이 조화를 이루는 사주입니다.
# - 화와 금은 다소 약하지만, 목과 수가 균형을 잡아주어 유연하면서도 현실적인 성격이 나타납니다.
# - 상생(생) 관계: 목→화→토→금→수 순으로 상생하므로, 목과 토가 강한 점은 좋은 조화입니다.
# - 상극(극) 관계: 목이 토를 극하나, 토가 강해 균형을 유지합니다.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 癸 기준)
#
# - 일간(日干): 癸(계수, 음수)
# - 나머지 7자와의 관계:
#
# | 대상 문자 | 천간/지지 | 십신 관계 | 해석 |
# |-----------|-----------|-----------|-------|
# | 乙(을) | 년간 | 편재 | 재물과 재능, 적극적 재물운 |
# | 亥(해) | 년지 | 편인 | 보호, 학문, 지혜, 어머니 상징 |
# | 己(기) | 월간 | 편관 | 규율, 권위, 도전, 직장운 |
# | 卯(묘) | 월지 | 편재 | 재물, 기회, 외부 도움 |
# | 申(신) | 일지 | 편관 | 권위, 도전, 경쟁 |
# | 戊(무) | 시간 | 정재 | 재물, 안정, 부 |
# | 午(오) | 시지 | 식신 | 창조력, 표현력, 건강 |
#
# ### 해석
#
# - 편재(乙, 卯)와 정재(戊)로 재물운이 좋고, 재능과 기회가 많음.
# - 편관(己, 申)은 권위와 도전을 의미, 직장이나 사회적 위치에서 경쟁력이 있음.
# - 식신(午)은 창의력과 건강을 상징, 표현력이 뛰어남.
# - 편인(亥)은 지혜와 보호를 의미, 학문적 재능과 보호자가 있음.
#
# ---
#
# ## 5. 성격 및 기질
#
# - 현실적이고 신중하며, 성장과 발전을 중시하는 성격.
# - 지혜롭고 감성적이며, 창의력과 표현력이 뛰어남.
# - 권위와 도전을 두려워하지 않고, 적극적으로 사회적 위치를 추구함.
# - 재물운이 좋아 경제적 안정 가능.
# - 다소 내성적이나, 주변의 도움과 보호를 받음.
#
# ---
#
# ## 6. 대운(大運) 및 세운(歲運) 분석
#
# - 대운 시작: 5세부터 시작
# - 대운 흐름:
#
# | 나이 | 대운 | 오행 | 해석 |
# |-------|-------|-------|-------|
# | 5~14세 | 무인(戊寅) | 토, 목 | 성장기, 안정과 발전 |
# | 15~24세 | 정축(丁丑) | 화, 토 | 활력과 현실적 기반 강화 |
# | 25~34세 | 병자(丙子) | 화, 수 | 창의력과 지혜 발휘 시기 |
# | 35~44세 | 을해(乙亥) | 목, 수 | 성장과 지혜의 조화, 새로운 기회 |
#
# - 2024년 현재 29세로 병자 대운에 해당, 창의력과 지혜가 발휘되는 좋은 시기입니다.
# - 2030년부터 을해 대운으로 접어들어 새로운 기회와 변화를 맞이할 수 있습니다.
#
# ---
#
# ## 7. 종합 요약 및 조언
#
# - **강점**: 목과 토가 강해 성장과 안정이 조화롭고, 수와 화가 적절히 보완하여 지혜와 활력이 있음.
# - **성격**: 현실적이면서도 창의적이고, 도전 정신이 강함.
# - **운세**: 현재 대운이 좋은 시기로, 능력을 발휘하고 성취를 이루기에 적합함.
# - **조언**: 화와 금이 다소 약하므로, 화의 기운을 보충하는 붉은색 계열, 금의 기운을 보완하는 흰색이나 금속성 액세서리 활용 권장. 또한, 물과 나무가 강하므로 자연과의 교감, 독서, 학문 활동이 도움이 됨.
#
# ---
#
# 필요하시면 대운과 세운에 따른 구체적 시기별 운세 및 조언도 추가로 제공해 드리겠습니다.
#
# ---
#
# **출처:**
# - 한국명리학 전통 이론 (천간지지 오행 매핑 및 십신 해석 기준)
# - 사주팔자 분석 원리 (Wu Xing 계산법 및 대운 흐름)
#
# 궁금하신 점 있으면 언제든 문의해 주세요!
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 사주팔자(사주명리) 분석을 아래와 같이 정밀하게 진행하겠습니다.
#
# ---
#
# ## 1. 사주 구조 (천간지지 변환 및 시주 계산)
#
# - 출생일: 1995년 3월 28일 12시 30분 (양력 기준, 남성)
# - 시각: 12시 30분 → 지지 시각은 午시(11시~13시)로 분류됩니다.
#
# ### 사주팔자 (천간지지 8자)
#
# - 년주(年柱): 을해(乙亥)
# - 월주(月柱): 기묘(己卯)
# - 일주(日柱): 계신(癸申)
# - 시주(時柱): 무오(戊午)
#
# → 8자: 乙(을), 亥(해), 己(기), 卯(묘), 癸(계), 申(신), 戊(무), 午(오)
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 2-1) 천간지지 → 오행 매핑 (기준)
#
# | 오행 | 해당 천간/지지 문자 |
# |-------|--------------------|
# | 목(木) | 甲, 乙, 寅, 卯 |
# | 화(火) | 丙, 丁, 巳, 午 |
# | 토(土) | 戊, 己, 辰, 戌, 丑, 未 |
# | 금(金) | 庚, 辛, 申, 酉 |
# | 수(水) | 壬, 癸, 子, 亥 |
#
# ### 2-2) 8자별 오행 배정 및 점수
#
# | 문자 | 오행 | 점수 |
# |-------|-------|-------|
# | 乙(을) | 목(木) | 1 |
# | 亥(해) | 수(水) | 1 |
# | 己(기) | 토(土) | 1 |
# | 卯(묘) | 목(木) | 1 |
# | 癸(계) | 수(水) | 1 |
# | 申(신) | 금(金) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
#
# ### 2-3) 오행별 합산
#
# | 오행 | 점수 | 문자 |
# |-------|-------|-------|
# | 목(木) | 2 | 乙, 卯 |
# | 화(火) | 1 | 午 |
# | 토(土) | 2 | 己, 戊 |
# | 금(金) | 1 | 申 |
# | 수(水) | 2 | 亥, 癸 |
#
# **총합: 2+1+2+1+2 = 8 (계산 유효)**
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 강약 및 해석
#
# - **목(木): 2점** — 성장, 발전, 유연성, 창의력 상징. 목이 적당히 강해 새로운 것을 배우고 성장하는 성향이 강함.
# - **화(火): 1점** — 열정, 활력, 추진력. 다소 약한 편이나 존재하여 활발한 성격의 기초가 됨.
# - **토(土): 2점** — 안정, 현실감, 신뢰성. 토가 강해 현실적이고 신중한 면이 강함.
# - **금(金): 1점** — 결단력, 엄격함, 규율. 금이 약간 있어 결단력과 규칙성을 보완.
# - **수(水): 2점** — 지혜, 유연성, 감성. 수가 강해 지혜롭고 감성적인 면이 있음.
#
# ### 해석
#
# - 목과 토가 강한 편으로, 성장과 안정이 조화를 이루는 사주입니다.
# - 화와 금은 다소 약하지만, 목과 수가 균형을 잡아주어 유연하면서도 현실적인 성격이 나타납니다.
# - 상생(생) 관계: 목→화→토→금→수 순으로 상생하므로, 목과 토가 강한 점은 좋은 조화입니다.
# - 상극(극) 관계: 목이 토를 극하나, 토가 강해 균형을 유지합니다.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 癸 기준)
#
# - 일간(日干): 癸(계수, 음수)
# - 나머지 7자와의 관계:
#
# | 대상 문자 | 천간/지지 | 십신 관계 | 해석 |
# |-----------|-----------|-----------|-------|
# | 乙(을) | 년간 | 편재 | 재물과 재능, 적극적 재물운 |
# | 亥(해) | 년지 | 편인 | 보호, 학문, 지혜, 어머니 상징 |
# | 己(기) | 월간 | 편관 | 규율, 권위, 도전, 직장운 |
# | 卯(묘) | 월지 | 편재 | 재물, 기회, 외부 도움 |
# | 申(신) | 일지 | 편관 | 권위, 도전, 경쟁 |
# | 戊(무) | 시간 | 정재 | 재물, 안정, 부 |
# | 午(오) | 시지 | 식신 | 창조력, 표현력, 건강 |
#
# ### 해석
#
# - 편재(乙, 卯)와 정재(戊)로 재물운이 좋고, 재능과 기회가 많음.
# - 편관(己, 申)은 권위와 도전을 의미, 직장이나 사회적 위치에서 경쟁력이 있음.
# - 식신(午)은 창의력과 건강을 상징, 표현력이 뛰어남.
# - 편인(亥)은 지혜와 보호를 의미, 학문적 재능과 보호자가 있음.
#
# ---
#
# ## 5. 성격 및 기질
#
# - 현실적이고 신중하며, 성장과 발전을 중시하는 성격.
# - 지혜롭고 감성적이며, 창의력과 표현력이 뛰어남.
# - 권위와 도전을 두려워하지 않고, 적극적으로 사회적 위치를 추구함.
# - 재물운이 좋아 경제적 안정 가능.
# - 다소 내성적이나, 주변의 도움과 보호를 받음.
#
# ---
#
# ## 6. 대운(大運) 및 세운(歲運) 분석
#
# - 대운 시작: 5세부터 시작
# - 대운 흐름:
#
# | 나이 | 대운 | 오행 | 해석 |
# |-------|-------|-------|-------|
# | 5~14세 | 무인(戊寅) | 토, 목 | 성장기, 안정과 발전 |
# | 15~24세 | 정축(丁丑) | 화, 토 | 활력과 현실적 기반 강화 |
# | 25~34세 | 병자(丙子) | 화, 수 | 창의력과 지혜 발휘 시기 |
# | 35~44세 | 을해(乙亥) | 목, 수 | 성장과 지혜의 조화, 새로운 기회 |
#
# - 2024년 현재 29세로 병자 대운에 해당, 창의력과 지혜가 발휘되는 좋은 시기입니다.
# - 2030년부터 을해 대운으로 접어들어 새로운 기회와 변화를 맞이할 수 있습니다.
#
# ---
#
# ## 7. 종합 요약 및 조언
#
# - **강점**: 목과 토가 강해 성장과 안정이 조화롭고, 수와 화가 적절히 보완하여 지혜와 활력이 있음.
# - **성격**: 현실적이면서도 창의적이고, 도전 정신이 강함.
# - **운세**: 현재 대운이 좋은 시기로, 능력을 발휘하고 성취를 이루기에 적합함.
# - **조언**: 화와 금이 다소 약하므로, 화의 기운을 보충하는 붉은색 계열, 금의 기운을 보완하는 흰색이나 금속성 액세서리 활용 권장. 또한, 물과 나무가 강하므로 자연과의 교감, 독서, 학문 활동이 도움이 됨.
#
# ---
#
# 필요하시면 대운과 세운에 따른 구체적 시기별 운세 및 조언도 추가로 제공해 드리겠습니다.
#
# ---
#
# **출처:**
# - 한국명리학 전통 이론 (천간지지 오행 매핑 및 십신 해석 기준)
# - 사주팔자 분석 원리 (Wu Xing 계산법 및 대운 흐름)
#
# 궁금하신 점 있으면 언제든 문의해 주세요!
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# FINISH

# %%
# 추가질문 -> 바로 retriever tool로 들어갔다

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 1})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="대운과 세운분석 자세히 해줘"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 대운(大運)과 세운(歲運) 분석을 자세히 진행하겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 1-1) 대운 시작 시기 및 방향
#
# - 출생 월(3월, 양력 기준)은 춘분(3월 20~21일) 이후로 봄철에 해당합니다.
# - 남성은 대운을 **출생 후 앞으로 진행**합니다.
# - 대운은 보통 출생 후 5세부터 시작하며, 10년 단위로 바뀝니다.
#
# ### 1-2) 대운 목록 및 오행
#
# | 나이    | 대운  | 천간지지 | 오행        | 해석 및 특징                          |
# |---------|--------|-----------|-------------|-------------------------------------|
# | 5~14세  | 무인   | 戊寅      | 토(土), 목(木) | 성장기, 안정과 발전의 시기. 목과 토의 조화로 학습과 신체 발달에 유리. |
# | 15~24세 | 정축   | 丁丑      | 화(火), 토(土) | 활력과 현실적 기반 강화. 사회 진출 준비 및 인간관계 확장기. |
# | 25~34세 | 병자   | 丙子      | 화(火), 수(水) | 창의력과 지혜 발휘 시기. 새로운 도전과 성취 가능성이 높음. |
# | 35~44세 | 을해   | 乙亥      | 목(木), 수(水) | 성장과 지혜의 조화. 새로운 기회와 변화가 찾아오는 시기. |
#
# ### 1-3) 대운 해석
#
# - 현재(2024년 기준, 만 29세)는 **병자 대운(丙子)**에 해당합니다.
#   - 화(火)와 수(水)의 조화로 창의력과 지혜가 극대화되는 시기입니다.
#   - 사회적 활동과 자기 표현에 좋은 기운이 흐르며, 성취와 발전이 기대됩니다.
# - 앞으로 2030년부터 시작하는 **을해 대운(乙亥)**은 목과 수의 조화로 새로운 성장과 학문, 인간관계 확장에 유리한 시기입니다.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2022년~2025년)
#
# ### 2-1) 2022년 (임인, 壬寅)
#
# - 임(壬): 수(水), 인(寅): 목(木)
# - 임수는 일간 계수(癸水)와 같은 수(水) 계열로 보조 작용.
# - 인목은 목(木)으로 목이 강한 사주에 긍정적 영향.
# - **해석:** 지혜와 성장의 기운이 보강되어 학업, 직장, 인간관계에서 좋은 기운이 흐름.
#
# ### 2-2) 2023년 (계묘, 癸卯)
#
# - 계(癸): 수(水), 묘(卯): 목(木)
# - 일간과 동일한 계수와 목의 조합.
# - **해석:** 자기 자신과 조화로운 해로, 내면의 안정과 외부 성장 모두 좋은 시기. 새로운 기회와 창의력 발휘 가능.
#
# ### 2-3) 2024년 (갑진, 甲辰)
#
# - 갑(甲): 목(木), 진(辰): 토(土)
# - 갑목은 목의 시작을 상징, 진토는 토의 일부로 안정감 제공.
# - **해석:** 목과 토의 조화로 성장과 안정이 균형을 이루는 해. 다만, 토가 목을 극하는 면도 있어 건강과 스트레스 관리 필요.
#
# ### 2-4) 2025년 (을사, 乙巳)
#
# - 을(乙): 목(木), 사(巳): 화(火)
# - 을목과 사화의 조합으로 목생화(목이 화를 생함) 관계.
# - **해석:** 활력과 추진력이 증가하는 해. 새로운 일이나 프로젝트 시작에 적합하며, 대인관계도 활발해짐.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 현재 병자 대운과 2022~2025년 세운 모두 수(木)와 화(火), 토(土)의 조화가 잘 이루어져 있습니다.
# - 특히 목과 수가 강한 사주에 화의 기운이 점차 보강되어 활력과 추진력이 증가하는 시기입니다.
# - 토의 기운이 목을 극하는 면이 있으므로, 건강 관리와 스트레스 조절에 신경 쓰는 것이 좋습니다.
# - 대운과 세운 모두 재물운과 인간관계에 긍정적 영향을 주므로, 적극적인 사회 활동과 자기계발을 권장합니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분   | 내용                                   |
# |--------|--------------------------------------|
# | 대운   | 25~34세 병자 대운: 창의력과 지혜 발휘 최적기 |
# | 세운   | 2022~2025년: 목과 수, 화의 조화로 성장과 활력 증가 |
# | 조언   | 건강과 스트레스 관리에 유의, 적극적 사회 활동 권장 |
#
# ---
#
# 필요하시면 특정 연도별 상세 운세나 맞춤형 조언도 추가로 제공해 드리겠습니다.
#
# 궁금하신 점 있으시면 언제든 문의해 주세요!
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 대운(大運)과 세운(歲運) 분석을 자세히 진행하겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 1-1) 대운 시작 시기 및 방향
#
# - 출생 월(3월, 양력 기준)은 춘분(3월 20~21일) 이후로 봄철에 해당합니다.
# - 남성은 대운을 **출생 후 앞으로 진행**합니다.
# - 대운은 보통 출생 후 5세부터 시작하며, 10년 단위로 바뀝니다.
#
# ### 1-2) 대운 목록 및 오행
#
# | 나이    | 대운  | 천간지지 | 오행        | 해석 및 특징                          |
# |---------|--------|-----------|-------------|-------------------------------------|
# | 5~14세  | 무인   | 戊寅      | 토(土), 목(木) | 성장기, 안정과 발전의 시기. 목과 토의 조화로 학습과 신체 발달에 유리. |
# | 15~24세 | 정축   | 丁丑      | 화(火), 토(土) | 활력과 현실적 기반 강화. 사회 진출 준비 및 인간관계 확장기. |
# | 25~34세 | 병자   | 丙子      | 화(火), 수(水) | 창의력과 지혜 발휘 시기. 새로운 도전과 성취 가능성이 높음. |
# | 35~44세 | 을해   | 乙亥      | 목(木), 수(水) | 성장과 지혜의 조화. 새로운 기회와 변화가 찾아오는 시기. |
#
# ### 1-3) 대운 해석
#
# - 현재(2024년 기준, 만 29세)는 **병자 대운(丙子)**에 해당합니다.
#   - 화(火)와 수(水)의 조화로 창의력과 지혜가 극대화되는 시기입니다.
#   - 사회적 활동과 자기 표현에 좋은 기운이 흐르며, 성취와 발전이 기대됩니다.
# - 앞으로 2030년부터 시작하는 **을해 대운(乙亥)**은 목과 수의 조화로 새로운 성장과 학문, 인간관계 확장에 유리한 시기입니다.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2022년~2025년)
#
# ### 2-1) 2022년 (임인, 壬寅)
#
# - 임(壬): 수(水), 인(寅): 목(木)
# - 임수는 일간 계수(癸水)와 같은 수(水) 계열로 보조 작용.
# - 인목은 목(木)으로 목이 강한 사주에 긍정적 영향.
# - **해석:** 지혜와 성장의 기운이 보강되어 학업, 직장, 인간관계에서 좋은 기운이 흐름.
#
# ### 2-2) 2023년 (계묘, 癸卯)
#
# - 계(癸): 수(水), 묘(卯): 목(木)
# - 일간과 동일한 계수와 목의 조합.
# - **해석:** 자기 자신과 조화로운 해로, 내면의 안정과 외부 성장 모두 좋은 시기. 새로운 기회와 창의력 발휘 가능.
#
# ### 2-3) 2024년 (갑진, 甲辰)
#
# - 갑(甲): 목(木), 진(辰): 토(土)
# - 갑목은 목의 시작을 상징, 진토는 토의 일부로 안정감 제공.
# - **해석:** 목과 토의 조화로 성장과 안정이 균형을 이루는 해. 다만, 토가 목을 극하는 면도 있어 건강과 스트레스 관리 필요.
#
# ### 2-4) 2025년 (을사, 乙巳)
#
# - 을(乙): 목(木), 사(巳): 화(火)
# - 을목과 사화의 조합으로 목생화(목이 화를 생함) 관계.
# - **해석:** 활력과 추진력이 증가하는 해. 새로운 일이나 프로젝트 시작에 적합하며, 대인관계도 활발해짐.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 현재 병자 대운과 2022~2025년 세운 모두 수(木)와 화(火), 토(土)의 조화가 잘 이루어져 있습니다.
# - 특히 목과 수가 강한 사주에 화의 기운이 점차 보강되어 활력과 추진력이 증가하는 시기입니다.
# - 토의 기운이 목을 극하는 면이 있으므로, 건강 관리와 스트레스 조절에 신경 쓰는 것이 좋습니다.
# - 대운과 세운 모두 재물운과 인간관계에 긍정적 영향을 주므로, 적극적인 사회 활동과 자기계발을 권장합니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분   | 내용                                   |
# |--------|--------------------------------------|
# | 대운   | 25~34세 병자 대운: 창의력과 지혜 발휘 최적기 |
# | 세운   | 2022~2025년: 목과 수, 화의 조화로 성장과 활력 증가 |
# | 조언   | 건강과 스트레스 관리에 유의, 적극적 사회 활동 권장 |
#
# ---
#
# 필요하시면 특정 연도별 상세 운세나 맞춤형 조언도 추가로 제공해 드리겠습니다.
#
# 궁금하신 점 있으시면 언제든 문의해 주세요!
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# FINISH

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 1})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="난 미래에 대한 대운과 세운분석이 궁금해"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 미래 대운과 세운 분석을 중심으로 자세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 미래 대운(大運) 분석
#
# ### 대운 진행 및 미래 대운 목록
#
# | 나이    | 대운  | 천간지지 | 오행        | 해석 및 특징                          |
# |---------|--------|-----------|-------------|-------------------------------------|
# | 25~34세 | 병자   | 丙子      | 화(火), 수(水) | 현재 진행 중인 대운. 창의력과 지혜 발휘 최적기. 성취와 발전 가능성 높음. |
# | 35~44세 | 을해   | 乙亥      | 목(木), 수(水) | 2030년부터 시작. 성장과 지혜의 조화, 새로운 기회와 변화가 찾아오는 시기. 학문, 인간관계 확장에 유리. |
# | 45~54세 | 갑술   | 甲戌      | 목(木), 토(土) | 안정과 성숙의 시기. 목과 토의 조화로 현실적이고 신중한 판단력 강화. |
# | 55~64세 | 계유   | 癸酉      | 수(水), 금(金) | 지혜와 결단력의 시기. 금의 기운이 보강되어 결단력과 실행력이 증가. 재물운과 건강에 유의. |
# | 65~74세 | 임신   | 壬申      | 수(水), 금(金) | 지혜와 권위의 조화. 사회적 위치 확장과 명예 상승 가능성. |
#
# ### 해석
#
# - 35세 이후부터는 을해 대운으로 목과 수의 조화가 강화되어 새로운 성장과 학문, 인간관계 확장에 매우 유리한 시기입니다.
# - 45세부터는 갑술 대운으로 현실적이고 신중한 판단력이 강화되어 안정적인 삶을 영위할 수 있습니다.
# - 55세 이후 계유, 임신 대운에서는 수와 금의 조화로 지혜와 결단력이 높아지며, 사회적 명예와 재물운이 좋아질 수 있으나 건강 관리에 신경 써야 합니다.
#
# ---
#
# ## 2. 미래 세운(歲運) 분석 (2026년~2030년)
#
# | 연도 | 세운  | 오행 구성 | 해석 및 특징 |
# |-------|--------|------------|--------------|
# | 2026년 | 병술(丙戌) | 화(火), 토(土) | 활력과 안정의 조화. 새로운 일 추진에 적합하나, 스트레스 관리 필요. |
# | 2027년 | 정해(丁亥) | 화(火), 수(水) | 창의력과 지혜가 상승하는 해. 학업, 연구, 자기계발에 유리. |
# | 2028년 | 무자(戊子) | 토(土), 수(水) | 안정과 지혜의 조화. 재물운과 인간관계에 긍정적 영향. |
# | 2029년 | 기축(己丑) | 토(土), 토(土) | 토의 기운이 강해 현실적이고 신중한 시기. 건강과 재물 관리에 주의. |
# | 2030년 | 경인(庚寅) | 금(金), 목(木) | 결단력과 성장의 조화. 새로운 도전과 기회가 찾아오는 해. |
#
# ### 해석
#
# - 2026~2027년은 화와 수의 조화로 활력과 지혜가 상승하는 시기입니다.
# - 2028~2029년은 토의 기운이 강해 안정과 신중함이 요구되며, 건강과 재물 관리에 신경 써야 합니다.
# - 2030년 경인년은 금과 목의 조화로 결단력과 성장이 함께하는 해로, 새로운 도전과 기회가 찾아올 것입니다.
#
# ---
#
# ## 3. 종합 조언
#
# - **35세 이후 대운 변화에 주목:** 을해 대운부터 시작되는 성장과 지혜의 조화 시기를 적극 활용하세요. 학문, 인간관계, 자기계발에 집중하면 좋은 결과가 있을 것입니다.
# - **건강 관리:** 2029년 기축년과 55세 이후 대운에서 토와 금의 기운이 강해지므로, 건강과 스트레스 관리에 특히 신경 써야 합니다.
# - **적극적 도전:** 2030년 경인년부터는 새로운 도전과 기회가 많으니, 준비를 철저히 하시고 자신감을 가지고 임하시길 바랍니다.
# - **재물과 인간관계:** 대운과 세운 모두 재물운과 인간관계에 긍정적인 기운이 흐르므로, 사회적 네트워크 확장과 재테크에 관심을 가지는 것이 좋습니다.
#
# ---
#
# 필요하시면 특정 연도별 상세 운세나 맞춤형 조언도 추가로 제공해 드리겠습니다.
#
# 궁금하신 점 있으시면 언제든 문의해 주세요!
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 미래 대운과 세운 분석을 중심으로 자세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 미래 대운(大運) 분석
#
# ### 대운 진행 및 미래 대운 목록
#
# | 나이    | 대운  | 천간지지 | 오행        | 해석 및 특징                          |
# |---------|--------|-----------|-------------|-------------------------------------|
# | 25~34세 | 병자   | 丙子      | 화(火), 수(水) | 현재 진행 중인 대운. 창의력과 지혜 발휘 최적기. 성취와 발전 가능성 높음. |
# | 35~44세 | 을해   | 乙亥      | 목(木), 수(水) | 2030년부터 시작. 성장과 지혜의 조화, 새로운 기회와 변화가 찾아오는 시기. 학문, 인간관계 확장에 유리. |
# | 45~54세 | 갑술   | 甲戌      | 목(木), 토(土) | 안정과 성숙의 시기. 목과 토의 조화로 현실적이고 신중한 판단력 강화. |
# | 55~64세 | 계유   | 癸酉      | 수(水), 금(金) | 지혜와 결단력의 시기. 금의 기운이 보강되어 결단력과 실행력이 증가. 재물운과 건강에 유의. |
# | 65~74세 | 임신   | 壬申      | 수(水), 금(金) | 지혜와 권위의 조화. 사회적 위치 확장과 명예 상승 가능성. |
#
# ### 해석
#
# - 35세 이후부터는 을해 대운으로 목과 수의 조화가 강화되어 새로운 성장과 학문, 인간관계 확장에 매우 유리한 시기입니다.
# - 45세부터는 갑술 대운으로 현실적이고 신중한 판단력이 강화되어 안정적인 삶을 영위할 수 있습니다.
# - 55세 이후 계유, 임신 대운에서는 수와 금의 조화로 지혜와 결단력이 높아지며, 사회적 명예와 재물운이 좋아질 수 있으나 건강 관리에 신경 써야 합니다.
#
# ---
#
# ## 2. 미래 세운(歲運) 분석 (2026년~2030년)
#
# | 연도 | 세운  | 오행 구성 | 해석 및 특징 |
# |-------|--------|------------|--------------|
# | 2026년 | 병술(丙戌) | 화(火), 토(土) | 활력과 안정의 조화. 새로운 일 추진에 적합하나, 스트레스 관리 필요. |
# | 2027년 | 정해(丁亥) | 화(火), 수(水) | 창의력과 지혜가 상승하는 해. 학업, 연구, 자기계발에 유리. |
# | 2028년 | 무자(戊子) | 토(土), 수(水) | 안정과 지혜의 조화. 재물운과 인간관계에 긍정적 영향. |
# | 2029년 | 기축(己丑) | 토(土), 토(土) | 토의 기운이 강해 현실적이고 신중한 시기. 건강과 재물 관리에 주의. |
# | 2030년 | 경인(庚寅) | 금(金), 목(木) | 결단력과 성장의 조화. 새로운 도전과 기회가 찾아오는 해. |
#
# ### 해석
#
# - 2026~2027년은 화와 수의 조화로 활력과 지혜가 상승하는 시기입니다.
# - 2028~2029년은 토의 기운이 강해 안정과 신중함이 요구되며, 건강과 재물 관리에 신경 써야 합니다.
# - 2030년 경인년은 금과 목의 조화로 결단력과 성장이 함께하는 해로, 새로운 도전과 기회가 찾아올 것입니다.
#
# ---
#
# ## 3. 종합 조언
#
# - **35세 이후 대운 변화에 주목:** 을해 대운부터 시작되는 성장과 지혜의 조화 시기를 적극 활용하세요. 학문, 인간관계, 자기계발에 집중하면 좋은 결과가 있을 것입니다.
# - **건강 관리:** 2029년 기축년과 55세 이후 대운에서 토와 금의 기운이 강해지므로, 건강과 스트레스 관리에 특히 신경 써야 합니다.
# - **적극적 도전:** 2030년 경인년부터는 새로운 도전과 기회가 많으니, 준비를 철저히 하시고 자신감을 가지고 임하시길 바랍니다.
# - **재물과 인간관계:** 대운과 세운 모두 재물운과 인간관계에 긍정적인 기운이 흐르므로, 사회적 네트워크 확장과 재테크에 관심을 가지는 것이 좋습니다.
#
# ---
#
# 필요하시면 특정 연도별 상세 운세나 맞춤형 조언도 추가로 제공해 드리겠습니다.
#
# 궁금하신 점 있으시면 언제든 문의해 주세요!
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# FINISH

# %%
# GeneralQA 도구 테스트 - 일반 질문
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 1})

# 일반 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="나의 운세는 돈을 많이 벌 수 있을까?"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 사주를 바탕으로 재물운, 즉 돈을 많이 벌 수 있는 가능성에 대해 정밀하게 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 및 오행 분포 복습
#
# - 년주: 을해(乙亥)
# - 월주: 기묘(己卯)
# - 일주: 계신(癸申)
# - 시주: 무오(戊午)
#
# 오행 분포:
# - 목(木): 2 (乙, 卯)
# - 화(火): 1 (午)
# - 토(土): 2 (己, 戊)
# - 금(金): 1 (申)
# - 수(水): 2 (亥, 癸)
#
# 총 8자 중 목, 토, 수가 강한 편이며, 금과 화가 다소 약한 편입니다.
#
# ---
#
# ## 2. 재물운과 관련된 십신(十神) 분석
#
# - 재물운을 대표하는 십신은 **정재(正財)**와 **편재(偏財)**입니다.
# - 본 사주에서 재물운 관련 십신은 다음과 같습니다.
#
# | 문자 | 십신 관계 | 의미 |
# |-------|-----------|-------|
# | 乙(년간) | 편재 | 적극적 재물, 기회, 외부 재물운 |
# | 卯(월지) | 편재 | 외부 재물, 기회, 투자 가능성 |
# | 戊(시간) | 정재 | 안정적 재물, 근면성실한 재물운 |
#
# - 편재가 2개, 정재가 1개 있어 재물운이 비교적 좋은 편입니다.
# - 편재는 변동적이고 기회 중심의 재물운을 의미하며, 정재는 안정적이고 꾸준한 재물운을 뜻합니다.
#
# ---
#
# ## 3. 대운과 세운에서 재물운 흐름
#
# - 현재 대운(25~34세 병자 대운)은 화(火)와 수(水)의 조화로 창의력과 지혜가 발휘되는 시기입니다. 이는 새로운 사업이나 창의적 직업에서 재물운이 상승할 수 있음을 의미합니다.
# - 35~44세 을해 대운은 목(木)과 수(水)의 조화로 성장과 학문, 인간관계 확장에 유리하여 재물운이 더욱 좋아질 시기입니다.
# - 55세 이후 계유, 임신 대운에서는 수(水)와 금(金)의 조화로 결단력과 실행력이 증가하며, 재물운과 사회적 명예가 상승할 가능성이 큽니다.
#
# - 세운(2026~2030년) 중 2026년 병술년과 2027년 정해년은 활력과 지혜가 상승하는 시기로 재물운이 좋으며, 2030년 경인년은 결단력과 성장이 함께하는 해로 재물운에 긍정적입니다.
#
# ---
#
# ## 4. 종합 해석 및 조언
#
# - **재물운 강점:** 편재와 정재가 모두 존재하여 재물 기회가 많고, 안정적인 재물도 기대할 수 있습니다.
# - **대운 흐름:** 현재부터 40대 초반까지 재물운이 상승하는 시기로, 특히 창의력과 인간관계가 재물운에 긍정적 영향을 줍니다.
# - **성격과 기질:** 현실적이고 신중하며, 도전 정신과 창의력이 있어 재물 축적에 유리합니다.
# - **보완점:** 화(火)와 금(金)이 다소 약하므로, 화의 기운을 보충하는 붉은색 계열, 금의 기운을 보완하는 흰색이나 금속성 액세서리 활용을 권장합니다. 또한, 스트레스 관리와 건강 유지가 재물운 유지에 중요합니다.
#
# ---
#
# ## 5. 결론
#
# - **돈을 많이 벌 수 있는 가능성은 충분히 높습니다.**
# - 특히 창의력과 인간관계가 중요한 분야에서 성공할 가능성이 크며, 꾸준한 노력과 기회 포착이 중요합니다.
# - 대운과 세운의 흐름도 재물운 상승을 뒷받침하고 있어, 적극적인 사회 활동과 자기계발을 통해 재물운을 극대화할 수 있습니다.
#
# ---
#
# 필요하시면 구체적인 재물운 상승 시기별 전략이나 맞춤형 조언도 추가로 제공해 드리겠습니다.
#
# 궁금하신 점 있으면 언제든 문의해 주세요!
#
# ---
#
# **출처:**
# - 한국명리학 전통 이론 (십신과 오행 분석 기준)
# - 사주팔자 분석 원리 (대운 및 세운 해석법)
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 사주를 바탕으로 재물운, 즉 돈을 많이 벌 수 있는 가능성에 대해 정밀하게 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 및 오행 분포 복습
#
# - 년주: 을해(乙亥)
# - 월주: 기묘(己卯)
# - 일주: 계신(癸申)
# - 시주: 무오(戊午)
#
# 오행 분포:
# - 목(木): 2 (乙, 卯)
# - 화(火): 1 (午)
# - 토(土): 2 (己, 戊)
# - 금(金): 1 (申)
# - 수(水): 2 (亥, 癸)
#
# 총 8자 중 목, 토, 수가 강한 편이며, 금과 화가 다소 약한 편입니다.
#
# ---
#
# ## 2. 재물운과 관련된 십신(十神) 분석
#
# - 재물운을 대표하는 십신은 **정재(正財)**와 **편재(偏財)**입니다.
# - 본 사주에서 재물운 관련 십신은 다음과 같습니다.
#
# | 문자 | 십신 관계 | 의미 |
# |-------|-----------|-------|
# | 乙(년간) | 편재 | 적극적 재물, 기회, 외부 재물운 |
# | 卯(월지) | 편재 | 외부 재물, 기회, 투자 가능성 |
# | 戊(시간) | 정재 | 안정적 재물, 근면성실한 재물운 |
#
# - 편재가 2개, 정재가 1개 있어 재물운이 비교적 좋은 편입니다.
# - 편재는 변동적이고 기회 중심의 재물운을 의미하며, 정재는 안정적이고 꾸준한 재물운을 뜻합니다.
#
# ---
#
# ## 3. 대운과 세운에서 재물운 흐름
#
# - 현재 대운(25~34세 병자 대운)은 화(火)와 수(水)의 조화로 창의력과 지혜가 발휘되는 시기입니다. 이는 새로운 사업이나 창의적 직업에서 재물운이 상승할 수 있음을 의미합니다.
# - 35~44세 을해 대운은 목(木)과 수(水)의 조화로 성장과 학문, 인간관계 확장에 유리하여 재물운이 더욱 좋아질 시기입니다.
# - 55세 이후 계유, 임신 대운에서는 수(水)와 금(金)의 조화로 결단력과 실행력이 증가하며, 재물운과 사회적 명예가 상승할 가능성이 큽니다.
#
# - 세운(2026~2030년) 중 2026년 병술년과 2027년 정해년은 활력과 지혜가 상승하는 시기로 재물운이 좋으며, 2030년 경인년은 결단력과 성장이 함께하는 해로 재물운에 긍정적입니다.
#
# ---
#
# ## 4. 종합 해석 및 조언
#
# - **재물운 강점:** 편재와 정재가 모두 존재하여 재물 기회가 많고, 안정적인 재물도 기대할 수 있습니다.
# - **대운 흐름:** 현재부터 40대 초반까지 재물운이 상승하는 시기로, 특히 창의력과 인간관계가 재물운에 긍정적 영향을 줍니다.
# - **성격과 기질:** 현실적이고 신중하며, 도전 정신과 창의력이 있어 재물 축적에 유리합니다.
# - **보완점:** 화(火)와 금(金)이 다소 약하므로, 화의 기운을 보충하는 붉은색 계열, 금의 기운을 보완하는 흰색이나 금속성 액세서리 활용을 권장합니다. 또한, 스트레스 관리와 건강 유지가 재물운 유지에 중요합니다.
#
# ---
#
# ## 5. 결론
#
# - **돈을 많이 벌 수 있는 가능성은 충분히 높습니다.**
# - 특히 창의력과 인간관계가 중요한 분야에서 성공할 가능성이 크며, 꾸준한 노력과 기회 포착이 중요합니다.
# - 대운과 세운의 흐름도 재물운 상승을 뒷받침하고 있어, 적극적인 사회 활동과 자기계발을 통해 재물운을 극대화할 수 있습니다.
#
# ---
#
# 필요하시면 구체적인 재물운 상승 시기별 전략이나 맞춤형 조언도 추가로 제공해 드리겠습니다.
#
# 궁금하신 점 있으면 언제든 문의해 주세요!
#
# ---
#
# **출처:**
# - 한국명리학 전통 이론 (십신과 오행 분석 기준)
# - 사주팔자 분석 원리 (대운 및 세운 해석법)
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# FINISH

# %%
# Enhanced Retriever with Query Expansion 테스트
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 2})

# 한글 사주 질문으로 테스트 (Query Expansion이 작동할 질문)
inputs = {
    "messages": [
        HumanMessage(
            content="정관이 뭐야? 상세히 설명해줘"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# "정관"은 여러 분야에서 사용되는 용어로, 문맥에 따라 의미가 다를 수 있습니다. 여기서는 대표적으로 두 가지 주요 의미를 상세히 설명해드리겠습니다.
#
# 1. 법률 및 기업 분야에서의 정관
# - 정의: 정관은 회사나 단체의 조직, 운영, 목적, 권한, 의무 등을 규정한 기본 규칙이나 규약을 말합니다.
# - 역할: 회사의 설립과 운영에 관한 기본적인 사항을 명시하여, 회사 내부의 질서 유지와 외부와의 법적 관계를 명확히 합니다.
# - 주요 내용: 회사의 명칭, 목적, 본점 소재지, 자본금, 주식의 종류와 발행, 이사 및 감사의 선임과 권한, 주주총회 운영 방식 등이 포함됩니다.
# - 법적 효력: 정관은 회사의 헌법과 같아서, 회사 구성원 모두가 준수해야 하며, 법률에 위반되지 않는 한 회사 운영의 근간이 됩니다.
#
# 2. 사주명리학에서의 정관
# - 정의: 사주명리학에서 정관은 십신(十神) 중 하나로, 자신의 일간(日干)을 기준으로 하는 특정한 오행 관계를 가진 신(神)을 의미합니다.
# - 역할: 정관은 주로 권위, 규율, 법, 질서, 책임, 엄격함 등을 상징하며, 개인의 성격이나 운명 해석에 중요한 요소로 작용합니다.
# - 예: 만약 일간이 '갑목'이라면, 정관은 '경금'이 됩니다. 이는 갑목이 경금을 통해 규율과 권위를 경험하는 관계를 나타냅니다.
# - 해석: 정관이 강하거나 적절히 작용하면 책임감 있고 규칙적인 성격을 나타내며, 사회적 지위나 권위를 얻는 데 도움이 됩니다. 반대로 과하면 엄격하거나 융통성 없는 성격으로 해석될 수 있습니다.
#
# 필요하신 분야나 맥락을 알려주시면 더 구체적이고 맞춤형 설명을 드릴 수 있습니다.
# ==================================================
# 🔄 Node: WebTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# "정관"은 여러 분야에서 사용되는 용어로, 문맥에 따라 의미가 다를 수 있습니다. 여기서는 대표적으로 두 가지 주요 의미를 상세히 설명해드리겠습니다.
#
# 1. 법률 및 기업 분야에서의 정관
# - 정의: 정관은 회사나 단체의 조직, 운영, 목적, 권한, 의무 등을 규정한 기본 규칙이나 규약을 말합니다.
# - 역할: 회사의 설립과 운영에 관한 기본적인 사항을 명시하여, 회사 내부의 질서 유지와 외부와의 법적 관계를 명확히 합니다.
# - 주요 내용: 회사의 명칭, 목적, 본점 소재지, 자본금, 주식의 종류와 발행, 이사 및 감사의 선임과 권한, 주주총회 운영 방식 등이 포함됩니다.
# - 법적 효력: 정관은 회사의 헌법과 같아서, 회사 구성원 모두가 준수해야 하며, 법률에 위반되지 않는 한 회사 운영의 근간이 됩니다.
#
# 2. 사주명리학에서의 정관
# - 정의: 사주명리학에서 정관은 십신(十神) 중 하나로, 자신의 일간(日干)을 기준으로 하는 특정한 오행 관계를 가진 신(神)을 의미합니다.
# - 역할: 정관은 주로 권위, 규율, 법, 질서, 책임, 엄격함 등을 상징하며, 개인의 성격이나 운명 해석에 중요한 요소로 작용합니다.
# - 예: 만약 일간이 '갑목'이라면, 정관은 '경금'이 됩니다. 이는 갑목이 경금을 통해 규율과 권위를 경험하는 관계를 나타냅니다.
# - 해석: 정관이 강하거나 적절히 작용하면 책임감 있고 규칙적인 성격을 나타내며, 사회적 지위나 권위를 얻는 데 도움이 됩니다. 반대로 과하면 엄격하거나 융통성 없는 성격으로 해석될 수 있습니다.
#
# 필요하신 분야나 맥락을 알려주시면 더 구체적이고 맞춤형 설명을 드릴 수 있습니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# FINISH

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, invoke_graph

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="사주의 개념에 대해서 알려줘"
        )
    ],
}

# 그래프 실행
invoke_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# next:
# WebTool
# ==================================================
#
# ==================================================
# 🔄 Node: agent in [WebTool] 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================== Ai Message ==================================
#
# 사주(四柱)는 한국과 중국 등 동아시아에서 전통적으로 사용되는 운명학의 한 분야로, 사람의 태어난 연도, 월, 일, 시를 기준으로 하여 그 사람의 운명과 성격, 인생의 흐름 등을 해석하는 체계입니다. '사주'라는 말은 '네 기둥'이라는 뜻으로, 태어난 연(年), 월(月), 일(日), 시(時)의 네 가지 시간을 각각 한 기둥으로 보고, 이를 바탕으로 사람의 운명을 분석합니다.
#
# 사주는 음양오행(陰陽五行) 이론에 근거하며, 각각의 기둥은 천간(天干)과 지지(地支)라는 10개의 천간과 12개의 지지로 구성되어 있습니다. 이 천간과 지지는 각각 목(木), 화(火), 토(土), 금(金), 수(水)의 오행과 음양의 조합으로 이루어져 있어, 이를 통해 개인의 성격, 건강, 직업, 인간관계, 운세 등을 예측합니다.
#
# 사주는 단순한 운세 풀이를 넘어서, 개인의 타고난 기질과 환경, 인생의 주기 등을 이해하는 도구로 활용되며, 전통적으로 결혼, 사업, 이사 등 중요한 결정을 할 때 참고하기도 합니다.
#
# 필요하면 사주를 구성하는 천간과 지지, 오행의 의미나 사주 풀이 방법에 대해서도 더 자세히 설명해 드릴 수 있습니다.
# ==================================================
#
# ==================================================
# 🔄 Node: WebTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================ Human Message =================================
# Name: WebTool
#
# 사주(四柱)는 한국과 중국 등 동아시아에서 전통적으로 사용되는 운명학의 한 분야로, 사람의 태어난 연도, 월, 일, 시를 기준으로 하여 그 사람의 운명과 성격, 인생의 흐름 등을 해석하는 체계입니다. '사주'라는 말은 '네 기둥'이라는 뜻으로, 태어난 연(年), 월(月), 일(日), 시(時)의 네 가지 시간을 각각 한 기둥으로 보고, 이를 바탕으로 사람의 운명을 분석합니다.
#
# 사주는 음양오행(陰陽五行) 이론에 근거하며, 각각의 기둥은 천간(天干)과 지지(地支)라는 10개의 천간과 12개의 지지로 구성되어 있습니다. 이 천간과 지지는 각각 목(木), 화(火), 토(土), 금(金), 수(水)의 오행과 음양의 조합으로 이루어져 있어, 이를 통해 개인의 성격, 건강, 직업, 인간관계, 운세 등을 예측합니다.
#
# 사주는 단순한 운세 풀이를 넘어서, 개인의 타고난 기질과 환경, 인생의 주기 등을 이해하는 도구로 활용되며, 전통적으로 결혼, 사업, 이사 등 중요한 결정을 할 때 참고하기도 합니다.
#
# 필요하면 사주를 구성하는 천간과 지지, 오행의 의미나 사주 풀이 방법에 대해서도 더 자세히 설명해 드릴 수 있습니다.
# ==================================================
#
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# next:
# Barricade
# ==================================================
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# next:
# FINISH
# ================================ Human Message =================================
#
# 사주의 개념에 대해서 알려줘
# ================================ Human Message =================================
# Name: WebTool
#
# 사주(四柱)는 한국과 중국 등 동아시아에서 전통적으로 사용되는 운명학의 한 분야로, 사람의 태어난 연도, 월, 일, 시를 기준으로 하여 그 사람의 운명과 성격, 인생의 흐름 등을 해석하는 체계입니다. '사주'라는 말은 '네 기둥'이라는 뜻으로, 태어난 연(年), 월(月), 일(日), 시(時)의 네 가지 시간을 각각 한 기둥으로 보고, 이를 바탕으로 사람의 운명을 분석합니다.
#
# 사주는 음양오행(陰陽五行) 이론에 근거하며, 각각의 기둥은 천간(天干)과 지지(地支)라는 10개의 천간과 12개의 지지로 구성되어 있습니다. 이 천간과 지지는 각각 목(木), 화(火), 토(土), 금(金), 수(水)의 오행과 음양의 조합으로 이루어져 있어, 이를 통해 개인의 성격, 건강, 직업, 인간관계, 운세 등을 예측합니다.
#
# 사주는 단순한 운세 풀이를 넘어서, 개인의 타고난 기질과 환경, 인생의 주기 등을 이해하는 도구로 활용되며, 전통적으로 결혼, 사업, 이사 등 중요한 결정을 할 때 참고하기도 합니다.
#
# 필요하면 사주를 구성하는 천간과 지지, 오행의 의미나 사주 풀이 방법에 대해서도 더 자세히 설명해 드릴 수 있습니다.
# ==================================================

# %%
# # GeneralQA 도구 테스트 - 일반 질문
# from langchain_core.runnables import RunnableConfig
# from langchain_teddynote.messages import random_uuid, stream_graph

# # config 설정(재귀 최대 횟수, thread_id)
# config = RunnableConfig(recursion_limit=10, configurable={"thread_id": 2})

# # 일반 질문 입력
# inputs = {
#     "messages": [
#         HumanMessage(
#             content="파이썬에서 딕셔너리와 리스트의 차이점을 알려주세요"
#         )
#     ],
# }

# # 그래프 실행
# stream_graph(graph, inputs, config)

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="1995년 9월 22일 남자, 15시 29분 출생 운세봐줘"
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 을해
# 월주(月柱): 을유
# 일주(日柱): 신오
# 시주(時柱): 을미
# 일간(日干): 신
#
# === 오행 강약 ===
# 목: 65점
# 화: 14점
# 토: 13점
# 금: 35점
# 수: 10점
#
# === 십신 분석 ===
# 년주: 천간:편재, 지지:상관(70%), 지지:정재(30%)
# 월주: 천간:편재
# 일주: 지지:편관(70%), 지지:편인(30%)
# 시주: 천간:편재, 지지:편인(60%), 지지:편관(30%), 지지:편재(10%)
#
# === 대운 (정밀 계산) ===
# 5세: 갑신 (2000년 ~ 2009년)
# 15세: 계미 (2010년 ~ 2019년)
# 25세: 임오 (2020년 ~ 2029년)
# 35세: 신사 (2030년 ~ 2039년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 9월 22일 15시 29분 출생 남성의 사주팔자 분석 결과입니다.
#
# 년주: 을해, 월주: 을유, 일주: 신오, 시주: 을미로 구성되어 있습니다.
# 오행 강약은 목이 가장 강하고(65점), 금(35점), 화(14점), 토(13점), 수(10점) 순입니다.
#
# 십신 분석에서는 편재와 상관, 편관, 편인 등의 기운이 혼재되어 있어 다방면에 능력을 발휘할 수 있는 성향입니다.
#
# 대운은 현재 25세부터 2029년까지 임오 대운이 진행 중이며, 이후 35세부터 신사 대운이 시작됩니다.
#
# 이 사주는 목의 기운이 강해 성장과 발전, 창의력에 유리하며, 금의 기운도 있어 결단력과 실행력이 좋습니다. 다만 화와 토, 수의 기운이 약해 균형을 맞추는 것이 중요합니다.
#
# 전반적으로 다재다능하고 추진력이 강한 운세로, 자신의 능력을 잘 활용하면 좋은 성과를 낼 수 있습니다.
# ==================================================
# 🔄 Node: ManseTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 9월 22일 15시 29분 출생 남성의 사주팔자 분석 결과입니다.
#
# 년주: 을해, 월주: 을유, 일주: 신오, 시주: 을미로 구성되어 있습니다.
# 오행 강약은 목이 가장 강하고(65점), 금(35점), 화(14점), 토(13점), 수(10점) 순입니다.
#
# 십신 분석에서는 편재와 상관, 편관, 편인 등의 기운이 혼재되어 있어 다방면에 능력을 발휘할 수 있는 성향입니다.
#
# 대운은 현재 25세부터 2029년까지 임오 대운이 진행 중이며, 이후 35세부터 신사 대운이 시작됩니다.
#
# 이 사주는 목의 기운이 강해 성장과 발전, 창의력에 유리하며, 금의 기운도 있어 결단력과 실행력이 좋습니다. 다만 화와 토, 수의 기운이 약해 균형을 맞추는 것이 중요합니다.
#
# 전반적으로 다재다능하고 추진력이 강한 운세로, 자신의 능력을 잘 활용하면 좋은 성과를 낼 수 있습니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 9월 22일 15시 29분 출생 남성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ### 1. 사주 구조 (천간지지 변환)
#
# - 출생일: 1995년 9월 22일 15시 29분 (양력 기준)
# - 성별: 남성
# - 출생시간: 15시 29분 → 지지 시각으로는 15시~17시가 '신시(申時)'에 해당합니다.
#
# 따라서 사주팔자는 다음과 같습니다.
#
# | 구분 | 천간 | 지지 |
# |------|------|------|
# | 연주 | 을(乙) | 해(亥) |
# | 월주 | 을(乙) | 유(酉) |
# | 일주 | 신(辛) | 오(午) |
# | 시주 | 을(乙) | 미(未) |
#
# ---
#
# ### 2. 오행(五行) 분석
#
# #### 1) 천간지지 → 오행 매핑 (기준)
#
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# #### 2) 8자 오행 분포
#
# | 위치 | 글자 | 오행 | 점수 |
# |------|------|------|-------|
# | 연간 | 乙   | 목   | 1     |
# | 연지 | 亥   | 수   | 1     |
# | 월간 | 乙   | 목   | 1     |
# | 월지 | 酉   | 금   | 1     |
# | 일간 | 辛   | 금   | 1     |
# | 일지 | 午   | 화   | 1     |
# | 시간 | 乙   | 목   | 1     |
# | 시지 | 未   | 토   | 1     |
#
# #### 3) 오행별 점수 집계
#
# | 오행 | 점수 | 해당 글자          |
# |------|-------|-------------------|
# | 목   | 3     | 乙, 乙, 乙         |
# | 화   | 1     | 午                 |
# | 토   | 1     | 未                 |
# | 금   | 2     | 酉, 辛             |
# | 수   | 1     | 亥                 |
#
# 총 점수 = 3 + 1 + 1 + 2 + 1 = 8 (계산 유효)
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ### 3. 오행 강약 및 해석
#
# - **목(木)**이 가장 강한 편으로, 성장, 발전, 창의력, 융통성에 유리합니다.
# - **금(金)**도 비교적 강해 결단력, 실행력, 분석력에 도움을 줍니다.
# - **화(火), 토(土), 수(水)**는 상대적으로 약한 편으로, 균형을 맞추기 위해 보완이 필요합니다.
#
# **상생상극 관계:**
#
# - 목은 화를 생하고, 화는 토를 생하며, 토는 금을 생하고, 금은 수를 생하며, 수는 목을 생합니다.
# - 목이 강하므로 화를 보완하면 더욱 좋은 흐름이 됩니다.
# - 금이 강하므로 목과 금의 조화가 중요하며, 토와 수가 약해 이 부분을 신경 써야 합니다.
#
# **보완 제안:**
#
# - 화의 기운을 보충하는 활동(빨간색 계열, 따뜻한 음식, 적극적인 활동 등)
# - 토의 기운 보완(노란색, 안정적인 생활, 규칙적인 식사)
# - 수의 기운 보완(검은색, 물과 관련된 활동, 휴식)
#
# ---
#
# ### 4. 십신(十神) 분석
#
# - 일간(신금辛金)을 기준으로 주변 천간과 지지와의 관계를 살펴보면,
# - 연간과 월간에 을목(乙木)이 있어 편재(재물, 외부 자원)와 상관(창의력, 재능)이 강한 편입니다.
# - 시간에도 을목이 있어 편재가 중복되어 재물운과 외부 활동에 유리합니다.
# - 월지 유금(酉金)과 일간 신금(辛金)은 정관과 비견의 관계로, 규율과 자기주장이 강한 성향을 나타냅니다.
# - 일지 오화(午火)는 식신으로 창의력과 표현력을 돕습니다.
# - 시지 미토(未土)는 인성으로 지혜와 배려를 의미합니다.
#
# **종합적으로, 편재와 상관, 편관, 식신, 인성의 조화로 다방면에 능력을 발휘할 수 있는 성향입니다.**
#
# ---
#
# ### 5. 성격 및 기질
#
# - 목의 기운이 강해 성장욕구가 크고, 새로운 것을 배우고자 하는 열정이 강합니다.
# - 금의 기운이 있어 결단력과 실행력이 뛰어나며, 자기주장이 뚜렷합니다.
# - 화와 토, 수가 약해 감성적 안정과 체력 관리에 신경 써야 합니다.
# - 대인관계에서 융통성과 배려가 필요하며, 지나친 고집은 조심해야 합니다.
#
# ---
#
# ### 6. 대운(大運) 및 세운(歲運) 분석
#
# - 1995년 9월 22일 출생 남성의 대운은 25세부터 임오(壬午) 대운이 시작되어 2029년까지 진행 중입니다.
# - 임수(壬水)와 오화(午火)의 조합으로, 목과 화의 기운을 보완하는 시기입니다.
# - 35세부터는 신사(辛巳) 대운이 시작되어 금과 화의 기운이 강해집니다.
# - 현재 대운은 목과 화의 부족한 부분을 보완해 주어 좋은 시기입니다.
#
# - 2023년부터 2025년까지 세운은 각각 계묘(癸卯), 갑진(甲辰), 을사(乙巳)로, 목과 토, 화의 기운이 보완되어 운세가 상승하는 흐름입니다.
#
# ---
#
# ### 7. 종합 요약 및 주의사항
#
# - **강점:** 목과 금의 조화로 창의력과 실행력이 뛰어나며, 다방면에 재능이 많음.
# - **약점:** 화, 토, 수의 기운이 약해 감성 안정과 체력 관리가 필요.
# - **성격:** 성장욕구가 크고 자기주장이 강하지만, 융통성과 배려를 키우면 대인관계가 원만해짐.
# - **운세:** 현재 대운과 세운이 부족한 오행을 보완해 주어 좋은 시기이며, 앞으로도 꾸준한 자기계발이 중요.
# - **조언:** 화와 토, 수의 기운을 보완하는 생활습관과 색상, 음식, 활동을 통해 균형을 맞추는 것이 좋음.
#
# ---
#
# 필요하시면 대운과 세운에 대한 더 상세한 분석도 제공해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 이론 및 오행 분석 기준 (천간지지-오행 매핑 표 참조)
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 9월 22일 15시 29분 출생 남성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ### 1. 사주 구조 (천간지지 변환)
#
# - 출생일: 1995년 9월 22일 15시 29분 (양력 기준)
# - 성별: 남성
# - 출생시간: 15시 29분 → 지지 시각으로는 15시~17시가 '신시(申時)'에 해당합니다.
#
# 따라서 사주팔자는 다음과 같습니다.
#
# | 구분 | 천간 | 지지 |
# |------|------|------|
# | 연주 | 을(乙) | 해(亥) |
# | 월주 | 을(乙) | 유(酉) |
# | 일주 | 신(辛) | 오(午) |
# | 시주 | 을(乙) | 미(未) |
#
# ---
#
# ### 2. 오행(五行) 분석
#
# #### 1) 천간지지 → 오행 매핑 (기준)
#
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# #### 2) 8자 오행 분포
#
# | 위치 | 글자 | 오행 | 점수 |
# |------|------|------|-------|
# | 연간 | 乙   | 목   | 1     |
# | 연지 | 亥   | 수   | 1     |
# | 월간 | 乙   | 목   | 1     |
# | 월지 | 酉   | 금   | 1     |
# | 일간 | 辛   | 금   | 1     |
# | 일지 | 午   | 화   | 1     |
# | 시간 | 乙   | 목   | 1     |
# | 시지 | 未   | 토   | 1     |
#
# #### 3) 오행별 점수 집계
#
# | 오행 | 점수 | 해당 글자          |
# |------|-------|-------------------|
# | 목   | 3     | 乙, 乙, 乙         |
# | 화   | 1     | 午                 |
# | 토   | 1     | 未                 |
# | 금   | 2     | 酉, 辛             |
# | 수   | 1     | 亥                 |
#
# 총 점수 = 3 + 1 + 1 + 2 + 1 = 8 (계산 유효)
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ### 3. 오행 강약 및 해석
#
# - **목(木)**이 가장 강한 편으로, 성장, 발전, 창의력, 융통성에 유리합니다.
# - **금(金)**도 비교적 강해 결단력, 실행력, 분석력에 도움을 줍니다.
# - **화(火), 토(土), 수(水)**는 상대적으로 약한 편으로, 균형을 맞추기 위해 보완이 필요합니다.
#
# **상생상극 관계:**
#
# - 목은 화를 생하고, 화는 토를 생하며, 토는 금을 생하고, 금은 수를 생하며, 수는 목을 생합니다.
# - 목이 강하므로 화를 보완하면 더욱 좋은 흐름이 됩니다.
# - 금이 강하므로 목과 금의 조화가 중요하며, 토와 수가 약해 이 부분을 신경 써야 합니다.
#
# **보완 제안:**
#
# - 화의 기운을 보충하는 활동(빨간색 계열, 따뜻한 음식, 적극적인 활동 등)
# - 토의 기운 보완(노란색, 안정적인 생활, 규칙적인 식사)
# - 수의 기운 보완(검은색, 물과 관련된 활동, 휴식)
#
# ---
#
# ### 4. 십신(十神) 분석
#
# - 일간(신금辛金)을 기준으로 주변 천간과 지지와의 관계를 살펴보면,
# - 연간과 월간에 을목(乙木)이 있어 편재(재물, 외부 자원)와 상관(창의력, 재능)이 강한 편입니다.
# - 시간에도 을목이 있어 편재가 중복되어 재물운과 외부 활동에 유리합니다.
# - 월지 유금(酉金)과 일간 신금(辛金)은 정관과 비견의 관계로, 규율과 자기주장이 강한 성향을 나타냅니다.
# - 일지 오화(午火)는 식신으로 창의력과 표현력을 돕습니다.
# - 시지 미토(未土)는 인성으로 지혜와 배려를 의미합니다.
#
# **종합적으로, 편재와 상관, 편관, 식신, 인성의 조화로 다방면에 능력을 발휘할 수 있는 성향입니다.**
#
# ---
#
# ### 5. 성격 및 기질
#
# - 목의 기운이 강해 성장욕구가 크고, 새로운 것을 배우고자 하는 열정이 강합니다.
# - 금의 기운이 있어 결단력과 실행력이 뛰어나며, 자기주장이 뚜렷합니다.
# - 화와 토, 수가 약해 감성적 안정과 체력 관리에 신경 써야 합니다.
# - 대인관계에서 융통성과 배려가 필요하며, 지나친 고집은 조심해야 합니다.
#
# ---
#
# ### 6. 대운(大運) 및 세운(歲運) 분석
#
# - 1995년 9월 22일 출생 남성의 대운은 25세부터 임오(壬午) 대운이 시작되어 2029년까지 진행 중입니다.
# - 임수(壬水)와 오화(午火)의 조합으로, 목과 화의 기운을 보완하는 시기입니다.
# - 35세부터는 신사(辛巳) 대운이 시작되어 금과 화의 기운이 강해집니다.
# - 현재 대운은 목과 화의 부족한 부분을 보완해 주어 좋은 시기입니다.
#
# - 2023년부터 2025년까지 세운은 각각 계묘(癸卯), 갑진(甲辰), 을사(乙巳)로, 목과 토, 화의 기운이 보완되어 운세가 상승하는 흐름입니다.
#
# ---
#
# ### 7. 종합 요약 및 주의사항
#
# - **강점:** 목과 금의 조화로 창의력과 실행력이 뛰어나며, 다방면에 재능이 많음.
# - **약점:** 화, 토, 수의 기운이 약해 감성 안정과 체력 관리가 필요.
# - **성격:** 성장욕구가 크고 자기주장이 강하지만, 융통성과 배려를 키우면 대인관계가 원만해짐.
# - **운세:** 현재 대운과 세운이 부족한 오행을 보완해 주어 좋은 시기이며, 앞으로도 꾸준한 자기계발이 중요.
# - **조언:** 화와 토, 수의 기운을 보완하는 생활습관과 색상, 음식, 활동을 통해 균형을 맞추는 것이 좋음.
#
# ---
#
# 필요하시면 대운과 세운에 대한 더 상세한 분석도 제공해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 이론 및 오행 분석 기준 (천간지지-오행 매핑 표 참조)
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# FINISH

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="1997년 9월 1일 여자, 12시 29분 출생 운세봐줘"
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 정축
# 월주(月柱): 기유
# 일주(日柱): 신신
# 시주(時柱): 갑오
# 일간(日干): 신
#
# === 오행 강약 ===
# 목: 20점
# 화: 30점
# 토: 34점
# 금: 45점
# 수: 8점
#
# === 십신 분석 ===
# 년주: 천간:편관, 지지:편인(60%), 지지:식신(30%)
# 월주: 천간:편인
# 일주: 지지:겁재(60%), 지지:상관(30%), 지지:정인(10%)
# 시주: 천간:정재, 지지:편관(70%), 지지:편인(30%)
#
# === 대운 (정밀 계산) ===
# 6세: 경술 (2003년 ~ 2012년)
# 16세: 신해 (2013년 ~ 2022년)
# 26세: 임자 (2023년 ~ 2032년)
# 36세: 계축 (2033년 ~ 2042년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1997년 9월 1일 12시 29분 출생 여성분의 사주팔자 분석 결과입니다.
#
# 년주는 정축(丁丑), 월주는 기유(己酉), 일주는 신신(辛辛), 시주는 갑오(甲午)로 구성되어 있습니다. 일간은 신금(辛)입니다.
#
# 오행 강약을 보면 금의 기운이 가장 강하며(45점), 토(34점), 화(30점), 목(20점), 수(8점) 순으로 나타납니다. 금과 토, 화의 기운이 강한 편이고 수의 기운은 약한 편입니다.
#
# 십신 분석에서는 편관, 편인, 식신, 정재, 겁재, 상관, 정인 등 다양한 기운이 혼재되어 있어 다방면에 능력을 발휘할 수 있는 성향입니다.
#
# 대운은 6세부터 경술 대운이 시작되어 2012년까지 진행되었고, 16세부터 신해 대운(2013~2022년), 26세부터 임자 대운(2023~2032년), 36세부터 계축 대운(2033~2042년)이 예정되어 있습니다.
#
# 이 사주는 금의 기운이 강해 결단력과 분석력이 뛰어나며, 토와 화의 기운이 보완되어 안정감과 활력이 있습니다. 다만 수의 기운이 약해 감성적 안정과 휴식이 필요합니다.
#
# 전반적으로 추진력과 실행력이 강하며, 다양한 분야에서 재능을 발휘할 수 있는 운세입니다. 앞으로 대운의 흐름에 따라 자기계발과 균형 잡힌 생활이 중요합니다.
# ==================================================
# 🔄 Node: ManseTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1997년 9월 1일 12시 29분 출생 여성분의 사주팔자 분석 결과입니다.
#
# 년주는 정축(丁丑), 월주는 기유(己酉), 일주는 신신(辛辛), 시주는 갑오(甲午)로 구성되어 있습니다. 일간은 신금(辛)입니다.
#
# 오행 강약을 보면 금의 기운이 가장 강하며(45점), 토(34점), 화(30점), 목(20점), 수(8점) 순으로 나타납니다. 금과 토, 화의 기운이 강한 편이고 수의 기운은 약한 편입니다.
#
# 십신 분석에서는 편관, 편인, 식신, 정재, 겁재, 상관, 정인 등 다양한 기운이 혼재되어 있어 다방면에 능력을 발휘할 수 있는 성향입니다.
#
# 대운은 6세부터 경술 대운이 시작되어 2012년까지 진행되었고, 16세부터 신해 대운(2013~2022년), 26세부터 임자 대운(2023~2032년), 36세부터 계축 대운(2033~2042년)이 예정되어 있습니다.
#
# 이 사주는 금의 기운이 강해 결단력과 분석력이 뛰어나며, 토와 화의 기운이 보완되어 안정감과 활력이 있습니다. 다만 수의 기운이 약해 감성적 안정과 휴식이 필요합니다.
#
# 전반적으로 추진력과 실행력이 강하며, 다양한 분야에서 재능을 발휘할 수 있는 운세입니다. 앞으로 대운의 흐름에 따라 자기계발과 균형 잡힌 생활이 중요합니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 12시 29분 출생 여성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ### 1. 사주 구조 (천간지지 변환)
#
# - 출생일: 1997년 9월 1일 12시 29분 (양력 기준)
# - 성별: 여성
# - 출생시간: 12시 29분 → 지지 시각으로는 11시~13시가 '오시(午時)'에 해당합니다.
#
# 따라서 사주팔자는 다음과 같습니다.
#
# | 구분 | 천간 | 지지 |
# |------|------|------|
# | 연주 | 정(丁) | 축(丑) |
# | 월주 | 기(己) | 유(酉) |
# | 일주 | 신(辛) | 신(申) |
# | 시주 | 갑(甲) | 오(午) |
#
# ---
#
# ### 2. 오행(五行) 분석
#
# #### 1) 천간지지 → 오행 매핑 (기준)
#
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# #### 2) 8자 오행 분포
#
# | 위치 | 글자 | 오행 | 점수 |
# |------|------|------|-------|
# | 연간 | 丁   | 화   | 1     |
# | 연지 | 丑   | 토   | 1     |
# | 월간 | 己   | 토   | 1     |
# | 월지 | 酉   | 금   | 1     |
# | 일간 | 辛   | 금   | 1     |
# | 일지 | 申   | 금   | 1     |
# | 시간 | 甲   | 목   | 1     |
# | 시지 | 午   | 화   | 1     |
#
# #### 3) 오행별 점수 집계
#
# | 오행 | 점수 | 해당 글자          |
# |------|-------|-------------------|
# | 목   | 1     | 甲                 |
# | 화   | 2     | 丁, 午             |
# | 토   | 2     | 丑, 己             |
# | 금   | 3     | 酉, 辛, 申         |
# | 수   | 0     |                   |
#
# 총 점수 = 1 + 2 + 2 + 3 + 0 = 8 (계산 유효)
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ### 3. 오행 강약 및 해석
#
# - **금(金)**이 가장 강한 편으로, 결단력, 분석력, 집중력이 뛰어납니다.
# - **토(土)**와 **화(火)**도 비교적 강해 안정감과 활력, 추진력을 제공합니다.
# - **목(木)**은 약한 편이며, **수(水)**는 전혀 없는 상태입니다.
# - 수의 기운이 부족하여 감성적 안정과 휴식이 필요합니다.
#
# **상생상극 관계:**
#
# - 금이 강하므로 목을 극하는 기운이 강해 목이 약한 상태입니다.
# - 화와 토가 금을 제어하는 역할을 하면서 균형을 맞추고 있습니다.
# - 수가 부족하여 목과 금의 조화에 영향을 줄 수 있으니 보완이 필요합니다.
#
# **보완 제안:**
#
# - 수의 기운을 보충하는 활동(검은색 계열, 물과 관련된 활동, 휴식)
# - 목의 기운 보완(초록색, 식물과 자연, 창의적 활동)
# - 균형을 위해 지나친 금의 기운을 조절하는 생활습관 권장
#
# ---
#
# ### 4. 십신(十神) 분석
#
# - 일간(辛금)을 기준으로 주변 천간과 지지와의 관계를 살펴보면,
# - 연간 정화(丁火)는 편관으로, 규율과 도전 정신을 의미합니다.
# - 월간 기토(己土)는 정재로 재물과 안정적인 자원을 나타냅니다.
# - 월지 유금(酉金), 일지 신금(申金)은 비견과 겁재로 자기주장과 경쟁심이 강합니다.
# - 시간 갑목(甲木)은 편인으로 지혜와 배움, 보호를 의미합니다.
# - 일지 신금(申金)은 일간과 같은 금으로 자기 자신을 나타내며, 강한 자기주장과 독립성을 뜻합니다.
#
# **종합적으로, 편관, 정재, 비견, 편인 등 다양한 십신이 조화를 이루어 다방면에 능력을 발휘할 수 있는 성향입니다.**
#
# ---
#
# ### 5. 성격 및 기질
#
# - 금의 기운이 강해 결단력과 분석력이 뛰어나며, 자기주장이 뚜렷합니다.
# - 토와 화의 기운이 안정감과 활력을 주어 추진력이 강합니다.
# - 목과 수가 약해 감성적 안정과 창의력, 휴식이 부족할 수 있습니다.
# - 대인관계에서 융통성과 배려가 필요하며, 지나친 고집은 조심해야 합니다.
#
# ---
#
# ### 6. 대운(大運) 및 세운(歲運) 분석
#
# - 6세부터 경술(庚戌) 대운이 시작되어 2012년까지 진행되었습니다.
# - 16세부터 신해(辛亥) 대운(2013~2022년)이 진행 중이며, 금과 수의 기운이 보완되는 시기입니다.
# - 26세부터 임자(壬子) 대운(2023~2032년)이 시작되어 수의 기운이 보강되어 감성적 안정과 휴식이 좋아집니다.
# - 36세부터 계축(癸丑) 대운(2033~2042년)이 예정되어 있으며, 수와 토의 조화가 기대됩니다.
#
# - 최근 3년 세운(2023~2025년)은 임자(壬子), 계축(癸丑), 갑인(甲寅)으로 수와 목의 기운이 보완되어 운세가 상승하는 흐름입니다.
#
# ---
#
# ### 7. 종합 요약 및 주의사항
#
# - **강점:** 금과 토, 화의 조화로 결단력, 분석력, 추진력이 뛰어나며 다방면에 재능이 많음.
# - **약점:** 목과 수의 기운이 약해 감성 안정과 창의력, 휴식이 필요.
# - **성격:** 자기주장이 강하고 추진력이 있으나 융통성과 배려를 키우면 대인관계가 원만해짐.
# - **운세:** 현재 대운과 세운이 부족한 수와 목의 기운을 보완해 주어 좋은 시기이며, 앞으로도 균형 잡힌 자기계발이 중요.
# - **조언:** 수와 목의 기운을 보완하는 생활습관과 색상, 음식, 활동을 통해 균형을 맞추는 것이 좋음.
#
# ---
#
# 필요하시면 대운과 세운에 대한 더 상세한 분석도 제공해 드리겠습니다.
#
# 감사합니다.
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 12시 29분 출생 여성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ### 1. 사주 구조 (천간지지 변환)
#
# - 출생일: 1997년 9월 1일 12시 29분 (양력 기준)
# - 성별: 여성
# - 출생시간: 12시 29분 → 지지 시각으로는 11시~13시가 '오시(午時)'에 해당합니다.
#
# 따라서 사주팔자는 다음과 같습니다.
#
# | 구분 | 천간 | 지지 |
# |------|------|------|
# | 연주 | 정(丁) | 축(丑) |
# | 월주 | 기(己) | 유(酉) |
# | 일주 | 신(辛) | 신(申) |
# | 시주 | 갑(甲) | 오(午) |
#
# ---
#
# ### 2. 오행(五行) 분석
#
# #### 1) 천간지지 → 오행 매핑 (기준)
#
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# #### 2) 8자 오행 분포
#
# | 위치 | 글자 | 오행 | 점수 |
# |------|------|------|-------|
# | 연간 | 丁   | 화   | 1     |
# | 연지 | 丑   | 토   | 1     |
# | 월간 | 己   | 토   | 1     |
# | 월지 | 酉   | 금   | 1     |
# | 일간 | 辛   | 금   | 1     |
# | 일지 | 申   | 금   | 1     |
# | 시간 | 甲   | 목   | 1     |
# | 시지 | 午   | 화   | 1     |
#
# #### 3) 오행별 점수 집계
#
# | 오행 | 점수 | 해당 글자          |
# |------|-------|-------------------|
# | 목   | 1     | 甲                 |
# | 화   | 2     | 丁, 午             |
# | 토   | 2     | 丑, 己             |
# | 금   | 3     | 酉, 辛, 申         |
# | 수   | 0     |                   |
#
# 총 점수 = 1 + 2 + 2 + 3 + 0 = 8 (계산 유효)
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ### 3. 오행 강약 및 해석
#
# - **금(金)**이 가장 강한 편으로, 결단력, 분석력, 집중력이 뛰어납니다.
# - **토(土)**와 **화(火)**도 비교적 강해 안정감과 활력, 추진력을 제공합니다.
# - **목(木)**은 약한 편이며, **수(水)**는 전혀 없는 상태입니다.
# - 수의 기운이 부족하여 감성적 안정과 휴식이 필요합니다.
#
# **상생상극 관계:**
#
# - 금이 강하므로 목을 극하는 기운이 강해 목이 약한 상태입니다.
# - 화와 토가 금을 제어하는 역할을 하면서 균형을 맞추고 있습니다.
# - 수가 부족하여 목과 금의 조화에 영향을 줄 수 있으니 보완이 필요합니다.
#
# **보완 제안:**
#
# - 수의 기운을 보충하는 활동(검은색 계열, 물과 관련된 활동, 휴식)
# - 목의 기운 보완(초록색, 식물과 자연, 창의적 활동)
# - 균형을 위해 지나친 금의 기운을 조절하는 생활습관 권장
#
# ---
#
# ### 4. 십신(十神) 분석
#
# - 일간(辛금)을 기준으로 주변 천간과 지지와의 관계를 살펴보면,
# - 연간 정화(丁火)는 편관으로, 규율과 도전 정신을 의미합니다.
# - 월간 기토(己土)는 정재로 재물과 안정적인 자원을 나타냅니다.
# - 월지 유금(酉金), 일지 신금(申金)은 비견과 겁재로 자기주장과 경쟁심이 강합니다.
# - 시간 갑목(甲木)은 편인으로 지혜와 배움, 보호를 의미합니다.
# - 일지 신금(申金)은 일간과 같은 금으로 자기 자신을 나타내며, 강한 자기주장과 독립성을 뜻합니다.
#
# **종합적으로, 편관, 정재, 비견, 편인 등 다양한 십신이 조화를 이루어 다방면에 능력을 발휘할 수 있는 성향입니다.**
#
# ---
#
# ### 5. 성격 및 기질
#
# - 금의 기운이 강해 결단력과 분석력이 뛰어나며, 자기주장이 뚜렷합니다.
# - 토와 화의 기운이 안정감과 활력을 주어 추진력이 강합니다.
# - 목과 수가 약해 감성적 안정과 창의력, 휴식이 부족할 수 있습니다.
# - 대인관계에서 융통성과 배려가 필요하며, 지나친 고집은 조심해야 합니다.
#
# ---
#
# ### 6. 대운(大運) 및 세운(歲運) 분석
#
# - 6세부터 경술(庚戌) 대운이 시작되어 2012년까지 진행되었습니다.
# - 16세부터 신해(辛亥) 대운(2013~2022년)이 진행 중이며, 금과 수의 기운이 보완되는 시기입니다.
# - 26세부터 임자(壬子) 대운(2023~2032년)이 시작되어 수의 기운이 보강되어 감성적 안정과 휴식이 좋아집니다.
# - 36세부터 계축(癸丑) 대운(2033~2042년)이 예정되어 있으며, 수와 토의 조화가 기대됩니다.
#
# - 최근 3년 세운(2023~2025년)은 임자(壬子), 계축(癸丑), 갑인(甲寅)으로 수와 목의 기운이 보완되어 운세가 상승하는 흐름입니다.
#
# ---
#
# ### 7. 종합 요약 및 주의사항
#
# - **강점:** 금과 토, 화의 조화로 결단력, 분석력, 추진력이 뛰어나며 다방면에 재능이 많음.
# - **약점:** 목과 수의 기운이 약해 감성 안정과 창의력, 휴식이 필요.
# - **성격:** 자기주장이 강하고 추진력이 있으나 융통성과 배려를 키우면 대인관계가 원만해짐.
# - **운세:** 현재 대운과 세운이 부족한 수와 목의 기운을 보완해 주어 좋은 시기이며, 앞으로도 균형 잡힌 자기계발이 중요.
# - **조언:** 수와 목의 기운을 보완하는 생활습관과 색상, 음식, 활동을 통해 균형을 맞추는 것이 좋음.
#
# ---
#
# 필요하시면 대운과 세운에 대한 더 상세한 분석도 제공해 드리겠습니다.
#
# 감사합니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# QueryExpansion
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# QueryExpansion
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# QueryExpansion
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# QueryExpansion
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# QueryExpansion
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# QueryExpansion
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# QueryExpansion
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: Barricade 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# QueryExpansion
# ---------------------------------------------------------------------------
# GraphRecursionError                       Traceback (most recent call last)
# Cell In[58], line 19
#       9 inputs = {
#      10     "messages": [
#      11         HumanMessage(
#    (...)     15     ],
#      16 }
#      18 # 그래프 실행
# ---> 19 stream_graph(graph, inputs, config)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_teddynote\messages.py:363, in stream_graph(graph, inputs, config, node_names, callback)
#     348 """
#     349 LangGraph의 실행 결과를 스트리밍하여 출력하는 함수입니다.
#     350
#    (...)    360     None: 함수는 스트리밍 결과를 출력만 하고 반환값은 없습니다.
#     361 """
#     362 prev_node = ""
# --> 363 for chunk_msg, metadata in graph.stream(inputs, config, stream_mode="messages"):
#     364     curr_node = metadata["langgraph_node"]
#     366     # node_names가 비어있거나 현재 노드가 node_names에 있는 경우에만 처리
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\__init__.py:2456, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2447 if loop.status == "out_of_steps":
#    2448     msg = create_error_message(
#    2449         message=(
#    2450             f"Recursion limit of {config['recursion_limit']} reached "
#    (...)   2454         error_code=ErrorCode.GRAPH_RECURSION_LIMIT,
#    2455     )
# -> 2456     raise GraphRecursionError(msg)
#    2457 # set final channel values as run output
#    2458 run_manager.on_chain_end(loop.output)
#
# GraphRecursionError: Recursion limit of 20 reached without hitting a stop condition. You can increase the limit by setting the `recursion_limit` config key.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/GRAPH_RECURSION_LIMIT

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="1996년 12월 13일 남자, 10시 30분 출생 운세봐줘"
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[75], line 19
#       9 inputs = {
#      10     "messages": [
#      11         HumanMessage(
#    (...)     15     ],
#      16 }
#      18 # 그래프 실행
# ---> 19 stream_graph(graph, inputs, config)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_teddynote\messages.py:363, in stream_graph(graph, inputs, config, node_names, callback)
#     348 """
#     349 LangGraph의 실행 결과를 스트리밍하여 출력하는 함수입니다.
#     350
#    (...)    360     None: 함수는 스트리밍 결과를 출력만 하고 반환값은 없습니다.
#     361 """
#     362 prev_node = ""
# --> 363 for chunk_msg, metadata in graph.stream(inputs, config, stream_mode="messages"):
#     364     curr_node = metadata["langgraph_node"]
#     366     # node_names가 비어있거나 현재 노드가 node_names에 있는 경우에만 처리
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\__init__.py:2436, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2434         for task in loop.match_cached_writes():
#    2435             loop.output_writes(task.id, task.writes, cached=True)
# -> 2436         for _ in runner.tick(
#    2437             [t for t in loop.tasks.values() if not t.writes],
#    2438             timeout=self.step_timeout,
#    2439             get_waiter=get_waiter,
#    2440             schedule_task=loop.accept_push,
#    2441         ):
#    2442             # emit output
#    2443             yield from output()
#    2444 # emit output
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\runner.py:252, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     250 # panic on failure or timeout
#     251 try:
# --> 252     _panic_or_proceed(
#     253         futures.done.union(f for f, t in futures.items() if t is not None),
#     254         panic=reraise,
#     255     )
#     256 except Exception as exc:
#     257     if tb := exc.__traceback__:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\runner.py:509, in _panic_or_proceed(futs, timeout_exc_cls, panic)
#     507                 interrupts.append(exc)
#     508             elif fut not in SKIP_RERAISE_SET:
# --> 509                 raise exc
#     510 # raise combined interrupts
#     511 if interrupts:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\executor.py:80, in BackgroundExecutor.done(self, task)
#      78 """Remove the task from the tasks dict when it's done."""
#      79 try:
# ---> 80     task.result()
#      81 except GraphBubbleUp:
#      82     # This exception is an interruption signal, not an error
#      83     # so we don't want to re-raise it on exit
#      84     self.tasks.pop(task)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langgraph\utils\runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[40], line 49, in supervisor_agent(state)
#      47 supervisor_chain = prompt | llm.with_structured_output(RouteResponse)
#      48 # Agent 호출
# ---> 49 return supervisor_chain.invoke(state)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\runnables\base.py:5430, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5423 @override
#    5424 def invoke(
#    5425     self,
#    (...)   5428     **kwargs: Optional[Any],
#    5429 ) -> Output:
# -> 5430     return self.bound.invoke(
#    5431         input,
#    5432         self._merge_configs(config),
#    5433         **{**self.kwargs, **kwargs},
#    5434     )
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)    954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1011, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1005 if self._should_stream(
#    1006     async_api=False,
#    1007     run_manager=run_manager,
#    1008     **kwargs,
#    1009 ):
#    1010     chunks: list[ChatGenerationChunk] = []
# -> 1011     for chunk in self._stream(messages, stop=stop, **kwargs):
#    1012         chunk.message.response_metadata = _gen_info_and_msg_metadata(chunk)
#    1013         if run_manager:
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:668, in BaseChatOpenAI._stream(self, messages, stop, run_manager, **kwargs)
#     666     base_generation_info = {"headers": dict(raw_response.headers)}
#     667 else:
# --> 668     response = self.client.create(**payload)
#     669 with response:
#     670     is_first_chunk = True
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:925, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     882 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     883 def create(
#     884     self,
#    (...)    922     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     923 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     924     validate_response_format(response_format)
# --> 925     return self._post(
#     926         "/chat/completions",
#     927         body=maybe_transform(
#     928             {
#     929                 "messages": messages,
#     930                 "model": model,
#     931                 "audio": audio,
#     932                 "frequency_penalty": frequency_penalty,
#     933                 "function_call": function_call,
#     934                 "functions": functions,
#     935                 "logit_bias": logit_bias,
#     936                 "logprobs": logprobs,
#     937                 "max_completion_tokens": max_completion_tokens,
#     938                 "max_tokens": max_tokens,
#     939                 "metadata": metadata,
#     940                 "modalities": modalities,
#     941                 "n": n,
#     942                 "parallel_tool_calls": parallel_tool_calls,
#     943                 "prediction": prediction,
#     944                 "presence_penalty": presence_penalty,
#     945                 "reasoning_effort": reasoning_effort,
#     946                 "response_format": response_format,
#     947                 "seed": seed,
#     948                 "service_tier": service_tier,
#     949                 "stop": stop,
#     950                 "store": store,
#     951                 "stream": stream,
#     952                 "stream_options": stream_options,
#     953                 "temperature": temperature,
#     954                 "tool_choice": tool_choice,
#     955                 "tools": tools,
#     956                 "top_logprobs": top_logprobs,
#     957                 "top_p": top_p,
#     958                 "user": user,
#     959                 "web_search_options": web_search_options,
#     960             },
#     961             completion_create_params.CompletionCreateParamsStreaming
#     962             if stream
#     963             else completion_create_params.CompletionCreateParamsNonStreaming,
#     964         ),
#     965         options=make_request_options(
#     966             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     967         ),
#     968         cast_to=ChatCompletion,
#     969         stream=stream or False,
#     970         stream_cls=Stream[ChatCompletionChunk],
#     971     )
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\skyop\JaehoNote_2\.venv\Lib\site-packages\openai\_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1034             err.response.read()
#    1036         log.debug("Re-raising status error")
# -> 1037         raise self._make_status_error_from_response(err.response) from None
#    1039     break
#    1041 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Request too large for gpt-4.1-mini-long-context in organization org-n8h6eTrPolQT4RTdz1CaZ4kB on tokens per min (TPM): Limit 1000000, Requested 1188580. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# During task with name 'Supervisor' and id '350adb21-2f04-55c6-446a-157dcebb1b12'
