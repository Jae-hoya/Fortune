# %%
from datetime import datetime
 
now = datetime.now()
today = now.strftime("%Y-%m-%d")
today
# Out:
# '2025-06-17'

# %% [markdown]
# 1. manse_tool_agent
# 2. retriever_tool_agent
# 3. 일반 답변에 대한 web search

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Enhanced Retriever 및 Chain (Query Expansion 포함)

# %%
# 기존 Retriever 및 Chain (원래대로 복원)
from pdf_retriever_saju import pdf_rag_chain, compression_retriever

pdf_retriever = compression_retriever()
pdf_chain = pdf_rag_chain()

# %%
# Manse_tool

# %%
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent
from manse_6 import calculate_saju_tool

# Agent 생성 시 tools 리스트에 추가

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
tools = [calculate_saju_tool]  # 사주 툴 추가

manse_tool_agent = create_react_agent(llm, tools)

# %%
response = manse_tool_agent.invoke({"messages": [("user", "1995년 3월 28일 남자, 12시 30분")]})

# %%
print(response["messages"][-1].content)
# Out:
# 1995년 3월 28일 12시 30분에 태어난 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주: 을해
# - 월주: 기묘
# - 일주: 무오
# - 시주: 무오
# - 일간: 무
#
# 오행의 강약은 토가 가장 강하고, 그 다음으로 목, 화, 수, 금 순입니다. 금이 부족한 편입니다.
#
# 십신 분석에서는 년주에 정관과 편재, 편관이 혼재되어 있고, 월주에는 겁재와 정관, 일주와 시주에는 정인과 겁재가 주로 나타납니다.
#
# 대운은 5세부터 10년 단위로 무인, 정축, 병자, 을해 순으로 변화하며, 현재 25세부터 2029년까지 병자 대운에 해당합니다.
#
# 이 사주는 토의 기운이 강하고 금의 기운이 약한 편이므로, 금과 관련된 분야나 활동에 신경을 쓰면 좋습니다. 또한 정관과 편재가 혼재되어 있어 직업이나 재물운에 있어서 균형을 잘 맞추는 것이 중요합니다.

# %%
response = manse_tool_agent.invoke({"messages": [("user", "1997년 9월 1일 여자, 11시 30분")]})
print(response["messages"][-1].content)
# Out:
# 1997년 9월 1일 여자, 11시 30분 출생자의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주: 정축
# - 월주: 무신
# - 일주: 병오
# - 시주: 계사
# - 일간: 병화
#
# 오행의 강약은 화가 가장 강하고, 그 다음으로 토, 수, 금 순이며 목은 없습니다.
#
# 십신 분석에서는 겁재, 상관, 정관, 편재, 식신 등이 주요하게 나타납니다.
#
# 대운은 6세부터 10년 단위로 기유, 경술, 신해, 임자 대운이 순서대로 진행됩니다.
#
# 이 사주는 화의 기운이 강해 열정적이고 활동적인 성격을 가질 가능성이 높으며, 토와 수의 조화로 안정감과 지혜도 함께 갖추고 있습니다. 다만 목의 기운이 부족해 창의력이나 성장 동력에 다소 제약이 있을 수 있습니다.
#
# 더 구체적인 운세나 성격, 직업 적성 등 궁금한 점이 있으면 알려주세요.

# %%
from langchain_core.tools.retriever import create_retriever_tool
from langchain_core.prompts import PromptTemplate


# PDF 문서를 기반으로 검색 도구 생성
retriever_tool = create_retriever_tool(
    pdf_retriever,
    "pdf_retriever",
    "A tool for searching information related to Saju (Four Pillars of Destiny)",
    document_prompt=PromptTemplate.from_template(
        "<document><context>{page_content}</context><metadata><source>{source}</source><page>{page}</page></metadata></document>"
    ),
)

# %%
retriever_tools = [retriever_tool]

# %%
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI
from langchain_core.prompts import load_prompt, ChatPromptTemplate, MessagesPlaceholder

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

retriever_tool_agent = create_react_agent(llm, retriever_tools)

base_prompt = load_prompt("prompt/saju-rag-promt_2.yaml")
saju_prompt = ChatPromptTemplate.from_messages([
    ("system", base_prompt.template),
    MessagesPlaceholder("messages"),
])
retriever_tool_agent = create_react_agent(llm, retriever_tools, prompt=saju_prompt)

# %%
response = retriever_tool_agent.invoke({"messages": [("user", "1995년 3월 28일 남자의 사주 알려줘")]})

# %%
print(response["messages"][-1].content)
# Out:
# 안녕하세요. 1995년 3월 28일 남자분의 사주를 분석해드리겠습니다.
#
# 우선, 태어난 날짜와 시간을 기준으로 정확한 천간지지(년, 월, 일, 시)를 변환해야 합니다. 다만, 태어난 시간이 없으므로 기본적으로 12지지 시간대 중 어느 시간대인지 알려주시면 더욱 정확한 분석이 가능합니다. 예를 들어, 자시(23:00~01:00), 축시(01:00~03:00) 등입니다.
#
# 현재 시간 정보가 없으므로, 우선 1995년 3월 28일의 사주(년, 월, 일) 천간지지 변환과 오시(11:30~13:30) 기준 시주를 가정하여 분석을 진행하겠습니다.
#
# ---
#
# ### 1. 사주 구조 (천간지지)
#
# - 년주: 을해(乙亥)년 (1995년)
# - 월주: 갑진(甲辰)월 (3월)
# - 일주: 병인(丙寅)일 (28일)
# - 시주: 병오(丙午)시 (오시, 11:30~13:30 가정)
#
# ---
#
# ### 2. 오행(五行) 분석
#
# #### 1) 천간지지 → 오행 매핑
#
# | 천간/지지 | 오행  |
# |-----------|-------|
# | 甲, 乙, 寅, 卯 | 목(木) |
# | 丙, 丁, 巳, 午 | 화(火) |
# | 戊, 己, 辰, 戌, 丑, 未 | 토(土) |
# | 庚, 辛, 申, 酉 | 금(金) |
# | 壬, 癸, 子, 亥 | 수(水) |
#
# #### 2) 사주 8글자
#
# - 년간: 乙 (목)
# - 년지: 亥 (수)
# - 월간: 甲 (목)
# - 월지: 辰 (토)
# - 일간: 丙 (화)
# - 일지: 寅 (목)
# - 시간간: 丙 (화)
# - 시지: 午 (화)
#
# #### 3) 오행 점수 계산
#
# | 글자 | 오행 | 점수 |
# |-------|-------|-------|
# | 乙    | 목    | 1     |
# | 亥    | 수    | 1     |
# | 甲    | 목    | 1     |
# | 辰    | 토    | 1     |
# | 丙    | 화    | 1     |
# | 寅    | 목    | 1     |
# | 丙    | 화    | 1     |
# | 午    | 화    | 1     |
#
# #### 4) 오행별 합산
#
# | 오행 | 점수 | 글자          |
# |-------|-------|---------------|
# | 목(木) | 3     | 乙, 甲, 寅    |
# | 화(火) | 3     | 丙, 丙, 午    |
# | 토(土) | 1     | 辰            |
# | 금(金) | 0     |               |
# | 수(水) | 1     | 亥            |
#
# 총 점수 = 3 + 3 + 1 + 0 + 1 = 8 (계산 유효)
#
# ---
#
# ### 3. 오행 분포 및 해석
#
# - 목(木)과 화(火)가 강한 편이며, 토(土)와 수(水)는 약간 존재하지만 금(金)은 전혀 없습니다.
# - 목과 화가 강하면 성장, 발전, 열정과 활력이 풍부한 성격을 나타냅니다.
# - 토는 안정과 현실적인 면을 보완하며, 수는 지혜와 감성을 더합니다.
# - 금이 부족하므로 결단력이나 냉철함이 다소 약할 수 있습니다.
#
# ---
#
# ### 4. 십신(十神) 분석 (일간 丙火 기준)
#
# - 년간 乙목: 편재 (재물, 능력)
# - 년지 亥수: 편인 (지식, 보호)
# - 월간 甲목: 정재 (재물, 안정)
# - 월지 辰토: 편관 (권위, 규율)
# - 일간 丙화: 본인
# - 일지 寅목: 식신 (창의, 표현)
# - 시간간 丙화: 비견 (동료, 경쟁)
# - 시지 午화: 식신 (창의, 활력)
#
# 십신 분포가 다양하며, 특히 재물과 창의력이 강한 편입니다.
#
# ---
#
# ### 5. 성격 및 기질
#
# - 활발하고 적극적이며, 창의적이고 표현력이 뛰어납니다.
# - 재물운과 능력이 좋아 사업이나 재테크에 관심이 많을 수 있습니다.
# - 다만 금이 부족해 때로는 결단력이나 냉철한 판단이 부족할 수 있으니 보완이 필요합니다.
# - 주변 사람과 협력하며 경쟁하는 것을 좋아합니다.
#
# ---
#
# ### 6. 대운 및 세운 (간략)
#
# - 1995년 3월 28일 남성의 대운은 양력 3월 기준으로 10년 단위로 진행하며, 대운의 천간지지가 사주와 상생 또는 상극 관계에 따라 운세가 변동합니다.
# - 2025년 현재는 31세로 대운 31~40세 구간에 해당하며, 이 시기의 대운과 세운을 분석하면 재물과 인간관계에 좋은 기운이 들어올 수 있습니다.
#
# ---
#
# ### 종합 요약
#
# - 1995년 3월 28일 남성의 사주는 목과 화가 강한 활발하고 창의적인 성격입니다.
# - 재물운과 능력이 뛰어나 사업이나 재테크에 유리하며, 주변과 협력하는 것을 좋아합니다.
# - 금이 부족해 결단력 보완이 필요하며, 현실적인 안정과 냉철함을 키우는 것이 좋습니다.
# - 대운과 세운을 잘 활용하면 좋은 기회를 잡을 수 있습니다.
#
# ---
#
# 필요하시면 태어난 시간을 알려주시면 시주를 정확히 반영하여 더욱 상세한 분석을 제공해드리겠습니다.
#
# 감사합니다.

# %%
# Query Expansion Agent (manse_tool처럼 간단하게)
from query_expansion_agent import get_query_expansion_agent

query_expansion_agent = get_query_expansion_agent()

# %%
# Query Expansion Agent 올바른 사용법 테스트
response = query_expansion_agent.invoke({"messages": [("user", "1995년 3월 28일 남자 사주")]})
print(response["messages"][-1].content)
# Out:
# 확장된 영어 질문은 다음과 같습니다:
#
# "Could you provide a birth chart analysis for a male born on March 28, 1995, focusing on the Four Pillars of Destiny (Ba Zi)? I am interested in understanding the implications of his birth date on his personality, career prospects, and overall life path. Please analyze the birth chart and Great Luck Period (Da Yun) based on Four Pillars of Destiny."
#
# 이 질문을 사용하여 문서 검색을 진행하실 수 있습니다. 추가적인 도움이 필요하시면 말씀해 주세요!

# %%
from query_expansion_agent import get_query_expansion_node

query_expansion_node = get_query_expansion_node()

# %%
# 노드 테스트
test_state = {"messages": [("user", "정관이 뭐야?")]}
result = query_expansion_node(test_state)

print("노드 테스트 결과:")
print(f"원본 질문: {result.get('original_query')}")
print(f"확장된 질문: {result.get('expanded_query')}")
print(f"확장 결과: {result.get('expansion_result')}")
# Out:
# 노드 테스트 결과:
# 원본 질문: ('user', '정관이 뭐야?')
# 확장된 질문: What is the concept of "Jeonggwan" (正官) in the context of the Four Pillars of Destiny (Ba Zi)? I would like to understand its significance and how it influences one's birth chart analysis, particularly in relation to career and authority.
# 확장 결과:
# [Query Expansion 결과]
# 원본 질문: ('user', '정관이 뭐야?')
# 확장된 영어 질문: What is the concept of "Jeonggwan" (正官) in the context of the Four Pillars of Destiny (Ba Zi)? I would like to understand its significance and how it influences one's birth chart analysis, particularly in relation to career and authority.
#
# 검색을 위해 확장된 쿼리를 사용합니다.

# %%
from query_expansion_agent import get_query_expansion_node

query_expansion_node = get_query_expansion_node()

# 노드 테스트
test_state = {"messages": [("user", "1995년 3월 28일 남자 사주")]}
result = query_expansion_node(test_state)

print("노드 테스트 결과:")
print(f"원본 질문: {result.get('original_query')}")
print(f"확장된 질문: {result.get('expanded_query')}")
print(f"확장 결과: {result.get('expansion_result')}")
# Out:
# 노드 테스트 결과:
# 원본 질문: ('user', '1995년 3월 28일 남자 사주')
# 확장된 질문: Could you provide a detailed analysis of the Four Pillars of Destiny (Ba Zi) for a male born on March 28, 1995? I am interested in understanding how his birth chart influences his personality, career prospects, and overall life path. Please analyze the birth chart and Great Luck Period (Da Yun) based on Four Pillars of Destiny.
# 확장 결과:
# [Query Expansion 결과]
# 원본 질문: ('user', '1995년 3월 28일 남자 사주')
# 확장된 영어 질문: Could you provide a detailed analysis of the Four Pillars of Destiny (Ba Zi) for a male born on March 28, 1995? I am interested in understanding how his birth chart influences his personality, career prospects, and overall life path. Please analyze the birth chart and Great Luck Period (Da Yun) based on Four Pillars of Destiny.
#
# 검색을 위해 확장된 쿼리를 사용합니다.

# %%
from langchain_teddynote.tools.tavily import TavilySearch
from langchain.tools import DuckDuckGoSearchRun, DuckDuckGoSearchResults

tavily_tool = TavilySearch(
    max_results=5,
    include_domains=["namu.wiki", "wikipedia.org"]
)

duck_tool = DuckDuckGoSearchResults(
    max_results=5,
)

# %%
# web_tool = [tavily_tool]
web_tool = [tavily_tool, duck_tool]

# %%
prompt = """
사주 또는 사주 오행의 개념적 질문이나, 일상 질문이 들어오면, web search를 통해 답합니다.
"""
web_tool_agent = create_react_agent(llm, tools=web_tool, prompt=prompt)

# %%
response = web_tool_agent.invoke({"messages": [("user", "사주오행에 대해서 설명해줘")]})

# %%
response
# Out:
# {'messages': [HumanMessage(content='사주오행에 대해서 설명해줘', additional_kwargs={}, response_metadata={}, id='0b8ff6a0-7500-4a45-b7aa-7680892d8292'),
#   AIMessage(content="사주오행은 동양 철학과 점성학에서 중요한 개념으로, 사람의 운명과 성격, 인생의 흐름을 해석하는 데 사용됩니다. '사주'는 태어난 연, 월, 일, 시의 네 기둥(四柱)을 의미하며, 각각 천간(하늘의 기운)과 지지(땅의 기운)로 구성되어 있습니다. 이 네 기둥을 통해 개인의 운명을 분석합니다.\n\n'오행'은 우주 만물을 구성하는 다섯 가지 기본 원소인 목(木), 화(火), 토(土), 금(金), 수(水)를 말합니다. 각각의 오행은 특정한 성질과 상호작용을 가지며, 사주에서는 이 오행들이 어떻게 조화를 이루고 충돌하는지에 따라 개인의 운세와 성격을 해석합니다.\n\n간단히 정리하면:\n- 목(木): 나무, 성장과 발전, 생명력\n- 화(火): 불, 열정과 에너지, 변화\n- 토(土): 흙, 안정과 중심, 신뢰\n- 금(金): 금속, 결단과 강인함, 수확\n- 수(水): 물, 지혜와 유연성, 감정\n\n사주오행은 이 다섯 가지 요소가 개인의 사주에 어떻게 배치되어 있는지 분석하여, 그 사람의 성격, 건강, 직업, 인간관계, 운세 등을 예측하는 데 활용됩니다. 더 구체적인 사주 분석이나 오행의 상생(서로 돕는 관계)과 상극(서로 억제하는 관계)에 대해서도 궁금하면 알려드릴 수 있습니다.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 369, 'prompt_tokens': 181, 'total_tokens': 550, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_6f2eabb9a5', 'finish_reason': 'stop', 'logprobs': None}, id='run--44b9a620-434d-4234-be46-f1af5b86227e-0', usage_metadata={'input_tokens': 181, 'output_tokens': 369, 'total_tokens': 550, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
print(response["messages"][-1].content)
# Out:
# 사주오행은 동양 철학과 점성학에서 중요한 개념으로, 사람의 운명과 성격, 인생의 흐름을 해석하는 데 사용됩니다. '사주'는 태어난 연, 월, 일, 시의 네 기둥(四柱)을 의미하며, 각각의 기둥은 천간(하늘의 기운)과 지지(땅의 기운)로 구성되어 있습니다. 이 네 기둥을 통해 개인의 운명을 분석합니다.
#
# '오행'은 우주 만물을 구성하는 다섯 가지 기본 원소인 목(木), 화(火), 토(土), 금(金), 수(水)를 말합니다. 사주에서는 이 오행이 각 기둥의 천간과 지지에 배치되어 있어, 이들의 상호작용을 통해 개인의 성격, 건강, 운세 등을 해석합니다.
#
# 간단히 정리하면:
# - 목(木): 나무, 성장과 발전, 생명력
# - 화(火): 불, 열정과 에너지, 변화
# - 토(土): 흙, 안정과 중심, 신뢰
# - 금(金): 금속, 결단과 강인함, 수확
# - 수(水): 물, 지혜와 유연성, 감정
#
# 사주오행은 이 다섯 원소가 균형을 이루는지, 어느 원소가 부족하거나 과한지를 분석하여 개인의 운명을 예측하고 조언을 제공합니다. 더 궁금한 점이나 구체적인 사주풀이가 필요하면 알려주세요!

# %%
# GeneralQA Tool
from langchain.tools import  tool
from langchain_google_genai import ChatGoogleGenerativeAI
google_llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

@tool
def general_qa_tool(query: str) -> str:
    """
    일반적인 질문이나 상식적인 내용에 대해 답변합니다. 사주와 관련 없는 모든 질문에 사용할 수 있습니다.
    """
    google_llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")
    return google_llm.invoke(query)

# %%
from langgraph.prebuilt import create_react_agent

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
general_qa_tools = [general_qa_tool]

prompt = "일반적인 질문이나 상식적인 내용에 대해 답변합니다."

general_qa_agent = create_react_agent(llm, tools=general_qa_tools, prompt=prompt)

# %% [markdown]
# # Agent node 생성

# %%
from langchain_core.messages import HumanMessage

# 지정한 agent와 name을 사용하여 agent 노드를 생성
def agent_node(state, agent, name):

    # agent 호출
    agent_response = agent.invoke(state)
    # agent의 마지막 메시지를 HumanMessage로 변환하여 반환
    return {
        "messages": [
            HumanMessage(content=agent_response["messages"][-1].content, name=name)
        ]
    }

# %% [markdown]
# # node 생성

# %%
import functools

manse_tool_agent_node = functools.partial(agent_node, agent=manse_tool_agent, name="ManseTool")
retriever_tool_agent_node = functools.partial(agent_node, agent=retriever_tool_agent, name="RetrieverTool")
web_tool_agent_node = functools.partial(agent_node, agent=web_tool_agent, name="WebTool")
general_qa_agent_node = functools.partial(agent_node, agent=general_qa_agent, name="GeneralQA")

# %% [markdown]
# # 노드 실험

# %%
manse_message = manse_tool_agent_node(
    {
        "messages": [
            HumanMessage(content="1995년 3월 28일 남자")
        ]
    }
)
print(manse_message)
# Out:
# {'messages': [HumanMessage(content='1995년 3월 28일 남자분의 사주팔자를 분석해보면 다음과 같습니다.\n\n- 년주: 을해\n- 월주: 기묘\n- 일주: 무오\n- 시주: 무오\n- 일간: 무\n\n오행 강약은 토가 가장 강하고, 목과 화가 그 다음이며 금은 거의 없는 편입니다.\n\n십신 분석에서는 년주에 정관과 편재, 편관이 혼재되어 있고, 월주에는 겁재와 정관, 일주와 시주에는 정인과 겁재가 주로 나타납니다.\n\n대운은 5세부터 무인, 15세부터 정축, 25세부터 병자, 35세부터 을해 대운이 순서대로 진행됩니다.\n\n이 사주는 토의 기운이 강해 안정적이고 현실적인 성향이 강하며, 정관과 편재가 있어 책임감과 재물운이 좋은 편입니다. 다만 금의 기운이 약해 결단력이나 추진력에서 보완이 필요할 수 있습니다.', additional_kwargs={}, response_metadata={}, name='ManseTool')]}

# %%
retriever_message =  retriever_tool_agent_node(
    {
        "messages": [
            HumanMessage(content="1995년 3월 28일 남자 12시 30분")
        ]
    }
)
print(retriever_message)
# Out:
# {'messages': [HumanMessage(content='안녕하세요. 1995년 3월 28일 남자 12시 30분 출생 사주 분석을 진행하겠습니다.\n\n---\n\n### 1. 사주 구조 (천간지지 변환)\n\n- 출생일: 1995년 3월 28일 (양력 기준)\n- 출생시간: 12시 30분 → 지지 시간대는 午시 (11:30~13:30)\n\n#### 1) 연주 (년간, 년지)\n- 1995년은 을해년 (乙亥年)\n  - 연간: 乙 (을목)\n  - 연지: 亥 (해수)\n\n#### 2) 월주 (월간, 월지)\n- 3월은 음력 2월 또는 3월에 따라 다르나, 양력 3월 28일은 음력 2월 28일경으로 추정\n- 1995년 3월의 월주는 병진월 (丙辰月)\n  - 월간: 丙 (병화)\n  - 월지: 辰 (진토)\n\n#### 3) 일주 (일간, 일지)\n- 1995년 3월 28일의 일주는 을사일 (乙巳日)\n  - 일간: 乙 (을목)\n  - 일지: 巳 (사화)\n\n#### 4) 시주 (시간간, 시간지)\n- 12시 30분은 午시 (11:30~13:30)\n- 午시는 병화(丙) 시간\n  - 시간간: 丙 (병화)\n  - 시간지: 午 (오화)\n\n---\n\n### 2. 사주 8자 (천간지지) 정리\n\n| 구분 | 천간 | 지지 |\n|------|------|------|\n| 연주 | 乙   | 亥   |\n| 월주 | 丙   | 辰   |\n| 일주 | 乙   | 巳   |\n| 시주 | 丙   | 午   |\n\n→ 8자: 乙 亥 丙 辰 乙 巳 丙 午\n\n---\n\n### 3. 오행 분포 분석\n\n#### 1) 오행 분류표\n\n| 오행 | 천간/지지 문자 |\n|-------|----------------|\n| 목(木) | 甲, 乙, 寅, 卯 |\n| 화(火) | 丙, 丁, 巳, 午 |\n| 토(土) | 戊, 己, 辰, 戌, 丑, 未 |\n| 금(金) | 庚, 辛, 申, 酉 |\n| 수(水) | 壬, 癸, 子, 亥 |\n\n#### 2) 8자 오행 매핑 및 점수 부여\n\n- 乙 → 목 +1\n- 亥 → 수 +1\n- 丙 → 화 +1\n- 辰 → 토 +1\n- 乙 → 목 +1\n- 巳 → 화 +1\n- 丙 → 화 +1\n- 午 → 화 +1\n\n#### 3) 오행별 점수 집계\n\n| 오행 | 점수 | 문자          |\n|-------|-------|---------------|\n| 목(木) | 2     | 乙, 乙         |\n| 화(火) | 4     | 丙, 巳, 丙, 午  |\n| 토(土) | 1     | 辰             |\n| 금(金) | 0     |               |\n| 수(水) | 1     | 亥             |\n\n총합: 2 + 4 + 1 + 0 + 1 = 8 (계산 유효)\n\n---\n\n### 4. 오행 분포 검증\n\n- 총 8자 중 8점으로 정확히 일치합니다.\n- **Wu Xing total score = 8 (Calculation is valid.)**\n\n---\n\n### 5. 오행 해석\n\n- **화(火)가 매우 강함 (4점)**: 열정적이고 활발하며, 리더십과 추진력이 강함.\n- **목(木) 2점**: 성장과 발전, 창의력과 인내심이 있음.\n- **토(土) 1점**: 현실적이고 안정적인 면이 있으나 다소 부족.\n- **수(水) 1점**: 지혜와 유연성, 감성적 측면이 있으나 약한 편.\n- **금(金) 0점**: 금의 기운이 전혀 없어 의사결정이나 냉철함이 부족할 수 있음.\n\n**상호생극 관계**\n\n- 목(木)은 화(火)를 생(生)하여 화를 돕고 있음.\n- 화(火)는 토(土)를 생하여 토를 돕고 있음.\n- 토(土)는 금(金)을 생하지만 금이 없음.\n- 금(金)은 수(水)를 생하지만 금이 없으므로 수가 약함.\n- 수(水)는 목(木)을 생하지만 수가 약함.\n\n→ 화가 강하고 목이 이를 뒷받침하는 구조이나 금이 전혀 없어 균형이 깨짐.\n\n**보완 제안**\n\n- 금(金) 기운 보충 필요 (흰색, 금속, 가을, 금 관련 활동)\n- 토(土) 보완도 고려 (노란색, 안정적인 활동)\n- 수(水) 보완 시 감성 및 지혜 강화 가능\n\n---\n\n### 6. 십신(十神) 분석 (일간 乙목 기준)\n\n- 일간: 乙 (을목, 나 자신)\n- 연간 乙 (을목): 비견 (같은 목)\n- 연지 亥 (해수): 정재 (물을 통해 재물)\n- 월간 丙 (병화): 식신 (나를 도와주는 불)\n- 월지 辰 (진토): 편재 (토는 목을 극하나 辰은 복합지지)\n- 일지 巳 (사화): 편관 (화는 목을 극하나 사화는 불)\n- 시간간 丙 (병화): 식신\n- 시간지 午 (오화): 편관\n\n**해석**\n\n- 비견 乙이 있어 자기주장이 강하고 독립적임.\n- 식신 丙이 두 번 있어 창의력과 표현력이 뛰어남.\n- 편재 辰과 정재 亥가 있어 재물운과 경제적 능력이 있음.\n- 편관 巳, 午가 있어 권위적이고 책임감이 강함.\n\n---\n\n### 7. 성격 및 기질\n\n- 활발하고 열정적이며 리더십이 강함.\n- 창의적이고 표현력이 뛰어나며 자기주장이 뚜렷함.\n- 재물운이 좋고 경제적 감각이 있음.\n- 다만 금 기운 부족으로 냉철한 판단력이나 객관성이 다소 부족할 수 있음.\n- 감성적이고 유연한 면은 있으나 수 기운이 약해 감정 조절에 주의 필요.\n\n---\n\n### 8. 대운(大運) 및 세운(歲運) 분석\n\n- 1995년 3월 28일 남자 출생, 양력 기준\n- 대운은 남성 기준으로 생월의 절기 이후부터 순행 (앞으로 진행)\n- 3월 28일은 경칩(3월 5일) 이후 출생 → 대운 시작 나이 1세부터\n\n**대운 예시 (10년 단위)**\n\n| 나이 | 대운  | 오행 특징          |\n|-------|--------|--------------------|\n| 1~10  | 병오 (丙午) | 화 기운 강함, 본인 사주와 유사 |\n| 11~20 | 정미 (丁未) | 화+토, 안정과 성장 |\n| 21~30 | 무신 (戊申) | 토+금, 금 기운 보완 가능 |\n| 31~40 | 기유 (己酉) | 토+금, 금 기운 강화 |\n| 41~50 | 경술 (庚戌) | 금+토, 금 기운 강함 |\n| 51~60 | 신해 (辛亥) | 금+수, 금과 수 보완 |\n\n→ 20대 후반부터 금 기운이 보완되어 균형이 맞아짐.\n\n**세운 (2023~2025년)**\n\n- 2023년 계묘 (癸卯): 수+목, 부족한 수 기운 보완, 성장 가능성\n- 2024년 갑진 (甲辰): 목+토, 목 기운 강화, 토 보완\n- 2025년 을사 (乙巳): 목+화, 본인 사주와 유사, 활발한 시기\n\n---\n\n### 9. 종합 요약 및 주의사항\n\n- 본 사주는 화(火)와 목(木)이 강하고 금(金)이 부족한 구조입니다.\n- 활발하고 리더십이 뛰어나며 창의적이고 경제적 감각이 좋습니다.\n- 금 기운 부족으로 인해 냉철한 판단력과 객관성이 다소 약할 수 있으니 보완이 필요합니다.\n- 대운에서 20대 후반부터 금 기운이 보완되어 점차 균형이 맞아질 것입니다.\n- 감정 조절과 스트레스 관리에 주의하시고, 금 기운을 보완하는 색상(흰색, 은색), 음식(금속성 식품), 활동(가을철 활동, 금속 관련 취미)을 권장합니다.\n\n---\n\n필요하시면 대운과 세운에 대한 더 상세한 분석도 가능합니다.\n\n감사합니다.', additional_kwargs={}, response_metadata={}, name='RetrieverTool')]}

# %%
web_message = web_tool_agent_node(
    {
        "messages": [
            HumanMessage(content="사주오행에서의 불")
        ]
    }
)
print(web_message)
# Out:
# {'messages': [HumanMessage(content="사주오행에서 '불(火)'은 오행 중 하나로, 다섯 가지 기본 요소인 목(木), 화(火), 토(土), 금(金), 수(水) 중 '화(火)'를 의미합니다. 불은 다음과 같은 개념과 상징을 가집니다.\n\n1. **속성 및 상징**  \n   - 불은 열정, 에너지, 빛, 따뜻함, 변화, 활동성을 상징합니다.  \n   - 밝고 활기찬 성격, 강한 의지와 추진력을 나타냅니다.\n\n2. **계절과 방향**  \n   - 불은 여름과 남쪽을 상징합니다.  \n   - 여름의 뜨거운 태양과 같은 기운을 지니고 있습니다.\n\n3. **색깔**  \n   - 붉은색, 주황색, 분홍색 등이 불의 색으로 여겨집니다.\n\n4. **사람의 성격과 건강**  \n   - 불의 기운이 강한 사람은 열정적이고 활발하며 리더십이 뛰어납니다.  \n   - 반면 과하면 성급하거나 다혈질일 수 있습니다.  \n   - 건강 면에서는 심장, 혈액순환과 관련이 깊습니다.\n\n5. **상생과 상극**  \n   - 상생: 목(木)이 불을 키우고, 불은 토(土)를 생성합니다.  \n   - 상극: 불은 수(水)와 상극 관계로, 물은 불을 끄는 역할을 합니다.\n\n사주에서 불의 위치와 강약에 따라 그 사람의 성격, 운명, 건강 상태 등이 해석됩니다. 더 구체적인 사주 분석을 원하시면 태어난 연월일시를 알려주시면 도움을 드릴 수 있습니다.", additional_kwargs={}, response_metadata={}, name='WebTool')]}

# %%
# GeneralQA 테스트
general_qa_message = general_qa_agent_node(
    {
        "messages": [
            HumanMessage(content="파이썬에서 리스트와 튜플의 차이점?")
        ]
    }
)
print(general_qa_message)
# Out:
# {'messages': [HumanMessage(content='파이썬에서 리스트와 튜플은 모두 여러 개의 항목을 담을 수 있는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.\n\n### 1. 가변성 (Mutability)\n- **리스트 (List)**: 가변적(Mutable)입니다. 즉, 리스트를 생성한 후에도 요소를 추가, 삭제, 변경할 수 있습니다.\n- **튜플 (Tuple)**: 불변적(Immutable)입니다. 튜플을 생성한 후에는 요소를 변경할 수 없습니다. 요소를 추가, 삭제, 수정하려고 하면 에러가 발생합니다.\n\n### 2. 문법\n- **리스트 (List)**: 대괄호 `[]`를 사용하여 정의합니다.\n  ```python\n  my_list = [1, 2, 3, "hello"]\n  ```\n- **튜플 (Tuple)**: 소괄호 `()`를 사용하여 정의합니다.\n  ```python\n  my_tuple = (1, 2, 3, "hello")\n  ```\n  - 요소가 하나인 튜플을 만들 때는 쉼표를 붙여야 합니다. 예: `my_tuple = (1,)`\n\n### 3. 성능\n- **튜플 (Tuple)**: 일반적으로 리스트보다 약간 더 빠릅니다. 튜플은 불변성이 보장되므로, 파이썬 인터프리터가 튜플을 최적화하기 쉽기 때문입니다. 특히 튜플을 함수의 인자로 전달하거나, 딕셔너리의 키로 사용할 때 성능상의 이점이 있습니다.\n\n### 4. 용도\n- **리스트 (List)**: 데이터가 변경될 가능성이 있는 경우에 사용합니다. 예를 들어, 사용자의 입력 데이터를 저장하거나, 프로그램 실행 중에 값이 변경되는 데이터를 저장할 때 적합합니다.\n- **튜플 (Tuple)**: 데이터가 변경되지 않아야 하는 경우에 사용합니다. 예를 들어, 좌표 (x, y), RGB 색상 코드 (255, 0, 0), 데이터베이스 레코드 등을 표현할 때 적합합니다. 또한, 튜플은 딕셔너리의 키로 사용할 수 있지만, 리스트는 사용할 수 없습니다.\n\n### 5. 메서드\n- **리스트 (List)**: 요소를 추가, 삭제, 정렬하는 다양한 메서드를 제공합니다 (예: `append()`, `insert()`, `remove()`, `sort()`).\n- **튜플 (Tuple)**: 리스트에 비해 제공하는 메서드가 적습니다. (예: `count()`, `index()`) 불변성이 있기 때문에 요소를 변경하는 메서드는 제공하지 않습니다.\n\n### 요약\n\n| 특징        | 리스트 (List) | 튜플 (Tuple) |\n| ----------- | ----------- | ----------- |\n| 가변성      | 가변적       | 불변적       |\n| 문법        | `[]`        | `()`        |\n| 성능        | 상대적으로 느림 | 상대적으로 빠름 |\n| 용도        | 데이터 변경 가능성 | 데이터 불변성 |\n| 메서드      | 다양함       | 제한적       |\n\n### 예제\n\n```python\n# 리스트\nmy_list = [1, 2, 3]\nmy_list.append(4)  # 요소 추가\nmy_list[0] = 10  # 요소 변경\nprint(my_list)  # 출력: [10, 2, 3, 4]\n\n# 튜플\nmy_tuple = (1, 2, 3)\n# my_tuple.append(4)  # 에러 발생: \'tuple\' object has no attribute \'append\'\n# my_tuple[0] = 10  # 에러 발생: \'tuple\' object does not support item assignment\nprint(my_tuple)  # 출력: (1, 2, 3)\n```\n\n어떤 자료구조를 사용할지는 데이터의 특성과 프로그램의 요구사항에 따라 결정해야 합니다. 데이터가 변경될 가능성이 있다면 리스트를, 데이터가 변경되지 않아야 한다면 튜플을 사용하는 것이 좋습니다. 성능이 중요한 경우에는 튜플을 사용하는 것을 고려해볼 수 있습니다.', additional_kwargs={}, response_metadata={}, name='GeneralQA')]}

# %% [markdown]
# # Agent Supervisor 생성

# %%
from pydantic import BaseModel
from typing import Literal

# 멤버 Agent 목록 정의 (QueryExpansion, GeneralQA 추가)
members = ["ManseTool", "RetrieverTool", "WebTool", "GeneralQA"]

# 다음 작업자 선택 옵션 목록 정의
options_for_next = ["FINISH"] + members

# 작업자 선택 응답 모델 정의: 다음 작업자를 선택하거나 작업 완료를 나타냄
class RouteResponse(BaseModel):
    next: Literal[*options_for_next]

# %%
# system_prompt = (
#     "You are a supervisor tasked with orchestrating a multi-step workflow with the following specialized agents: {members}.\n"
#     "The tools are:\n"
#     "- ManseTool: For extracting and calculating Saju information (year, month, day, hour pillars) from user input (such as date/time of birth).\n"
#     "- RetrieverTool: For interpreting Saju details and providing all Saju or Four Pillars explanations, follow-up answers, and analysis based on calculated information.\n"
#     "- WebTool: ONLY for general or non-Saju-specific questions that require external web search, or for questions about the history or origins of Saju that are not covered by the calculated result.\n"
#     "- GeneralQA: For questions completely unrelated to Saju (e.g., programming, science, general knowledge, weather, etc.).\n\n"

#     "Your job is to:\n"
#     "1. Route the user's request to the most appropriate tool:\n"
#     "   - If the user input contains raw birth information (date/time, etc.), ALWAYS call ManseTool FIRST.\n"
#     "   - IMPORTANT: **After using ManseTool, you MUST ALWAYS call RetrieverTool next to interpret the calculated Saju results, including any follow-up or clarifying Saju-related questions. Do NOT skip this step.**\n"
#     "   - If the user asks ANY question related to Saju (e.g., explanation, meaning, further Saju guidance, or even requests about specific aspects of the Saju reading), always route to RetrieverTool—even if it is a follow-up question.\n"
#     "   - Only use WebTool if the user's question cannot be answered from the Saju calculation and is asking for general Saju theory, history, or needs external web information (e.g., 'What is the history of Saju?', 'Who invented Saju?', 'What does a certain Saju term mean globally?').\n"
#     "   - If the input is completely unrelated to Saju, call GeneralQA.\n"
#     "2. NEVER finish the workflow after ManseTool alone. Always pass the result to RetrieverTool before considering FINISH.\n"
#     "3. After all needed steps are complete, respond with FINISH.\n"
#     "You MUST always decide the most logical next agent for the task and strictly follow this tool sequence: ManseTool → RetrieverTool → (if necessary WebTool or GeneralQA) → FINISH."
# )

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI


# 시스템 프롬프트 정의: 작업자 간의 대화를 관리하는 감독자 역할
system_prompt = (
    "You are a supervisor tasked with orchestrating a multi-step workflow with the following specialized agents: {members}.\n"
    "The tools are:\n"
    "- ManseTool: For extracting and calculating Saju information (year, month, day, hour pillars) from user input (such as date/time of birth).\n"
    "- RetrieverTool: For interpreting Saju details and providing in-depth Saju or Four Pillars explanations and analysis based on calculated information.\n"
    "- WebTool: For answering general or conceptual questions about Saju, or handling everyday/non-specialized queries, by searching the web.\n"
    "- GeneralQA: For answering general questions that are NOT related to Saju at all (e.g., programming, science, general knowledge, weather, etc.).\n\n"

    "Your job is to:\n"
    "1. Route the user's request to the most appropriate tool:\n"
    "   - If the user input contains raw birth information (date/time, etc.), ALWAYS call ManseTool FIRST.\n"
    "   - IMPORTANT: **After using ManseTool, you MUST ALWAYS call RetrieverTool next to interpret the calculated Saju results, before finishing or moving to any other step. Do NOT skip this step.**\n"
    "   - If the input is purely a general, conceptual, or non-specialized Saju question, and does NOT require document search, call WebTool.\n"
    "   - If the input is completely unrelated to Saju, call GeneralQA.\n"
    "2. NEVER finish the workflow after ManseTool alone. Always pass the result to RetrieverTool before considering FINISH.\n"
    "3. For completely non-Saju questions, use GeneralQA directly.\n"
    "3. After all needed steps are complete, respond with FINISH.\n"
    "You MUST always decide the most logical next agent for the task and strictly follow this tool sequence."
)

# ChatPromptTemplate 생성
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        MessagesPlaceholder(variable_name="messages"),
        (
            "system",
            "Given the conversation above, who should act next? "
            "Or should we FINISH? Select one of: {options}",
        ),
    ]
).partial(options=str(options_for_next), members=", ".join(members))

# LLM 초기화
llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

# Supervisor Agent 생성
def supervisor_agent(state):
    # 프롬프트와 LLM을 결합하여 체인 구성
    supervisor_chain = prompt | llm.with_structured_output(RouteResponse)
    # Agent 호출
    return supervisor_chain.invoke(state)

# %%
import operator
from typing import Sequence, Annotated
from typing_extensions import TypedDict

from langchain_core.messages import BaseMessage

# 상태 정의
class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage], operator.add]  # 메시지
    next: str  # 다음으로 라우팅할 에이전트

# %%
from langgraph.graph import END, StateGraph, START
from langgraph.checkpoint.memory import MemorySaver

# Query Expansion 노드가 포함된 그래프 생성
workflow = StateGraph(AgentState)

# 그래프에 노드 추가: members = ["ManseTool", "QueryExpansion", "RetrieverTool", "WebTool", "GeneralQA"]
workflow.add_node("ManseTool", manse_tool_agent_node)
# workflow.add_node("QueryExpansion", query_expansion_node)  # Query Expansion 노드 추가
workflow.add_node("RetrieverTool", retriever_tool_agent_node)  # 기존 Retriever 사용
workflow.add_node("WebTool", web_tool_agent_node)
workflow.add_node("GeneralQA", general_qa_agent_node)  # GeneralQA 노드 추가
workflow.add_node("Supervisor", supervisor_agent)



# 멤버 노드 > Supervisor 노드로 엣지 추가
for member in members:
    workflow.add_edge(member, "Supervisor")

# 조건부 엣지 추가
conditional_map = {k: k for k in members}
conditional_map["FINISH"] = END

def get_next(state):
    return state["next"]

# Supervisor 노드에서 조건부 엣지 추가
workflow.add_conditional_edges("Supervisor", get_next, conditional_map)

# 시작점
# workflow.add_edge(START, "QueryExpansion")
workflow.add_edge(START, "Supervisor")

# 그래프 컴파일
graph = workflow.compile(checkpointer=MemorySaver())

# %%
graph

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
question = "1996년 12월 13일 남자, 10시 30분 출생 운세봐줘."

inputs = {
    "messages": [
        HumanMessage(
            content=question
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 병자
# 월주(月柱): 경자
# 일주(日柱): 갑신
# 시주(時柱): 기사
# 일간(日干): 갑
#
# === 오행 강약 ===
# 목: 20점
# 화: 29점
# 토: 25점
# 금: 30점
# 수: 34점
#
# === 십신 분석 ===
# 년주: 천간:식신, 지지:정인(100%)
# 월주: 천간:편관, 지지:정인(100%)
# 일주: 지지:편관(60%), 지지:편인(30%), 지지:편재(10%)
# 시주: 천간:정재, 지지:식신(60%), 지지:편재(30%), 지지:편관(10%)
#
# === 대운 (정밀 계산) ===
# 6세: 신축 (2002년 ~ 2011년)
# 16세: 임인 (2012년 ~ 2021년)
# 26세: 계묘 (2022년 ~ 2031년)
# 36세: 갑진 (2032년 ~ 2041년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1996년 12월 13일 10시 30분에 태어난 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주(年柱): 병자
# - 월주(月柱): 경자
# - 일주(日柱): 갑신
# - 시주(時柱): 기사
# - 일간(日干): 갑
#
# 오행의 강약은 목 20점, 화 29점, 토 25점, 금 30점, 수 34점으로 수와 금이 비교적 강한 편입니다.
#
# 십신 분석에서는 식신, 정인, 편관, 편인, 편재 등이 조화를 이루고 있습니다.
#
# 대운은 다음과 같이 흐릅니다.
# - 6세부터 11년간 신축 대운 (2002년 ~ 2011년)
# - 16세부터 10년간 임인 대운 (2012년 ~ 2021년)
# - 26세부터 10년간 계묘 대운 (2022년 ~ 2031년)
# - 36세부터 10년간 갑진 대운 (2032년 ~ 2041년)
#
# 현재 26세부터 시작된 계묘 대운이 진행 중이며, 앞으로의 운세는 이 대운의 영향을 받게 됩니다.
#
# 더 구체적인 운세나 조언이 필요하시면 말씀해 주세요.
# ==================================================
# 🔄 Node: ManseTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1996년 12월 13일 10시 30분에 태어난 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주(年柱): 병자
# - 월주(月柱): 경자
# - 일주(日柱): 갑신
# - 시주(時柱): 기사
# - 일간(日干): 갑
#
# 오행의 강약은 목 20점, 화 29점, 토 25점, 금 30점, 수 34점으로 수와 금이 비교적 강한 편입니다.
#
# 십신 분석에서는 식신, 정인, 편관, 편인, 편재 등이 조화를 이루고 있습니다.
#
# 대운은 다음과 같이 흐릅니다.
# - 6세부터 11년간 신축 대운 (2002년 ~ 2011년)
# - 16세부터 10년간 임인 대운 (2012년 ~ 2021년)
# - 26세부터 10년간 계묘 대운 (2022년 ~ 2031년)
# - 36세부터 10년간 갑진 대운 (2032년 ~ 2041년)
#
# 현재 26세부터 시작된 계묘 대운이 진행 중이며, 앞으로의 운세는 이 대운의 영향을 받게 됩니다.
#
# 더 구체적인 운세나 조언이 필요하시면 말씀해 주세요.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1996년 12월 13일 10시 30분 출생 남성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 (천간지지 변환)
#
# - 출생일: 1996년 12월 13일, 10시 30분 (양력 기준)
# - 성별: 남성
# - 출생시간: 10시 30분 → 지지 시각으로는 巳시 (09:00~11:00) 해당
#
# ### 사주팔자 (년, 월, 일, 시)
#
# - 년주(年柱): 병자 (丙子)
# - 월주(月柱): 경자 (庚子)
# - 일주(日柱): 갑신 (甲申)
# - 시주(時柱): 기사 (己巳)
#
# → 총 8글자: 丙, 子, 庚, 子, 甲, 申, 己, 巳
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 1) 천간지지 → 오행 매핑
#
# | 글자 | 오행 |
# |-------|-------|
# | 丙    | 火     |
# | 子    | 水     |
# | 庚    | 金     |
# | 子    | 水     |
# | 甲    | 木     |
# | 申    | 金     |
# | 己    | 土     |
# | 巳    | 火     |
#
# ### 2) 오행별 점수 부여 (각 글자 1점)
#
# - 木(목): 甲 → 1점
# - 火(화): 丙, 巳 → 2점
# - 土(토): 己 → 1점
# - 金(금): 庚, 申 → 2점
# - 水(수): 子, 子 → 2점
#
# ### 3) 오행 분포 표
#
# | 오행 | 점수 | 글자       |
# |-------|-------|------------|
# | 목    | 1     | 甲         |
# | 화    | 2     | 丙, 巳     |
# | 토    | 1     | 己         |
# | 금    | 2     | 庚, 申     |
# | 수    | 2     | 子, 子     |
#
# 총점 = 1 + 2 + 1 + 2 + 2 = 8 (계산 정확)
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 강약 및 해석
#
# - **강한 오행:** 수(水) 2점, 금(金) 2점, 화(火) 2점
# - **약한 오행:** 목(木) 1점, 토(土) 1점
#
# ### 해석
#
# - 수와 금, 화가 비교적 강한 편이며, 목과 토가 약한 편입니다.
# - 수는 지혜, 유연성, 감성, 금은 결단력, 조직력, 화는 열정, 추진력, 목은 성장, 창의력, 토는 안정, 신뢰를 의미합니다.
# - 목과 토가 약하므로 성장과 안정 면에서 보완이 필요합니다.
#
# ### 상생상극 관계
#
# - 목은 화를 생하고, 화는 토를 생하며, 토는 금을 생하고, 금은 수를 생하며, 수는 목을 생합니다.
# - 현재 목과 토가 약하므로, 수와 금가 강한 상태에서 목과 토를 보완하는 것이 좋습니다.
# - 화가 중간 정도 있어 추진력은 있으나, 목과 토가 약해 창의력과 안정감이 부족할 수 있습니다.
#
# ### 보완 제안 (일반적 조언)
#
# - 목과 토를 보완하는 색상(녹색, 갈색 계열), 음식(채소, 곡류), 활동(자연과 접촉, 명상 등)을 권장합니다.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 갑목 기준)
#
# - 일간(日干): 갑목(甲)
# - 나머지 7글자와의 관계:
#
# | 글자 | 십신 관계 | 의미 및 영향 |
# |-------|-----------|--------------|
# | 丙(년간) | 편관(偏官) | 도전, 경쟁, 권위, 스트레스 요인 |
# | 子(년지) | 편재(偏財) | 재물, 기회, 외부 자원 |
# | 庚(월간) | 정재(正財) | 재물, 안정적 자원 |
# | 子(월지) | 편재(偏財) | 재물, 기회 |
# | 申(일지) | 편인(偏印) | 지식, 학문, 보호자 |
# | 己(시간) | 식신(食神) | 창조, 표현, 건강 |
# | 巳(시지) | 편관(偏官) | 도전, 경쟁, 권위 |
#
# ### 해석
#
# - 편관(丙, 巳)이 두 개 있어 도전과 경쟁심이 강하며, 권위적인 성향이 있음.
# - 재물과 기회를 나타내는 편재(子)가 두 번 있어 재물운과 기회가 많음.
# - 편인(申)은 지식과 보호를 의미해 학문적 재능과 보호자가 있음.
# - 식신(己)은 창조력과 건강을 나타냄.
#
# ---
#
# ## 5. 성격 및 기질
#
# - 도전적이고 경쟁심이 강하며, 추진력이 뛰어남.
# - 재물과 기회가 많아 사업이나 재테크에 유리.
# - 지식과 학문에 대한 관심이 높고, 보호자나 스승의 도움을 받을 가능성 있음.
# - 창의적이고 표현력이 좋으나, 목과 토가 약해 안정감과 성장에 다소 부족함.
# - 스트레스 관리와 안정적인 생활이 필요.
#
# ---
#
# ## 6. 대운(大運) 흐름
#
# - 6세부터 11년간 신축(辛丑) 대운 (2002~2012)
# - 16세부터 10년간 임인(壬寅) 대운 (2012~2021)
# - 26세부터 10년간 계묘(癸卯) 대운 (2022~2031) → 현재 진행 중
# - 36세부터 10년간 갑진(甲辰) 대운 (2032~2041)
#
# ### 현재 대운(계묘)
#
# - 계(癸): 수(水), 묘(卯): 목(木)
# - 수와 목이 보완되어 약한 목을 강화하는 좋은 대운임.
# - 창의력과 성장, 안정에 긍정적 영향.
#
# ---
#
# ## 7. 세운(歲運) 분석 (2023~2025년)
#
# - 2023년 계묘(癸卯): 대운과 동일, 목과 수가 보완되어 좋은 시기
# - 2024년 갑진(甲辰): 갑목과 진토, 목과 토가 보완되어 안정과 성장 가능
# - 2025년 을사(乙巳): 을목과 사화, 목과 화가 보완되어 추진력과 창의력 상승
#
# ---
#
# ## 8. 종합 요약 및 주의사항
#
# - 수, 금, 화가 강하고 목, 토가 약한 사주로, 목과 토를 보완하는 생활습관과 환경 조성이 필요.
# - 도전적이고 경쟁심이 강하며, 재물운과 학문적 재능이 뛰어남.
# - 현재 대운이 약한 목을 보완하는 좋은 흐름으로, 성장과 발전에 유리한 시기.
# - 스트레스 관리와 안정적인 생활이 중요하며, 자연과 접촉하는 활동 권장.
# - 재물과 기회를 잘 활용하면 좋은 성과 기대 가능.
#
# ---
#
# 필요하시면 더 구체적인 운세나 특정 분야(직업, 건강, 인간관계 등) 상담도 가능합니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 이론 및 천간지지-오행 매핑 기준
# (내부 데이터 및 한국 고전 명리학 자료 참고)
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1996년 12월 13일 10시 30분 출생 남성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 (천간지지 변환)
#
# - 출생일: 1996년 12월 13일, 10시 30분 (양력 기준)
# - 성별: 남성
# - 출생시간: 10시 30분 → 지지 시각으로는 巳시 (09:00~11:00) 해당
#
# ### 사주팔자 (년, 월, 일, 시)
#
# - 년주(年柱): 병자 (丙子)
# - 월주(月柱): 경자 (庚子)
# - 일주(日柱): 갑신 (甲申)
# - 시주(時柱): 기사 (己巳)
#
# → 총 8글자: 丙, 子, 庚, 子, 甲, 申, 己, 巳
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 1) 천간지지 → 오행 매핑
#
# | 글자 | 오행 |
# |-------|-------|
# | 丙    | 火     |
# | 子    | 水     |
# | 庚    | 金     |
# | 子    | 水     |
# | 甲    | 木     |
# | 申    | 金     |
# | 己    | 土     |
# | 巳    | 火     |
#
# ### 2) 오행별 점수 부여 (각 글자 1점)
#
# - 木(목): 甲 → 1점
# - 火(화): 丙, 巳 → 2점
# - 土(토): 己 → 1점
# - 金(금): 庚, 申 → 2점
# - 水(수): 子, 子 → 2점
#
# ### 3) 오행 분포 표
#
# | 오행 | 점수 | 글자       |
# |-------|-------|------------|
# | 목    | 1     | 甲         |
# | 화    | 2     | 丙, 巳     |
# | 토    | 1     | 己         |
# | 금    | 2     | 庚, 申     |
# | 수    | 2     | 子, 子     |
#
# 총점 = 1 + 2 + 1 + 2 + 2 = 8 (계산 정확)
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 강약 및 해석
#
# - **강한 오행:** 수(水) 2점, 금(金) 2점, 화(火) 2점
# - **약한 오행:** 목(木) 1점, 토(土) 1점
#
# ### 해석
#
# - 수와 금, 화가 비교적 강한 편이며, 목과 토가 약한 편입니다.
# - 수는 지혜, 유연성, 감성, 금은 결단력, 조직력, 화는 열정, 추진력, 목은 성장, 창의력, 토는 안정, 신뢰를 의미합니다.
# - 목과 토가 약하므로 성장과 안정 면에서 보완이 필요합니다.
#
# ### 상생상극 관계
#
# - 목은 화를 생하고, 화는 토를 생하며, 토는 금을 생하고, 금은 수를 생하며, 수는 목을 생합니다.
# - 현재 목과 토가 약하므로, 수와 금가 강한 상태에서 목과 토를 보완하는 것이 좋습니다.
# - 화가 중간 정도 있어 추진력은 있으나, 목과 토가 약해 창의력과 안정감이 부족할 수 있습니다.
#
# ### 보완 제안 (일반적 조언)
#
# - 목과 토를 보완하는 색상(녹색, 갈색 계열), 음식(채소, 곡류), 활동(자연과 접촉, 명상 등)을 권장합니다.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 갑목 기준)
#
# - 일간(日干): 갑목(甲)
# - 나머지 7글자와의 관계:
#
# | 글자 | 십신 관계 | 의미 및 영향 |
# |-------|-----------|--------------|
# | 丙(년간) | 편관(偏官) | 도전, 경쟁, 권위, 스트레스 요인 |
# | 子(년지) | 편재(偏財) | 재물, 기회, 외부 자원 |
# | 庚(월간) | 정재(正財) | 재물, 안정적 자원 |
# | 子(월지) | 편재(偏財) | 재물, 기회 |
# | 申(일지) | 편인(偏印) | 지식, 학문, 보호자 |
# | 己(시간) | 식신(食神) | 창조, 표현, 건강 |
# | 巳(시지) | 편관(偏官) | 도전, 경쟁, 권위 |
#
# ### 해석
#
# - 편관(丙, 巳)이 두 개 있어 도전과 경쟁심이 강하며, 권위적인 성향이 있음.
# - 재물과 기회를 나타내는 편재(子)가 두 번 있어 재물운과 기회가 많음.
# - 편인(申)은 지식과 보호를 의미해 학문적 재능과 보호자가 있음.
# - 식신(己)은 창조력과 건강을 나타냄.
#
# ---
#
# ## 5. 성격 및 기질
#
# - 도전적이고 경쟁심이 강하며, 추진력이 뛰어남.
# - 재물과 기회가 많아 사업이나 재테크에 유리.
# - 지식과 학문에 대한 관심이 높고, 보호자나 스승의 도움을 받을 가능성 있음.
# - 창의적이고 표현력이 좋으나, 목과 토가 약해 안정감과 성장에 다소 부족함.
# - 스트레스 관리와 안정적인 생활이 필요.
#
# ---
#
# ## 6. 대운(大運) 흐름
#
# - 6세부터 11년간 신축(辛丑) 대운 (2002~2012)
# - 16세부터 10년간 임인(壬寅) 대운 (2012~2021)
# - 26세부터 10년간 계묘(癸卯) 대운 (2022~2031) → 현재 진행 중
# - 36세부터 10년간 갑진(甲辰) 대운 (2032~2041)
#
# ### 현재 대운(계묘)
#
# - 계(癸): 수(水), 묘(卯): 목(木)
# - 수와 목이 보완되어 약한 목을 강화하는 좋은 대운임.
# - 창의력과 성장, 안정에 긍정적 영향.
#
# ---
#
# ## 7. 세운(歲運) 분석 (2023~2025년)
#
# - 2023년 계묘(癸卯): 대운과 동일, 목과 수가 보완되어 좋은 시기
# - 2024년 갑진(甲辰): 갑목과 진토, 목과 토가 보완되어 안정과 성장 가능
# - 2025년 을사(乙巳): 을목과 사화, 목과 화가 보완되어 추진력과 창의력 상승
#
# ---
#
# ## 8. 종합 요약 및 주의사항
#
# - 수, 금, 화가 강하고 목, 토가 약한 사주로, 목과 토를 보완하는 생활습관과 환경 조성이 필요.
# - 도전적이고 경쟁심이 강하며, 재물운과 학문적 재능이 뛰어남.
# - 현재 대운이 약한 목을 보완하는 좋은 흐름으로, 성장과 발전에 유리한 시기.
# - 스트레스 관리와 안정적인 생활이 중요하며, 자연과 접촉하는 활동 권장.
# - 재물과 기회를 잘 활용하면 좋은 성과 기대 가능.
#
# ---
#
# 필요하시면 더 구체적인 운세나 특정 분야(직업, 건강, 인간관계 등) 상담도 가능합니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 이론 및 천간지지-오행 매핑 기준
# (내부 데이터 및 한국 고전 명리학 자료 참고)
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent
from manse_6 import calculate_saju_tool
# Agent 생성 시 tools 리스트에 추가

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
tools = [calculate_saju_tool]  # 사주 툴 추가

manse_tool_agent = create_react_agent(llm, tools)

# 을해 을유 병진 을미
response = manse_tool_agent.invoke({"messages": [("user", "1995년 9월 22일 남자, 15시 30분")]})
print(response["messages"][-1].content)
# Out:
# 1995년 9월 22일 15시 30분에 태어난 남성의 사주팔자는 다음과 같습니다.
#
# - 년주: 을해
# - 월주: 을유
# - 일주: 병진
# - 시주: 을미
# - 일간: 병
#
# 오행 강약 점수는 목이 가장 강하고, 그 다음으로 화, 토, 금, 수 순입니다.
#
# 십신 분석에 따르면, 년주는 정인과 편관, 편인이 혼재되어 있고, 월주는 정인과 정재, 일주는 식신, 정인, 정관, 시주는 정인과 상관, 겁재, 정인이 포함되어 있습니다.
#
# 대운은 5세부터 시작하여 10년 단위로 갑신, 계미, 임오, 신사 대운이 이어집니다.
#
# 이 사주는 목의 기운이 강하고, 병화 일간이 목의 도움을 받는 구조로 보입니다. 더 구체적인 운세나 성격, 직업 적성 등 해석이 필요하면 알려주세요.

# %%
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent
from manse_6 import calculate_saju_tool
# Agent 생성 시 tools 리스트에 추가

llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
tools = [calculate_saju_tool]  # 사주 툴 추가

manse_tool_agent = create_react_agent(llm, tools)

# 을해 을유 병진 을미
response = manse_tool_agent.invoke({"messages": [("user", "1995년 9월 22일 남자, 15시 30분")]})
print(response["messages"][-1].content)
# Out:
# 1995년 9월 22일 15시 30분에 태어난 남성의 사주팔자는 다음과 같습니다.
#
# - 년주: 을해
# - 월주: 을유
# - 일주: 병진
# - 시주: 을미
# - 일간: 병
#
# 오행 강약 점수는 목이 가장 강하고, 그 다음으로 화, 토, 금, 수 순입니다.
#
# 십신 분석에 따르면, 년주는 정인과 편관, 편인이 혼재되어 있고, 월주는 정인과 정재, 일주는 식신, 정인, 정관, 시주는 정인과 상관, 겁재, 정인이 포함되어 있습니다.
#
# 대운은 5세부터 시작하여 10년 단위로 갑신, 계미, 임오, 신사 대운이 이어집니다.
#
# 이 사주는 목의 기운이 강하고, 병화 일간이 목의 도움을 받는 구조로 보입니다. 더 구체적인 운세나 성격, 직업 적성 등 해석이 필요하면 알려주세요.

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력

question = "연애운이 궁금해"

inputs = {
    "messages": [
        HumanMessage(
            content=question
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1996년 12월 13일 10시 30분 출생 남성분의 연애운을 사주팔자와 오행, 십신 분석을 바탕으로 상세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 복습
#
# - 년주: 병자 (丙子)
# - 월주: 경자 (庚子)
# - 일주: 갑신 (甲申)
# - 시주: 기사 (己巳)
#
# 일간(日干)은 갑목(甲)으로, 본인의 본성, 성격, 자아를 나타냅니다.
#
# ---
#
# ## 2. 오행과 십신에서 본 연애운 특징
#
# ### 1) 십신 중 연애와 관련 깊은 신살
#
# - **편관(偏官, 7살)**: 병(丙)년간과 시지(巳)에 편관이 두 개 있습니다. 편관은 권위, 도전, 경쟁을 의미하지만, 연애에서는 이성에 대한 관심과 매력, 때로는 긴장과 갈등을 나타냅니다.
# - **식신(食神)**: 시간(己)에 식신이 있어 표현력과 매력, 부드러운 소통 능력을 줍니다. 이는 연애에서 상대방에게 호감을 주고 관계를 원활하게 하는 긍정적 요소입니다.
# - **편재(偏財)**: 년지와 월지의 자(子)가 편재로 재물과 기회뿐 아니라 이성운과도 연결됩니다. 편재가 두 번 있어 이성운이 풍부하고 다양한 만남이 기대됩니다.
#
# ### 2) 일간 갑목과의 관계
#
# - 갑목은 생명력 넘치고 따뜻한 성격으로, 연애에 있어 진실하고 헌신적인 면이 강합니다.
# - 다만, 편관이 강해 때로는 상대방과의 갈등이나 긴장감이 있을 수 있으니 조율이 필요합니다.
#
# ---
#
# ## 3. 대운과 연애운의 영향
#
# - 현재 대운은 계묘(癸卯)로 수(水)와 목(木)이 보완되어 약한 목을 강화하는 시기입니다.
# - 목은 갑목 일간의 본질이므로, 이 시기는 본인의 매력과 자아가 더욱 빛나고, 연애운이 상승하는 좋은 시기입니다.
# - 2023~2025년 세운 역시 목과 수, 화가 보완되어 연애에 긍정적 영향을 줍니다.
#
# ---
#
# ## 4. 연애운 종합 해석 및 조언
#
# - **만남과 기회가 많고, 매력적이며 표현력이 좋아 상대방에게 호감을 쉽게 얻는 편입니다.**
# - 다만, 편관이 강해 때때로 권위적이거나 경쟁적인 태도가 연애에 긴장감을 줄 수 있으니 상대방과의 소통과 이해가 중요합니다.
# - 현재 대운과 세운이 목과 수를 보완해 주므로, 자신감을 가지고 적극적으로 만남을 추구하면 좋은 인연을 만날 수 있습니다.
# - 목과 토가 약한 점을 보완하기 위해 자연과 접촉하거나 안정적인 환경에서 만남을 가지면 관계가 더욱 원만해집니다.
#
# ---
#
# 필요하시면 구체적인 시기별 연애운이나 궁합, 이성관계에서 주의할 점도 추가로 안내해 드릴 수 있습니다.
#
# 감사합니다.
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1996년 12월 13일 10시 30분 출생 남성분의 연애운을 사주팔자와 오행, 십신 분석을 바탕으로 상세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 복습
#
# - 년주: 병자 (丙子)
# - 월주: 경자 (庚子)
# - 일주: 갑신 (甲申)
# - 시주: 기사 (己巳)
#
# 일간(日干)은 갑목(甲)으로, 본인의 본성, 성격, 자아를 나타냅니다.
#
# ---
#
# ## 2. 오행과 십신에서 본 연애운 특징
#
# ### 1) 십신 중 연애와 관련 깊은 신살
#
# - **편관(偏官, 7살)**: 병(丙)년간과 시지(巳)에 편관이 두 개 있습니다. 편관은 권위, 도전, 경쟁을 의미하지만, 연애에서는 이성에 대한 관심과 매력, 때로는 긴장과 갈등을 나타냅니다.
# - **식신(食神)**: 시간(己)에 식신이 있어 표현력과 매력, 부드러운 소통 능력을 줍니다. 이는 연애에서 상대방에게 호감을 주고 관계를 원활하게 하는 긍정적 요소입니다.
# - **편재(偏財)**: 년지와 월지의 자(子)가 편재로 재물과 기회뿐 아니라 이성운과도 연결됩니다. 편재가 두 번 있어 이성운이 풍부하고 다양한 만남이 기대됩니다.
#
# ### 2) 일간 갑목과의 관계
#
# - 갑목은 생명력 넘치고 따뜻한 성격으로, 연애에 있어 진실하고 헌신적인 면이 강합니다.
# - 다만, 편관이 강해 때로는 상대방과의 갈등이나 긴장감이 있을 수 있으니 조율이 필요합니다.
#
# ---
#
# ## 3. 대운과 연애운의 영향
#
# - 현재 대운은 계묘(癸卯)로 수(水)와 목(木)이 보완되어 약한 목을 강화하는 시기입니다.
# - 목은 갑목 일간의 본질이므로, 이 시기는 본인의 매력과 자아가 더욱 빛나고, 연애운이 상승하는 좋은 시기입니다.
# - 2023~2025년 세운 역시 목과 수, 화가 보완되어 연애에 긍정적 영향을 줍니다.
#
# ---
#
# ## 4. 연애운 종합 해석 및 조언
#
# - **만남과 기회가 많고, 매력적이며 표현력이 좋아 상대방에게 호감을 쉽게 얻는 편입니다.**
# - 다만, 편관이 강해 때때로 권위적이거나 경쟁적인 태도가 연애에 긴장감을 줄 수 있으니 상대방과의 소통과 이해가 중요합니다.
# - 현재 대운과 세운이 목과 수를 보완해 주므로, 자신감을 가지고 적극적으로 만남을 추구하면 좋은 인연을 만날 수 있습니다.
# - 목과 토가 약한 점을 보완하기 위해 자연과 접촉하거나 안정적인 환경에서 만남을 가지면 관계가 더욱 원만해집니다.
#
# ---
#
# 필요하시면 구체적인 시기별 연애운이나 궁합, 이성관계에서 주의할 점도 추가로 안내해 드릴 수 있습니다.
#
# 감사합니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력

question = "지금 연애안한지 오래됐는데 연애를 하고싶어. 언제쯤 만날 수 있을까?"

inputs = {
    "messages": [
        HumanMessage(
            content=question
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1996년 12월 13일 10시 30분 출생 남성분의 연애운과 만남 시기를 사주와 대운, 세운을 바탕으로 상세히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 현재 사주 및 대운 상황 복습
#
# - 일간: 갑목(甲)
# - 현재 대운: 계묘(癸卯, 2022~2031) → 수(水)와 목(木)이 보완되어 본인의 본질인 갑목이 강화되는 시기
# - 세운(2023~2025): 목과 수, 화가 보완되어 연애운에 긍정적 영향
#
# ---
#
# ## 2. 연애 만남 시기 분석
#
# ### 1) 대운의 영향
#
# - 현재 진행 중인 계묘 대운은 약한 목을 보완해 주는 좋은 대운으로, 본인의 매력과 자아가 빛나는 시기입니다.
# - 특히 목(木)은 갑목 일간의 본질이므로, 이 대운 기간(2022~2031) 내에 좋은 인연을 만날 가능성이 큽니다.
#
# ### 2) 세운(연도별 운세) 분석
#
# - 2023년 계묘(癸卯): 목과 수가 보완되어 만남과 소통이 원활한 시기
# - 2024년 갑진(甲辰): 갑목과 진토가 안정과 성장을 돕는 시기, 연애에 긍정적
# - 2025년 을사(乙巳): 을목과 사화가 추진력과 매력을 높여주는 시기
#
# → 2023년부터 2025년까지 3년간 연애운이 매우 좋은 흐름임을 알 수 있습니다.
#
# ### 3) 십신과 신살 관점
#
# - 편재(偏財)인 자(子)가 두 번 있어 이성운과 만남 기회가 많으나, 편관(偏官)도 강해 갈등이나 긴장감이 있을 수 있으니 소통에 신경 써야 합니다.
#
# ---
#
# ## 3. 종합 조언 및 예상 만남 시기
#
# - **현재부터 2025년까지가 연애를 시작하기에 매우 좋은 시기입니다.**
# - 특히 2023년과 2024년은 목과 수가 강해 본인의 매력과 표현력이 극대화되는 시기이므로, 적극적으로 만남을 추구하시길 권합니다.
# - 2025년에도 추진력과 매력이 상승하니, 이 시기까지 좋은 인연을 만날 가능성이 큽니다.
# - 만남을 원하신다면 자연과 접촉하는 활동, 모임, 취미 생활 등에서 적극적으로 사람들과 교류하는 것이 좋습니다.
# - 편관의 영향으로 갈등이 있을 수 있으니 상대방과의 소통과 이해에 신경 쓰는 것이 중요합니다.
#
# ---
#
# 필요하시면 구체적인 월별 운세나 궁합 상담도 도와드리겠습니다.
#
# 감사합니다.
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1996년 12월 13일 10시 30분 출생 남성분의 연애운과 만남 시기를 사주와 대운, 세운을 바탕으로 상세히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 현재 사주 및 대운 상황 복습
#
# - 일간: 갑목(甲)
# - 현재 대운: 계묘(癸卯, 2022~2031) → 수(水)와 목(木)이 보완되어 본인의 본질인 갑목이 강화되는 시기
# - 세운(2023~2025): 목과 수, 화가 보완되어 연애운에 긍정적 영향
#
# ---
#
# ## 2. 연애 만남 시기 분석
#
# ### 1) 대운의 영향
#
# - 현재 진행 중인 계묘 대운은 약한 목을 보완해 주는 좋은 대운으로, 본인의 매력과 자아가 빛나는 시기입니다.
# - 특히 목(木)은 갑목 일간의 본질이므로, 이 대운 기간(2022~2031) 내에 좋은 인연을 만날 가능성이 큽니다.
#
# ### 2) 세운(연도별 운세) 분석
#
# - 2023년 계묘(癸卯): 목과 수가 보완되어 만남과 소통이 원활한 시기
# - 2024년 갑진(甲辰): 갑목과 진토가 안정과 성장을 돕는 시기, 연애에 긍정적
# - 2025년 을사(乙巳): 을목과 사화가 추진력과 매력을 높여주는 시기
#
# → 2023년부터 2025년까지 3년간 연애운이 매우 좋은 흐름임을 알 수 있습니다.
#
# ### 3) 십신과 신살 관점
#
# - 편재(偏財)인 자(子)가 두 번 있어 이성운과 만남 기회가 많으나, 편관(偏官)도 강해 갈등이나 긴장감이 있을 수 있으니 소통에 신경 써야 합니다.
#
# ---
#
# ## 3. 종합 조언 및 예상 만남 시기
#
# - **현재부터 2025년까지가 연애를 시작하기에 매우 좋은 시기입니다.**
# - 특히 2023년과 2024년은 목과 수가 강해 본인의 매력과 표현력이 극대화되는 시기이므로, 적극적으로 만남을 추구하시길 권합니다.
# - 2025년에도 추진력과 매력이 상승하니, 이 시기까지 좋은 인연을 만날 가능성이 큽니다.
# - 만남을 원하신다면 자연과 접촉하는 활동, 모임, 취미 생활 등에서 적극적으로 사람들과 교류하는 것이 좋습니다.
# - 편관의 영향으로 갈등이 있을 수 있으니 상대방과의 소통과 이해에 신경 쓰는 것이 중요합니다.
#
# ---
#
# 필요하시면 구체적인 월별 운세나 궁합 상담도 도와드리겠습니다.
#
# 감사합니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력

question = "미래에 대한 연애운은 어때?"

inputs = {
    "messages": [
        HumanMessage(
            content=question
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1996년 12월 13일 10시 30분 출생 남성분의 미래 연애운을 사주팔자와 대운, 세운을 바탕으로 상세히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 및 현재 대운 복습
#
# - 일간(日干): 갑목(甲)
# - 현재 대운: 계묘(癸卯, 2022~2031) → 수(水)와 목(木)이 보완되어 본인의 본질인 갑목이 강화되는 시기
# - 다음 대운: 갑진(甲辰, 2032~2041) → 갑목과 진토로 안정과 성장을 돕는 대운
#
# ---
#
# ## 2. 미래 연애운 전망
#
# ### 1) 2022년~2031년 계묘 대운
#
# - 목과 수가 강해 본인의 매력과 자아가 빛나는 시기입니다.
# - 갑목 일간에게 목은 본질적인 힘이므로, 이 시기에는 연애운이 매우 좋고, 좋은 인연을 만날 가능성이 큽니다.
# - 특히 목이 강해지면서 창의력과 표현력이 좋아져 상대방과의 소통이 원활해지고, 매력도 상승합니다.
# - 다만, 편관(偏官)이 강한 편이라 때때로 갈등이나 긴장감이 있을 수 있으니 상대방과의 이해와 배려가 중요합니다.
#
# ### 2) 2032년~2041년 갑진 대운
#
# - 갑목과 진토가 조화를 이루어 안정과 성장을 돕는 시기입니다.
# - 이 시기에는 연애 관계가 더욱 안정되고 깊어질 가능성이 높습니다.
# - 토(土)는 목(木)을 생하는 역할도 하므로, 부족했던 토의 기운이 보완되어 관계의 안정감과 신뢰가 증대됩니다.
#
# ---
#
# ## 3. 세운(歲運) 분석 (2025년 이후 주요 연도)
#
# - 2025년 을사(乙巳): 목과 화가 보완되어 추진력과 매력이 상승하는 시기
# - 2026년 병오(丙午): 화가 강해 열정과 에너지가 넘치는 시기, 연애에 적극적일 수 있음
# - 2027년 정미(丁未): 화와 토가 보완되어 안정과 열정이 조화되는 시기
# - 2028년 무신(戊申): 토와 금이 보완되어 현실적이고 안정적인 관계 형성 가능
#
# → 2025년부터 2028년까지는 연애운이 계속해서 좋은 흐름을 유지하며, 특히 2026년과 2027년은 열정과 안정이 조화를 이루는 시기입니다.
#
# ---
#
# ## 4. 종합 해석 및 조언
#
# - 앞으로 10년 이상 연애운이 매우 좋은 편이며, 특히 2022년부터 2031년까지의 계묘 대운은 본인의 매력과 자아가 극대화되는 시기로 좋은 인연을 만날 확률이 높습니다.
# - 2032년부터 시작되는 갑진 대운은 연애 관계의 안정과 성장을 돕는 시기이므로, 장기적인 관계를 원하신다면 이 시기에도 좋은 기회가 있습니다.
# - 다만, 편관의 영향으로 갈등이나 긴장감이 있을 수 있으니 상대방과의 소통과 이해에 항상 신경 쓰는 것이 중요합니다.
# - 자연과 접촉하는 활동, 취미 모임, 사회적 교류를 통해 만남의 기회를 넓히는 것이 좋습니다.
#
# ---
#
# 필요하시면 특정 시기별 세부 연애운이나 궁합 상담도 도와드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 이론 및 천간지지-오행 매핑 기준
# (내부 데이터 및 한국 고전 명리학 자료 참고)
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1996년 12월 13일 10시 30분 출생 남성분의 미래 연애운을 사주팔자와 대운, 세운을 바탕으로 상세히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 및 현재 대운 복습
#
# - 일간(日干): 갑목(甲)
# - 현재 대운: 계묘(癸卯, 2022~2031) → 수(水)와 목(木)이 보완되어 본인의 본질인 갑목이 강화되는 시기
# - 다음 대운: 갑진(甲辰, 2032~2041) → 갑목과 진토로 안정과 성장을 돕는 대운
#
# ---
#
# ## 2. 미래 연애운 전망
#
# ### 1) 2022년~2031년 계묘 대운
#
# - 목과 수가 강해 본인의 매력과 자아가 빛나는 시기입니다.
# - 갑목 일간에게 목은 본질적인 힘이므로, 이 시기에는 연애운이 매우 좋고, 좋은 인연을 만날 가능성이 큽니다.
# - 특히 목이 강해지면서 창의력과 표현력이 좋아져 상대방과의 소통이 원활해지고, 매력도 상승합니다.
# - 다만, 편관(偏官)이 강한 편이라 때때로 갈등이나 긴장감이 있을 수 있으니 상대방과의 이해와 배려가 중요합니다.
#
# ### 2) 2032년~2041년 갑진 대운
#
# - 갑목과 진토가 조화를 이루어 안정과 성장을 돕는 시기입니다.
# - 이 시기에는 연애 관계가 더욱 안정되고 깊어질 가능성이 높습니다.
# - 토(土)는 목(木)을 생하는 역할도 하므로, 부족했던 토의 기운이 보완되어 관계의 안정감과 신뢰가 증대됩니다.
#
# ---
#
# ## 3. 세운(歲運) 분석 (2025년 이후 주요 연도)
#
# - 2025년 을사(乙巳): 목과 화가 보완되어 추진력과 매력이 상승하는 시기
# - 2026년 병오(丙午): 화가 강해 열정과 에너지가 넘치는 시기, 연애에 적극적일 수 있음
# - 2027년 정미(丁未): 화와 토가 보완되어 안정과 열정이 조화되는 시기
# - 2028년 무신(戊申): 토와 금이 보완되어 현실적이고 안정적인 관계 형성 가능
#
# → 2025년부터 2028년까지는 연애운이 계속해서 좋은 흐름을 유지하며, 특히 2026년과 2027년은 열정과 안정이 조화를 이루는 시기입니다.
#
# ---
#
# ## 4. 종합 해석 및 조언
#
# - 앞으로 10년 이상 연애운이 매우 좋은 편이며, 특히 2022년부터 2031년까지의 계묘 대운은 본인의 매력과 자아가 극대화되는 시기로 좋은 인연을 만날 확률이 높습니다.
# - 2032년부터 시작되는 갑진 대운은 연애 관계의 안정과 성장을 돕는 시기이므로, 장기적인 관계를 원하신다면 이 시기에도 좋은 기회가 있습니다.
# - 다만, 편관의 영향으로 갈등이나 긴장감이 있을 수 있으니 상대방과의 소통과 이해에 항상 신경 쓰는 것이 중요합니다.
# - 자연과 접촉하는 활동, 취미 모임, 사회적 교류를 통해 만남의 기회를 넓히는 것이 좋습니다.
#
# ---
#
# 필요하시면 특정 시기별 세부 연애운이나 궁합 상담도 도와드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 이론 및 천간지지-오행 매핑 기준
# (내부 데이터 및 한국 고전 명리학 자료 참고)
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="1997년 09월 01일 여자, 11시 30분 출생 운세봐줘"
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide a fortune reading for a female born on September 1, 1997, at 11:30 AM? I am interested in a detailed analysis of her Four Pillars of Destiny (Ba Zi) and how her birth chart influences her personality, career prospects, and relationships.1997년 09월 01일 여자, 11시 30분 출생 운세봐줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 정축
# 월주(月柱): 무신
# 일주(日柱): 병오
# 시주(時柱): 계사
# 일간(日干): 병
#
# === 오행 강약 ===
# 목: 0점
# 화: 59점
# 토: 38점
# 금: 11점
# 수: 28점
#
# === 십신 분석 ===
# 년주: 천간:겁재, 지지:상관(60%), 지지:정관(30%), 지지:정재(10%)
# 월주: 천간:식신, 지지:편재(60%), 지지:편관(30%), 지지:식신(10%)
# 일주: 지지:겁재(70%), 지지:상관(30%)
# 시주: 천간:정관, 지지:식신(30%), 지지:편재(10%)
#
# === 대운 (정밀 계산) ===
# 6세: 기유 (2003년 ~ 2012년)
# 16세: 경술 (2013년 ~ 2022년)
# 26세: 신해 (2023년 ~ 2032년)
# 36세: 임자 (2033년 ~ 2042년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1997년 9월 1일 오전 11시 30분에 태어난 여성분의 사주를 분석해보면 다음과 같습니다.
#
# - 사주 구성: 년주 정축, 월주 무신, 일주 병오, 시주 계사
# - 오행 강약: 화가 가장 강하고, 토, 수, 금 순이며 목은 부족한 편입니다.
# - 십신 분석: 겁재, 상관, 정관, 편재, 식신 등 다양한 십신이 조화를 이루고 있습니다.
# - 대운 흐름:
#   - 6세부터 16세까지 기유 대운
#   - 16세부터 26세까지 경술 대운
#   - 26세부터 36세까지 신해 대운 (현재 이 대운에 해당)
#   - 36세부터 46세까지 임자 대운 예정
#
# 현재 26세부터 시작된 신해 대운이 진행 중이며, 이 시기는 새로운 기회와 변화를 맞이할 수 있는 시기입니다. 화의 기운이 강하므로 열정과 추진력이 뛰어나며, 목이 부족해 균형을 맞추기 위해서는 목의 기운을 보완하는 노력이 필요합니다.
#
# 더 구체적인 운세나 조언이 필요하시면 알려주세요.
# ==================================================
# 🔄 Node: ManseTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1997년 9월 1일 오전 11시 30분에 태어난 여성분의 사주를 분석해보면 다음과 같습니다.
#
# - 사주 구성: 년주 정축, 월주 무신, 일주 병오, 시주 계사
# - 오행 강약: 화가 가장 강하고, 토, 수, 금 순이며 목은 부족한 편입니다.
# - 십신 분석: 겁재, 상관, 정관, 편재, 식신 등 다양한 십신이 조화를 이루고 있습니다.
# - 대운 흐름:
#   - 6세부터 16세까지 기유 대운
#   - 16세부터 26세까지 경술 대운
#   - 26세부터 36세까지 신해 대운 (현재 이 대운에 해당)
#   - 36세부터 46세까지 임자 대운 예정
#
# 현재 26세부터 시작된 신해 대운이 진행 중이며, 이 시기는 새로운 기회와 변화를 맞이할 수 있는 시기입니다. 화의 기운이 강하므로 열정과 추진력이 뛰어나며, 목이 부족해 균형을 맞추기 위해서는 목의 기운을 보완하는 노력이 필요합니다.
#
# 더 구체적인 운세나 조언이 필요하시면 알려주세요.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.Error: ConnectionError('Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download')
#  Please fix your mistakes.
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구성 (천간지지 변환)
#
# - 출생일: 1997년 9월 1일, 오전 11시 30분 (양력 기준)
# - 성별: 여자
# - 출생시간: 11시 30분은 지지로는 午시(11시~13시)에 해당합니다.
#
# ### 천간지지 변환
#
# - 연주(년간/년지): 1997년은 丁丑년 (정축년)
#   - 연간: 丁 (화)
#   - 연지: 丑 (토)
# - 월주(월간/월지): 9월은 음력 7월 또는 8월에 해당할 수 있으나, 양력 9월 1일은 음력 7월 중순경입니다. 음력 7월은 대체로 무신월(戊申月)입니다.
#   - 월간: 戊 (토)
#   - 월지: 申 (금)
# - 일주(일간/일지): 1997년 9월 1일 양력의 일간과 일지는 병오(丙午)입니다.
#   - 일간: 丙 (화)
#   - 일지: 午 (화)
# - 시주(시간간/시간지): 11시 30분은 午시(11시~13시)이며, 시간은 계(癸)로 추정됩니다.
#   - 시간간: 癸 (수)
#   - 시간지: 巳 (화)
#
# **최종 사주 8자:**
#
# | 구분 | 천간 | 지지 |
# |-------|-------|-------|
# | 연주  | 丁     | 丑     |
# | 월주  | 戊     | 申     |
# | 일주  | 丙     | 午     |
# | 시주  | 癸     | 巳     |
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 1) 천간지지 → 오행 매핑
#
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 2) 8자 오행 분포
#
# | 글자 | 오행 |
# |-------|-------|
# | 丁     | 화    |
# | 丑     | 토    |
# | 戊     | 토    |
# | 申     | 금    |
# | 丙     | 화    |
# | 午     | 화    |
# | 癸     | 수    |
# | 巳     | 화    |
#
# ### 3) 오행 점수 계산
#
# - 화(火): 丁, 丙, 午, 巳 → 4점
# - 토(土): 丑, 戊 → 2점
# - 금(金): 申 → 1점
# - 수(水): 癸 → 1점
# - 목(木): 없음 → 0점
#
# ### 4) 오행 분포 표
#
# | 오행 | 점수 | 해당 글자          |
# |-------|-------|-------------------|
# | 목(木) | 0     |                   |
# | 화(火) | 4     | 丁, 丙, 午, 巳     |
# | 토(土) | 2     | 丑, 戊             |
# | 금(金) | 1     | 申                 |
# | 수(水) | 1     | 癸                 |
#
# **총합: 8점 (계산 유효)**
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 해석 및 균형
#
# - 화(火)가 매우 강한 사주입니다 (4점).
# - 토(土)가 그 다음으로 강하며, 금(金)과 수(水)는 약간 있습니다.
# - 목(木)은 전혀 없어서 부족한 상태입니다.
#
# ### 해석
#
# - 화가 강하면 열정적이고 활발하며 추진력이 강한 성격입니다.
# - 토는 안정과 신뢰를 주며 현실적이고 책임감이 강합니다.
# - 금과 수는 약간 있어 지혜와 융통성, 감성도 일부 갖추고 있습니다.
# - 목이 부족하면 성장과 발전, 융통성, 부드러움이 부족할 수 있으니 보완이 필요합니다.
#
# ### 상생상극 관계
#
# - 화는 토를 생하고, 토는 금을 생하며, 금은 수를 생하고, 수는 목을 생하며, 목은 화를 생합니다.
# - 현재 목이 부족하므로 수의 기운을 보완해 목을 키우는 것이 좋습니다.
# - 화가 너무 강하면 과열되거나 성급할 수 있으니 토와 수의 균형을 맞추는 것이 중요합니다.
#
# ### 보완 제안 (일반적 조언)
#
# - 목의 기운을 보완하기 위해 녹색 계열의 옷이나 자연과의 접촉을 늘리세요.
# - 목과 수를 돕는 음식(채소, 해조류 등)을 섭취하면 좋습니다.
# - 스트레스 해소와 마음의 안정에 신경 쓰세요.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 丙 기준)
#
# - 일간 丙(화) 기준으로 다른 천간과 지지와의 관계를 분석합니다.
#
# | 위치 | 글자 | 십신 관계 (일간 丙 기준) |
# |-------|-------|-------------------------|
# | 연간  | 丁     | 비견 (같은 화)           |
# | 연지  | 丑     | 편재 (토, 일간 화를 극함) |
# | 월간  | 戊     | 편재 (토, 일간 화를 극함) |
# | 월지  | 申     | 편관 (금, 화를 극함)      |
# | 일지  | 午     | 일지 (본인)               |
# | 시간  | 癸     | 편인 (수, 화를 생함)      |
# | 시지  | 巳     | 식신 (화, 일간과 같은 오행) |
#
# - 비견(丁)은 자신과 비슷한 성향, 경쟁과 협력의 관계
# - 편재(丑, 戊)는 재물과 재능, 다소 경쟁적이고 적극적인 재물운
# - 편관(申)은 권위와 규율, 직장과 사회적 위치를 의미
# - 편인(癸)은 지혜와 보호, 학문과 정신적 지원
# - 식신(巳)은 창의력과 표현력, 재능 발휘
#
# ### 해석
#
# - 경쟁심과 추진력이 강하며, 재물과 직업에 대한 욕심과 능력이 있습니다.
# - 권위와 규율을 중시하며 사회적 위치를 중요하게 생각합니다.
# - 창의력과 표현력이 뛰어나며, 정신적 지지와 학문적 능력도 갖추고 있습니다.
#
# ---
#
# ## 5. 대운(大運) 흐름 (예상)
#
# - 출생 연도 기준으로 대운은 보통 8세 전후부터 시작합니다.
# - 여성은 음력 생월 기준으로 대운을 역행합니다.
#
# ### 대운 예시 (대략)
#
# | 나이 | 대운  | 오행 및 해석                      |
# |-------|--------|---------------------------------|
# | 0~8   | (태어난 해부터)                  |
# | 8~18  | 기유(己酉) 토-금, 금의 기운 보강  |
# | 18~28 | 경술(庚戌) 금-토, 금의 기운 강화  |
# | 28~38 | 신해(辛亥) 금-수, 수의 기운 보강  |
# | 38~48 | 임자(壬子) 수-수, 수의 기운 강화  |
#
# - 현재 2024년 기준으로 27세이므로 신해 대운에 해당합니다.
# - 신해 대운은 금과 수의 기운이 강해 목 부족을 보완하는 좋은 시기입니다.
#
# ---
#
# ## 6. 종합 해석 및 조언
#
# - 화가 강한 성격으로 열정적이고 추진력이 뛰어나며, 리더십과 창의력이 뛰어납니다.
# - 목이 부족해 융통성과 부드러움, 성장력이 약할 수 있으니 자연과의 접촉, 녹색 계열 활용, 목 기운 보완에 신경 쓰세요.
# - 재물과 직업운이 좋으며, 권위와 사회적 위치를 중시하는 경향이 있습니다.
# - 현재 대운이 목 부족을 보완하는 시기이므로 좋은 기회와 변화를 맞이할 수 있습니다.
# - 스트레스 관리와 균형 잡힌 생활이 중요합니다.
#
# ---
#
# 필요하시면 대운과 세운(연운) 분석도 추가로 상세히 안내해 드리겠습니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행 분석 기준에 따름.
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구성 (천간지지 변환)
#
# - 출생일: 1997년 9월 1일, 오전 11시 30분 (양력 기준)
# - 성별: 여자
# - 출생시간: 11시 30분은 지지로는 午시(11시~13시)에 해당합니다.
#
# ### 천간지지 변환
#
# - 연주(년간/년지): 1997년은 丁丑년 (정축년)
#   - 연간: 丁 (화)
#   - 연지: 丑 (토)
# - 월주(월간/월지): 9월은 음력 7월 또는 8월에 해당할 수 있으나, 양력 9월 1일은 음력 7월 중순경입니다. 음력 7월은 대체로 무신월(戊申月)입니다.
#   - 월간: 戊 (토)
#   - 월지: 申 (금)
# - 일주(일간/일지): 1997년 9월 1일 양력의 일간과 일지는 병오(丙午)입니다.
#   - 일간: 丙 (화)
#   - 일지: 午 (화)
# - 시주(시간간/시간지): 11시 30분은 午시(11시~13시)이며, 시간은 계(癸)로 추정됩니다.
#   - 시간간: 癸 (수)
#   - 시간지: 巳 (화)
#
# **최종 사주 8자:**
#
# | 구분 | 천간 | 지지 |
# |-------|-------|-------|
# | 연주  | 丁     | 丑     |
# | 월주  | 戊     | 申     |
# | 일주  | 丙     | 午     |
# | 시주  | 癸     | 巳     |
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 1) 천간지지 → 오행 매핑
#
# - 목(木): 甲, 乙, 寅, 卯
# - 화(火): 丙, 丁, 巳, 午
# - 토(土): 戊, 己, 辰, 戌, 丑, 未
# - 금(金): 庚, 辛, 申, 酉
# - 수(水): 壬, 癸, 子, 亥
#
# ### 2) 8자 오행 분포
#
# | 글자 | 오행 |
# |-------|-------|
# | 丁     | 화    |
# | 丑     | 토    |
# | 戊     | 토    |
# | 申     | 금    |
# | 丙     | 화    |
# | 午     | 화    |
# | 癸     | 수    |
# | 巳     | 화    |
#
# ### 3) 오행 점수 계산
#
# - 화(火): 丁, 丙, 午, 巳 → 4점
# - 토(土): 丑, 戊 → 2점
# - 금(金): 申 → 1점
# - 수(水): 癸 → 1점
# - 목(木): 없음 → 0점
#
# ### 4) 오행 분포 표
#
# | 오행 | 점수 | 해당 글자          |
# |-------|-------|-------------------|
# | 목(木) | 0     |                   |
# | 화(火) | 4     | 丁, 丙, 午, 巳     |
# | 토(土) | 2     | 丑, 戊             |
# | 금(金) | 1     | 申                 |
# | 수(水) | 1     | 癸                 |
#
# **총합: 8점 (계산 유효)**
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 해석 및 균형
#
# - 화(火)가 매우 강한 사주입니다 (4점).
# - 토(土)가 그 다음으로 강하며, 금(金)과 수(水)는 약간 있습니다.
# - 목(木)은 전혀 없어서 부족한 상태입니다.
#
# ### 해석
#
# - 화가 강하면 열정적이고 활발하며 추진력이 강한 성격입니다.
# - 토는 안정과 신뢰를 주며 현실적이고 책임감이 강합니다.
# - 금과 수는 약간 있어 지혜와 융통성, 감성도 일부 갖추고 있습니다.
# - 목이 부족하면 성장과 발전, 융통성, 부드러움이 부족할 수 있으니 보완이 필요합니다.
#
# ### 상생상극 관계
#
# - 화는 토를 생하고, 토는 금을 생하며, 금은 수를 생하고, 수는 목을 생하며, 목은 화를 생합니다.
# - 현재 목이 부족하므로 수의 기운을 보완해 목을 키우는 것이 좋습니다.
# - 화가 너무 강하면 과열되거나 성급할 수 있으니 토와 수의 균형을 맞추는 것이 중요합니다.
#
# ### 보완 제안 (일반적 조언)
#
# - 목의 기운을 보완하기 위해 녹색 계열의 옷이나 자연과의 접촉을 늘리세요.
# - 목과 수를 돕는 음식(채소, 해조류 등)을 섭취하면 좋습니다.
# - 스트레스 해소와 마음의 안정에 신경 쓰세요.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 丙 기준)
#
# - 일간 丙(화) 기준으로 다른 천간과 지지와의 관계를 분석합니다.
#
# | 위치 | 글자 | 십신 관계 (일간 丙 기준) |
# |-------|-------|-------------------------|
# | 연간  | 丁     | 비견 (같은 화)           |
# | 연지  | 丑     | 편재 (토, 일간 화를 극함) |
# | 월간  | 戊     | 편재 (토, 일간 화를 극함) |
# | 월지  | 申     | 편관 (금, 화를 극함)      |
# | 일지  | 午     | 일지 (본인)               |
# | 시간  | 癸     | 편인 (수, 화를 생함)      |
# | 시지  | 巳     | 식신 (화, 일간과 같은 오행) |
#
# - 비견(丁)은 자신과 비슷한 성향, 경쟁과 협력의 관계
# - 편재(丑, 戊)는 재물과 재능, 다소 경쟁적이고 적극적인 재물운
# - 편관(申)은 권위와 규율, 직장과 사회적 위치를 의미
# - 편인(癸)은 지혜와 보호, 학문과 정신적 지원
# - 식신(巳)은 창의력과 표현력, 재능 발휘
#
# ### 해석
#
# - 경쟁심과 추진력이 강하며, 재물과 직업에 대한 욕심과 능력이 있습니다.
# - 권위와 규율을 중시하며 사회적 위치를 중요하게 생각합니다.
# - 창의력과 표현력이 뛰어나며, 정신적 지지와 학문적 능력도 갖추고 있습니다.
#
# ---
#
# ## 5. 대운(大運) 흐름 (예상)
#
# - 출생 연도 기준으로 대운은 보통 8세 전후부터 시작합니다.
# - 여성은 음력 생월 기준으로 대운을 역행합니다.
#
# ### 대운 예시 (대략)
#
# | 나이 | 대운  | 오행 및 해석                      |
# |-------|--------|---------------------------------|
# | 0~8   | (태어난 해부터)                  |
# | 8~18  | 기유(己酉) 토-금, 금의 기운 보강  |
# | 18~28 | 경술(庚戌) 금-토, 금의 기운 강화  |
# | 28~38 | 신해(辛亥) 금-수, 수의 기운 보강  |
# | 38~48 | 임자(壬子) 수-수, 수의 기운 강화  |
#
# - 현재 2024년 기준으로 27세이므로 신해 대운에 해당합니다.
# - 신해 대운은 금과 수의 기운이 강해 목 부족을 보완하는 좋은 시기입니다.
#
# ---
#
# ## 6. 종합 해석 및 조언
#
# - 화가 강한 성격으로 열정적이고 추진력이 뛰어나며, 리더십과 창의력이 뛰어납니다.
# - 목이 부족해 융통성과 부드러움, 성장력이 약할 수 있으니 자연과의 접촉, 녹색 계열 활용, 목 기운 보완에 신경 쓰세요.
# - 재물과 직업운이 좋으며, 권위와 사회적 위치를 중시하는 경향이 있습니다.
# - 현재 대운이 목 부족을 보완하는 시기이므로 좋은 기회와 변화를 맞이할 수 있습니다.
# - 스트레스 관리와 균형 잡힌 생활이 중요합니다.
#
# ---
#
# 필요하시면 대운과 세운(연운) 분석도 추가로 상세히 안내해 드리겠습니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행 분석 기준에 따름.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="대운과 세운, 조심해야 할것들 알려줘"
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide insights on the major luck cycles (Da Yun) and annual luck cycles (Se Yun) in my Four Pillars of Destiny (Ba Zi) chart? Additionally, I would like to know what specific areas I should be cautious about during these cycles, based on my birth chart analysis.대운과 세운, 조심해야 할것들 알려줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 대운과 세운, 그리고 주의사항에 대해 상세히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 대운 시작 나이 및 방향
#
# - 출생 월(음력 7월, 무신월) 기준으로 여성은 대운을 역행(뒤로) 시작합니다.
# - 대운 시작 나이는 보통 8세 전후이며, 정확한 시작 시점은 음력 생월과 생일에 따라 다르지만 대략 7~8세부터 시작한다고 봅니다.
#
# ### 대운 목록 및 해석
#
# | 나이 구간 | 대운  | 천간지지 | 오행 구성 | 해석 및 특징                          |
# |-----------|--------|----------|-----------|-------------------------------------|
# | 0~8       | -      | -        | -         | 출생부터 대운 시작 전, 성장기        |
# | 8~18      | 기유(己酉) | 己(土), 酉(金) | 토, 금    | 토와 금의 기운 강화, 안정과 규율 중시  |
# | 18~28     | 경술(庚戌) | 庚(金), 戌(土) | 금, 토    | 금과 토의 기운 지속 강화, 직장운과 권위 상승 |
# | 28~38     | 신해(辛亥) | 辛(金), 亥(水) | 금, 수    | 금과 수의 기운 강화, 지혜와 융통성 증가, 목 부족 보완 |
# | 38~48     | 임자(壬子) | 壬(水), 子(水) | 수        | 수의 기운 강해짐, 감성 및 정신적 안정, 목 기운 보완 지속 |
#
# - 현재 2024년 기준으로 27세이므로 **신해 대운(28~38세)**에 해당합니다.
# - 신해 대운은 금과 수의 기운이 강해 목 부족을 보완하고, 지혜와 융통성을 키우는 좋은 시기입니다.
# - 이 시기에 새로운 기회와 변화를 맞이할 수 있으며, 특히 학문, 직업, 인간관계에서 긍정적인 발전이 기대됩니다.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2023~2025년)
#
# | 연도 | 세운  | 천간지지 | 오행 구성 | 해석 및 주의사항                      |
# |-------|--------|----------|-----------|-------------------------------------|
# | 2023  | 계묘(癸卯) | 癸(水), 卯(木) | 수, 목    | 부족한 목 기운 보완, 성장과 발전 기회, 건강 주의 (간, 신장) |
# | 2024  | 갑진(甲辰) | 甲(木), 辰(土) | 목, 토    | 목과 토의 조화, 새로운 시작과 안정, 과로 주의 |
# | 2025  | 을사(乙巳) | 乙(木), 巳(火) | 목, 화    | 목과 화의 상승, 열정과 추진력 증가, 감정 조절 필요 |
#
# - 2023년부터 2025년까지는 부족한 목 기운이 보완되는 시기로, 성장과 발전에 유리합니다.
# - 특히 2024년 갑진년은 목과 토가 조화를 이루어 새로운 시작과 안정에 좋은 해입니다.
# - 2025년 을사년은 화의 기운이 강해져 열정이 넘치지만, 감정 조절과 건강 관리에 주의가 필요합니다.
#
# ---
#
# ## 3. 주의해야 할 점 및 조언
#
# ### 1) 건강 관련 주의
#
# - 화가 강하고 목이 부족한 사주이므로, 간과 신장 건강에 신경 써야 합니다.
# - 스트레스가 쌓이면 화가 과도해져 소화기 계통이나 심장에 무리가 올 수 있으니 규칙적인 운동과 휴식이 필요합니다.
#
# ### 2) 성격 및 대인관계
#
# - 화가 강해 성격이 급하고 열정적이지만, 목이 부족해 융통성과 부드러움이 부족할 수 있습니다.
# - 대인관계에서 다소 직설적이거나 고집이 셀 수 있으니 상대방의 입장을 배려하는 노력이 필요합니다.
#
# ### 3) 운세 흐름에 따른 조심사항
#
# - 대운과 세운에서 금과 수가 강화되는 시기에는 감정 기복이나 건강 문제에 주의하세요.
# - 특히 2025년 을사년은 화의 기운이 강해져 감정 조절이 어려울 수 있으니 명상, 요가 등 마음을 다스리는 활동을 권장합니다.
#
# ### 4) 오행 보완 방법
#
# - 목 기운 보완을 위해 녹색 계열의 옷차림, 자연과의 접촉, 채소와 해조류 섭취를 권장합니다.
# - 수 기운을 돕는 검은색, 파란색 계열도 좋으며, 물과 관련된 활동(수영, 산책 등)을 늘리면 좋습니다.
#
# ---
#
# ## 4. 종합 요약
#
# - 현재 신해 대운으로 금과 수의 기운이 강화되어 목 부족을 보완하는 좋은 시기입니다.
# - 2023~2025년 세운 역시 목 기운이 보완되어 성장과 발전에 유리합니다.
# - 건강과 감정 조절에 주의하며, 특히 간과 신장 건강을 챙기세요.
# - 대인관계에서 부드러움과 융통성을 키우는 노력이 필요합니다.
# - 오행 보완을 위한 생활습관 개선과 자연 친화적 활동을 권장합니다.
#
# ---
#
# 필요하시면 더 상세한 대운별 운세 변화나 특정 시기별 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행 분석 기준에 따름.
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 대운과 세운, 그리고 주의사항에 대해 상세히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 대운 시작 나이 및 방향
#
# - 출생 월(음력 7월, 무신월) 기준으로 여성은 대운을 역행(뒤로) 시작합니다.
# - 대운 시작 나이는 보통 8세 전후이며, 정확한 시작 시점은 음력 생월과 생일에 따라 다르지만 대략 7~8세부터 시작한다고 봅니다.
#
# ### 대운 목록 및 해석
#
# | 나이 구간 | 대운  | 천간지지 | 오행 구성 | 해석 및 특징                          |
# |-----------|--------|----------|-----------|-------------------------------------|
# | 0~8       | -      | -        | -         | 출생부터 대운 시작 전, 성장기        |
# | 8~18      | 기유(己酉) | 己(土), 酉(金) | 토, 금    | 토와 금의 기운 강화, 안정과 규율 중시  |
# | 18~28     | 경술(庚戌) | 庚(金), 戌(土) | 금, 토    | 금과 토의 기운 지속 강화, 직장운과 권위 상승 |
# | 28~38     | 신해(辛亥) | 辛(金), 亥(水) | 금, 수    | 금과 수의 기운 강화, 지혜와 융통성 증가, 목 부족 보완 |
# | 38~48     | 임자(壬子) | 壬(水), 子(水) | 수        | 수의 기운 강해짐, 감성 및 정신적 안정, 목 기운 보완 지속 |
#
# - 현재 2024년 기준으로 27세이므로 **신해 대운(28~38세)**에 해당합니다.
# - 신해 대운은 금과 수의 기운이 강해 목 부족을 보완하고, 지혜와 융통성을 키우는 좋은 시기입니다.
# - 이 시기에 새로운 기회와 변화를 맞이할 수 있으며, 특히 학문, 직업, 인간관계에서 긍정적인 발전이 기대됩니다.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2023~2025년)
#
# | 연도 | 세운  | 천간지지 | 오행 구성 | 해석 및 주의사항                      |
# |-------|--------|----------|-----------|-------------------------------------|
# | 2023  | 계묘(癸卯) | 癸(水), 卯(木) | 수, 목    | 부족한 목 기운 보완, 성장과 발전 기회, 건강 주의 (간, 신장) |
# | 2024  | 갑진(甲辰) | 甲(木), 辰(土) | 목, 토    | 목과 토의 조화, 새로운 시작과 안정, 과로 주의 |
# | 2025  | 을사(乙巳) | 乙(木), 巳(火) | 목, 화    | 목과 화의 상승, 열정과 추진력 증가, 감정 조절 필요 |
#
# - 2023년부터 2025년까지는 부족한 목 기운이 보완되는 시기로, 성장과 발전에 유리합니다.
# - 특히 2024년 갑진년은 목과 토가 조화를 이루어 새로운 시작과 안정에 좋은 해입니다.
# - 2025년 을사년은 화의 기운이 강해져 열정이 넘치지만, 감정 조절과 건강 관리에 주의가 필요합니다.
#
# ---
#
# ## 3. 주의해야 할 점 및 조언
#
# ### 1) 건강 관련 주의
#
# - 화가 강하고 목이 부족한 사주이므로, 간과 신장 건강에 신경 써야 합니다.
# - 스트레스가 쌓이면 화가 과도해져 소화기 계통이나 심장에 무리가 올 수 있으니 규칙적인 운동과 휴식이 필요합니다.
#
# ### 2) 성격 및 대인관계
#
# - 화가 강해 성격이 급하고 열정적이지만, 목이 부족해 융통성과 부드러움이 부족할 수 있습니다.
# - 대인관계에서 다소 직설적이거나 고집이 셀 수 있으니 상대방의 입장을 배려하는 노력이 필요합니다.
#
# ### 3) 운세 흐름에 따른 조심사항
#
# - 대운과 세운에서 금과 수가 강화되는 시기에는 감정 기복이나 건강 문제에 주의하세요.
# - 특히 2025년 을사년은 화의 기운이 강해져 감정 조절이 어려울 수 있으니 명상, 요가 등 마음을 다스리는 활동을 권장합니다.
#
# ### 4) 오행 보완 방법
#
# - 목 기운 보완을 위해 녹색 계열의 옷차림, 자연과의 접촉, 채소와 해조류 섭취를 권장합니다.
# - 수 기운을 돕는 검은색, 파란색 계열도 좋으며, 물과 관련된 활동(수영, 산책 등)을 늘리면 좋습니다.
#
# ---
#
# ## 4. 종합 요약
#
# - 현재 신해 대운으로 금과 수의 기운이 강화되어 목 부족을 보완하는 좋은 시기입니다.
# - 2023~2025년 세운 역시 목 기운이 보완되어 성장과 발전에 유리합니다.
# - 건강과 감정 조절에 주의하며, 특히 간과 신장 건강을 챙기세요.
# - 대인관계에서 부드러움과 융통성을 키우는 노력이 필요합니다.
# - 오행 보완을 위한 생활습관 개선과 자연 친화적 활동을 권장합니다.
#
# ---
#
# 필요하시면 더 상세한 대운별 운세 변화나 특정 시기별 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행 분석 기준에 따름.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 3})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="금전운알려줘"
            
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide an analysis of my financial luck based on my Four Pillars of Destiny (Ba Zi)? I am particularly interested in understanding how my birth chart influences my financial opportunities and challenges.금전운알려줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 금전운에 대해 사주 원리와 오행, 십신 분석을 바탕으로 상세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구성 및 오행 요약
#
# | 구분 | 천간 | 지지 | 오행 |
# |-------|-------|-------|-------|
# | 연주  | 丁     | 丑     | 화, 토 |
# | 월주  | 戊     | 申     | 토, 금 |
# | 일주  | 丙     | 午     | 화, 화 |
# | 시주  | 癸     | 巳     | 수, 화 |
#
# - 화(火) 4점, 토(土) 2점, 금(金) 1점, 수(水) 1점, 목(木) 0점
# - 화가 매우 강하고, 토가 그 다음이며 금과 수는 약간, 목은 부족한 상태입니다.
#
# ---
#
# ## 2. 금전운과 관련된 십신 및 오행 해석
#
# ### 1) 금전운을 나타내는 십신
#
# - 금전운은 일간(일주 천간 丙火) 기준으로 재성(財星)과 편재(偏財), 정재(正財)로 판단합니다.
# - 火(일간 丙) 기준으로:
#   - 재성(正財): 토(土) → 戊, 己, 丑, 辰, 戌, 未
#   - 편재(偏財): 토(土) → 같은 토지만 재성과 구분됨
# - 본 사주에서 토(土)는 연지 丑, 월간 戊가 있어 재성(재물) 기운이 존재합니다.
# - 또한 월지 申(金)은 금(金)으로, 금은 화(火)를 극하는 오행으로 재물과 관련된 권위, 직업운과도 연결됩니다.
#
# ### 2) 재물운 강약
#
# - 토(土)가 2점으로 재성 기운이 적당히 있으나, 화(火)가 너무 강해 재성을 많이 극할 수 있습니다.
# - 금(金)은 1점으로 재물과 직업운에 도움을 주는 요소이나, 전체적으로 금이 약한 편입니다.
# - 수(水) 1점은 재물운에 간접적으로 도움을 줄 수 있으나, 목(木)이 전혀 없어 재물의 성장과 확장에 다소 제약이 있을 수 있습니다.
#
# ---
#
# ## 3. 대운과 금전운의 관계
#
# - 현재 대운은 신해(辛亥) 대운(28~38세)으로 금(金)과 수(水)의 기운이 강화되는 시기입니다.
# - 금과 수가 강화되면 재물운이 보완되고, 목 부족을 어느 정도 보완하여 재물의 확장과 관리에 유리합니다.
# - 특히 금의 기운이 강해지면 직업적 안정과 권위가 상승하여 금전적 기회가 늘어납니다.
#
# ---
#
# ## 4. 세운과 금전운
#
# - 2023년 계묘(癸卯), 2024년 갑진(甲辰), 2025년 을사(乙巳) 세운 모두 목(木)과 수(水), 화(火)의 기운이 보완되어 재물운에 긍정적입니다.
# - 특히 2024년 갑진년은 목과 토의 조화로 새로운 재물 기회와 안정이 기대됩니다.
# - 2025년 을사년은 화의 기운이 강해져 추진력과 열정이 증가하지만, 감정 조절이 필요하므로 재물 관리에 신중함이 요구됩니다.
#
# ---
#
# ## 5. 금전운 종합 해석 및 조언
#
# - 재성(土) 기운이 있으나 화(火)가 강해 재물을 다소 극하는 경향이 있으므로 재물 관리에 신중함이 필요합니다.
# - 현재 대운과 세운에서 금과 수가 강화되어 금전운이 점차 좋아지는 시기입니다.
# - 목(木) 부족으로 인해 재물의 성장과 확장에 한계가 있을 수 있으니, 목 기운을 보완하는 생활습관(녹색 계열 옷, 자연과의 접촉 등)을 권장합니다.
# - 재물운을 높이기 위해서는 계획적이고 체계적인 재물 관리가 중요하며, 감정에 치우치지 않는 냉철한 판단력이 필요합니다.
# - 투자나 재테크 시에는 신중한 분석과 전문가 조언을 참고하는 것이 좋습니다.
#
# ---
#
# 필요하시면 구체적인 시기별 금전운 변화나 투자 적기 등도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행, 십신 분석 기준에 따름.
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1997년 9월 1일 오전 11시 30분 출생 여성분의 금전운에 대해 사주 원리와 오행, 십신 분석을 바탕으로 상세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구성 및 오행 요약
#
# | 구분 | 천간 | 지지 | 오행 |
# |-------|-------|-------|-------|
# | 연주  | 丁     | 丑     | 화, 토 |
# | 월주  | 戊     | 申     | 토, 금 |
# | 일주  | 丙     | 午     | 화, 화 |
# | 시주  | 癸     | 巳     | 수, 화 |
#
# - 화(火) 4점, 토(土) 2점, 금(金) 1점, 수(水) 1점, 목(木) 0점
# - 화가 매우 강하고, 토가 그 다음이며 금과 수는 약간, 목은 부족한 상태입니다.
#
# ---
#
# ## 2. 금전운과 관련된 십신 및 오행 해석
#
# ### 1) 금전운을 나타내는 십신
#
# - 금전운은 일간(일주 천간 丙火) 기준으로 재성(財星)과 편재(偏財), 정재(正財)로 판단합니다.
# - 火(일간 丙) 기준으로:
#   - 재성(正財): 토(土) → 戊, 己, 丑, 辰, 戌, 未
#   - 편재(偏財): 토(土) → 같은 토지만 재성과 구분됨
# - 본 사주에서 토(土)는 연지 丑, 월간 戊가 있어 재성(재물) 기운이 존재합니다.
# - 또한 월지 申(金)은 금(金)으로, 금은 화(火)를 극하는 오행으로 재물과 관련된 권위, 직업운과도 연결됩니다.
#
# ### 2) 재물운 강약
#
# - 토(土)가 2점으로 재성 기운이 적당히 있으나, 화(火)가 너무 강해 재성을 많이 극할 수 있습니다.
# - 금(金)은 1점으로 재물과 직업운에 도움을 주는 요소이나, 전체적으로 금이 약한 편입니다.
# - 수(水) 1점은 재물운에 간접적으로 도움을 줄 수 있으나, 목(木)이 전혀 없어 재물의 성장과 확장에 다소 제약이 있을 수 있습니다.
#
# ---
#
# ## 3. 대운과 금전운의 관계
#
# - 현재 대운은 신해(辛亥) 대운(28~38세)으로 금(金)과 수(水)의 기운이 강화되는 시기입니다.
# - 금과 수가 강화되면 재물운이 보완되고, 목 부족을 어느 정도 보완하여 재물의 확장과 관리에 유리합니다.
# - 특히 금의 기운이 강해지면 직업적 안정과 권위가 상승하여 금전적 기회가 늘어납니다.
#
# ---
#
# ## 4. 세운과 금전운
#
# - 2023년 계묘(癸卯), 2024년 갑진(甲辰), 2025년 을사(乙巳) 세운 모두 목(木)과 수(水), 화(火)의 기운이 보완되어 재물운에 긍정적입니다.
# - 특히 2024년 갑진년은 목과 토의 조화로 새로운 재물 기회와 안정이 기대됩니다.
# - 2025년 을사년은 화의 기운이 강해져 추진력과 열정이 증가하지만, 감정 조절이 필요하므로 재물 관리에 신중함이 요구됩니다.
#
# ---
#
# ## 5. 금전운 종합 해석 및 조언
#
# - 재성(土) 기운이 있으나 화(火)가 강해 재물을 다소 극하는 경향이 있으므로 재물 관리에 신중함이 필요합니다.
# - 현재 대운과 세운에서 금과 수가 강화되어 금전운이 점차 좋아지는 시기입니다.
# - 목(木) 부족으로 인해 재물의 성장과 확장에 한계가 있을 수 있으니, 목 기운을 보완하는 생활습관(녹색 계열 옷, 자연과의 접촉 등)을 권장합니다.
# - 재물운을 높이기 위해서는 계획적이고 체계적인 재물 관리가 중요하며, 감정에 치우치지 않는 냉철한 판단력이 필요합니다.
# - 투자나 재테크 시에는 신중한 분석과 전문가 조언을 참고하는 것이 좋습니다.
#
# ---
#
# 필요하시면 구체적인 시기별 금전운 변화나 투자 적기 등도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 전통 원리 및 오행, 십신 분석 기준에 따름.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 1})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="1995년 3월 28일 남자, 12시 30분 출생 운세봐줘"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide a fortune reading for a male born on March 28, 1995, at 12:30 PM? I am interested in a detailed analysis of his Four Pillars of Destiny (Ba Zi) and how they may influence his personality, career prospects, and overall life path. Please include insights based on his birth chart analysis and any significant elements or interactions present in his chart.1995년 3월 28일 남자, 12시 30분 출생 운세봐줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# === 사주팔자 ===
# 년주(年柱): 을해
# 월주(月柱): 기묘
# 일주(日柱): 무오
# 시주(時柱): 무오
# 일간(日干): 무
#
# === 오행 강약 ===
# 목: 39점
# 화: 20점
# 토: 68점
# 금: 0점
# 수: 10점
#
# === 십신 분석 ===
# 년주: 천간:정관, 지지:편재(70%), 지지:편관(30%)
# 월주: 천간:겁재, 지지:정관(100%)
# 일주: 지지:정인(70%), 지지:겁재(30%)
# 시주: 지지:정인(70%), 지지:겁재(30%)
#
# === 대운 (정밀 계산) ===
# 5세: 무인 (2000년 ~ 2009년)
# 15세: 정축 (2010년 ~ 2019년)
# 25세: 병자 (2020년 ~ 2029년)
# 35세: 을해 (2030년 ~ 2039년)
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주: 을해
# - 월주: 기묘
# - 일주: 무오
# - 시주: 무오
# - 일간: 무
#
# 오행 강약은 토가 가장 강하고, 목과 화가 그 다음이며 금은 부족한 편입니다.
#
# 십신 분석에서는 정관, 편재, 편관, 겁재, 정인이 혼재되어 있어 다양한 성격과 운의 흐름을 나타냅니다.
#
# 대운은 현재 25세부터 2029년까지 병자 대운이 진행 중이며, 이후 35세부터 을해 대운이 시작됩니다.
#
# 이 사주는 토의 기운이 강해 안정적이고 현실적인 성향이 강하며, 목과 화의 기운이 있어 창의력과 활동성도 겸비되어 있습니다. 금의 기운이 부족하므로 금과 관련된 분야나 성격은 보완이 필요할 수 있습니다.
#
# 대운의 흐름에 따라 20대 후반부터 30대 초반까지는 중요한 변화와 성장이 예상되니 이 시기를 잘 활용하는 것이 좋겠습니다.
# ==================================================
# 🔄 Node: ManseTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 1995년 3월 28일 12시 30분 출생 남성의 사주팔자를 분석해보면 다음과 같습니다.
#
# - 년주: 을해
# - 월주: 기묘
# - 일주: 무오
# - 시주: 무오
# - 일간: 무
#
# 오행 강약은 토가 가장 강하고, 목과 화가 그 다음이며 금은 부족한 편입니다.
#
# 십신 분석에서는 정관, 편재, 편관, 겁재, 정인이 혼재되어 있어 다양한 성격과 운의 흐름을 나타냅니다.
#
# 대운은 현재 25세부터 2029년까지 병자 대운이 진행 중이며, 이후 35세부터 을해 대운이 시작됩니다.
#
# 이 사주는 토의 기운이 강해 안정적이고 현실적인 성향이 강하며, 목과 화의 기운이 있어 창의력과 활동성도 겸비되어 있습니다. 금의 기운이 부족하므로 금과 관련된 분야나 성격은 보완이 필요할 수 있습니다.
#
# 대운의 흐름에 따라 20대 후반부터 30대 초반까지는 중요한 변화와 성장이 예상되니 이 시기를 잘 활용하는 것이 좋겠습니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 (천간지지 변환 및 시주 계산)
#
# - 출생일: 1995년 3월 28일 12시 30분 (양력)
# - 성별: 남성
# - 출생시간: 12시 30분은 지지로 "오시(午時)"에 해당 (11:30~13:30)
#
# ### 사주팔자 (천간지지)
#
# - 연주(년간/년지): 을해(乙亥)
# - 월주(월간/월지): 기묘(己卯)
# - 일주(일간/일지): 무오(戊午)
# - 시주(시간/시지): 무오(戊午)
#
# 총 8글자: 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 1) 천간지지 → 오행 매핑 (기준)
#
# | 오행 | 해당 글자(천간/지지)          |
# |-------|-----------------------------|
# | 목(木) | 甲, 乙, 寅, 卯              |
# | 화(火) | 丙, 丁, 巳, 午              |
# | 토(土) | 戊, 己, 辰, 戌, 丑, 未      |
# | 금(金) | 庚, 辛, 申, 酉              |
# | 수(水) | 壬, 癸, 子, 亥              |
#
# ### 2) 8글자 오행 분류 및 점수
#
# | 글자 | 오행 | 점수 |
# |-------|-------|-------|
# | 乙(을) | 목(木) | 1 |
# | 亥(해) | 수(水) | 1 |
# | 己(기) | 토(土) | 1 |
# | 卯(묘) | 목(木) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
#
# ### 3) 오행별 점수 합산 및 글자
#
# | 오행 | 점수 | 글자             |
# |-------|-------|------------------|
# | 목(木) | 2     | 乙, 卯            |
# | 화(火) | 2     | 午, 午            |
# | 토(土) | 3     | 己, 戊, 戊        |
# | 금(金) | 0     |                  |
# | 수(水) | 1     | 亥                |
#
# **총합: 2+2+3+0+1 = 8 (계산 유효)**
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 강약 및 균형 분석
#
# - **토(土)**가 가장 강함 (3점) → 안정적이고 현실적, 책임감 강함
# - **목(木)**과 **화(火)**가 중간 수준 (각 2점) → 창의력, 성장, 활동성, 열정 있음
# - **수(水)**는 약간 있음 (1점) → 지혜, 유연성, 감성
# - **금(金)**은 전혀 없음 (0점) → 금의 기운 부족, 결단력, 냉철함, 조직력 보완 필요
#
# ### 상생상극 관계
#
# - 목(木)은 화(火)를 생하고, 화(火)는 토(土)를 생함 → 목과 화가 토를 도와주는 좋은 구조
# - 토(土)는 수(水)를 극하고, 수(水)는 화(火)를 극함 → 수가 약해 화를 제어하지 못함
# - 금(金)이 없어 토(土)를 극하거나 목(木)을 제어하는 힘이 부족함
#
# **요약:** 토(土) 중심의 강한 기운에 목(木)과 화(火)가 조화를 이루고 있으나, 금(金) 부족으로 균형이 다소 깨진 상태입니다.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 무(土) 기준)
#
# - 일간(日干): 무(土)
# - 나머지 7글자와의 관계를 십신으로 해석
#
# | 글자 | 십신 관계 (무(土) 기준) | 의미 요약 |
# |-------|-------------------------|-----------|
# | 乙(을) | 편재 (목은 토의 재성) | 재물, 재능, 경쟁 |
# | 亥(해) | 편인 (수는 토의 인성) | 지혜, 보호, 학문 |
# | 己(기) | 비견 (토는 토의 비견) | 동료, 경쟁, 협력 |
# | 卯(묘) | 편재 (목) | 재물, 경쟁 |
# | 戊(무) | 비견 (토) | 동료, 경쟁 |
# | 午(오) | 식신 (화는 토의 식신) | 창의, 표현, 활동 |
# | 戊(무) | 비견 (토) | 동료, 경쟁 |
# | 午(오) | 식신 (화) | 창의, 활동 |
#
# - 비견(己, 戊)과 편재(乙, 卯)가 많아 경쟁심과 자기주장이 강함
# - 식신(午)이 있어 창의력과 표현력이 뛰어남
# - 편인(亥)은 지혜와 보호를 의미해 균형을 맞춤
#
# ---
#
# ## 5. 대운(大運) 분석
#
# - 출생 연도와 월을 기준으로 대운 시작 시기 산출
# - 남성은 출생 월의 절기 기준으로 앞으로 대운이 진행됨
#
# ### 대운 흐름 (예상)
#
# | 나이 | 대운  | 오행 및 특징          |
# |-------|--------|---------------------|
# | 0~5   | 기미(己未) | 토, 안정, 성장기       |
# | 6~15  | 경신(庚申) | 금, 부족한 금 보완 가능 |
# | 16~25 | 신유(辛酉) | 금, 금 기운 강화       |
# | 26~35 | 임술(壬戌) | 수, 감성 및 지혜 보완  |
# | 36~45 | 계해(癸亥) | 수, 지혜와 보호 강화   |
#
# - 25세부터 35세까지는 수(水) 기운이 보완되어 감성과 지혜가 강화되는 시기
# - 금(金) 기운이 부족하므로 6~25세 대운에서 금 기운이 들어와 보완됨
#
# ---
#
# ## 6. 종합 해석 및 조언
#
# ### 성격 및 기질
#
# - 현실적이고 책임감 강한 토(土) 기운이 주도
# - 목(木)과 화(火)의 조화로 창의적이고 활동적이며 성장욕구가 강함
# - 경쟁심과 자기주장이 강하며, 표현력과 활동성이 뛰어남
# - 금(金) 부족으로 인해 때로는 결단력이나 냉철함이 부족할 수 있음
#
# ### 건강 및 생활 조언
#
# - 금(金) 기운 보완을 위해 흰색, 금속성 물건, 규칙적인 운동 권장
# - 수(水) 기운이 약간 있으나 대운에서 보완되므로 감성적 안정에 도움
# - 토(土) 기운이 강해 소화기 계통 건강에 유의 필요
#
# ### 운세 및 대운 활용
#
# - 20대 후반부터 30대 초반까지 수(水) 대운이 들어와 지혜와 감성이 보완되는 시기
# - 금(金) 대운 시기에는 부족한 금 기운을 보완하여 결단력과 조직력이 강화됨
# - 창의력과 활동성을 살려 자신의 분야에서 성장을 도모하면 좋은 결과 기대
#
# ---
#
# ## 7. 요약
#
# | 구분 | 내용 |
# |-------|-------|
# | 사주팔자 | 을해(乙亥), 기묘(己卯), 무오(戊午), 무오(戊午) |
# | 오행분포 | 토 3, 목 2, 화 2, 수 1, 금 0 |
# | 십신특징 | 경쟁심 강한 비견과 편재, 창의적 식신, 지혜의 편인 |
# | 대운흐름 | 금과 수 기운 보완 대운 진행 중 |
# | 성격특징 | 현실적, 책임감, 창의적, 경쟁심 강함, 결단력 보완 필요 |
# | 건강조언 | 소화기 건강 주의, 금 기운 보완 권장 |
# | 운세조언 | 20대 후반~30대 초반 대운 활용 중요 |
#
# ---
#
# 필요하시면 대운과 세운(연운) 분석도 추가로 상세히 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 사주를 정확히 분석해 드리겠습니다.
#
# ---
#
# ## 1. 사주 구조 (천간지지 변환 및 시주 계산)
#
# - 출생일: 1995년 3월 28일 12시 30분 (양력)
# - 성별: 남성
# - 출생시간: 12시 30분은 지지로 "오시(午時)"에 해당 (11:30~13:30)
#
# ### 사주팔자 (천간지지)
#
# - 연주(년간/년지): 을해(乙亥)
# - 월주(월간/월지): 기묘(己卯)
# - 일주(일간/일지): 무오(戊午)
# - 시주(시간/시지): 무오(戊午)
#
# 총 8글자: 乙(을), 亥(해), 己(기), 卯(묘), 戊(무), 午(오), 戊(무), 午(오)
#
# ---
#
# ## 2. 오행(五行) 분석
#
# ### 1) 천간지지 → 오행 매핑 (기준)
#
# | 오행 | 해당 글자(천간/지지)          |
# |-------|-----------------------------|
# | 목(木) | 甲, 乙, 寅, 卯              |
# | 화(火) | 丙, 丁, 巳, 午              |
# | 토(土) | 戊, 己, 辰, 戌, 丑, 未      |
# | 금(金) | 庚, 辛, 申, 酉              |
# | 수(水) | 壬, 癸, 子, 亥              |
#
# ### 2) 8글자 오행 분류 및 점수
#
# | 글자 | 오행 | 점수 |
# |-------|-------|-------|
# | 乙(을) | 목(木) | 1 |
# | 亥(해) | 수(水) | 1 |
# | 己(기) | 토(土) | 1 |
# | 卯(묘) | 목(木) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
# | 戊(무) | 토(土) | 1 |
# | 午(오) | 화(火) | 1 |
#
# ### 3) 오행별 점수 합산 및 글자
#
# | 오행 | 점수 | 글자             |
# |-------|-------|------------------|
# | 목(木) | 2     | 乙, 卯            |
# | 화(火) | 2     | 午, 午            |
# | 토(土) | 3     | 己, 戊, 戊        |
# | 금(金) | 0     |                  |
# | 수(水) | 1     | 亥                |
#
# **총합: 2+2+3+0+1 = 8 (계산 유효)**
#
# **Wu Xing total score = 8 (Calculation is valid.)**
#
# ---
#
# ## 3. 오행 강약 및 균형 분석
#
# - **토(土)**가 가장 강함 (3점) → 안정적이고 현실적, 책임감 강함
# - **목(木)**과 **화(火)**가 중간 수준 (각 2점) → 창의력, 성장, 활동성, 열정 있음
# - **수(水)**는 약간 있음 (1점) → 지혜, 유연성, 감성
# - **금(金)**은 전혀 없음 (0점) → 금의 기운 부족, 결단력, 냉철함, 조직력 보완 필요
#
# ### 상생상극 관계
#
# - 목(木)은 화(火)를 생하고, 화(火)는 토(土)를 생함 → 목과 화가 토를 도와주는 좋은 구조
# - 토(土)는 수(水)를 극하고, 수(水)는 화(火)를 극함 → 수가 약해 화를 제어하지 못함
# - 금(金)이 없어 토(土)를 극하거나 목(木)을 제어하는 힘이 부족함
#
# **요약:** 토(土) 중심의 강한 기운에 목(木)과 화(火)가 조화를 이루고 있으나, 금(金) 부족으로 균형이 다소 깨진 상태입니다.
#
# ---
#
# ## 4. 십신(十神) 분석 (일간 무(土) 기준)
#
# - 일간(日干): 무(土)
# - 나머지 7글자와의 관계를 십신으로 해석
#
# | 글자 | 십신 관계 (무(土) 기준) | 의미 요약 |
# |-------|-------------------------|-----------|
# | 乙(을) | 편재 (목은 토의 재성) | 재물, 재능, 경쟁 |
# | 亥(해) | 편인 (수는 토의 인성) | 지혜, 보호, 학문 |
# | 己(기) | 비견 (토는 토의 비견) | 동료, 경쟁, 협력 |
# | 卯(묘) | 편재 (목) | 재물, 경쟁 |
# | 戊(무) | 비견 (토) | 동료, 경쟁 |
# | 午(오) | 식신 (화는 토의 식신) | 창의, 표현, 활동 |
# | 戊(무) | 비견 (토) | 동료, 경쟁 |
# | 午(오) | 식신 (화) | 창의, 활동 |
#
# - 비견(己, 戊)과 편재(乙, 卯)가 많아 경쟁심과 자기주장이 강함
# - 식신(午)이 있어 창의력과 표현력이 뛰어남
# - 편인(亥)은 지혜와 보호를 의미해 균형을 맞춤
#
# ---
#
# ## 5. 대운(大運) 분석
#
# - 출생 연도와 월을 기준으로 대운 시작 시기 산출
# - 남성은 출생 월의 절기 기준으로 앞으로 대운이 진행됨
#
# ### 대운 흐름 (예상)
#
# | 나이 | 대운  | 오행 및 특징          |
# |-------|--------|---------------------|
# | 0~5   | 기미(己未) | 토, 안정, 성장기       |
# | 6~15  | 경신(庚申) | 금, 부족한 금 보완 가능 |
# | 16~25 | 신유(辛酉) | 금, 금 기운 강화       |
# | 26~35 | 임술(壬戌) | 수, 감성 및 지혜 보완  |
# | 36~45 | 계해(癸亥) | 수, 지혜와 보호 강화   |
#
# - 25세부터 35세까지는 수(水) 기운이 보완되어 감성과 지혜가 강화되는 시기
# - 금(金) 기운이 부족하므로 6~25세 대운에서 금 기운이 들어와 보완됨
#
# ---
#
# ## 6. 종합 해석 및 조언
#
# ### 성격 및 기질
#
# - 현실적이고 책임감 강한 토(土) 기운이 주도
# - 목(木)과 화(火)의 조화로 창의적이고 활동적이며 성장욕구가 강함
# - 경쟁심과 자기주장이 강하며, 표현력과 활동성이 뛰어남
# - 금(金) 부족으로 인해 때로는 결단력이나 냉철함이 부족할 수 있음
#
# ### 건강 및 생활 조언
#
# - 금(金) 기운 보완을 위해 흰색, 금속성 물건, 규칙적인 운동 권장
# - 수(水) 기운이 약간 있으나 대운에서 보완되므로 감성적 안정에 도움
# - 토(土) 기운이 강해 소화기 계통 건강에 유의 필요
#
# ### 운세 및 대운 활용
#
# - 20대 후반부터 30대 초반까지 수(水) 대운이 들어와 지혜와 감성이 보완되는 시기
# - 금(金) 대운 시기에는 부족한 금 기운을 보완하여 결단력과 조직력이 강화됨
# - 창의력과 활동성을 살려 자신의 분야에서 성장을 도모하면 좋은 결과 기대
#
# ---
#
# ## 7. 요약
#
# | 구분 | 내용 |
# |-------|-------|
# | 사주팔자 | 을해(乙亥), 기묘(己卯), 무오(戊午), 무오(戊午) |
# | 오행분포 | 토 3, 목 2, 화 2, 수 1, 금 0 |
# | 십신특징 | 경쟁심 강한 비견과 편재, 창의적 식신, 지혜의 편인 |
# | 대운흐름 | 금과 수 기운 보완 대운 진행 중 |
# | 성격특징 | 현실적, 책임감, 창의적, 경쟁심 강함, 결단력 보완 필요 |
# | 건강조언 | 소화기 건강 주의, 금 기운 보완 권장 |
# | 운세조언 | 20대 후반~30대 초반 대운 활용 중요 |
#
# ---
#
# 필요하시면 대운과 세운(연운) 분석도 추가로 상세히 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
# 추가질문 -> 바로 retriever tool로 들어갔다

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 1})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="대운과 세운분석 자세히 해줘"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you provide a detailed analysis of my Daewoon (major luck cycle) and Sewoon (annual luck cycle) in relation to my Four Pillars of Destiny (Ba Zi)? I am particularly interested in understanding how these cycles influence my current life circumstances and future prospects based on my birth chart.대운과 세운분석 자세히 해줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 대운과 세운(연운) 분석을 자세히 진행하겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 대운 시작 시기 산출
#
# - 출생 월: 3월 (양력)
# - 출생 시: 午시 (11:30~13:30)
# - 남성은 출생 월의 절기 기준으로 앞으로 대운이 진행됨
# - 1995년 3월 28일은 춘분(3월 21일) 이후 출생이므로 대운은 출생 후 약 1년 5개월 후부터 시작 (대략 1세 5개월부터)
#
# ### 대운별 10년 주기 및 오행 특성
#
# | 나이 구간 | 대운  | 천간지지 | 오행 및 특징                      |
# |-----------|--------|-----------|---------------------------------|
# | 1~10세    | 기미(己未) | 토(土) 중심 | 토 기운 강화, 안정과 성장 기반 마련 |
# | 11~20세   | 경신(庚申) | 금(金) 중심 | 부족한 금 기운 보완, 결단력과 조직력 강화 |
# | 21~30세   | 신유(辛酉) | 금(金) 중심 | 금 기운 지속 강화, 냉철함과 실행력 증대 |
# | 31~40세   | 임술(壬戌) | 수(水) 중심 | 감성, 지혜, 유연성 보완, 대인관계 개선 |
# | 41~50세   | 계해(癸亥) | 수(水) 중심 | 지혜와 보호 강화, 내면 성장과 안정 |
#
# ### 대운 해석
#
# - **기미 대운(1~10세):** 토(土) 기운이 강해 안정적인 성장기. 부모와의 관계가 좋고, 기본적인 생활 기반이 튼튼함.
# - **경신, 신유 대운(11~30세):** 부족한 금(金) 기운이 보완되어 결단력과 조직력이 강화됨. 학업과 사회 진출에 유리한 시기.
# - **임술, 계해 대운(31~50세):** 수(水) 기운이 보완되어 감성과 지혜가 증대. 대인관계가 원만해지고 내면적 성장이 이루어짐.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2023~2025년)
#
# - 현재 기준 연도: 2025년
# - 최근 3년간 세운과 사주팔자의 상호작용 분석
#
# | 연도 | 세운(천간지지) | 오행 | 세운과 사주 상호작용 및 운세 영향 |
# |-------|----------------|-------|----------------------------------|
# | 2023  | 계묘(癸卯)     | 수(木) | 수와 목 기운이 보완되어 창의력과 감성 증대. 다만 토 기운과 일부 충돌 가능, 건강 주의 필요 |
# | 2024  | 갑진(甲辰)     | 목(土) | 목과 토의 상생으로 성장과 발전 기회. 새로운 일이나 학업에 좋은 시기 |
# | 2025  | 을사(乙巳)     | 목(火) | 목과 화 기운이 강해 활동성과 열정 증가. 다만 토 기운과의 균형 유지 필요 |
#
# ### 세운 해석
#
# - 2023년 계묘년은 수와 목의 기운이 강해 감성과 창의력이 증대되는 시기입니다. 다만 토 기운과 일부 충돌이 있어 건강과 스트레스 관리에 유의해야 합니다.
# - 2024년 갑진년은 목과 토의 상생으로 새로운 성장과 발전의 기회가 많습니다. 학업, 직장, 인간관계에서 좋은 성과 기대 가능.
# - 2025년 을사년은 목과 화의 기운이 강해 활동성과 열정이 증가합니다. 다만 토 기운과의 균형을 잘 유지해야 하며, 무리한 계획은 피하는 것이 좋습니다.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 20대 후반부터 30대 초반(임술 대운)에는 수 기운이 보완되어 감성과 지혜가 증대되는 시기입니다. 이 시기에 대인관계와 내면 성장을 중점적으로 관리하면 좋습니다.
# - 2023~2025년 세운은 목과 수, 화 기운이 강해 창의력과 활동성이 증가하는 시기입니다. 자신의 능력을 발휘하기 좋은 시기이나, 토 기운과의 균형을 유지하는 것이 중요합니다.
# - 금 기운이 부족한 사주이므로, 대운과 세운에서 금 기운이 들어오는 시기를 잘 활용하여 결단력과 조직력을 보완하는 것이 좋습니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분       | 내용                                                         |
# |------------|--------------------------------------------------------------|
# | 대운 시작  | 출생 후 약 1년 5개월부터 시작, 10년 단위로 변화               |
# | 대운 특징  | 토→금→금→수→수 순으로 변화, 금과 수 기운 보완이 핵심          |
# | 세운(2023~2025) | 목, 수, 화 기운 강화, 창의력과 활동성 증가, 토 기운과 균형 필요 |
# | 운세 조언  | 금 기운 보완에 신경 쓰고, 20대 후반~30대 초반 대운 활용 중요  |
# | 건강 조언  | 스트레스 관리 및 소화기 건강 주의, 규칙적 운동 권장            |
#
# ---
#
# 필요하시면 특정 대운별 상세 운세나 세운별 구체적 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 대운과 세운(연운) 분석을 자세히 진행하겠습니다.
#
# ---
#
# ## 1. 대운(大運) 분석
#
# ### 대운 시작 시기 산출
#
# - 출생 월: 3월 (양력)
# - 출생 시: 午시 (11:30~13:30)
# - 남성은 출생 월의 절기 기준으로 앞으로 대운이 진행됨
# - 1995년 3월 28일은 춘분(3월 21일) 이후 출생이므로 대운은 출생 후 약 1년 5개월 후부터 시작 (대략 1세 5개월부터)
#
# ### 대운별 10년 주기 및 오행 특성
#
# | 나이 구간 | 대운  | 천간지지 | 오행 및 특징                      |
# |-----------|--------|-----------|---------------------------------|
# | 1~10세    | 기미(己未) | 토(土) 중심 | 토 기운 강화, 안정과 성장 기반 마련 |
# | 11~20세   | 경신(庚申) | 금(金) 중심 | 부족한 금 기운 보완, 결단력과 조직력 강화 |
# | 21~30세   | 신유(辛酉) | 금(金) 중심 | 금 기운 지속 강화, 냉철함과 실행력 증대 |
# | 31~40세   | 임술(壬戌) | 수(水) 중심 | 감성, 지혜, 유연성 보완, 대인관계 개선 |
# | 41~50세   | 계해(癸亥) | 수(水) 중심 | 지혜와 보호 강화, 내면 성장과 안정 |
#
# ### 대운 해석
#
# - **기미 대운(1~10세):** 토(土) 기운이 강해 안정적인 성장기. 부모와의 관계가 좋고, 기본적인 생활 기반이 튼튼함.
# - **경신, 신유 대운(11~30세):** 부족한 금(金) 기운이 보완되어 결단력과 조직력이 강화됨. 학업과 사회 진출에 유리한 시기.
# - **임술, 계해 대운(31~50세):** 수(水) 기운이 보완되어 감성과 지혜가 증대. 대인관계가 원만해지고 내면적 성장이 이루어짐.
#
# ---
#
# ## 2. 세운(歲運) 분석 (2023~2025년)
#
# - 현재 기준 연도: 2025년
# - 최근 3년간 세운과 사주팔자의 상호작용 분석
#
# | 연도 | 세운(천간지지) | 오행 | 세운과 사주 상호작용 및 운세 영향 |
# |-------|----------------|-------|----------------------------------|
# | 2023  | 계묘(癸卯)     | 수(木) | 수와 목 기운이 보완되어 창의력과 감성 증대. 다만 토 기운과 일부 충돌 가능, 건강 주의 필요 |
# | 2024  | 갑진(甲辰)     | 목(土) | 목과 토의 상생으로 성장과 발전 기회. 새로운 일이나 학업에 좋은 시기 |
# | 2025  | 을사(乙巳)     | 목(火) | 목과 화 기운이 강해 활동성과 열정 증가. 다만 토 기운과의 균형 유지 필요 |
#
# ### 세운 해석
#
# - 2023년 계묘년은 수와 목의 기운이 강해 감성과 창의력이 증대되는 시기입니다. 다만 토 기운과 일부 충돌이 있어 건강과 스트레스 관리에 유의해야 합니다.
# - 2024년 갑진년은 목과 토의 상생으로 새로운 성장과 발전의 기회가 많습니다. 학업, 직장, 인간관계에서 좋은 성과 기대 가능.
# - 2025년 을사년은 목과 화의 기운이 강해 활동성과 열정이 증가합니다. 다만 토 기운과의 균형을 잘 유지해야 하며, 무리한 계획은 피하는 것이 좋습니다.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 20대 후반부터 30대 초반(임술 대운)에는 수 기운이 보완되어 감성과 지혜가 증대되는 시기입니다. 이 시기에 대인관계와 내면 성장을 중점적으로 관리하면 좋습니다.
# - 2023~2025년 세운은 목과 수, 화 기운이 강해 창의력과 활동성이 증가하는 시기입니다. 자신의 능력을 발휘하기 좋은 시기이나, 토 기운과의 균형을 유지하는 것이 중요합니다.
# - 금 기운이 부족한 사주이므로, 대운과 세운에서 금 기운이 들어오는 시기를 잘 활용하여 결단력과 조직력을 보완하는 것이 좋습니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분       | 내용                                                         |
# |------------|--------------------------------------------------------------|
# | 대운 시작  | 출생 후 약 1년 5개월부터 시작, 10년 단위로 변화               |
# | 대운 특징  | 토→금→금→수→수 순으로 변화, 금과 수 기운 보완이 핵심          |
# | 세운(2023~2025) | 목, 수, 화 기운 강화, 창의력과 활동성 증가, 토 기운과 균형 필요 |
# | 운세 조언  | 금 기운 보완에 신경 쓰고, 20대 후반~30대 초반 대운 활용 중요  |
# | 건강 조언  | 스트레스 관리 및 소화기 건강 주의, 규칙적 운동 권장            |
#
# ---
#
# 필요하시면 특정 대운별 상세 운세나 세운별 구체적 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
#config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 1})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="난 미래에 대한 대운과 세운분석이 궁금해"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# I am curious about the analysis of my luck cycles (Da Yun) and annual luck (Se Yun) in relation to my Four Pillars of Destiny (Ba Zi). Specifically, I would like to understand how these cycles will influence my future and what insights can be drawn from my birth chart analysis. Could you provide guidance on how to interpret these aspects in my life?난 미래에 대한 대운과 세운분석이 궁금해
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 미래 대운과 세운(연운) 분석을 자세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 미래 대운(大運) 분석
#
# ### 대운 시작 시기 및 진행 방향
#
# - 출생 월(3월) 기준으로 남성은 앞으로 대운이 진행됩니다.
# - 대운 시작은 출생 후 약 1년 5개월부터 시작하여 10년 단위로 변화합니다.
#
# ### 미래 대운 목록 및 특징
#
# | 나이 구간 | 대운  | 천간지지 | 오행 및 특징                      |
# |-----------|--------|-----------|---------------------------------|
# | 26~35세   | 임술(壬戌) | 수(土) 중심 | 감성, 지혜, 유연성 보완, 대인관계 개선 |
# | 36~45세   | 계해(癸亥) | 수(水) 중심 | 지혜와 보호 강화, 내면 성장과 안정 |
# | 46~55세   | 갑자(甲子) | 목(水) 중심 | 새로운 시작과 성장, 활력 증대 |
# | 56~65세   | 을축(乙丑) | 목(土) 중심 | 안정과 성숙, 재물운 상승 가능 |
# | 66~75세   | 병인(丙寅) | 화(木) 중심 | 활력과 창의력 증가, 건강 주의 필요 |
#
# ### 대운 해석
#
# - **26~35세 임술 대운:** 수 기운이 보완되어 감성과 지혜가 증대되는 시기입니다. 대인관계가 원만해지고 내면적 성장이 이루어집니다. 중요한 인생 전환점이 될 수 있습니다.
# - **36~45세 계해 대운:** 수 기운이 계속 강화되어 내면의 안정과 보호가 강화됩니다. 지혜로운 판단과 신중한 행동이 요구되는 시기입니다.
# - **46~55세 갑자 대운:** 목과 수 기운이 강해 새로운 시작과 활력이 증가합니다. 사업이나 새로운 분야 도전이 유리합니다.
# - **56~65세 을축 대운:** 목과 토 기운이 조화를 이루어 안정과 성숙의 시기입니다. 재물운이 상승할 가능성이 높습니다.
# - **66~75세 병인 대운:** 화와 목 기운이 강해 활력과 창의력이 증가하지만, 건강에 유의해야 합니다.
#
# ---
#
# ## 2. 미래 세운(歲運) 분석 (2026년 이후)
#
# | 연도 | 세운(천간지지) | 오행 | 세운과 사주 상호작용 및 운세 영향 |
# |-------|----------------|-------|----------------------------------|
# | 2026  | 병오(丙午)     | 화(火) | 화 기운 강화, 활동성과 열정 증가. 토 기운과 조화 필요 |
# | 2027  | 정미(丁未)     | 화(土) | 화와 토의 조화로 성장과 안정. 재물운 상승 가능 |
# | 2028  | 무신(戊申)     | 토(金) | 토와 금 기운 보완, 결단력과 조직력 강화 |
# | 2029  | 기유(己酉)     | 토(金) | 토와 금의 조화, 사업과 재물운에 좋은 시기 |
# | 2030  | 경술(庚戌)     | 금(土) | 금 기운 강화, 결단력과 실행력 증대 |
#
# ### 세운 해석
#
# - 2026~2027년은 화와 토 기운이 강해 활동성과 안정이 조화를 이루는 시기입니다. 새로운 일이나 사업에 좋은 기회가 많습니다.
# - 2028~2030년은 토와 금 기운이 보완되어 결단력과 조직력이 강화됩니다. 재물운과 사업운이 상승하는 좋은 시기입니다.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 26~35세 임술 대운과 2026~2030년 세운이 조화를 이루어 감성과 지혜, 활동성과 결단력이 균형 있게 발휘되는 시기입니다.
# - 이 시기에 자신의 능력을 최대한 발휘하고, 새로운 도전과 사업에 집중하면 좋은 성과를 기대할 수 있습니다.
# - 금 기운이 부족한 사주이므로, 2028년 이후 금 기운이 강화되는 대운과 세운을 잘 활용하여 결단력과 조직력을 보완하는 것이 중요합니다.
# - 건강 관리에 유의하며, 특히 소화기 계통과 스트레스 관리를 신경 써야 합니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분       | 내용                                                         |
# |------------|--------------------------------------------------------------|
# | 미래 대운  | 26~35세 임술 대운부터 수 기운 보완, 36~45세 계해 대운 안정 강화 |
# | 미래 세운  | 2026~2030년 화, 토, 금 기운 강화, 활동성과 결단력 증대        |
# | 운세 조언  | 26~35세 대운과 2026~2030년 세운 활용하여 성장과 성공 도모    |
# | 건강 조언  | 소화기 건강 및 스트레스 관리 중요                             |
#
# ---
#
# 필요하시면 특정 대운별 상세 운세나 세운별 구체적 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: RetrieverTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 안녕하세요. 1995년 3월 28일 12시 30분 출생 남성분의 미래 대운과 세운(연운) 분석을 자세히 안내해 드리겠습니다.
#
# ---
#
# ## 1. 미래 대운(大運) 분석
#
# ### 대운 시작 시기 및 진행 방향
#
# - 출생 월(3월) 기준으로 남성은 앞으로 대운이 진행됩니다.
# - 대운 시작은 출생 후 약 1년 5개월부터 시작하여 10년 단위로 변화합니다.
#
# ### 미래 대운 목록 및 특징
#
# | 나이 구간 | 대운  | 천간지지 | 오행 및 특징                      |
# |-----------|--------|-----------|---------------------------------|
# | 26~35세   | 임술(壬戌) | 수(土) 중심 | 감성, 지혜, 유연성 보완, 대인관계 개선 |
# | 36~45세   | 계해(癸亥) | 수(水) 중심 | 지혜와 보호 강화, 내면 성장과 안정 |
# | 46~55세   | 갑자(甲子) | 목(水) 중심 | 새로운 시작과 성장, 활력 증대 |
# | 56~65세   | 을축(乙丑) | 목(土) 중심 | 안정과 성숙, 재물운 상승 가능 |
# | 66~75세   | 병인(丙寅) | 화(木) 중심 | 활력과 창의력 증가, 건강 주의 필요 |
#
# ### 대운 해석
#
# - **26~35세 임술 대운:** 수 기운이 보완되어 감성과 지혜가 증대되는 시기입니다. 대인관계가 원만해지고 내면적 성장이 이루어집니다. 중요한 인생 전환점이 될 수 있습니다.
# - **36~45세 계해 대운:** 수 기운이 계속 강화되어 내면의 안정과 보호가 강화됩니다. 지혜로운 판단과 신중한 행동이 요구되는 시기입니다.
# - **46~55세 갑자 대운:** 목과 수 기운이 강해 새로운 시작과 활력이 증가합니다. 사업이나 새로운 분야 도전이 유리합니다.
# - **56~65세 을축 대운:** 목과 토 기운이 조화를 이루어 안정과 성숙의 시기입니다. 재물운이 상승할 가능성이 높습니다.
# - **66~75세 병인 대운:** 화와 목 기운이 강해 활력과 창의력이 증가하지만, 건강에 유의해야 합니다.
#
# ---
#
# ## 2. 미래 세운(歲運) 분석 (2026년 이후)
#
# | 연도 | 세운(천간지지) | 오행 | 세운과 사주 상호작용 및 운세 영향 |
# |-------|----------------|-------|----------------------------------|
# | 2026  | 병오(丙午)     | 화(火) | 화 기운 강화, 활동성과 열정 증가. 토 기운과 조화 필요 |
# | 2027  | 정미(丁未)     | 화(土) | 화와 토의 조화로 성장과 안정. 재물운 상승 가능 |
# | 2028  | 무신(戊申)     | 토(金) | 토와 금 기운 보완, 결단력과 조직력 강화 |
# | 2029  | 기유(己酉)     | 토(金) | 토와 금의 조화, 사업과 재물운에 좋은 시기 |
# | 2030  | 경술(庚戌)     | 금(土) | 금 기운 강화, 결단력과 실행력 증대 |
#
# ### 세운 해석
#
# - 2026~2027년은 화와 토 기운이 강해 활동성과 안정이 조화를 이루는 시기입니다. 새로운 일이나 사업에 좋은 기회가 많습니다.
# - 2028~2030년은 토와 금 기운이 보완되어 결단력과 조직력이 강화됩니다. 재물운과 사업운이 상승하는 좋은 시기입니다.
#
# ---
#
# ## 3. 대운과 세운의 상호작용 및 조언
#
# - 26~35세 임술 대운과 2026~2030년 세운이 조화를 이루어 감성과 지혜, 활동성과 결단력이 균형 있게 발휘되는 시기입니다.
# - 이 시기에 자신의 능력을 최대한 발휘하고, 새로운 도전과 사업에 집중하면 좋은 성과를 기대할 수 있습니다.
# - 금 기운이 부족한 사주이므로, 2028년 이후 금 기운이 강화되는 대운과 세운을 잘 활용하여 결단력과 조직력을 보완하는 것이 중요합니다.
# - 건강 관리에 유의하며, 특히 소화기 계통과 스트레스 관리를 신경 써야 합니다.
#
# ---
#
# ## 4. 종합 요약
#
# | 구분       | 내용                                                         |
# |------------|--------------------------------------------------------------|
# | 미래 대운  | 26~35세 임술 대운부터 수 기운 보완, 36~45세 계해 대운 안정 강화 |
# | 미래 세운  | 2026~2030년 화, 토, 금 기운 강화, 활동성과 결단력 증대        |
# | 운세 조언  | 26~35세 대운과 2026~2030년 세운 활용하여 성장과 성공 도모    |
# | 건강 조언  | 소화기 건강 및 스트레스 관리 중요                             |
#
# ---
#
# 필요하시면 특정 대운별 상세 운세나 세운별 구체적 조언도 추가로 안내해 드리겠습니다.
#
# 감사합니다.
#
# ---
#
# **출처:** 한국 명리학 원전 및 현대 사주 분석법 기준
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
# Enhanced Retriever with Query Expansion 테스트
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 2})

# 한글 사주 질문으로 테스트 (Query Expansion이 작동할 질문)
inputs = {
    "messages": [
        HumanMessage(
            content="정관이 뭐야? 상세히 설명해줘"
        )
    ],
}


# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# What is the concept of "Jeonggwan" (正官) in the context of the Four Pillars of Destiny (Ba Zi)? Please provide a detailed explanation, including its significance in birth chart analysis and how it influences an individual's personality, career, and relationships. Additionally, could you elaborate on how Jeonggwan interacts with other elements in a person's birth chart?정관이 뭐야? 상세히 설명해줘
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# "정관"은 여러 분야에서 사용되는 용어로, 문맥에 따라 의미가 다를 수 있습니다. 하지만 일반적으로 가장 많이 쓰이는 두 가지 의미를 중심으로 설명드리겠습니다.
#
# 1. **사주명리학에서의 정관(正官)**
# 사주명리학(사주팔자)에서 '정관'은 십신(十神) 중 하나로, 자신의 일간(日干, 태어난 날의 천간)과 음양이 같고, 오행의 관계에서 '관계'에 해당하는 천간을 말합니다.
# - 예를 들어, 일간이 갑목(甲木)일 때, 정관은 일간과 음양이 같고, 일간을 극하는 오행인 금(金) 중에서 음양이 같은 경금(庚金)이 됩니다.
# - 정관은 주로 '공적인 직업, 권위, 규율, 법, 책임감' 등을 상징합니다.
# - 정관이 강하면 책임감이 강하고, 사회적 지위나 명예를 중시하는 성향이 있다고 봅니다.
# - 반대로 정관이 약하거나 흉하게 작용하면 권위에 대한 반발, 법적 문제, 스트레스 등이 나타날 수 있습니다.
#
# 2. **법률 및 기업에서의 정관(定款)**
# 법률이나 기업 경영에서 '정관'은 회사나 단체의 기본 규칙을 정리한 문서입니다.
# - 회사의 목적, 조직, 업무 범위, 주주 권리, 이사회 구성, 의사결정 절차 등을 명시합니다.
# - 정관은 회사 설립 시 필수적으로 작성하며, 법적 효력을 가집니다.
# - 정관에 따라 회사 운영이 이루어지며, 주주나 임원 간 분쟁 시 중요한 기준이 됩니다.
#
# 만약 사주명리학에서의 '정관'에 대해 더 자세히 알고 싶으시거나, 법률상의 '정관'에 대해 궁금하시면 말씀해 주세요. 추가로 설명드리겠습니다.
# ==================================================
# 🔄 Node: WebTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# "정관"은 여러 분야에서 사용되는 용어로, 문맥에 따라 의미가 다를 수 있습니다. 하지만 일반적으로 가장 많이 쓰이는 두 가지 의미를 중심으로 설명드리겠습니다.
#
# 1. **사주명리학에서의 정관(正官)**
# 사주명리학(사주팔자)에서 '정관'은 십신(十神) 중 하나로, 자신의 일간(日干, 태어난 날의 천간)과 음양이 같고, 오행의 관계에서 '관계'에 해당하는 천간을 말합니다.
# - 예를 들어, 일간이 갑목(甲木)일 때, 정관은 일간과 음양이 같고, 일간을 극하는 오행인 금(金) 중에서 음양이 같은 경금(庚金)이 됩니다.
# - 정관은 주로 '공적인 직업, 권위, 규율, 법, 책임감' 등을 상징합니다.
# - 정관이 강하면 책임감이 강하고, 사회적 지위나 명예를 중시하는 성향이 있다고 봅니다.
# - 반대로 정관이 약하거나 흉하게 작용하면 권위에 대한 반발, 법적 문제, 스트레스 등이 나타날 수 있습니다.
#
# 2. **법률 및 기업에서의 정관(定款)**
# 법률이나 기업 경영에서 '정관'은 회사나 단체의 기본 규칙을 정리한 문서입니다.
# - 회사의 목적, 조직, 업무 범위, 주주 권리, 이사회 구성, 의사결정 절차 등을 명시합니다.
# - 정관은 회사 설립 시 필수적으로 작성하며, 법적 효력을 가집니다.
# - 정관에 따라 회사 운영이 이루어지며, 주주나 임원 간 분쟁 시 중요한 기준이 됩니다.
#
# 만약 사주명리학에서의 '정관'에 대해 더 자세히 알고 싶으시거나, 법률상의 '정관'에 대해 궁금하시면 말씀해 주세요. 추가로 설명드리겠습니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, invoke_graph

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="사주의 개념에 대해서 알려줘"
        )
    ],
}

# 그래프 실행
invoke_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================ Human Message =================================
#
# 사주의 개념에 대해서 알려줘
# ==================================================
#
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# next:
# WebTool
# ==================================================
#
# ==================================================
# 🔄 Node: agent in [WebTool] 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================== Ai Message ==================================
#
# 사주(四柱)는 한국과 중국 등 동아시아에서 전통적으로 사용되는 운명학의 한 분야로, 사람의 태어난 연, 월, 일, 시를 기준으로 하여 그 사람의 운명과 성격, 미래의 길흉화복을 해석하는 체계입니다.
#
# 사주는 '네 기둥'이라는 뜻으로, 태어난 연도, 월, 일, 시를 각각 한 기둥으로 보고, 이 네 기둥을 합쳐서 개인의 운명을 분석합니다. 각 기둥은 천간(10간)과 지지(12지)로 구성되어 있으며, 이를 통해 오행(목, 화, 토, 금, 수)의 상호작용과 음양의 조화를 살펴봅니다.
#
# 사주를 통해 개인의 성격, 건강, 직업, 인간관계, 재물운, 결혼운 등 다양한 인생의 측면을 예측하고 조언하는 데 활용합니다. 또한, 사주는 운세뿐 아니라 자신과 주변 환경과의 조화를 이해하고, 더 나은 삶을 위한 방향을 찾는 데 도움을 주는 도구로 여겨집니다.
#
# 필요하면 사주의 구성 요소나 오행, 천간과 지지에 대해서도 자세히 설명해 드릴 수 있습니다.
# ==================================================
#
# ==================================================
# 🔄 Node: WebTool 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================ Human Message =================================
# Name: WebTool
#
# 사주(四柱)는 한국과 중국 등 동아시아에서 전통적으로 사용되는 운명학의 한 분야로, 사람의 태어난 연, 월, 일, 시를 기준으로 하여 그 사람의 운명과 성격, 미래의 길흉화복을 해석하는 체계입니다.
#
# 사주는 '네 기둥'이라는 뜻으로, 태어난 연도, 월, 일, 시를 각각 한 기둥으로 보고, 이 네 기둥을 합쳐서 개인의 운명을 분석합니다. 각 기둥은 천간(10간)과 지지(12지)로 구성되어 있으며, 이를 통해 오행(목, 화, 토, 금, 수)의 상호작용과 음양의 조화를 살펴봅니다.
#
# 사주를 통해 개인의 성격, 건강, 직업, 인간관계, 재물운, 결혼운 등 다양한 인생의 측면을 예측하고 조언하는 데 활용합니다. 또한, 사주는 운세뿐 아니라 자신과 주변 환경과의 조화를 이해하고, 더 나은 삶을 위한 방향을 찾는 데 도움을 주는 도구로 여겨집니다.
#
# 필요하면 사주의 구성 요소나 오행, 천간과 지지에 대해서도 자세히 설명해 드릴 수 있습니다.
# ==================================================
#
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# next:
# FINISH
# ==================================================

# %%
# GeneralQA 도구 테스트 - 일반 질문
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import random_uuid, stream_graph

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": 2})

# 일반 질문 입력
inputs = {
    "messages": [
        HumanMessage(
            content="파이썬에서 딕셔너리와 리스트의 차이점을 알려주세요"
        )
    ],
}

# 그래프 실행
stream_graph(graph, inputs, config)
# Out:
# ==================================================
# 🔄 Node: QueryExpansion 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Could you explain the differences between a dictionary and a list in Python, particularly in the context of data structures used for organizing information? Additionally, I am interested in understanding how these concepts might relate to the analysis of a birth chart in the Four Pillars of Destiny (Ba Zi), where different elements and their relationships can be represented in various formats.파이썬에서 딕셔너리와 리스트의 차이점을 알려주세요
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ## 파이썬 딕셔너리와 리스트의 차이점
#
# 파이썬에서 딕셔너리(dictionary)와 리스트(list)는 모두 여러 개의 값을 저장하는 데 사용되는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.
#
# **1. 데이터 접근 방식:**
#
# *   **리스트 (List):**
#     *   **순서 기반 접근:** 리스트는 요소의 순서가 중요하며, 각 요소는 **인덱스(index)**를 통해 접근합니다. 인덱스는 0부터 시작하는 정수입니다.
#     *   예시: `my_list[0]`은 리스트의 첫 번째 요소를 가져옵니다.
# *   **딕셔너리 (Dictionary):**
#     *   **키(Key) 기반 접근:** 딕셔너리는 **키(key)**와 **값(value)**의 쌍으로 데이터를 저장합니다. 각 값은 고유한 키를 사용하여 접근합니다. 키는 변경 불가능한(immutable) 데이터 타입(문자열, 숫자, 튜플 등)이어야 합니다.
#     *   예시: `my_dict["name"]`은 딕셔너리에서 키가 "name"인 값(value)을 가져옵니다.
#
# **2. 순서 유무:**
#
# *   **리스트 (List):**
#     *   **순서가 있습니다.** 리스트에 추가된 요소는 추가된 순서대로 유지됩니다.
# *   **딕셔너리 (Dictionary):**
#     *   **파이썬 3.7+ 부터는 순서가 보장됩니다.** (삽입 순서대로). 이전 버전에서는 순서가 보장되지 않았습니다.  하지만 순서를 활용하기보다는 키를 통해 접근하는 것이 일반적입니다.
#
# **3. 데이터 저장 방식:**
#
# *   **리스트 (List):**
#     *   **동일한 타입 또는 다른 타입의 데이터 저장 가능:** 리스트는 숫자, 문자열, 객체 등 다양한 타입의 데이터를 함께 저장할 수 있습니다.
# *   **딕셔너리 (Dictionary):**
#     *   **키-값 쌍으로 데이터 저장:** 딕셔너리는 각 키에 해당하는 값을 저장하며, 키는 고유해야 합니다. 값은 다양한 타입이 될 수 있습니다.
#
# **4. 용도:**
#
# *   **리스트 (List):**
#     *   순서가 있는 데이터 모음, 데이터 목록 관리, 반복적인 작업 등에 적합합니다.
# *   **딕셔너리 (Dictionary):**
#     *   키-값으로 연관된 데이터를 저장하고 검색하는 데 적합합니다. 예를 들어, 사용자 정보 (이름, 나이, 주소 등), 설정 정보 등을 저장하는 데 유용합니다.
#
# **5. 주요 연산:**
#
# | 연산           | 리스트 (List)                                    | 딕셔너리 (Dictionary)                                   |
# | -------------- | ------------------------------------------------- | ------------------------------------------------------- |
# | 요소 추가       | `append()`, `insert()`                           | `dict[key] = value`, `update()`                        |
# | 요소 삭제       | `del list[index]`, `remove()`, `pop()`            | `del dict[key]`, `pop()`, `popitem()`                   |
# | 요소 접근       | `list[index]`                                     | `dict[key]`, `get()`                                   |
# | 요소 검색       | `in`, `index()`                                  | `in` (키 존재 여부 확인), `values()`, `items()`       |
# | 전체 순회       | `for item in list:`                             | `for key in dict:`, `for value in dict.values():`, `for key, value in dict.items():` |
#
# **예제 코드:**
#
# ```python
# # 리스트 예제
# my_list = ["apple", "banana", "cherry"]
# print(my_list[0])  # 출력: apple
# my_list.append("orange")
# print(my_list)  # 출력: ['apple', 'banana', 'cherry', 'orange']
#
# # 딕셔너리 예제
# my_dict = {"name": "Alice", "age": 30, "city": "New York"}
# print(my_dict["name"])  # 출력: Alice
# my_dict["occupation"] = "Engineer"
# print(my_dict)  # 출력: {'name': 'Alice', 'age': 30, 'city': 'New York', 'occupation': 'Engineer'}
#
# # 딕셔너리 순회
# for key, value in my_dict.items():
#     print(f"{key}: {value}")
# ```
#
# **요약:**
#
# | 특징           | 리스트 (List)          | 딕셔너리 (Dictionary)            |
# | -------------- | ----------------------- | --------------------------------- |
# | 접근 방식       | 인덱스 기반           | 키 기반                             |
# | 순서            | 순서 유지              | 파이썬 3.7+ 부터는 순서 보장.       |
# | 데이터 저장 방식 | 순서대로 저장          | 키-값 쌍으로 저장                   |
# | 키 중복        | 해당 없음               | 키는 중복 불가                      |
# | 용도            | 순서 있는 데이터 목록   | 키-값 연관 데이터 저장 및 검색      |
#
# 어떤 자료구조를 사용할지는 데이터의 특성과 사용 목적에 따라 결정해야 합니다. 순서가 중요하고 인덱스를 통해 접근해야 하는 데이터는 리스트를, 키-값 쌍으로 연관된 데이터를 저장하고 검색해야 하는 경우에는 딕셔너리를 사용하는 것이 좋습니다.
# content='## 파이썬 딕셔너리와 리스트의 차이점\n\n파이썬에서 딕셔너리(dictionary)와 리스트(list)는 모두 여러 개의 값을 저장하는 데 사용되는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.\n\n**1. 데이터 접근 방식:**\n\n*   **리스트 (List):**\n    *   **순서 기반 접근:** 리스트는 요소의 순서가 중요하며, 각 요소는 **인덱스(index)**를 통해 접근합니다. 인덱스는 0부터 시작하는 정수입니다.\n    *   예시: `my_list[0]`은 리스트의 첫 번째 요소를 가져옵니다.\n*   **딕셔너리 (Dictionary):**\n    *   **키(Key) 기반 접근:** 딕셔너리는 **키(key)**와 **값(value)**의 쌍으로 데이터를 저장합니다. 각 값은 고유한 키를 사용하여 접근합니다. 키는 변경 불가능한(immutable) 데이터 타입(문자열, 숫자, 튜플 등)이어야 합니다.\n    *   예시: `my_dict["name"]`은 딕셔너리에서 키가 "name"인 값(value)을 가져옵니다.\n\n**2. 순서 유무:**\n\n*   **리스트 (List):**\n    *   **순서가 있습니다.** 리스트에 추가된 요소는 추가된 순서대로 유지됩니다.\n*   **딕셔너리 (Dictionary):**\n    *   **파이썬 3.7+ 부터는 순서가 보장됩니다.** (삽입 순서대로). 이전 버전에서는 순서가 보장되지 않았습니다.  하지만 순서를 활용하기보다는 키를 통해 접근하는 것이 일반적입니다.\n\n**3. 데이터 저장 방식:**\n\n*   **리스트 (List):**\n    *   **동일한 타입 또는 다른 타입의 데이터 저장 가능:** 리스트는 숫자, 문자열, 객체 등 다양한 타입의 데이터를 함께 저장할 수 있습니다.\n*   **딕셔너리 (Dictionary):**\n    *   **키-값 쌍으로 데이터 저장:** 딕셔너리는 각 키에 해당하는 값을 저장하며, 키는 고유해야 합니다. 값은 다양한 타입이 될 수 있습니다.\n\n**4. 용도:**\n\n*   **리스트 (List):**\n    *   순서가 있는 데이터 모음, 데이터 목록 관리, 반복적인 작업 등에 적합합니다.\n*   **딕셔너리 (Dictionary):**\n    *   키-값으로 연관된 데이터를 저장하고 검색하는 데 적합합니다. 예를 들어, 사용자 정보 (이름, 나이, 주소 등), 설정 정보 등을 저장하는 데 유용합니다.\n\n**5. 주요 연산:**\n\n| 연산           | 리스트 (List)                                    | 딕셔너리 (Dictionary)                                   |\n| -------------- | ------------------------------------------------- | ------------------------------------------------------- |\n| 요소 추가       | `append()`, `insert()`                           | `dict[key] = value`, `update()`                        |\n| 요소 삭제       | `del list[index]`, `remove()`, `pop()`            | `del dict[key]`, `pop()`, `popitem()`                   |\n| 요소 접근       | `list[index]`                                     | `dict[key]`, `get()`                                   |\n| 요소 검색       | `in`, `index()`                                  | `in` (키 존재 여부 확인), `values()`, `items()`       |\n| 전체 순회       | `for item in list:`                             | `for key in dict:`, `for value in dict.values():`, `for key, value in dict.items():` |\n\n**예제 코드:**\n\n```python\n# 리스트 예제\nmy_list = ["apple", "banana", "cherry"]\nprint(my_list[0])  # 출력: apple\nmy_list.append("orange")\nprint(my_list)  # 출력: [\'apple\', \'banana\', \'cherry\', \'orange\']\n\n# 딕셔너리 예제\nmy_dict = {"name": "Alice", "age": 30, "city": "New York"}\nprint(my_dict["name"])  # 출력: Alice\nmy_dict["occupation"] = "Engineer"\nprint(my_dict)  # 출력: {\'name\': \'Alice\', \'age\': 30, \'city\': \'New York\', \'occupation\': \'Engineer\'}\n\n# 딕셔너리 순회\nfor key, value in my_dict.items():\n    print(f"{key}: {value}")\n```\n\n**요약:**\n\n| 특징           | 리스트 (List)          | 딕셔너리 (Dictionary)            |\n| -------------- | ----------------------- | --------------------------------- |\n| 접근 방식       | 인덱스 기반           | 키 기반                             |\n| 순서            | 순서 유지              | 파이썬 3.7+ 부터는 순서 보장.       |\n| 데이터 저장 방식 | 순서대로 저장          | 키-값 쌍으로 저장                   |\n| 키 중복        | 해당 없음               | 키는 중복 불가                      |\n| 용도            | 순서 있는 데이터 목록   | 키-값 연관 데이터 저장 및 검색      |\n\n어떤 자료구조를 사용할지는 데이터의 특성과 사용 목적에 따라 결정해야 합니다. 순서가 중요하고 인덱스를 통해 접근해야 하는 데이터는 리스트를, 키-값 쌍으로 연관된 데이터를 저장하고 검색해야 하는 경우에는 딕셔너리를 사용하는 것이 좋습니다.\n' additional_kwargs={} response_metadata={'safety_ratings': [], 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash'} id='run--1704bceb-ff7e-4a32-8be4-b46e825bbcfe' usage_metadata={'input_tokens': 15, 'output_tokens': 1307, 'total_tokens': 1322, 'input_token_details': {'cache_read': 0}}
# ==================================================
# 🔄 Node: agent 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 파이썬에서 딕셔너리(dictionary)와 리스트(list)는 모두 여러 개의 값을 저장하는 데 사용되는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.
#
# ## 1. 데이터 접근 방식
# - **리스트 (List)**:
#   - **순서 기반 접근**: 리스트는 요소의 순서가 중요하며, 각 요소는 **인덱스(index)**를 통해 접근합니다. 인덱스는 0부터 시작하는 정수입니다.
#   - 예시: `my_list[0]`은 리스트의 첫 번째 요소를 가져옵니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **키(Key) 기반 접근**: 딕셔너리는 **키(key)**와 **값(value)**의 쌍으로 데이터를 저장합니다. 각 값은 고유한 키를 사용하여 접근합니다. 키는 변경 불가능한(immutable) 데이터 타입(문자열, 숫자, 튜플 등)이어야 합니다.
#   - 예시: `my_dict["name"]`은 딕셔너리에서 키가 "name"인 값(value)을 가져옵니다.
#
# ## 2. 순서 유무
# - **리스트 (List)**:
#   - **순서가 있습니다**. 리스트에 추가된 요소는 추가된 순서대로 유지됩니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **파이썬 3.7+ 부터는 순서가 보장됩니다**. (삽입 순서대로). 이전 버전에서는 순서가 보장되지 않았습니다.
#
# ## 3. 데이터 저장 방식
# - **리스트 (List)**:
#   - **동일한 타입 또는 다른 타입의 데이터 저장 가능**: 리스트는 숫자, 문자열, 객체 등 다양한 타입의 데이터를 함께 저장할 수 있습니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **키-값 쌍으로 데이터 저장**: 딕셔너리는 각 키에 해당하는 값을 저장하며, 키는 고유해야 합니다. 값은 다양한 타입이 될 수 있습니다.
#
# ## 4. 용도
# - **리스트 (List)**:
#   - 순서가 있는 데이터 모음, 데이터 목록 관리, 반복적인 작업 등에 적합합니다.
#
# - **딕셔너리 (Dictionary)**:
#   - 키-값으로 연관된 데이터를 저장하고 검색하는 데 적합합니다. 예를 들어, 사용자 정보 (이름, 나이, 주소 등), 설정 정보 등을 저장하는 데 유용합니다.
#
# ## 5. 주요 연산
# | 연산           | 리스트 (List)                                    | 딕셔너리 (Dictionary)                                   |
# | -------------- | ------------------------------------------------- | ------------------------------------------------------- |
# | 요소 추가       | `append()`, `insert()`                           | `dict[key] = value`, `update()`                        |
# | 요소 삭제       | `del list[index]`, `remove()`, `pop()`            | `del dict[key]`, `pop()`, `popitem()`                   |
# | 요소 접근       | `list[index]`                                     | `dict[key]`, `get()`                                   |
# | 요소 검색       | `in`, `index()`                                  | `in` (키 존재 여부 확인), `values()`, `items()`       |
# | 전체 순회       | `for item in list:`                             | `for key in dict:`, `for value in dict.values():`, `for key, value in dict.items():` |
#
# ## 예제 코드
# ```python
# # 리스트 예제
# my_list = ["apple", "banana", "cherry"]
# print(my_list[0])  # 출력: apple
# my_list.append("orange")
# print(my_list)  # 출력: ['apple', 'banana', 'cherry', 'orange']
#
# # 딕셔너리 예제
# my_dict = {"name": "Alice", "age": 30, "city": "New York"}
# print(my_dict["name"])  # 출력: Alice
# my_dict["occupation"] = "Engineer"
# print(my_dict)  # 출력: {'name': 'Alice', 'age': 30, 'city': 'New York', 'occupation': 'Engineer'}
#
# # 딕셔너리 순회
# for key, value in my_dict.items():
#     print(f"{key}: {value}")
# ```
#
# ## 요약
# | 특징           | 리스트 (List)          | 딕셔너리 (Dictionary)            |
# | -------------- | ----------------------- | --------------------------------- |
# | 접근 방식       | 인덱스 기반           | 키 기반                             |
# | 순서            | 순서 유지              | 파이썬 3.7+ 부터는 순서 보장.       |
# | 데이터 저장 방식 | 순서대로 저장          | 키-값 쌍으로 저장                   |
# | 키 중복        | 해당 없음               | 키는 중복 불가                      |
# | 용도            | 순서 있는 데이터 목록   | 키-값 연관 데이터 저장 및 검색      |
#
# 어떤 자료구조를 사용할지는 데이터의 특성과 사용 목적에 따라 결정해야 합니다. 순서가 중요하고 인덱스를 통해 접근해야 하는 데이터는 리스트를, 키-값 쌍으로 연관된 데이터를 저장하고 검색해야 하는 경우에는 딕셔너리를 사용하는 것이 좋습니다.
# ==================================================
# 🔄 Node: GeneralQA 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 파이썬에서 딕셔너리(dictionary)와 리스트(list)는 모두 여러 개의 값을 저장하는 데 사용되는 자료구조이지만, 몇 가지 중요한 차이점이 있습니다.
#
# ## 1. 데이터 접근 방식
# - **리스트 (List)**:
#   - **순서 기반 접근**: 리스트는 요소의 순서가 중요하며, 각 요소는 **인덱스(index)**를 통해 접근합니다. 인덱스는 0부터 시작하는 정수입니다.
#   - 예시: `my_list[0]`은 리스트의 첫 번째 요소를 가져옵니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **키(Key) 기반 접근**: 딕셔너리는 **키(key)**와 **값(value)**의 쌍으로 데이터를 저장합니다. 각 값은 고유한 키를 사용하여 접근합니다. 키는 변경 불가능한(immutable) 데이터 타입(문자열, 숫자, 튜플 등)이어야 합니다.
#   - 예시: `my_dict["name"]`은 딕셔너리에서 키가 "name"인 값(value)을 가져옵니다.
#
# ## 2. 순서 유무
# - **리스트 (List)**:
#   - **순서가 있습니다**. 리스트에 추가된 요소는 추가된 순서대로 유지됩니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **파이썬 3.7+ 부터는 순서가 보장됩니다**. (삽입 순서대로). 이전 버전에서는 순서가 보장되지 않았습니다.
#
# ## 3. 데이터 저장 방식
# - **리스트 (List)**:
#   - **동일한 타입 또는 다른 타입의 데이터 저장 가능**: 리스트는 숫자, 문자열, 객체 등 다양한 타입의 데이터를 함께 저장할 수 있습니다.
#
# - **딕셔너리 (Dictionary)**:
#   - **키-값 쌍으로 데이터 저장**: 딕셔너리는 각 키에 해당하는 값을 저장하며, 키는 고유해야 합니다. 값은 다양한 타입이 될 수 있습니다.
#
# ## 4. 용도
# - **리스트 (List)**:
#   - 순서가 있는 데이터 모음, 데이터 목록 관리, 반복적인 작업 등에 적합합니다.
#
# - **딕셔너리 (Dictionary)**:
#   - 키-값으로 연관된 데이터를 저장하고 검색하는 데 적합합니다. 예를 들어, 사용자 정보 (이름, 나이, 주소 등), 설정 정보 등을 저장하는 데 유용합니다.
#
# ## 5. 주요 연산
# | 연산           | 리스트 (List)                                    | 딕셔너리 (Dictionary)                                   |
# | -------------- | ------------------------------------------------- | ------------------------------------------------------- |
# | 요소 추가       | `append()`, `insert()`                           | `dict[key] = value`, `update()`                        |
# | 요소 삭제       | `del list[index]`, `remove()`, `pop()`            | `del dict[key]`, `pop()`, `popitem()`                   |
# | 요소 접근       | `list[index]`                                     | `dict[key]`, `get()`                                   |
# | 요소 검색       | `in`, `index()`                                  | `in` (키 존재 여부 확인), `values()`, `items()`       |
# | 전체 순회       | `for item in list:`                             | `for key in dict:`, `for value in dict.values():`, `for key, value in dict.items():` |
#
# ## 예제 코드
# ```python
# # 리스트 예제
# my_list = ["apple", "banana", "cherry"]
# print(my_list[0])  # 출력: apple
# my_list.append("orange")
# print(my_list)  # 출력: ['apple', 'banana', 'cherry', 'orange']
#
# # 딕셔너리 예제
# my_dict = {"name": "Alice", "age": 30, "city": "New York"}
# print(my_dict["name"])  # 출력: Alice
# my_dict["occupation"] = "Engineer"
# print(my_dict)  # 출력: {'name': 'Alice', 'age': 30, 'city': 'New York', 'occupation': 'Engineer'}
#
# # 딕셔너리 순회
# for key, value in my_dict.items():
#     print(f"{key}: {value}")
# ```
#
# ## 요약
# | 특징           | 리스트 (List)          | 딕셔너리 (Dictionary)            |
# | -------------- | ----------------------- | --------------------------------- |
# | 접근 방식       | 인덱스 기반           | 키 기반                             |
# | 순서            | 순서 유지              | 파이썬 3.7+ 부터는 순서 보장.       |
# | 데이터 저장 방식 | 순서대로 저장          | 키-값 쌍으로 저장                   |
# | 키 중복        | 해당 없음               | 키는 중복 불가                      |
# | 용도            | 순서 있는 데이터 목록   | 키-값 연관 데이터 저장 및 검색      |
#
# 어떤 자료구조를 사용할지는 데이터의 특성과 사용 목적에 따라 결정해야 합니다. 순서가 중요하고 인덱스를 통해 접근해야 하는 데이터는 리스트를, 키-값 쌍으로 연관된 데이터를 저장하고 검색해야 하는 경우에는 딕셔너리를 사용하는 것이 좋습니다.
# ==================================================
# 🔄 Node: Supervisor 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
